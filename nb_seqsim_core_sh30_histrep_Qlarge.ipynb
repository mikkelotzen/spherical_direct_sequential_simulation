# %%
# %matplotlib notebook

from sdss import SDSS
import mikkel_tools.utility as mt_util
import plot as sds_plt

import numpy as np
#import cupy as cp
import scipy as sp
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

import pyshtools
import pickle

comment = "Realizations generated with best case for hist reproduction. Large conditional distributions."
nb_name = "nb_seqsim_core_sh30_histrep_Qlarge"

# %% [markdown]
# # Core

# %%
shc_g = 30
shc_grid = 30

core = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([core.grid_phi, 90-core.grid_theta]).T
core.make_grid(core.r_cmb, grid_in, calc_sph_d = True)

# %%
core.generate_map(target_var_factor = 1)

# %%
#core.data = core.data - np.mean(core.data)

# %%
#mt_util.plot_cartopy_global(lat = core.lat, lon = core.lon, plot_quality = "high", 
#                            data=core.data, point_size=10, shift_grid = True, 
#                            transpose_grid = True, shape = (121,61), cmap = 'PuOr_r', 
#                            title="Prior radial lithosphere information")

# %%
core.condtab(normsize=1000, quantiles = 100, 
             rangn_lim = 3.5, rangn_N = 501, rangv_lim = 2.0, rangv_N = 101)

# %%
core.semivar(model_lags = "all", model = "exponential", max_dist = 20000, lag_length = 200,
             zero_nugget = True, hit_target_var = True)

keep_sv_curve = core.sv_curve.copy()
keep_lags_sv_curve = core.lags_sv_curve.copy()

C_e_const = 2.0

#nugget = C_e_const**2
#nugget_p = 0.01
#var_fac = 0.1

#set_model = {"a": 2000, "C0": var_fac*core.target_var*nugget_p, "C1": var_fac*core.target_var*(1-nugget_p), "C2": None, "C3": None}
#set_model = {"a": 1800, "C0": nugget, "C1": var_fac*core.target_var-nugget, "C2": None, "C3": None}

set_model = {"a": 1700, "C0": 0.0, "C1": core.target_var, "C2": None, "C3": None}


#set_model = {"a": 200, "C0": 0.0, "C1": 0.15*core.target_var,
#             "C2": core.target_var-0.15*core.target_var, "C3": 20000}


#core.semivar(model_lags = "all", model = "dub_spherical", max_dist = 20000, lag_length = 200,
#             zero_nugget = True, hit_target_var = True, set_model = set_model)

core.semivar(model_lags = "all", model = "exponential", max_dist = 20000, lag_length = 200,
             zero_nugget = True, hit_target_var = True, set_model = set_model)
# Out:
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 200.0 km
# Number of lags: 54
# Number of modelling lags: all
#
# Semi-variogram model determined, starting LUT computation
#
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 200.0 km
# Number of lags: 54
# Number of modelling lags: all
#
# Semi-variogram model determined, starting LUT computation

# %%
#%% PLOT SEMI-VARIOGRAM
plt.figure(figsize=(10,8)) 
plt.plot(core.lags,core.pics,'o', markersize=5,color = 'C4',label='Semi-variogram')
plt.plot(core.lags_sv_curve,core.sv_curve,color='C1', linewidth = 3,label='Defined model')
plt.plot(keep_lags_sv_curve,keep_sv_curve,"--",color='C0',linewidth = 3,label='Fitted model')

plt.plot(core.lags_sv_curve,np.ones(core.lags_sv_curve.shape)*core.target_var,linewidth = 3,
         color="C2", linestyle="dashed", label="Training image variance")
plt.ylabel('Semi-variance $[%s^2]$' % "nT",fontsize=18,labelpad=18)
plt.xlabel('Lag [km]',fontsize=18,labelpad=18)
plt.title("Semi-variogram model of type: %s " % core.model_names[core.model],fontsize=18,y=1.02)
plt.legend(loc='best',fontsize=18)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#print(core)

# %% [markdown]
# # Synthetic sat

# %%
s_sat = SDSS(comment, N_SH = shc_g, sim_type = "core_ens", sat_height = 350, N_SH_secondary = None)

s_sat.load_swarm("A")

grid_in = np.array([s_sat.grid_phi, 90-s_sat.grid_theta]).T
s_sat.make_grid(s_sat.grid_radial, grid_in, calc_sph_d = False)

#s_sat.grid_equal_area(N_grid= 500, r_at = s_sat.r_sat, poles_remove = True)
#grid_in = np.array([s_sat.grid_phi, 90-s_sat.grid_theta]).T
#s_sat.grid(s_sat.r_sat, grid_in, calc_sph_d = False)

# %%
s_sat.generate_map(grid_type = "swarm")

# %%
s_sat.data += np.random.normal(scale = C_e_const, size = s_sat.data.shape)

# %%
#mt_util.plot_cartopy_global(lat = s_sat.lat, lon = s_sat.lon, plot_quality = "high", point_size=5, 
#                            data=s_sat.data, cmap = 'PuOr_r', title="Synthetic satellite data")

# %%
#print(s_sat)

# %% [markdown]
# # Source truth

# %%
s_source = SDSS(comment, N_SH = shc_g, sim_type = "core_ens", sat_height = 350, N_SH_secondary = None)

s_source.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([s_source.grid_phi, 90-s_source.grid_theta]).T
s_source.make_grid(s_source.r_cmb, grid_in, calc_sph_d = False)

s_source.generate_map()

# %% [markdown]
# # System equations

# %%
core.integrating_kernel(s_sat, C_e_const = C_e_const)
# Out:
# Gauss-Legendre RMSE:	 14351.244062455738
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # SDSSIM

# %%
N_sim = 100

core.run_sim(N_sim, core.grid_N, core.C_mm_all, core.C_dd, core.C_dm_all, core.G,
        s_sat.data, core.data, scale_m_i = True, unit_d = False, collect_all = True,
        sense_running_error = True, save_string = nb_name, sim_stochastic = False, solve_cho = True)
# Out:
#  |OOOOOOOOOO| 100.0%   realization nr. 0. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.326 minutes
# Total elapsed time: 11.326 minutes
# Variance: 265848388670.988
# Mean: -23990.554
# Max: 1636671.529
# Min: -1650875.519
# Run nr.: 1
#
#  |OOOOOOOOOO| 100.0%   realization nr. 1. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.978 minutes
# Total elapsed time: 22.304 minutes
# Variance: 274072646376.268
# Mean: -24298.323
# Max: 2787857.325
# Min: -1664968.473
# Run nr.: 2
#
#  |OOOOOOOOOO| 100.0%   realization nr. 2. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.928 minutes
# Total elapsed time: 33.232 minutes
# Variance: 282745672716.536
# Mean: -25491.080
# Max: 2740204.720
# Min: -1703443.957
# Run nr.: 3
#
#  |OOOOOOOOOO| 100.0%   realization nr. 3. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.989 minutes
# Total elapsed time: 44.222 minutes
# Variance: 306504341805.399
# Mean: -26371.746
# Max: 2774028.686
# Min: -1842645.140
# Run nr.: 4
#
#  |OOOOOOOOOO| 100.0%   realization nr. 4. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.143 minutes
# Total elapsed time: 55.364 minutes
# Variance: 272723591813.189
# Mean: -27165.520
# Max: 1612040.176
# Min: -1641509.634
# Run nr.: 5
#
#  |OOOOOOOOOO| 100.0%   realization nr. 5. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.849 minutes
# Total elapsed time: 1.104 hours
# Variance: 298261985208.072
# Mean: -23156.123
# Max: 2741742.199
# Min: -1802824.132
# Run nr.: 6
#
#  |OOOOOOOOOO| 100.0%   realization nr. 6. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.936 minutes
# Total elapsed time: 1.286 hours
# Variance: 283052256044.893
# Mean: -26701.965
# Max: 2604978.694
# Min: -1613839.469
# Run nr.: 7
#
#  |OOOOOOOOOO| 100.0%   realization nr. 7. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.236 minutes
# Total elapsed time: 1.473 hours
# Variance: 302197697689.341
# Mean: -25840.726
# Max: 2715062.628
# Min: -1698639.286
# Run nr.: 8
#
#  |OOOOOOOOOO| 100.0%   realization nr. 8. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.020 minutes
# Total elapsed time: 1.657 hours
# Variance: 283342215730.996
# Mean: -25673.173
# Max: 2700024.285
# Min: -1693533.996
# Run nr.: 9
#
#  |OOOOOOOOOO| 100.0%   realization nr. 9. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.926 minutes
# Total elapsed time: 1.839 hours
# Variance: 289212671080.206
# Mean: -28518.731
# Max: 2235261.055
# Min: -1652591.155
# Run nr.: 10
#
#  |OOOOOOOOOO| 100.0%   realization nr. 10. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.929 minutes
# Total elapsed time: 2.021 hours
# Variance: 278905548865.360
# Mean: -25431.414
# Max: 2743264.748
# Min: -1627322.967
# Run nr.: 11
#
#  |OOOOOOOOOO| 100.0%   realization nr. 11. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.902 minutes
# Total elapsed time: 2.203 hours
# Variance: 286163250513.302
# Mean: -29898.059
# Max: 2723589.602
# Min: -2068343.717
# Run nr.: 12
#
#  |OOOOOOOOOO| 100.0%   realization nr. 12. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.978 minutes
# Total elapsed time: 2.386 hours
# Variance: 284923943372.935
# Mean: -27306.593
# Max: 1834880.284
# Min: -1648693.081
# Run nr.: 13
#
#  |OOOOOOOOOO| 100.0%   realization nr. 13. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.975 minutes
# Total elapsed time: 2.569 hours
# Variance: 297720642396.583
# Mean: -28777.749
# Max: 2686878.658
# Min: -1965600.715
# Run nr.: 14
#
#  |OOOOOOOOOO| 100.0%   realization nr. 14. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.895 minutes
# Total elapsed time: 2.750 hours
# Variance: 275169824260.158
# Mean: -26248.338
# Max: 2511069.455
# Min: -1708527.916
# Run nr.: 15
#
#  |OOOOOOOOOO| 100.0%   realization nr. 15. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.046 minutes
# Total elapsed time: 2.934 hours
# Variance: 281392336308.604
# Mean: -25776.150
# Max: 2703266.267
# Min: -1978364.748
# Run nr.: 16
#
#  |OOOOOOOOOO| 100.0%   realization nr. 16. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.942 minutes
# Total elapsed time: 3.117 hours
# Variance: 270823453173.388
# Mean: -26466.547
# Max: 1584888.269
# Min: -1659513.243
# Run nr.: 17
#
#  |OOOOOOOOOO| 100.0%   realization nr. 17. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.062 minutes
# Total elapsed time: 3.301 hours
# Variance: 278974453801.893
# Mean: -25483.462
# Max: 1791599.455
# Min: -1823321.216
# Run nr.: 18
#
#  |OOOOOOOOOO| 100.0%   realization nr. 18. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.940 minutes
# Total elapsed time: 3.483 hours
# Variance: 286584688869.107
# Mean: -26155.198
# Max: 2521992.969
# Min: -1854863.732
# Run nr.: 19
#
#  |OOOOOOOOOO| 100.0%   realization nr. 19. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.924 minutes
# Total elapsed time: 3.665 hours
# Variance: 289941920724.435
# Mean: -26962.680
# Max: 2734097.016
# Min: -1607067.981
# Run nr.: 20
#
#  |OOOOOOOOOO| 100.0%   realization nr. 20. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.975 minutes
# Total elapsed time: 3.848 hours
# Variance: 284965719008.765
# Mean: -21029.653
# Max: 2678384.208
# Min: -1734100.080
# Run nr.: 21
#
#  |OOOOOOOOOO| 100.0%   realization nr. 21. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.860 minutes
# Total elapsed time: 4.029 hours
# Variance: 291533392289.923
# Mean: -22524.141
# Max: 2716553.018
# Min: -2088723.291
# Run nr.: 22
#
#  |OOOOOOOOOO| 100.0%   realization nr. 22. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.099 minutes
# Total elapsed time: 4.214 hours
# Variance: 285647284978.042
# Mean: -28594.822
# Max: 2690529.307
# Min: -1893257.926
# Run nr.: 23
#
#  |OOOOOOOOOO| 100.0%   realization nr. 23. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.985 minutes
# Total elapsed time: 4.397 hours
# Variance: 278354476575.684
# Mean: -23560.338
# Max: 1727920.428
# Min: -1822577.239
# Run nr.: 24
#
#  |OOOOOOOOOO| 100.0%   realization nr. 24. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.928 minutes
# Total elapsed time: 4.580 hours
# Variance: 300485793648.321
# Mean: -20691.187
# Max: 2720928.639
# Min: -1784278.052
# Run nr.: 25
#
#  |OOOOOOOOOO| 100.0%   realization nr. 25. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.893 minutes
# Total elapsed time: 4.761 hours
# Variance: 272902787893.611
# Mean: -15706.168
# Max: 1919355.068
# Min: -1770132.245
# Run nr.: 26
#
#  |OOOOOOOOOO| 100.0%   realization nr. 26. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.054 minutes
# Total elapsed time: 4.945 hours
# Variance: 279403058219.256
# Mean: -27396.428
# Max: 1447482.170
# Min: -1654223.917
# Run nr.: 27
#
#  |OOOOOOOOOO| 100.0%   realization nr. 27. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.031 minutes
# Total elapsed time: 5.129 hours
# Variance: 290601210926.130
# Mean: -20028.803
# Max: 2695479.077
# Min: -1792705.258
# Run nr.: 28
#
#  |OOOOOOOOOO| 100.0%   realization nr. 28. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.002 minutes
# Total elapsed time: 5.313 hours
# Variance: 280686293351.761
# Mean: -28435.103
# Max: 2684523.890
# Min: -1730623.830
# Run nr.: 29
#
#  |OOOOOOOOOO| 100.0%   realization nr. 29. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.921 minutes
# Total elapsed time: 5.495 hours
# Variance: 274649946340.890
# Mean: -27163.807
# Max: 1434702.779
# Min: -1789253.935
# Run nr.: 30
#
#  |OOOOOOOOOO| 100.0%   realization nr. 30. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.795 minutes
# Total elapsed time: 5.674 hours
# Variance: 281190166683.464
# Mean: -28208.529
# Max: 2696276.891
# Min: -1630256.549
# Run nr.: 31
#
#  |OOOOOOOOOO| 100.0%   realization nr. 31. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.068 minutes
# Total elapsed time: 5.859 hours
# Variance: 292688079105.626
# Mean: -29636.516
# Max: 2690667.964
# Min: -1662598.633
# Run nr.: 32
#
#  |OOOOOOOOOO| 100.0%   realization nr. 32. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.885 minutes
# Total elapsed time: 6.040 hours
# Variance: 288981624202.604
# Mean: -31346.534
# Max: 2707514.088
# Min: -1664829.269
# Run nr.: 33
#
#  |OOOOOOOOOO| 100.0%   realization nr. 33. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.311 minutes
# Total elapsed time: 6.229 hours
# Variance: 289123872729.900
# Mean: -30017.712
# Max: 2726307.724
# Min: -1809838.910
# Run nr.: 34
#  |OOOOOOOOOO| 100.0%   realization nr. 34. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.880 minutes
# Total elapsed time: 6.410 hours
# Variance: 292060203099.377
# Mean: -32396.235
# Max: 2659383.987
# Min: -1665058.367
# Run nr.: 35
#
#  |OOOOOOOOOO| 100.0%   realization nr. 35. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.279 minutes
# Total elapsed time: 6.598 hours
# Variance: 288850595004.352
# Mean: -23619.508
# Max: 2489594.808
# Min: -1779935.246
# Run nr.: 36
#
#  |OOOOOOOOOO| 100.0%   realization nr. 36. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.904 minutes
# Total elapsed time: 6.780 hours
# Variance: 303663758517.001
# Mean: -25581.757
# Max: 2723124.377
# Min: -1656884.324
# Run nr.: 37
#
#  |OOOOOOOOOO| 100.0%   realization nr. 37. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.002 minutes
# Total elapsed time: 6.963 hours
# Variance: 275401048458.565
# Mean: -24451.436
# Max: 2723487.755
# Min: -1614885.351
# Run nr.: 38
#
#  |OOOOOOOOOO| 100.0%   realization nr. 38. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.927 minutes
# Total elapsed time: 7.145 hours
# Variance: 291452993947.183
# Mean: -26907.915
# Max: 2738300.943
# Min: -1642738.650
# Run nr.: 39
#
#  |OOOOOOOOOO| 100.0%   realization nr. 39. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.062 minutes
# Total elapsed time: 7.330 hours
# Variance: 283859422869.501
# Mean: -24533.631
# Max: 2760820.444
# Min: -1656158.223
# Run nr.: 40
#
#  |OOOOOOOOOO| 100.0%   realization nr. 40. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.959 minutes
# Total elapsed time: 7.512 hours
# Variance: 284189859560.292
# Mean: -23458.522
# Max: 2733475.324
# Min: -1654116.368
# Run nr.: 41
#
#  |OOOOOOOOOO| 100.0%   realization nr. 41. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.922 minutes
# Total elapsed time: 7.694 hours
# Variance: 268651440046.182
# Mean: -25364.473
# Max: 2094784.737
# Min: -1636594.945
# Run nr.: 42
#
#  |OOOOOOOOOO| 100.0%   realization nr. 42. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.880 minutes
# Total elapsed time: 7.876 hours
# Variance: 278565758884.101
# Mean: -26791.107
# Max: 1696495.404
# Min: -1659211.482
# Run nr.: 43
#
#  |OOOOOOOOOO| 100.0%   realization nr. 43. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.900 minutes
# Total elapsed time: 8.057 hours
# Variance: 271175061106.889
# Mean: -27401.900
# Max: 1508113.593
# Min: -1631888.502
# Run nr.: 44
#
#  |OOOOOOOOOO| 100.0%   realization nr. 44. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.055 minutes
# Total elapsed time: 8.242 hours
# Variance: 274030468292.265
# Mean: -27889.401
# Max: 1823745.948
# Min: -1585834.076
# Run nr.: 45
#
#  |OOOOOOOOOO| 100.0%   realization nr. 45. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.013 minutes
# Total elapsed time: 8.425 hours
# Variance: 276875263622.337
# Mean: -27515.937
# Max: 2708345.948
# Min: -1953545.493
# Run nr.: 46
#
#  |OOOOOOOOOO| 100.0%   realization nr. 46. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.089 minutes
# Total elapsed time: 8.610 hours
# Variance: 278886117509.690
# Mean: -24117.374
# Max: 2714254.414
# Min: -1671237.997
# Run nr.: 47
#
#  |OOOOOOOOOO| 100.0%   realization nr. 47. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.982 minutes
# Total elapsed time: 8.793 hours
# Variance: 273051853796.858
# Mean: -27688.960
# Max: 2061157.846
# Min: -1596705.491
# Run nr.: 48
#
#  |OOOOOOOOOO| 100.0%   realization nr. 48. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.935 minutes
# Total elapsed time: 8.975 hours
# Variance: 276142098850.235
# Mean: -26772.470
# Max: 1431533.472
# Min: -1658361.237
# Run nr.: 49
#
#  |OOOOOOOOOO| 100.0%   realization nr. 49. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.026 minutes
# Total elapsed time: 9.159 hours
# Variance: 278984044460.849
# Mean: -24980.833
# Max: 2707171.270
# Min: -1730506.226
# Run nr.: 50
#
#  |OOOOOOOOOO| 100.0%   realization nr. 50. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.937 minutes
# Total elapsed time: 9.341 hours
# Variance: 282294373656.490
# Mean: -20148.093
# Max: 2765760.108
# Min: -1661643.868
# Run nr.: 51
#
#  |OOOOOOOOOO| 100.0%   realization nr. 51. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.982 minutes
# Total elapsed time: 9.524 hours
# Variance: 271178395304.192
# Mean: -25991.995
# Max: 2546345.791
# Min: -1679287.340
# Run nr.: 52
#
#  |OOOOOOOOOO| 100.0%   realization nr. 52. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.956 minutes
# Total elapsed time: 9.707 hours
# Variance: 288763317777.315
# Mean: -23970.705
# Max: 2620072.912
# Min: -1717497.193
# Run nr.: 53
#
#  |OOOOOOOOOO| 100.0%   realization nr. 53. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.950 minutes
# Total elapsed time: 9.890 hours
# Variance: 278571927214.872
# Mean: -28092.947
# Max: 2752331.735
# Min: -2018720.419
# Run nr.: 54
#
#  |OOOOOOOOOO| 100.0%   realization nr. 54. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.078 minutes
# Total elapsed time: 10.074 hours
# Variance: 274069103290.033
# Mean: -27536.323
# Max: 2706730.218
# Min: -1675645.922
# Run nr.: 55
#
#  |OOOOOOOOOO| 100.0%   realization nr. 55. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.928 minutes
# Total elapsed time: 10.256 hours
# Variance: 283165291827.451
# Mean: -22847.890
# Max: 2733337.460
# Min: -1685996.469
# Run nr.: 56
#
#  |OOOOOOOOOO| 100.0%   realization nr. 56. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.814 minutes
# Total elapsed time: 10.436 hours
# Variance: 281637214014.515
# Mean: -29369.270
# Max: 2700000.926
# Min: -1668612.756
# Run nr.: 57
#
#  |OOOOOOOOOO| 100.0%   realization nr. 57. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.012 minutes
# Total elapsed time: 10.620 hours
# Variance: 276114252371.919
# Mean: -23104.412
# Max: 2682709.606
# Min: -1658576.907
# Run nr.: 58
#
#  |OOOOOOOOOO| 100.0%   realization nr. 58. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.940 minutes
# Total elapsed time: 10.802 hours
# Variance: 273724648108.171
# Mean: -24433.814
# Max: 1777083.713
# Min: -1676012.680
# Run nr.: 59
#
#  |OOOOOOOOOO| 100.0%   realization nr. 59. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.844 minutes
# Total elapsed time: 10.983 hours
# Variance: 279149063826.643
# Mean: -25523.781
# Max: 2735004.670
# Min: -1663127.478
# Run nr.: 60
#
#  |OOOOOOOOOO| 100.0%   realization nr. 60. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.920 minutes
# Total elapsed time: 11.165 hours
# Variance: 282604200592.421
# Mean: -29410.274
# Max: 1476775.144
# Min: -1721265.926
# Run nr.: 61
#
#  |OOOOOOOOOO| 100.0%   realization nr. 61. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.984 minutes
# Total elapsed time: 11.348 hours
# Variance: 281141138158.748
# Mean: -22325.952
# Max: 2726018.787
# Min: -1746464.774
# Run nr.: 62
#
#  |OOOOOOOOOO| 100.0%   realization nr. 62. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.084 minutes
# Total elapsed time: 11.533 hours
# Variance: 277841618958.273
# Mean: -26466.166
# Max: 2532290.595
# Min: -1843069.414
# Run nr.: 63
#
#  |OOOOOOOOOO| 100.0%   realization nr. 63. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.125 minutes
# Total elapsed time: 11.718 hours
# Variance: 273725072417.059
# Mean: -22888.514
# Max: 2740902.942
# Min: -1738674.840
# Run nr.: 64
#
#  |OOOOOOOOOO| 100.0%   realization nr. 64. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.020 minutes
# Total elapsed time: 11.902 hours
# Variance: 287226573755.497
# Mean: -24859.032
# Max: 2747981.998
# Min: -1728732.197
# Run nr.: 65
#
#  |OOOOOOOOOO| 100.0%   realization nr. 65. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.025 minutes
# Total elapsed time: 12.086 hours
# Variance: 280321731198.881
# Mean: -24321.223
# Max: 2749259.221
# Min: -1736007.435
# Run nr.: 66
#
#  |OOOOOOOOOO| 100.0%   realization nr. 66. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.201 minutes
# Total elapsed time: 12.272 hours
# Variance: 289356231084.239
# Mean: -24946.661
# Max: 2555535.557
# Min: -1976572.906
# Run nr.: 67
#
#  |OOOOOOOOOO| 100.0%   realization nr. 67. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.166 minutes
# Total elapsed time: 12.458 hours
# Variance: 285280433621.154
# Mean: -27233.805
# Max: 2703451.239
# Min: -1664536.448
# Run nr.: 68
#  |OOOOOOOOOO| 100.0%   realization nr. 68. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.018 minutes
# Total elapsed time: 12.642 hours
# Variance: 269570294985.192
# Mean: -28433.603
# Max: 1991159.365
# Min: -1643995.953
# Run nr.: 69
#
#  |OOOOOOOOOO| 100.0%   realization nr. 69. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.053 minutes
# Total elapsed time: 12.826 hours
# Variance: 287022046939.389
# Mean: -22801.097
# Max: 1647428.008
# Min: -1663781.847
# Run nr.: 70
#
#  |OOOOOOOOOO| 100.0%   realization nr. 70. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.192 minutes
# Total elapsed time: 13.013 hours
# Variance: 276104377191.582
# Mean: -27245.227
# Max: 2009425.837
# Min: -1648936.977
# Run nr.: 71
#
#  |OOOOOOOOOO| 100.0%   realization nr. 71. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.072 minutes
# Total elapsed time: 13.197 hours
# Variance: 275524399765.187
# Mean: -20291.449
# Max: 2385751.626
# Min: -1684188.304
# Run nr.: 72
#
#  |OOOOOOOOOO| 100.0%   realization nr. 72. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.916 minutes
# Total elapsed time: 13.379 hours
# Variance: 282180017003.177
# Mean: -28144.545
# Max: 2505026.320
# Min: -1693785.247
# Run nr.: 73
#
#  |OOOOOOOOOO| 100.0%   realization nr. 73. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.922 minutes
# Total elapsed time: 13.561 hours
# Variance: 287204285287.470
# Mean: -30999.393
# Max: 2673636.628
# Min: -1638210.317
# Run nr.: 74
#
#  |OOOOOOOOOO| 100.0%   realization nr. 74. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.975 minutes
# Total elapsed time: 13.744 hours
# Variance: 285143207222.843
# Mean: -24588.132
# Max: 2717928.443
# Min: -1678785.865
# Run nr.: 75
#
#  |OOOOOOOOOO| 100.0%   realization nr. 75. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.884 minutes
# Total elapsed time: 13.926 hours
# Variance: 290611567939.072
# Mean: -28377.163
# Max: 2708287.069
# Min: -1678795.773
# Run nr.: 76
#
#  |OOOOOOOOOO| 100.0%   realization nr. 76. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.000 minutes
# Total elapsed time: 14.109 hours
# Variance: 283689299921.900
# Mean: -28956.567
# Max: 2535469.773
# Min: -1640215.879
# Run nr.: 77
#
#  |OOOOOOOOOO| 100.0%   realization nr. 77. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.944 minutes
# Total elapsed time: 14.291 hours
# Variance: 266630969441.380
# Mean: -26260.974
# Max: 1909877.315
# Min: -1633768.999
# Run nr.: 78
#
#  |OOOOOOOOOO| 100.0%   realization nr. 78. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.104 minutes
# Total elapsed time: 14.476 hours
# Variance: 274144218264.439
# Mean: -24887.469
# Max: 2637577.424
# Min: -1922968.776
# Run nr.: 79
#
#  |OOOOOOOOOO| 100.0%   realization nr. 79. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.987 minutes
# Total elapsed time: 14.660 hours
# Variance: 283902182073.151
# Mean: -21729.411
# Max: 2776498.815
# Min: -1661393.219
# Run nr.: 80
#
#  |OOOOOOOOOO| 100.0%   realization nr. 80. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.932 minutes
# Total elapsed time: 14.842 hours
# Variance: 304017903168.438
# Mean: -19024.419
# Max: 2739440.170
# Min: -1683716.375
# Run nr.: 81
#
#  |OOOOOOOOOO| 100.0%   realization nr. 81. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.016 minutes
# Total elapsed time: 15.025 hours
# Variance: 282065004558.018
# Mean: -30177.047
# Max: 1477098.406
# Min: -1667176.524
# Run nr.: 82
#
#  |OOOOOOOOOO| 100.0%   realization nr. 82. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.037 minutes
# Total elapsed time: 15.209 hours
# Variance: 264180464625.860
# Mean: -21589.151
# Max: 1377357.686
# Min: -1848086.533
# Run nr.: 83
#
#  |OOOOOOOOOO| 100.0%   realization nr. 83. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.088 minutes
# Total elapsed time: 15.394 hours
# Variance: 284167992569.008
# Mean: -28140.803
# Max: 2651477.226
# Min: -1600485.415
# Run nr.: 84
#
#  |OOOOOOOOOO| 100.0%   realization nr. 84. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.977 minutes
# Total elapsed time: 15.577 hours
# Variance: 290843816912.196
# Mean: -22065.633
# Max: 2672366.300
# Min: -1884592.941
# Run nr.: 85
#
#  |OOOOOOOOOO| 100.0%   realization nr. 85. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.986 minutes
# Total elapsed time: 15.760 hours
# Variance: 276763166114.690
# Mean: -24244.993
# Max: 2266559.446
# Min: -1638032.040
# Run nr.: 86
#
#  |OOOOOOOOOO| 100.0%   realization nr. 86. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.819 minutes
# Total elapsed time: 15.941 hours
# Variance: 280858402908.480
# Mean: -25176.300
# Max: 2695370.832
# Min: -1667094.176
# Run nr.: 87
#
#  |OOOOOOOOOO| 100.0%   realization nr. 87. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.796 minutes
# Total elapsed time: 16.120 hours
# Variance: 275609908252.401
# Mean: -27478.350
# Max: 1755065.087
# Min: -1683640.810
# Run nr.: 88
#
#  |OOOOOOOOOO| 100.0%   realization nr. 88. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.993 minutes
# Total elapsed time: 16.304 hours
# Variance: 287814769796.120
# Mean: -19587.292
# Max: 2688615.211
# Min: -1688905.384
# Run nr.: 89
#
#  |OOOOOOOOOO| 100.0%   realization nr. 89. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.929 minutes
# Total elapsed time: 16.486 hours
# Variance: 280305059670.592
# Mean: -26386.748
# Max: 2716622.798
# Min: -2091982.004
# Run nr.: 90
#
#  |OOOOOOOOOO| 100.0%   realization nr. 90. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.956 minutes
# Total elapsed time: 16.668 hours
# Variance: 274636698900.488
# Mean: -24441.123
# Max: 1647184.056
# Min: -1603706.802
# Run nr.: 91
#
#  |OOOOOOOOOO| 100.0%   realization nr. 91. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.933 minutes
# Total elapsed time: 16.851 hours
# Variance: 288229444033.149
# Mean: -25286.952
# Max: 2719380.779
# Min: -1710826.252
# Run nr.: 92
#
#  |OOOOOOOOOO| 100.0%   realization nr. 92. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.050 minutes
# Total elapsed time: 17.035 hours
# Variance: 279190371396.234
# Mean: -28251.662
# Max: 1441435.975
# Min: -1774435.434
# Run nr.: 93
#
#  |OOOOOOOOOO| 100.0%   realization nr. 93. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.912 minutes
# Total elapsed time: 17.217 hours
# Variance: 288619140158.749
# Mean: -23400.697
# Max: 2755298.416
# Min: -2041132.847
# Run nr.: 94
#
#  |OOOOOOOOOO| 100.0%   realization nr. 94. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.918 minutes
# Total elapsed time: 17.399 hours
# Variance: 280547568651.914
# Mean: -26251.615
# Max: 2735521.804
# Min: -1691703.830
# Run nr.: 95
#
#  |OOOOOOOOOO| 100.0%   realization nr. 95. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.087 minutes
# Total elapsed time: 17.583 hours
# Variance: 284215062957.001
# Mean: -23166.306
# Max: 2188473.673
# Min: -2106698.744
# Run nr.: 96
#
#  |OOOOOOOOOO| 100.0%   realization nr. 96. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.213 minutes
# Total elapsed time: 17.770 hours
# Variance: 283715343289.986
# Mean: -22304.321
# Max: 2722294.946
# Min: -1669557.591
# Run nr.: 97
#
#  |OOOOOOOOOO| 100.0%   realization nr. 97. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.065 minutes
# Total elapsed time: 17.955 hours
# Variance: 288362876287.264
# Mean: -27394.734
# Max: 2714925.067
# Min: -1650009.589
# Run nr.: 98
#
#  |OOOOOOOOOO| 100.0%   realization nr. 98. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.960 minutes
# Total elapsed time: 18.137 hours
# Variance: 287065159356.764
# Mean: -29043.625
# Max: 2722137.432
# Min: -1658489.034
# Run nr.: 99
#
#  |OOOOOOOOOO| 100.0%   realization nr. 99. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.097 minutes
# Total elapsed time: 18.322 hours
# Variance: 278039995443.010
# Mean: -30419.580
# Max: 2221888.505
# Min: -1632691.750
# Run nr.: 100
#
#
# Seqsim RMSE:	 [[1.99571495 1.98861392 2.03975721 2.03168291 1.98368138 2.0021028
#   1.9977203  2.01204919 1.98965581 2.00478091 1.981465   1.99388134
#   1.98748509 2.00736499 2.01765835 2.01183387 2.01741123 1.99708649
#   1.99041585 2.01158233 1.99935945 2.03597982 2.01681135 2.00413727
#   2.02495908 1.99617387 2.00923721 1.98940383 2.02623397 2.00412858
#   1.98102366 2.00254979 1.99622498 2.00846836 1.98534178 1.98451811
#   1.99302519 1.99497353 2.01406374 2.02406911 2.00817639 1.99801811
#   2.0068671  1.99449884 1.99153357 2.01170943 2.01586728 1.99479309
#   2.00262415 1.98893679 2.00399885 2.00227212 2.01297807 2.01147477
#   2.01113323 1.99940708 1.9952433  1.99445774 2.02038126 2.01446876
#   1.98953215 2.03092471 1.99893438 2.02102298 1.98249699 2.03165531
#   2.00272982 2.00624959 2.01649269 2.0257302  1.98378049 2.01578132
#   2.00065268 1.99205659 1.99959047 2.00922408 2.0025644  1.97602164
#   2.00699005 2.00706717 2.00718404 2.00260906 2.00101818 1.99265967
#   2.01894058 2.00277801 2.02494737 1.99645982 2.00394973 2.00820111
#   2.01889517 1.99604981 2.00594343 2.00807066 2.0038726  2.00680681
#   1.99909193 2.01908184 1.99240594 1.99939641]]
# <img src="data:image/png;base64,..." width="640">

# %%
core.realization_to_sh_coeff(core.r_cmb, set_nmax = shc_g)

# %%
core.covmod_lsq_equiv(s_sat.data, core.C_mm_all, core.G, core.r_cmb)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)
mt_util.plot_sdssim_reproduce(core, core.m_DSS_res, m_equiv_lsq = core.m_equiv_lsq, truth_obj = s_source,
                              lags_use = 1000, spec_r_at = core.r_cmb, spec_show_differences = False,
                              model_dict = {}, figsize=(9,16),
                              hist_bins = 25, res_bins = 25,
                              savefig = False, save_string = "core_sh30_synth_Qlarge", save_dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
skip = 1

m_skip = core.m_DSS[:,:][0::skip]

lat_skip = core.lat[0::skip]

lon_skip = core.lon[0::skip]

# %%
N_bins = 100
m_centers = []
m_y = []

for i in np.arange(0,m_skip.shape[0]):
    y,binEdges=np.histogram(m_skip[i,:],bins=N_bins)
    bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
    
    m_centers.append(bincenters)
    m_y.append(y)
    
m_centers = np.array(m_centers)
m_y = np.array(m_y)

# %%
deg_range = 1

lat_skip_lin = np.linspace(lat_skip-deg_range,lat_skip+deg_range,N_bins)
lon_skip_lin = np.linspace(lon_skip-2*deg_range,lon_skip+2*deg_range,N_bins)

# %%
m_y_scaled = []

for i in np.arange(0,m_skip.shape[0]):
    scale = np.min(lat_skip_lin[:,i]) + (m_y[i,:]-np.min(m_y[i,:]))*(np.max(lat_skip_lin[:,i])-np.min(lat_skip_lin[:,i]))/(np.max(m_y[i,:])-np.min(m_y[i,:]))

    m_y_scaled.append(scale)
    
m_y_scaled = np.array(m_y_scaled)

# %%
local_lat = m_y_scaled.reshape(-1,)

local_lon = lon_skip_lin.T.reshape(-1,)

local_data = m_centers.reshape(-1,)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)



mt_util.plot_global(lat = local_lat, lon = local_lon, data = local_data, 
                cbar_h = 0.03, cbar_mm_factor = 2/3, unit_transform_n_to_m = True,
                cbar_text = "mT", figsize=(9,10), coast_width = 0.4,
                bottom=0.5, top=0.95, hspace=0.01, left = 0.05,
                title='Local model parameter distributions', point_size=0.05, projection_transformation = "PlateCarree",
                savefig = False, save_dpi = 100, save_string ="core_sh30_synth_Qlarge_loc_mod_dist",
                use_gridlines = True, gridlines_width = 0.4, gridlines_alpha = 0.4)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
core.grid_glq(nmax = 256, r_at = core.r_cmb)
#core.grid_glq(nmax = 120, r_at = core.r_cmb)

set_nmax = shc_g

core.ensemble_B(core.g_spec, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_eqa = core.B_ensemble[:,0,:].copy()

#core.g_spec_mean = np.mean(core.g_spec,axis=1)
core.ensemble_B(core.g_spec_mean, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_mean_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
core.ensemble_B(s_sat.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
prior_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_lsq_equiv, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
#lsq_eqa = core.B_ensemble[:,0].copy()

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)
# ccrs.PlateCarree()
# ccrs.Mollweide()
# ccrs.Orthographic(central_longitude=0.0, central_latitude=0.0)

mt_util.plot_ensemble_map_tiles(core.grid_phi, 90-core.grid_theta, zs_eqa, 
                        field_compare = prior_eqa, field_lsq = None, field_mean = zs_mean_eqa,
                        tile_size_row = 3, tile_size_column = 2, 
                        figsize=(9,12), limit_for_SF = 10**6, point_size = 10, cbar_mm_factor = 2/3,
                        coast_width = 0.4, coast_color = "grey", unit_transform_n_to_m = True,
                        cbar_h = 0.1, cbar_text = "mT", cbar_text_color = "black",
                        left=0.03, bottom=0.12, right=0.97, top=0.95, wspace = 0.05, hspace=0.25, 
                        savefig = False, save_string = "core_sh30_synth_Qlarge", 
                        projection = ccrs.Mollweide(), use_gridlines = True, 
                        gridlines_width = 0.4, gridlines_alpha = 0.4, save_dpi = 100)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
training_image = core.B_ensemble[:,0].copy()

mt_util.plot_global(lat = 90-core.grid_theta, lon = core.grid_phi, data=training_image, 
                cbar_h = 0.075, cbar_mm_factor = 2/3, unit_transform_n_to_m = True,
                cbar_text = "mT", figsize=(6,6), coast_width = 0.4,
                bottom=0.35, top=0.95, hspace=0.01,
                title='Training image', point_size=1,
                savefig = False, save_dpi = 100, save_string ="core_sh30_synth_TI",
                use_gridlines = True, gridlines_width = 0.4, gridlines_alpha = 0.4)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# SAVE RESULT
#print("\nSaving job")
#file_clip = open("core_{}.obj".format(nb_name), "wb")
#pickle.dump(core, file_clip, protocol=4)
#file_clip.close()

#file_clip = open("sat_{}.obj".format(nb_name), "wb")
#pickle.dump(s_sat, file_clip, protocol=4)
#file_clip.close()
#print("\nJob saved and finished")
