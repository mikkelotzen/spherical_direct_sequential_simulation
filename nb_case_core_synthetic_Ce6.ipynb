# %%
# %matplotlib notebook

from sdss import SDSS
import mikkel_tools.utility as mt_util

import numpy as np
from math import inf
from scipy.optimize import curve_fit
import scipy as sp
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import time
import pyshtools
import pickle

comment = "Synthetic core with tapered ensemble as prior"
nb_name = "nb_case_core_synthetic_Ce6"

# %%
shc_g = 30
shc_grid = 30

core = SDSS(comment, N_SH = shc_g, sim_type = "core_ens", sat_height = 350)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([core.grid_phi, 90-core.grid_theta]).T
core.make_grid(core.r_cmb, grid_in, calc_sph_d = False)
core.generate_map()

core.condtab(normsize=10000, quantiles = 1000, 
             rangn_lim = 3.5, rangn_N = 501, rangv_lim = 2.0, rangv_N = 101, model_hist = "ensemble") #model_hist = "ensemble"

# %% [markdown]
# # Covariance model

# %%
core.cov_model_taper(r_at = core.r_cmb, tap_to = 500, tap_exp_p1 = 5, tap_exp_p2 = 2,
                     tap_scale_start = 0, tap_scale_end = 24, plot_taper = True,
                     save_fig = False, save_string = "case_core_synthetic", save_dpi = 300)
# Out:
# All eigenvalues > 0: True
# Cov model is pos def: True
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Synthetic sat

# %%
C_e_const = 6.0

s_sat = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_sat.load_swarm("A")

grid_in = np.array([s_sat.grid_phi, 90-s_sat.grid_theta]).T
s_sat.make_grid(s_sat.grid_radial, grid_in, calc_sph_d = False)

s_sat.generate_map(grid_type = "swarm")

s_sat.data += np.random.normal(scale = 2.0, size = s_sat.data.shape)

# %% [markdown]
# # Source truth

# %%
s_source = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_source.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([s_source.grid_phi, 90-s_source.grid_theta]).T
s_source.make_grid(s_source.r_cmb, grid_in, calc_sph_d = False)

s_source.generate_map()

# %% [markdown]
# # System equations

# %%
core.integrating_kernel(s_sat, C_e_const = C_e_const, C_mm_supply = core.C_ens_tap)

# %% [markdown]
# # SDSSIM

# %%
N_sim = 100
core.target_var = np.max(core.C_ens_tap)

core.run_sim(N_sim, core.grid_N, core.C_mm_all, core.C_dd, core.C_dm_all, core.G,
        s_sat.data, core.data, scale_m_i = True, unit_d = False, collect_all = True,
        sense_running_error = True, save_string = nb_name, sim_stochastic = False, solve_cho = True)
# Out:
#  |OOOOOOOOOO| 100.0%   realization nr. 0. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.998 minutes
# Total elapsed time: 12.998 minutes
# Variance: 330354803243.202
# Mean: -14419.542
# Max: 4939548.488
# Min: -1624669.851
# Run nr.: 1
#
#  |OOOOOOOOOO| 100.0%   realization nr. 1. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.577 minutes
# Total elapsed time: 26.575 minutes
# Variance: 312460736143.651
# Mean: -14454.768
# Max: 1842909.851
# Min: -1760929.337
# Run nr.: 2
#
#  |OOOOOOOOOO| 100.0%   realization nr. 2. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.756 minutes
# Total elapsed time: 40.332 minutes
# Variance: 309790032430.845
# Mean: -15395.335
# Max: 2234872.149
# Min: -1655300.729
# Run nr.: 3
#
#  |OOOOOOOOOO| 100.0%   realization nr. 3. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.740 minutes
# Total elapsed time: 54.071 minutes
# Variance: 316933166097.502
# Mean: -8224.549
# Max: 1780515.804
# Min: -1581612.430
# Run nr.: 4
#
#  |OOOOOOOOOO| 100.0%   realization nr. 4. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.540 minutes
# Total elapsed time: 1.127 hours
# Variance: 321736876532.864
# Mean: -9204.022
# Max: 1931419.923
# Min: -1815445.035
# Run nr.: 5
#
#  |OOOOOOOOOO| 100.0%   realization nr. 5. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.406 minutes
# Total elapsed time: 1.350 hours
# Variance: 307945573699.279
# Mean: -9071.089
# Max: 1808068.904
# Min: -1780211.354
# Run nr.: 6
#
#  |OOOOOOOOOO| 100.0%   realization nr. 6. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.609 minutes
# Total elapsed time: 1.577 hours
# Variance: 317086216163.422
# Mean: -13346.789
# Max: 1837292.115
# Min: -1659320.700
# Run nr.: 7
#
#  |OOOOOOOOOO| 100.0%   realization nr. 7. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.603 minutes
# Total elapsed time: 1.804 hours
# Variance: 317506886878.404
# Mean: -9147.302
# Max: 2507324.144
# Min: -1759074.624
# Run nr.: 8
#
#  |OOOOOOOOOO| 100.0%   realization nr. 8. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.710 minutes
# Total elapsed time: 2.032 hours
# Variance: 315906066721.698
# Mean: -10250.596
# Max: 2118585.760
# Min: -1503415.120
# Run nr.: 9
#
#  |OOOOOOOOOO| 100.0%   realization nr. 9. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.504 minutes
# Total elapsed time: 2.257 hours
# Variance: 327383007412.808
# Mean: -7976.995
# Max: 4522919.761
# Min: -1997666.464
# Run nr.: 10
#
#  |OOOOOOOOOO| 100.0%   realization nr. 10. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.862 minutes
# Total elapsed time: 2.488 hours
# Variance: 313416413463.951
# Mean: -9917.534
# Max: 1911823.201
# Min: -1615404.993
# Run nr.: 11
#
#  |OOOOOOOOOO| 100.0%   realization nr. 11. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 13.806 minutes
# Total elapsed time: 2.719 hours
# Variance: 320992224733.896
# Mean: -8522.085
# Max: 2050076.813
# Min: -1769336.304
# Run nr.: 12
#
#  |OOOOOOOOOO| 100.0%   realization nr. 12. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 13.394 minutes
# Total elapsed time: 2.942 hours
# Variance: 309341896160.768
# Mean: -13075.564
# Max: 1935811.549
# Min: -1656562.133
# Run nr.: 13
#
#  |OOOOOOOOOO| 100.0%   realization nr. 13. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.572 minutes
# Total elapsed time: 3.168 hours
# Variance: 320960959334.059
# Mean: -11351.211
# Max: 1757939.286
# Min: -1742589.182
# Run nr.: 14
#
#  |OOOOOOOOOO| 100.0%   realization nr. 14. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 13.592 minutes
# Total elapsed time: 3.395 hours
# Variance: 309960850945.578
# Mean: -8614.945
# Max: 1869735.874
# Min: -1721151.769
# Run nr.: 15
#
#  |OOOOOOOOOO| 100.0%   realization nr. 15. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.745 minutes
# Total elapsed time: 3.624 hours
# Variance: 329131818645.277
# Mean: -17182.284
# Max: 1987402.683
# Min: -1675082.751
# Run nr.: 16
#
#  |OOOOOOOOOO| 100.0%   realization nr. 16. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.436 minutes
# Total elapsed time: 3.848 hours
# Variance: 314044828567.758
# Mean: -6739.279
# Max: 2181453.221
# Min: -1669130.183
# Run nr.: 17
#
#  |OOOOOOOOOO| 100.0%   realization nr. 17. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.470 minutes
# Total elapsed time: 4.072 hours
# Variance: 320064911379.484
# Mean: -11985.147
# Max: 1910238.573
# Min: -1622731.703
# Run nr.: 18
#
#  |OOOOOOOOOO| 100.0%   realization nr. 18. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 13.427 minutes
# Total elapsed time: 4.296 hours
# Variance: 312014206130.354
# Mean: -9092.522
# Max: 1883003.363
# Min: -1909352.682
# Run nr.: 19
#
#  |OOOOOOOOOO| 100.0%   realization nr. 19. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 13.702 minutes
# Total elapsed time: 4.524 hours
# Variance: 317885704483.719
# Mean: -12307.654
# Max: 1832038.871
# Min: -1832339.559
# Run nr.: 20
#
#  |OOOOOOOOOO| 100.0%   realization nr. 20. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.528 minutes
# Total elapsed time: 4.750 hours
# Variance: 319707472923.321
# Mean: -12583.817
# Max: 2039329.622
# Min: -1663816.658
# Run nr.: 21
#
#  |OOOOOOOOOO| 100.0%   realization nr. 21. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.850 minutes
# Total elapsed time: 4.980 hours
# Variance: 320730562393.479
# Mean: -6114.610
# Max: 2073073.573
# Min: -1715070.766
# Run nr.: 22
#
#  |OOOOOOOOOO| 100.0%   realization nr. 22. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.553 minutes
# Total elapsed time: 5.206 hours
# Variance: 313306505279.734
# Mean: -7132.352
# Max: 2013668.218
# Min: -1705928.770
# Run nr.: 23
#
#  |OOOOOOOOOO| 100.0%   realization nr. 23. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.510 minutes
# Total elapsed time: 5.432 hours
# Variance: 315453490558.294
# Mean: -5863.782
# Max: 1971756.852
# Min: -1494317.863
# Run nr.: 24
#
#  |OOOOOOOOOO| 100.0%   realization nr. 24. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.487 minutes
# Total elapsed time: 5.656 hours
# Variance: 316161378556.374
# Mean: -5259.779
# Max: 1729706.001
# Min: -1841616.837
# Run nr.: 25
#
#  |OOOOOOOOOO| 100.0%   realization nr. 25. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 13.944 minutes
# Total elapsed time: 5.889 hours
# Variance: 310968052361.944
# Mean: -11867.283
# Max: 1894403.078
# Min: -1856227.007
# Run nr.: 26
#
#  |OOOOOOOOOO| 100.0%   realization nr. 26. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.537 minutes
# Total elapsed time: 6.114 hours
# Variance: 309480360883.490
# Mean: -12186.883
# Max: 1760805.067
# Min: -1650180.536
# Run nr.: 27
#
#  |OOOOOOOOOO| 100.0%   realization nr. 27. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 14.263 minutes
# Total elapsed time: 6.352 hours
# Variance: 313005163041.386
# Mean: -15443.091
# Max: 1748894.435
# Min: -1423546.411
# Run nr.: 28
#
#  |OOOOOOOOOO| 100.0%   realization nr. 28. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.451 minutes
# Total elapsed time: 6.576 hours
# Variance: 308843908217.995
# Mean: -10211.693
# Max: 1783165.909
# Min: -1576328.957
# Run nr.: 29
#
#  |OOOOOOOOOO| 100.0%   realization nr. 29. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 13.455 minutes
# Total elapsed time: 6.800 hours
# Variance: 302387808357.257
# Mean: -7928.026
# Max: 1921352.408
# Min: -1733910.603
# Run nr.: 30
#
#  |OOOOOOOOOO| 100.0%   realization nr. 30. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.800 minutes
# Total elapsed time: 7.030 hours
# Variance: 319943737224.162
# Mean: -13842.931
# Max: 2273083.281
# Min: -1893794.662
# Run nr.: 31
#
#  |OOOOOOOOOO| 100.0%   realization nr. 31. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.456 minutes
# Total elapsed time: 7.255 hours
# Variance: 308485848294.449
# Mean: -8704.820
# Max: 1854608.170
# Min: -1651111.701
# Run nr.: 32
#
#  |OOOOOOOOOO| 100.0%   realization nr. 32. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.501 minutes
# Total elapsed time: 7.480 hours
# Variance: 311263156327.021
# Mean: -14325.209
# Max: 2277700.760
# Min: -1518979.260
# Run nr.: 33
#
#  |OOOOOOOOOO| 100.0%   realization nr. 33. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.638 minutes
# Total elapsed time: 7.707 hours
# Variance: 323831448735.985
# Mean: -10909.685
# Max: 1887619.492
# Min: -1808475.267
# Run nr.: 34
#  |OOOOOOOOOO| 100.0%   realization nr. 34. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.557 minutes
# Total elapsed time: 7.933 hours
# Variance: 317121886005.559
# Mean: -7994.602
# Max: 2027063.218
# Min: -1636681.189
# Run nr.: 35
#
#  |OOOOOOOOOO| 100.0%   realization nr. 35. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.436 minutes
# Total elapsed time: 8.157 hours
# Variance: 321515808706.726
# Mean: -9234.304
# Max: 1861442.809
# Min: -1956006.704
# Run nr.: 36
#
#  |OOOOOOOOOO| 100.0%   realization nr. 36. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.416 minutes
# Total elapsed time: 8.381 hours
# Variance: 321508200518.324
# Mean: -12885.946
# Max: 2016639.385
# Min: -1545341.572
# Run nr.: 37
#
#  |OOOOOOOOOO| 100.0%   realization nr. 37. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.512 minutes
# Total elapsed time: 8.606 hours
# Variance: 316508986071.476
# Mean: -12461.193
# Max: 2405964.219
# Min: -1633408.383
# Run nr.: 38
#
#  |OOOOOOOOOO| 100.0%   realization nr. 38. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 13.266 minutes
# Total elapsed time: 8.827 hours
# Variance: 318072318269.760
# Mean: -5367.929
# Max: 1714060.542
# Min: -1639776.893
# Run nr.: 39
#
#  |OOOOOOOOOO| 100.0%   realization nr. 39. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.642 minutes
# Total elapsed time: 9.038 hours
# Variance: 350693238560.807
# Mean: -12625.195
# Max: 2626495.166
# Min: -4771602.084
# Run nr.: 40
#
#  |OOOOOOOOOO| 100.0%   realization nr. 40. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.661 minutes
# Total elapsed time: 9.249 hours
# Variance: 312290814438.662
# Mean: -13534.915
# Max: 2218560.944
# Min: -1418734.874
# Run nr.: 41
#
#  |OOOOOOOOOO| 100.0%   realization nr. 41. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.554 minutes
# Total elapsed time: 9.458 hours
# Variance: 317224602166.073
# Mean: -10773.525
# Max: 2199993.900
# Min: -1914553.350
# Run nr.: 42
#
#  |OOOOOOOOOO| 100.0%   realization nr. 42. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 12.347 minutes
# Total elapsed time: 9.664 hours
# Variance: 305664363267.491
# Mean: -6686.685
# Max: 2338792.794
# Min: -1525465.399
# Run nr.: 43
#
#  |OOOOOOOOOO| 100.0%   realization nr. 43. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.519 minutes
# Total elapsed time: 9.872 hours
# Variance: 315125033134.500
# Mean: -10599.370
# Max: 2255054.499
# Min: -1782955.599
# Run nr.: 44
#
#  |OOOOOOOOOO| 100.0%   realization nr. 44. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.749 minutes
# Total elapsed time: 10.085 hours
# Variance: 313419337384.920
# Mean: -12848.223
# Max: 2003697.565
# Min: -1744650.532
# Run nr.: 45
#
#  |OOOOOOOOOO| 100.0%   realization nr. 45. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.655 minutes
# Total elapsed time: 10.296 hours
# Variance: 315400688519.909
# Mean: -8494.389
# Max: 2157669.018
# Min: -1600169.466
# Run nr.: 46
#
#  |OOOOOOOOOO| 100.0%   realization nr. 46. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.530 minutes
# Total elapsed time: 10.504 hours
# Variance: 315379577287.917
# Mean: -11390.756
# Max: 2377405.170
# Min: -1595080.360
# Run nr.: 47
#
#  |OOOOOOOOOO| 100.0%   realization nr. 47. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 12.441 minutes
# Total elapsed time: 10.712 hours
# Variance: 314435237962.963
# Mean: -5646.250
# Max: 2008392.057
# Min: -1522765.391
# Run nr.: 48
#
#  |OOOOOOOOOO| 100.0%   realization nr. 48. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 12.432 minutes
# Total elapsed time: 10.919 hours
# Variance: 316546438529.260
# Mean: -14979.277
# Max: 2123420.451
# Min: -1663415.387
# Run nr.: 49
#
#  |OOOOOOOOOO| 100.0%   realization nr. 49. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.406 minutes
# Total elapsed time: 11.126 hours
# Variance: 327614737947.849
# Mean: -8645.888
# Max: 4865876.196
# Min: -1707831.842
# Run nr.: 50
#
#  |OOOOOOOOOO| 100.0%   realization nr. 50. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.489 minutes
# Total elapsed time: 11.334 hours
# Variance: 347784381715.597
# Mean: -12531.118
# Max: 2063749.806
# Min: -4866122.400
# Run nr.: 51
#
#  |OOOOOOOOOO| 100.0%   realization nr. 51. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.572 minutes
# Total elapsed time: 11.543 hours
# Variance: 315690501641.146
# Mean: -8761.849
# Max: 1719423.662
# Min: -1782487.062
# Run nr.: 52
#
#  |OOOOOOOOOO| 100.0%   realization nr. 52. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.630 minutes
# Total elapsed time: 11.754 hours
# Variance: 311517056897.737
# Mean: -12259.145
# Max: 2023013.857
# Min: -1577336.771
# Run nr.: 53
#
#  |OOOOOOOOOO| 100.0%   realization nr. 53. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.615 minutes
# Total elapsed time: 11.964 hours
# Variance: 323252278896.079
# Mean: -12719.537
# Max: 2167115.292
# Min: -2025839.960
# Run nr.: 54
#
#  |OOOOOOOOOO| 100.0%   realization nr. 54. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.581 minutes
# Total elapsed time: 12.174 hours
# Variance: 341576575812.556
# Mean: -13059.546
# Max: 2615282.260
# Min: -4556959.752
# Run nr.: 55
#
#  |OOOOOOOOOO| 100.0%   realization nr. 55. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 12.469 minutes
# Total elapsed time: 12.382 hours
# Variance: 306818025952.924
# Mean: -7757.502
# Max: 1852612.548
# Min: -1476664.474
# Run nr.: 56
#
#  |OOOOOOOOOO| 100.0%   realization nr. 56. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.552 minutes
# Total elapsed time: 12.591 hours
# Variance: 313405533894.680
# Mean: -8933.339
# Max: 1815239.227
# Min: -1757986.479
# Run nr.: 57
#
#  |OOOOOOOOOO| 100.0%   realization nr. 57. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.413 minutes
# Total elapsed time: 12.798 hours
# Variance: 319658837360.553
# Mean: -4247.653
# Max: 2119119.715
# Min: -1657371.162
# Run nr.: 58
#
#  |OOOOOOOOOO| 100.0%   realization nr. 58. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.356 minutes
# Total elapsed time: 13.004 hours
# Variance: 321416049615.030
# Mean: -5541.229
# Max: 1879376.215
# Min: -1966336.234
# Run nr.: 59
#
#  |OOOOOOOOOO| 100.0%   realization nr. 59. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.634 minutes
# Total elapsed time: 13.214 hours
# Variance: 318545818991.999
# Mean: -6648.190
# Max: 1938939.918
# Min: -1760529.329
# Run nr.: 60
#
#  |OOOOOOOOOO| 100.0%   realization nr. 60. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.617 minutes
# Total elapsed time: 13.425 hours
# Variance: 315645090319.891
# Mean: -10806.134
# Max: 3031345.967
# Min: -1676830.734
# Run nr.: 61
#
#  |OOOOOOOOOO| 100.0%   realization nr. 61. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.538 minutes
# Total elapsed time: 13.634 hours
# Variance: 343182836237.939
# Mean: -3851.279
# Max: 4853680.363
# Min: -1850527.004
# Run nr.: 62
#
#  |OOOOOOOOOO| 100.0%   realization nr. 62. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.505 minutes
# Total elapsed time: 13.842 hours
# Variance: 319108001573.534
# Mean: -6010.496
# Max: 1864487.037
# Min: -1503294.248
# Run nr.: 63
#
#  |OOOOOOOOOO| 100.0%   realization nr. 63. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.507 minutes
# Total elapsed time: 14.050 hours
# Variance: 311661046611.139
# Mean: -7303.617
# Max: 1624080.371
# Min: -1901723.644
# Run nr.: 64
#
#  |OOOOOOOOOO| 100.0%   realization nr. 64. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 12.353 minutes
# Total elapsed time: 14.256 hours
# Variance: 307102779119.040
# Mean: -11574.571
# Max: 2039335.627
# Min: -1702673.353
# Run nr.: 65
#
#  |OOOOOOOOOO| 100.0%   realization nr. 65. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.655 minutes
# Total elapsed time: 14.467 hours
# Variance: 319059464286.278
# Mean: -7592.965
# Max: 2110570.940
# Min: -1599480.668
# Run nr.: 66
#
#  |OOOOOOOOOO| 100.0%   realization nr. 66. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.672 minutes
# Total elapsed time: 14.678 hours
# Variance: 323473607653.919
# Mean: -6443.561
# Max: 1813987.199
# Min: -1834247.649
# Run nr.: 67
#
#  |OOOOOOOOOO| 100.0%   realization nr. 67. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.774 minutes
# Total elapsed time: 14.891 hours
# Variance: 316851500457.829
# Mean: -17618.477
# Max: 1877275.865
# Min: -1972247.527
# Run nr.: 68
#  |OOOOOOOOOO| 100.0%   realization nr. 68. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.291 minutes
# Total elapsed time: 15.096 hours
# Variance: 331885735741.341
# Mean: -11129.483
# Max: 4784552.644
# Min: -1762919.845
# Run nr.: 69
#
#  |OOOOOOOOOO| 100.0%   realization nr. 69. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.340 minutes
# Total elapsed time: 15.302 hours
# Variance: 312137343064.657
# Mean: -14971.226
# Max: 2417725.905
# Min: -2095643.242
# Run nr.: 70
#
#  |OOOOOOOOOO| 100.0%   realization nr. 70. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.543 minutes
# Total elapsed time: 15.511 hours
# Variance: 315985456983.546
# Mean: -12416.475
# Max: 1770975.728
# Min: -2220907.536
# Run nr.: 71
#
#  |OOOOOOOOOO| 100.0%   realization nr. 71. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 12.433 minutes
# Total elapsed time: 15.718 hours
# Variance: 319528188461.266
# Mean: -15520.626
# Max: 2176702.307
# Min: -1555339.554
# Run nr.: 72
#
#  |OOOOOOOOOO| 100.0%   realization nr. 72. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.713 minutes
# Total elapsed time: 15.930 hours
# Variance: 322683630084.313
# Mean: -8110.821
# Max: 2198611.557
# Min: -1757053.772
# Run nr.: 73
#
#  |OOOOOOOOOO| 100.0%   realization nr. 73. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.201 minutes
# Total elapsed time: 16.150 hours
# Variance: 317652956788.793
# Mean: -10491.599
# Max: 2167545.247
# Min: -1921691.645
# Run nr.: 74
#
#  |OOOOOOOOOO| 100.0%   realization nr. 74. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.530 minutes
# Total elapsed time: 16.375 hours
# Variance: 315601745395.585
# Mean: -6758.097
# Max: 2092405.964
# Min: -1712956.944
# Run nr.: 75
#
#  |OOOOOOOOOO| 100.0%   realization nr. 75. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 13.457 minutes
# Total elapsed time: 16.600 hours
# Variance: 311965561425.261
# Mean: -6218.306
# Max: 1914597.026
# Min: -1559237.519
# Run nr.: 76
#
#  |OOOOOOOOOO| 100.0%   realization nr. 76. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 14.006 minutes
# Total elapsed time: 16.833 hours
# Variance: 319627097985.580
# Mean: -7902.597
# Max: 2244685.786
# Min: -1830262.151
# Run nr.: 77
#
#  |OOOOOOOOOO| 100.0%   realization nr. 77. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.660 minutes
# Total elapsed time: 17.061 hours
# Variance: 309276529634.447
# Mean: -6770.184
# Max: 1784754.116
# Min: -1781604.027
# Run nr.: 78
#
#  |OOOOOOOOOO| 100.0%   realization nr. 78. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.487 minutes
# Total elapsed time: 17.286 hours
# Variance: 320676789639.739
# Mean: -17773.034
# Max: 2454845.193
# Min: -1771258.936
# Run nr.: 79
#
#  |OOOOOOOOOO| 100.0%   realization nr. 79. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.582 minutes
# Total elapsed time: 17.512 hours
# Variance: 318191997622.955
# Mean: -17272.942
# Max: 2127160.292
# Min: -1798683.996
# Run nr.: 80
#
#  |OOOOOOOOOO| 100.0%   realization nr. 80. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.544 minutes
# Total elapsed time: 17.738 hours
# Variance: 322494614470.905
# Mean: -9774.884
# Max: 1990901.723
# Min: -2044656.017
# Run nr.: 81
#
#  |OOOOOOOOOO| 100.0%   realization nr. 81. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 13.373 minutes
# Total elapsed time: 17.961 hours
# Variance: 321544094468.307
# Mean: -7662.481
# Max: 1833506.937
# Min: -1880708.871
# Run nr.: 82
#
#  |OOOOOOOOOO| 100.0%   realization nr. 82. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 13.426 minutes
# Total elapsed time: 18.184 hours
# Variance: 305922217227.501
# Mean: -9207.001
# Max: 1825306.374
# Min: -1568378.801
# Run nr.: 83
#
#  |OOOOOOOOOO| 100.0%   realization nr. 83. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.292 minutes
# Total elapsed time: 18.406 hours
# Variance: 307246139860.208
# Mean: -13827.277
# Max: 1625104.081
# Min: -1804519.952
# Run nr.: 84
#
#  |OOOOOOOOOO| 100.0%   realization nr. 84. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 13.342 minutes
# Total elapsed time: 18.628 hours
# Variance: 307837627359.267
# Mean: -6969.442
# Max: 1767895.997
# Min: -1739595.458
# Run nr.: 85
#
#  |OOOOOOOOOO| 100.0%   realization nr. 85. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.832 minutes
# Total elapsed time: 18.842 hours
# Variance: 312810979187.523
# Mean: -14807.688
# Max: 1778392.225
# Min: -1615304.429
# Run nr.: 86
#
#  |OOOOOOOOOO| 100.0%   realization nr. 86. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.588 minutes
# Total elapsed time: 19.052 hours
# Variance: 328707730401.670
# Mean: -9890.480
# Max: 2020070.637
# Min: -1844505.652
# Run nr.: 87
#
#  |OOOOOOOOOO| 100.0%   realization nr. 87. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.431 minutes
# Total elapsed time: 19.259 hours
# Variance: 317834062570.256
# Mean: -8801.902
# Max: 2345196.674
# Min: -1741978.020
# Run nr.: 88
#
#  |OOOOOOOOOO| 100.0%   realization nr. 88. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.538 minutes
# Total elapsed time: 19.468 hours
# Variance: 322039768052.922
# Mean: -15490.313
# Max: 1802031.028
# Min: -4886807.181
# Run nr.: 89
#
#  |OOOOOOOOOO| 100.0%   realization nr. 89. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.475 minutes
# Total elapsed time: 19.676 hours
# Variance: 311217507547.210
# Mean: -13919.798
# Max: 2004078.239
# Min: -1813598.065
# Run nr.: 90
#
#  |OOOOOOOOOO| 100.0%   realization nr. 90. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.712 minutes
# Total elapsed time: 19.888 hours
# Variance: 334327506379.368
# Mean: -10099.904
# Max: 4791922.847
# Min: -1456002.595
# Run nr.: 91
#
#  |OOOOOOOOOO| 100.0%   realization nr. 91. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.745 minutes
# Total elapsed time: 20.100 hours
# Variance: 320700344465.175
# Mean: -8322.879
# Max: 2527970.011
# Min: -1411939.555
# Run nr.: 92
#
#  |OOOOOOOOOO| 100.0%   realization nr. 92. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.861 minutes
# Total elapsed time: 20.315 hours
# Variance: 334151664758.392
# Mean: -10277.870
# Max: 4425280.488
# Min: -1782517.079
# Run nr.: 93
#
#  |OOOOOOOOOO| 100.0%   realization nr. 93. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 14.014 minutes
# Total elapsed time: 20.548 hours
# Variance: 320051152001.056
# Mean: -4980.042
# Max: 1978187.495
# Min: -1707912.758
# Run nr.: 94
#
#  |OOOOOOOOOO| 100.0%   realization nr. 94. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.865 minutes
# Total elapsed time: 20.813 hours
# Variance: 311312618188.769
# Mean: -8890.381
# Max: 1827821.417
# Min: -1600550.820
# Run nr.: 95
#
#  |OOOOOOOOOO| 100.0%   realization nr. 95. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.458 minutes
# Total elapsed time: 21.087 hours
# Variance: 318430579633.646
# Mean: -8120.518
# Max: 2009875.177
# Min: -2090691.995
# Run nr.: 96
#
#  |OOOOOOOOOO| 100.0%   realization nr. 96. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.863 minutes
# Total elapsed time: 21.318 hours
# Variance: 326684440356.725
# Mean: -6493.049
# Max: 2151778.652
# Min: -1375580.304
# Run nr.: 97
#
#  |OOOOOOOOOO| 100.0%   realization nr. 97. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 13.316 minutes
# Total elapsed time: 21.540 hours
# Variance: 328470576296.363
# Mean: -14075.681
# Max: 2077273.638
# Min: -1474428.854
# Run nr.: 98
#
#  |OOOOOOOOOO| 100.0%   realization nr. 98. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 13.469 minutes
# Total elapsed time: 21.764 hours
# Variance: 310437830011.017
# Mean: -12206.337
# Max: 1904794.145
# Min: -1814102.593
# Run nr.: 99
#
#  |OOOOOOOOOO| 100.0%   realization nr. 99. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.677 minutes
# Total elapsed time: 21.959 hours
# Variance: 324687917385.138
# Mean: -9429.289
# Max: 1737696.629
# Min: -1604842.947
# Run nr.: 100
#
#
# Seqsim RMSE:	 [[2.75685827 2.75035242 2.67856934 2.56093332 2.62609528 2.63789052
#   2.69989897 2.61723737 2.62923389 2.73976218 2.65121168 2.65341458
#   2.71151258 2.60365547 2.61122571 2.6413359  2.6890525  2.69845981
#   2.73328964 2.6446117  2.67042487 2.5926631  2.63779063 2.65441902
#   2.59121657 2.70958709 2.65683422 2.63056042 2.675848   2.71569733
#   2.64545521 2.70989879 2.6932761  2.64593964 2.63210356 2.73844491
#   2.58112465 2.76547472 2.72679501 2.7242723  2.64308763 2.63387902
#   2.66491971 2.68357191 2.64995289 2.67096302 2.58950185 2.6535856
#   2.68026495 2.71350634 2.68276606 2.68998284 2.67320169 2.69859028
#   2.73159623 2.6757504  2.69912254 2.60151724 2.66419736 2.67747172
#   2.76564757 2.65431489 2.75030981 2.65144662 2.70584711 2.69554153
#   2.69821151 2.69952667 2.65682597 2.64626001 2.6326764  2.69764533
#   2.78889142 2.66455174 2.65497094 2.53074526 2.61200017 2.66726158
#   2.60781431 2.77324006 2.62345135 2.69909319 2.69143184 2.71334379
#   2.7335375  2.62810118 2.63392472 2.67650852 2.76365827 2.65828057
#   2.804408   2.61440653 2.65516859 2.61128437 2.56684438 2.62765126
#   2.63867065 2.74256114 2.60667623 2.58197117]]
# <img src="data:image/png;base64,..." width="640">

# %%
core.realization_to_sh_coeff(core.r_cmb, set_nmax = shc_grid)

# %%
#core.covmod_lsq_equiv(s_sat.data, C_Br_model, core.G, core.r_cmb)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

#truth_obj = s_source

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)
#m_mode = m_DSS_mode
mt_util.plot_sdssim_reproduce(core, core.m_DSS_res, m_equiv_lsq = None, truth_obj = s_source,
                              lags_use = 1000, spec_r_at = core.r_cmb, spec_show_differences = False,
                              spec_ti_ens = True, lwidth = 0.6, lwidth_div = 3, lwidth_mult = 2,
                              label_fontsize = "small",
                              res_use = True, sv_use = False, unit_field = "[mT]", hist_ti_ens_limit = [-6,6],
                              unit_transform_n_to_m = True, patch_legend = True, ens_prior = True,
                              model_dict = {}, figsize=(9,16), hist_ti_ens = "all", hist_density = False,
                              hist_bins = 21, res_bins = 21, hist_pos_mean = False,
                              left=0.08, bottom=0.12, right=0.92, top=0.95, wspace = 0.2, hspace=0.25,
                              savefig = False, save_string = "case_core_synthetic", 
                              save_dpi = 100, save_path = "images/")
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
print(core)
# Out:
# ______current attributes______
#
# a:                  6371.2
# r_sat:              6721.2
# r_cmb:              3480.0
# rad:                0.017453292519943295
# mu0:                1.2566370614359173e-06
# comment:            Synthetic core with tapered ensemble as prior
# class_abs_path:     /home/mikotz/spherical_direct_sequential_simulation
# N_SH:               30
# N_SH_secondary:     None
# sim_type:           core_ens
# grid_zero:          (31,), Max/Min: 1.00 / -1.00
# grid_w_shtools:     (31,), Max/Min: 0.10 / 0.01
# grid_shape:         (2,), Max/Min: 61.00 / 31.00
# grid_w:             (1891,), Max/Min: 0.10 / 0.01
# grid_radial:        (1891,), Max/Min: 3480.00 / 3480.00
# grid_theta:         (1891,), Max/Min: 175.63 / 4.37
# grid_phi:           (1891,), Max/Min: 354.10 / 0.00
# grid_N:             1891
# grid_nmax:          30
# r_grid:             3480.0
# grid:               (1891, 2)
# sph_d:              None
# lon:                (1891,), Max/Min: 354.10 / 0.00
# lat:                (1891,), Max/Min: 85.63 / -85.63
# N_grid:             1891
# m_ens:              (1891, 487)
# ens_idx:            405
# data:               (1891,), Max/Min: 1987107.57 / -2234933.26
# r_grid_repeat:      (1891,), Max/Min: 3480.00 / 3480.00
# target_var:         378619655927.35596
# target_mean_true:   11528.099043986806
# target_mean:        0.0
# g_prior:            (960,), Max/Min: 1081.80 / -61095.96
# CQF_dist:           (501, 101, 10000)
# CQF_mean:           (501, 101)
# CQF_var:            (501, 101)
# rangv:              (101,), Max/Min: 2.00 / 0.00
# rangn:              (501,), Max/Min: 3.50 / -3.50
# condtab_normsize:   10000
# condtab_model_hist: ensemble
# condtab_table:      rough
# C_ens_tap:          (1891, 1891)
# G:                  (2773, 1891)
# C_mm_all:           (1891, 1891)
# C_dd:               (2773, 2773)
# C_dm_all:           (1891, 2773)
# C_e_const:          6.0
# N_sim:              100
# idx_nv_collect:     (189100, 2)
# kriging_mv_collect: (189100, 2)
# m_DSS:              (1891, 100)
# m_DSS_pred:         (2773, 100)
# m_DSS_res:          (2773, 100)
# C_DSS:              (1891, 1891)
# g_spec:             (960, 100)
# g_spec_mean:        (960,), Max/Min: 5004.73 / -51832.62

# %%
core.pickle_save_self(nb_name)
# Out:
# Saving job
#
# Job saved and finished

# %%
list_coord = np.array([[0,2], [-30,30], [45,-45], [70,-170]])
list_coord[:,0] = 90 - list_coord[:,0]
list_coord[:,1][list_coord[:,1]<0.0] = 360 + list_coord[:,1][list_coord[:,1]<0.0]

m_coord_sph = np.hstack((90 - core.lat.reshape(-1,1), core.lon.reshape(-1,1)))

idx_min = []
for coord in list_coord:
    idx_min.append(np.sum(np.abs(m_coord_sph - coord),axis=1).argmin())
    
print(idx_min)

m_hists_coord = m_coord_sph[idx_min]

m_hists = core.m_DSS[idx_min,:]
# Out:
# [915, 1225, 480, 215]

# %%
left=0.08
bottom=0.12
right=0.92
top=0.95
wspace = 0.2
hspace=0.25

color_rgb_zesty_pos = (1.0,  0.5372549019607843,  0.30196078431372547)
color_rgb_zesty_neg = (0.5019607843137255,  0.6862745098039216,  1.0)

# %%
m_hists_scale = m_hists*10**(-6)

tile_size_row = 2
tile_size_column = 2

label_fontsize = 10

fig = plt.figure(figsize=(9,9)) # Initiate figure with constrained layout
# Generate ratio lists
h_ratio = [1]*tile_size_row
w_ratio = [1]*tile_size_column
gs = fig.add_gridspec(tile_size_row, tile_size_column, height_ratios=h_ratio, width_ratios=w_ratio) # Add x-by-y grid

for i in np.arange(0,list_coord.shape[0]):

    ax = fig.add_subplot(gs[i])
    
    y,binEdges=np.histogram(m_hists_scale[i,:],bins=11,density=True)
    bincenters = 0.5*(binEdges[1:]+binEdges[:-1])    
    ax.plot(bincenters, y, '-', color = color_rgb_zesty_neg, 
            label='{}'.format(str(np.round(m_hists_coord[i,:],decimals=1))).lstrip('[').rstrip(']'),
            linewidth = 1)

    #ax.set_title('test')
    #ax.annotate("test", (0.05, 0.5), xycoords='axes fraction', va='center', fontsize = label_fontsize)
    ax.set_xlabel("Field value [mT]")
    ax.set_ylabel("PDF")
    ax.legend(loc='best', fontsize = label_fontsize)
    

fig.subplots_adjust(left=left, bottom=bottom, right=right, top=top, wspace=wspace, hspace=hspace)

# %%
#core.grid_glq(nmax = 256, r_at = core.r_cmb)
#core.grid_glq(nmax = 120, r_at = core.r_cmb)
core.grid_glq(nmax = 400, r_at = core.r_cmb)

set_nmax = shc_grid

core.ensemble_B(core.g_spec, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_eqa = core.B_ensemble[:,0,:].copy()

#core.g_spec_mean = np.mean(core.g_spec,axis=1)
core.ensemble_B(core.g_spec_mean, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_mean_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
core.ensemble_B(s_sat.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
prior_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_lsq_equiv, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
#lsq_eqa = core.B_ensemble[:,0].copy()

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)
# ccrs.PlateCarree()
# ccrs.Mollweide()
# ccrs.Orthographic(central_longitude=0.0, central_latitude=0.0)

mt_util.plot_ensemble_map_tiles(core.grid_phi, 90-core.grid_theta, zs_eqa, 
                        field_compare = prior_eqa, field_lsq = None, field_mean = zs_mean_eqa,
                        tile_size_row = 3, tile_size_column = 2, 
                        figsize=(9,12), limit_for_SF = 10**6, point_size = 0.1, cbar_mm_factor = 1, cbar_limit = [-1.6,1.6],
                        coast_width = 0.4, coast_color = "grey", unit_transform_n_to_m = True,
                        cbar_h = 0.1, cbar_text = "mT", cbar_text_color = "black",
                        left=0.03, bottom=0.12, right=0.97, top=0.95, wspace = 0.05, hspace=0.25, 
                        savefig = False, save_string = "case_core_synthetic", 
                        projection = ccrs.Mollweide(), use_gridlines = True, 
                        gridlines_width = 0.4, gridlines_alpha = 0.4, save_dpi = 100)
