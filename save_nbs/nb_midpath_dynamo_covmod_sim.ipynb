# %%
# %matplotlib notebook

from sdss import SDSS
import mikkel_tools.utility as mt_util
import plot as sds_plt

import numpy as np
from math import inf
from scipy.optimize import curve_fit
import scipy as sp
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

import pyshtools
import pickle

import scipy.linalg as spl

# Function for testing positive definiteness
def is_pos_def(A):
    if np.allclose(A, A.conj().T):
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            return False
    else:
        return False

comment = "Fit to covariance in sim"
nb_name = "nb_midpath_dynamo_covmod_sim"

# %%
shc_g = 30
shc_grid = 30

core = SDSS(comment, N_SH = shc_g, sim_type = "core_ens", sat_height = 350)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([core.grid_phi, 90-core.grid_theta]).T
core.make_grid(core.r_cmb, grid_in, calc_sph_d = True)
core.generate_map(target_var_factor = 1)

core.condtab(normsize=10000, quantiles = 100, 
             rangn_lim = 3.5, rangn_N = 501, rangv_lim = 2.0, rangv_N = 101) #model_hist = "ensemble"

# %%
core.semivar(model_lags = 20, model = "exponential", max_dist = 20000, lag_length = 100,
             zero_nugget = True, hit_target_var = False)
# Out:
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 100.0 km
# Number of lags: 109
# Number of modelling lags: 20
#
# Semi-variogram model determined, starting LUT computation

# %%
print(core)
# Out:
# ______current attributes______
#
# a:                     6371.2
# r_sat:                 6721.2
# r_cmb:                 3480.0
# rad:                   0.017453292519943295
# mu0:                   1.2566370614359173e-06
# comment:               Fit to covariance in sim
# class_abs_path:        /home/mikotz/spherical_direct_sequential_simulation
# N_SH:                  30
# N_SH_secondary:        None
# sim_type:              core_ens
# grid_zero:             (31,), Max/Min: 1.00 / -1.00
# grid_w_shtools:        (31,), Max/Min: 0.10 / 0.01
# grid_shape:            (2,), Max/Min: 61.00 / 31.00
# grid_w:                (1891,), Max/Min: 0.10 / 0.01
# grid_radial:           (1891,), Max/Min: 3480.00 / 3480.00
# grid_theta:            (1891,), Max/Min: 175.63 / 4.37
# grid_phi:              (1891,), Max/Min: 354.10 / 0.00
# grid_N:                1891
# grid_nmax:             30
# r_grid:                3480.0
# grid:                  (1891, 2)
# sph_d:                 (1891, 1891)
# lon:                   (1891,), Max/Min: 354.10 / 0.00
# lat:                   (1891,), Max/Min: 85.63 / -85.63
# N_grid:                1891
# m_core_ens:            (1891, 487)
# ens_idx:               405
# data:                  (1891,), Max/Min: 1987107.57 / -2234933.26
# r_grid_repeat:         (1891,), Max/Min: 3480.00 / 3480.00
# target_var:            347831506158.7656
# target_mean_true:      11528.099043986806
# target_mean:           0.0
# g_prior:               (960,), Max/Min: 1081.80 / -61095.96
# CQF_dist:              (501, 101, 10000)
# CQF_mean:              (501, 101)
# CQF_var:               (501, 101)
# rangv:                 (101,), Max/Min: 2.00 / 0.00
# rangn:                 (501,), Max/Min: 3.50 / -3.50
# condtab_normsize:      10000
# condtab_model_hist:    False
# condtab_table:         rough
# sv_model_lags:         20
# sv_max_dist:           20000
# sv_lag_length:         100
# sv_zero_nugget:        True
# sort_d:                (3575881,), Max/Min: 3575880.00 / 0.00
# cloud_sorted:          (3575881,), Max/Min: 8912814395390.37 / 0.00
# sph_d_sorted:          (3575881,), Max/Min: 10919.08 / 0.00
# max_cloud:             3575881
# n_lags:                109
# lags:                  (108,), Max/Min: 10274.75 / 0.00
# pics:                  (108,), Max/Min: 661103699254.27 / 0.00
# model_select_simple:   False
# model_select_advanced: False
# lags_model:            (20,), Max/Min: 2750.25 / 0.00
# pics_model:            (20,), Max/Min: 166781682494.35 / 0.00
# lags_sv_curve:         (108,), Max/Min: 10275.00 / 0.00
# sv_curve:              (108,), Max/Min: 166781360897.31 / 0.00
# sv_lut:                (1891, 1891)
# model:                 exponential
# a_sv:                  2342.5177948626183
# C0:                    0.0
# C1:                    166781682487.5071
# C2:                    None
# C3:                    None

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

# g ensemble and parameters
g_core_ens = np.genfromtxt("lithosphere_prior/grids/shcoeff_Dynamo/gnm_midpath.dat").T*10**9
g_core_ens = g_core_ens[:mt_util.shc_vec_len(shc_g),:]

a = core.a
c = core.r_cmb
n_max = shc_g

g_cut = g_core_ens[:n_max*(2+n_max),200:] # Truncate g
R = mt_util.lowe_shspec(n_max,c,a,g_cut)

# One spectra for comparison to SHTOOLS
g_cut_one = g_core_ens[:,core.ens_idx][:n_max*(2+n_max)]
R_one = mt_util.lowe_shspec(n_max,c,a,g_cut_one.reshape(-1,1))

# SHTOOLS
ens_cilm_compare = np.array(pyshtools.shio.SHVectorToCilm(np.hstack((np.zeros(1,), g_cut_one))))
p_spec_compare = pyshtools.gravmag.mag_spectrum(ens_cilm_compare, a, c, degrees = np.arange(1,np.shape(ens_cilm_compare)[1]))

# Spectra
plt.figure()
for i in np.arange(R.shape[1]):
    if i == 0:
        plt.semilogy(np.arange(1,n_max+1),R[:,i],color=(0.6,0.6,0.6),label="Ensemble")
    else:
        plt.semilogy(np.arange(1,n_max+1),R[:,i],color=(0.6,0.6,0.6))
plt.semilogy(np.arange(1,n_max+1),R_one,label="My Lowes")
plt.semilogy(np.arange(1,n_max+1),p_spec_compare,linestyle="dashed", label="SHTOOLS")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Cov based on c_angdist_range
N_range = 10000
c_angdist_range = np.linspace(-1.0,1.0,N_range)

# Compute covariances based on eqn. 11
C_const = (np.arange(1,n_max+1)+1)/(2*np.arange(1,n_max+1)+1)

C_Br_range = []

for cmu in np.ravel(c_angdist_range):
    C_Br_range.append(np.sum(C_const.reshape(-1,1)*R*pyshtools.legendre.PlSchmidt(n_max,cmu)[1:].reshape(-1,1),axis=0))
    
C_Br_range = np.array(C_Br_range).reshape((N_range,-1))
C_Br_model = C_Br_range[:,core.ens_idx]


c_Br_range = -1*(1-2*(C_Br_range-np.min(C_Br_range,axis=0))/(np.max(C_Br_range,axis=0)-np.min(C_Br_range,axis=0)))
c_Br_model = c_Br_range[:,core.ens_idx]

# %%
plt.figure()
#plt.plot(np.arccos(c_angdist_range)*180/np.pi,C_Br_range,color="k",linewidth=0.1)
plt.plot(core.r_cmb*np.arccos(c_angdist_range),c_Br_range,color="k",linewidth=0.1)
plt.plot(core.r_cmb*np.arccos(c_angdist_range),c_Br_model,color="C4",linewidth=1.0)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
model_cov = c_Br_model
model_gcd = core.r_cmb*np.arccos(c_angdist_range)

# %%
#Spherical
#def cov_return(t, c, c0, c1):
#    return c0+c1*(1+1/2*t/c)*(1-t/c)**2
#p0 = [10**3,0.0,np.max(C_Br_model)]
#bounds = ([0,0,0],inf)
#popt, _ = curve_fit(cov_return, model_gcd, model_cov, bounds=bounds, p0 = p0)
#cov_sph = cov_return(model_gcd, popt[0], popt[1], popt[2])
#print("Spherical:", popt)
#
##Power exp
#def cov_return(t, c, c0, c1,a):
#    return c0+c1*np.exp(-(t/c)**a)
#p0 = [10**1,0.0,np.max(C_Br_model),0.5]
#bounds = ([0,0,0,0.0001],[inf,inf,inf,1])
#popt, _ = curve_fit(cov_return, model_gcd, model_cov, bounds=bounds, p0 = p0)
#cov_pexp = cov_return(model_gcd, popt[0], popt[1], popt[2], popt[3])
#print("Power exp:", popt)
#
##Gen Cauchy
#def cov_return(t, c, c0, c1, a, tau):
#    return c0+c1*(1+(t/c))**(-tau/a)
#p0 = [10**1,0.0,np.max(C_Br_model),0.5, 0.5]
#bounds = ([0,0,0,0.0001, 0.0001],[inf,inf,inf,1, 1])
#popt, _ = curve_fit(cov_return, model_gcd, model_cov, bounds=bounds, p0 = p0)
#cov_cauchy = cov_return(model_gcd, popt[0], popt[1], popt[2], popt[3], popt[4])
#print("Gen Cauchy:", popt)
#
##Askey
#def cov_return(t, c, c0, c1, tau):
#    return c0+c1*(1-t/c)**tau
#p0 = [10**10,0.0,np.max(C_Br_model),3]
#bounds = ([0,0,0,2],[inf,inf,inf,inf])
#popt, _ = curve_fit(cov_return, model_gcd, model_cov, bounds=bounds, p0 = p0)
#cov_ask = cov_return(model_gcd, popt[0], popt[1], popt[2], popt[3])
#print("Askey:", popt)

#C2-Wendland
Nfit = 9950
model_gcd_fit = model_gcd[Nfit:]
model_cov_fit = model_cov[Nfit:]
def cov_return(t, c, tau):
    return (1+tau*t/c)*(1-t/c)**tau

p0 = [10**7,4]
bounds = ([0,4],inf)
popt, _ = curve_fit(cov_return, model_gcd_fit, model_cov_fit, bounds=bounds, p0 = p0)
cov_C2 = cov_return(model_gcd, popt[0], popt[1])#, popt[2], popt[3]
print("C2-Wendland:", popt)

#cov_C2 = (np.max(C_Br_model)-np.min(C_Br_model))*cov_C2+np.min(C_Br_model)
cov_C2 = (np.max(C_Br_model)-np.min(C_Br_model))*(-cov_C2-1)/-2 + np.min(C_Br_model)

##C4-Wendland
#def cov_return(t, c, c0, c1, tau):
#    return c0+c1*(1+tau*t/c+(tau**2-1)/3*t**2/c**2)*(1-t/c)**tau
#
#p0 = [10**7,0.0,np.max(C_Br_model),8]
#bounds = ([0,0,0,6],[inf,inf,inf,inf])
#popt, _ = curve_fit(cov_return, model_gcd, model_cov, bounds=bounds, p0 = p0)
#cov_C4 = cov_return(model_gcd, popt[0], popt[1], popt[2], popt[3])
#print("C4-Wendland:", popt)
# Out:
# C2-Wendland: [3793065.97028335   12938.39824936]

# %%
#%% PLOT COVARIANCE FROM RANGE
plt.figure(figsize=(10,8)) 

for i in np.arange(0,C_Br_range.shape[-1]):
    if i == 0:
        plt.plot(model_gcd,C_Br_range[:,0], 
                 linewidth = 0.8, color="k", label='Cov from spectra', zorder=0.1)
    else:
        plt.plot(model_gcd,C_Br_range[:,i], 
                 linewidth = 0.8, color="k", zorder=0.1)
        
plt.plot(model_gcd, C_Br_model, 
         linewidth = 2.0, color=(0.6,0.6,0.6), label='Training image', zorder=0.2)

plt.plot(model_gcd_fit, C_Br_model[Nfit:], 
         linewidth = 2.0, color=(0.3,0.3,0.3), label='Model target', zorder=0.3, linestyle = "dashed")

#plt.plot(core.lags, core.target_var - core.pics, 
#         linewidth = 2.0, color="C6", label='SV Training image', zorder=0.1)
#
#plt.plot(core.lags_sv_curve,core.target_var - core.sv_curve, 
#         linewidth = 2.0, color='C1', label='SV model', zorder=0.1)

#plt.plot(model_gcd, cov_sph, 
#         linewidth = 2.0, color="C0", label='Spherical', zorder=0.3)
#
#plt.plot(model_gcd, cov_pexp, 
#         linewidth = 2.0, color="C7", label='Power exp', zorder=0.3)
#
#plt.plot(model_gcd, cov_cauchy, 
#         linewidth = 2.0, color="C2", label='Gen Cauchy', zorder=0.3)
#
#plt.plot(model_gcd, cov_ask, 
#         linewidth = 2.0, color="C3", label='Askey', zorder=0.3)

plt.plot(model_gcd, cov_C2, 
         linewidth = 2.0, color="C4", label='C2-Wendland', zorder=0.25)

#plt.plot(model_gcd, cov_C4, 
#         linewidth = 2.0, color="C5", label='C4-Wendland', zorder=0.3)



plt.ylabel('Covariance $[%s^2]$' % "nT",fontsize=18,labelpad=18)
plt.xlabel('Lag [km]',fontsize=18,labelpad=18)
plt.title("Covariance from Aubert dynamo spectra",fontsize=18,y=1.02)
plt.legend(loc='best',fontsize=18)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
def cov_return(t, c, tau):
    return (1+tau*t/c)*(1-t/c)**tau

p0 = [10**7,4]
bounds = ([0,4],inf)
popt, _ = curve_fit(cov_return, model_gcd_fit, model_cov_fit, bounds=bounds, p0 = p0)
cov_C2 = cov_return(model_gcd, popt[0], popt[1])#, popt[2], popt[3]
print("C2-Wendland:", popt)

#cov_C2 = (np.max(C_Br_model)-np.min(C_Br_model))*cov_C2+np.min(C_Br_model)
cov_C2 = (np.max(C_Br_model)-np.min(C_Br_model))*(-cov_C2-1)/-2 + np.min(C_Br_model)
# Out:
# C2-Wendland: [3793065.97028335   12938.39824936]

# %%
# Compute cos(angdist) array for model parameter sphere
theta_s, theta_d, phi_s, phi_d = map(np.radians, 
                                     [core.grid_theta.reshape(1,-1), core.grid_theta.reshape(-1,1), 
                                      core.grid_phi.reshape(1,-1), core.grid_phi.reshape(-1,1)])

c_angdist = np.cos(theta_d)*np.cos(theta_s)+np.multiply(np.sin(theta_d)@np.sin(theta_s),np.cos(phi_d-phi_s))

c_angdist[c_angdist>1] = 1.0

sph_d = core.r_cmb*np.arccos(c_angdist)

# %%
Cm = cov_return(sph_d, popt[0], popt[1]) #, popt[2], popt[3]

#Cm = (np.max(C_Br_model)-np.min(C_Br_model))*Cm+np.min(C_Br_model)
Cm = (np.max(C_Br_model)-np.min(C_Br_model))*(-Cm-1)/-2 + np.min(C_Br_model)

# %%
Cm.shape
# Out:
# (1891, 1891)

# %%
plt.figure()
plt.title("Cm")
plt.imshow(Cm)
plt.colorbar()
plt.show()

# Positive definite covariance?
core_eigval = spl.eigh(Cm, eigvals_only=True)
N_neg_eigval = len(core_eigval[core_eigval<=0])
print("C_Br_model is pos def:", is_pos_def(Cm))
print("All eigenvalues > 0:", np.all(core_eigval>=0))
print("Number of negative eigenvalues:",N_neg_eigval,"/",len(core_eigval))

plt.figure()
plt.semilogy(np.arange(0,len(core_eigval)),core_eigval,'.',label="Eigenvalues")
plt.semilogy(np.ones((100,))*N_neg_eigval,np.linspace(core_eigval[N_neg_eigval],core_eigval[-1],100),label="Transition to negative")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C_Br_model is pos def: True
# All eigenvalues > 0: True
# Number of negative eigenvalues: 0 / 1891
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Synthetic sat

# %%
C_e_const = 2.0

s_sat = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_sat.load_swarm("A")

grid_in = np.array([s_sat.grid_phi, 90-s_sat.grid_theta]).T
s_sat.make_grid(s_sat.grid_radial, grid_in, calc_sph_d = False)

s_sat.generate_map(grid_type = "swarm")

s_sat.data += np.random.normal(scale = C_e_const, size = s_sat.data.shape)

# %% [markdown]
# # Source truth

# %%
s_source = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_source.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([s_source.grid_phi, 90-s_source.grid_theta]).T
s_source.make_grid(s_source.r_cmb, grid_in, calc_sph_d = False)

s_source.generate_map()

# %% [markdown]
# # System equations

# %%
core.integrating_kernel(s_sat, C_e_const = C_e_const, C_mm_supply = Cm)

# %% [markdown]
# # SDSSIM

# %%
N_sim = 100
core.target_var = np.max(Cm)
#core.target_var = np.var(core.data)

core.run_sim(N_sim, core.grid_N, core.C_mm_all, core.C_dd, core.C_dm_all, core.G,
        s_sat.data, core.data, scale_m_i = True, unit_d = False, collect_all = True,
        sense_running_error = True, save_string = nb_name, sim_stochastic = False, solve_cho = True)
# Out:
#  |OOOOOOOOOO| 100.0%   realization nr. 0. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.017 minutes
# Total elapsed time: 16.017 minutes
# Variance: 283320014524.220
# Mean: -11875.588
# Max: 1716419.308
# Min: -1368167.220
# Run nr.: 1
#
#  |OOOOOOOOOO| 100.0%   realization nr. 1. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.381 minutes
# Total elapsed time: 32.398 minutes
# Variance: 279502053536.323
# Mean: -13044.335
# Max: 1744016.994
# Min: -1573997.665
# Run nr.: 2
#
#  |OOOOOOOOOO| 100.0%   realization nr. 2. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.262 minutes
# Total elapsed time: 48.659 minutes
# Variance: 288505520580.855
# Mean: -5607.814
# Max: 1808586.703
# Min: -1454416.791
# Run nr.: 3
#
#  |OOOOOOOOOO| 100.0%   realization nr. 3. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.269 minutes
# Total elapsed time: 1.082 hours
# Variance: 286438510065.588
# Mean: -8124.680
# Max: 1814536.210
# Min: -1484902.985
# Run nr.: 4
#
#  |OOOOOOOOOO| 100.0%   realization nr. 4. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.225 minutes
# Total elapsed time: 1.353 hours
# Variance: 286437418038.992
# Mean: -4177.301
# Max: 1745399.285
# Min: -1706385.743
# Run nr.: 5
#
#  |OOOOOOOOOO| 100.0%   realization nr. 5. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.178 minutes
# Total elapsed time: 1.622 hours
# Variance: 285650690026.924
# Mean: -10693.849
# Max: 1839103.870
# Min: -1441992.579
# Run nr.: 6
#
#  |OOOOOOOOOO| 100.0%   realization nr. 6. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.050 minutes
# Total elapsed time: 1.890 hours
# Variance: 283623861097.478
# Mean: -11185.240
# Max: 1891616.708
# Min: -1788424.409
# Run nr.: 7
#
#  |OOOOOOOOOO| 100.0%   realization nr. 7. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.178 minutes
# Total elapsed time: 2.159 hours
# Variance: 281408886388.525
# Mean: -9063.595
# Max: 1647705.825
# Min: -1685774.712
# Run nr.: 8
#
#  |OOOOOOOOOO| 100.0%   realization nr. 8. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.422 minutes
# Total elapsed time: 2.433 hours
# Variance: 293935425691.159
# Mean: -11823.071
# Max: 1965321.043
# Min: -1748742.055
# Run nr.: 9
#
#  |OOOOOOOOOO| 100.0%   realization nr. 9. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 14.615 minutes
# Total elapsed time: 2.677 hours
# Variance: 281324346006.601
# Mean: -11045.806
# Max: 1754029.787
# Min: -1472091.514
# Run nr.: 10
#
#  |OOOOOOOOOO| 100.0%   realization nr. 10. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.561 minutes
# Total elapsed time: 2.853 hours
# Variance: 292540761176.539
# Mean: -16789.897
# Max: 1633402.527
# Min: -2196354.707
# Run nr.: 11
#
#  |OOOOOOOOOO| 100.0%   realization nr. 11. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.523 minutes
# Total elapsed time: 3.028 hours
# Variance: 289339337521.519
# Mean: -7733.877
# Max: 1706744.784
# Min: -2164906.705
# Run nr.: 12
#
#  |OOOOOOOOOO| 100.0%   realization nr. 12. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.504 minutes
# Total elapsed time: 3.203 hours
# Variance: 283644709619.641
# Mean: -4984.909
# Max: 1598393.192
# Min: -1360857.339
# Run nr.: 13
#
#  |OOOOOOOOOO| 100.0%   realization nr. 13. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.594 minutes
# Total elapsed time: 3.380 hours
# Variance: 281562255847.266
# Mean: -14032.761
# Max: 1812596.655
# Min: -1665309.685
# Run nr.: 14
#
#  |OOOOOOOOOO| 100.0%   realization nr. 14. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.526 minutes
# Total elapsed time: 3.555 hours
# Variance: 289675050580.089
# Mean: -12781.229
# Max: 1633644.965
# Min: -1719034.886
# Run nr.: 15
#
#  |OOOOOOOOOO| 100.0%   realization nr. 15. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.672 minutes
# Total elapsed time: 3.733 hours
# Variance: 281662459288.663
# Mean: -9755.309
# Max: 1753788.722
# Min: -1450233.944
# Run nr.: 16
#
#  |OOOOOOOOOO| 100.0%   realization nr. 16. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.438 minutes
# Total elapsed time: 3.907 hours
# Variance: 278978756364.303
# Mean: -10498.939
# Max: 1724617.307
# Min: -1544084.208
# Run nr.: 17
#
#  |OOOOOOOOOO| 100.0%   realization nr. 17. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.449 minutes
# Total elapsed time: 4.081 hours
# Variance: 285190019329.245
# Mean: -9880.864
# Max: 1841876.041
# Min: -1439594.282
# Run nr.: 18
#
#  |OOOOOOOOOO| 100.0%   realization nr. 18. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.612 minutes
# Total elapsed time: 4.258 hours
# Variance: 294059828030.069
# Mean: -4615.561
# Max: 1894551.125
# Min: -1490145.224
# Run nr.: 19
#
#  |OOOOOOOOOO| 100.0%   realization nr. 19. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.803 minutes
# Total elapsed time: 4.438 hours
# Variance: 281591459097.861
# Mean: -7878.217
# Max: 1689352.697
# Min: -1423986.225
# Run nr.: 20
#
#  |OOOOOOOOOO| 100.0%   realization nr. 20. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 12.253 minutes
# Total elapsed time: 4.642 hours
# Variance: 286563530207.248
# Mean: -11819.080
# Max: 1695564.284
# Min: -2236988.998
# Run nr.: 21
#
#  |OOOOOOOOOO| 100.0%   realization nr. 21. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.645 minutes
# Total elapsed time: 4.820 hours
# Variance: 287522003500.370
# Mean: -7119.242
# Max: 1698013.329
# Min: -1786771.358
# Run nr.: 22
#
#  |OOOOOOOOOO| 100.0%   realization nr. 22. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.508 minutes
# Total elapsed time: 4.995 hours
# Variance: 281473319543.680
# Mean: -14192.230
# Max: 1990230.910
# Min: -1686931.437
# Run nr.: 23
#
#  |OOOOOOOOOO| 100.0%   realization nr. 23. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.622 minutes
# Total elapsed time: 5.172 hours
# Variance: 282907422536.100
# Mean: -11689.941
# Max: 1717342.899
# Min: -1535434.653
# Run nr.: 24
#
#  |OOOOOOOOOO| 100.0%   realization nr. 24. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.671 minutes
# Total elapsed time: 5.350 hours
# Variance: 290111915750.952
# Mean: -6010.982
# Max: 1759692.285
# Min: -1634724.741
# Run nr.: 25
#
#  |OOOOOOOOOO| 100.0%   realization nr. 25. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.625 minutes
# Total elapsed time: 5.527 hours
# Variance: 286988443249.535
# Mean: -10514.835
# Max: 1764686.209
# Min: -1291068.092
# Run nr.: 26
#
#  |OOOOOOOOOO| 100.0%   realization nr. 26. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.475 minutes
# Total elapsed time: 5.701 hours
# Variance: 291986232943.602
# Mean: -11458.850
# Max: 1977870.422
# Min: -1845703.967
# Run nr.: 27
#
#  |OOOOOOOOOO| 100.0%   realization nr. 27. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.475 minutes
# Total elapsed time: 5.876 hours
# Variance: 295425330974.853
# Mean: -12296.774
# Max: 1698322.683
# Min: -1700700.684
# Run nr.: 28
#
#  |OOOOOOOOOO| 100.0%   realization nr. 28. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.465 minutes
# Total elapsed time: 6.050 hours
# Variance: 286545270721.121
# Mean: -11000.322
# Max: 1777148.145
# Min: -1802948.898
# Run nr.: 29
#
#  |OOOOOOOOOO| 100.0%   realization nr. 29. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.469 minutes
# Total elapsed time: 6.225 hours
# Variance: 285878577999.151
# Mean: -9783.800
# Max: 1852458.249
# Min: -1642441.525
# Run nr.: 30
#
#  |OOOOOOOOOO| 100.0%   realization nr. 30. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.854 minutes
# Total elapsed time: 6.406 hours
# Variance: 280528604012.268
# Mean: -12792.119
# Max: 1679104.951
# Min: -1505084.786
# Run nr.: 31
#
#  |OOOOOOOOOO| 100.0%   realization nr. 31. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.629 minutes
# Total elapsed time: 6.583 hours
# Variance: 292048945442.058
# Mean: -4803.515
# Max: 1914816.074
# Min: -1578509.392
# Run nr.: 32
#
#  |OOOOOOOOOO| 100.0%   realization nr. 32. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.924 minutes
# Total elapsed time: 6.765 hours
# Variance: 281501209901.289
# Mean: -8714.682
# Max: 1896483.938
# Min: -1500789.776
# Run nr.: 33
#
#  |OOOOOOOOOO| 100.0%   realization nr. 33. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.882 minutes
# Total elapsed time: 6.946 hours
# Variance: 279930210042.836
# Mean: -13060.949
# Max: 1797848.050
# Min: -1562561.897
# Run nr.: 34
#  |OOOOOOOOOO| 100.0%   realization nr. 34. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.351 minutes
# Total elapsed time: 7.119 hours
# Variance: 279780543980.610
# Mean: -10942.387
# Max: 1601792.086
# Min: -1700921.877
# Run nr.: 35
#
#  |OOOOOOOOOO| 100.0%   realization nr. 35. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.862 minutes
# Total elapsed time: 7.300 hours
# Variance: 294395357520.341
# Mean: -15946.972
# Max: 1797213.782
# Min: -1751566.127
# Run nr.: 36
#
#  |OOOOOOOOOO| 100.0%   realization nr. 36. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 12.145 minutes
# Total elapsed time: 7.502 hours
# Variance: 283764390312.453
# Mean: -7132.878
# Max: 1806118.035
# Min: -1543704.213
# Run nr.: 37
#
#  |OOOOOOOOOO| 100.0%   realization nr. 37. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.495 minutes
# Total elapsed time: 7.677 hours
# Variance: 285181446275.600
# Mean: -7420.288
# Max: 1737793.230
# Min: -1748125.171
# Run nr.: 38
#
#  |OOOOOOOOOO| 100.0%   realization nr. 38. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.542 minutes
# Total elapsed time: 7.853 hours
# Variance: 279956105300.227
# Mean: -16404.613
# Max: 1818226.349
# Min: -1418386.310
# Run nr.: 39
#
#  |OOOOOOOOOO| 100.0%   realization nr. 39. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.161 minutes
# Total elapsed time: 8.039 hours
# Variance: 290359994096.430
# Mean: -4314.057
# Max: 1609735.248
# Min: -1797586.574
# Run nr.: 40
#
#  |OOOOOOOOOO| 100.0%   realization nr. 40. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.826 minutes
# Total elapsed time: 8.236 hours
# Variance: 288585584521.593
# Mean: -1654.150
# Max: 1703440.060
# Min: -1517101.829
# Run nr.: 41
#
#  |OOOOOOOOOO| 100.0%   realization nr. 41. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.567 minutes
# Total elapsed time: 8.412 hours
# Variance: 286737855001.425
# Mean: -13594.071
# Max: 1900287.149
# Min: -1587770.683
# Run nr.: 42
#
#  |OOOOOOOOOO| 100.0%   realization nr. 42. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.570 minutes
# Total elapsed time: 8.588 hours
# Variance: 280956700397.313
# Mean: -8068.372
# Max: 1737554.990
# Min: -1466060.160
# Run nr.: 43
#
#  |OOOOOOOOOO| 100.0%   realization nr. 43. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.530 minutes
# Total elapsed time: 8.764 hours
# Variance: 285101802331.618
# Mean: -9209.356
# Max: 1742221.580
# Min: -1382598.553
# Run nr.: 44
#
#  |OOOOOOOOOO| 100.0%   realization nr. 44. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.516 minutes
# Total elapsed time: 8.939 hours
# Variance: 291076469438.321
# Mean: -6872.454
# Max: 1924443.762
# Min: -1614679.074
# Run nr.: 45
#
#  |OOOOOOOOOO| 100.0%   realization nr. 45. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.515 minutes
# Total elapsed time: 9.114 hours
# Variance: 289973441378.317
# Mean: -8403.231
# Max: 1814837.088
# Min: -1291867.613
# Run nr.: 46
#
#  |OOOOOOOOOO| 100.0%   realization nr. 46. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.506 minutes
# Total elapsed time: 9.289 hours
# Variance: 287941309238.933
# Mean: -11708.463
# Max: 1676529.914
# Min: -1460806.221
# Run nr.: 47
#
#  |OOOOOOOOOO| 100.0%   realization nr. 47. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.525 minutes
# Total elapsed time: 9.465 hours
# Variance: 288961563219.743
# Mean: -8974.312
# Max: 1748934.705
# Min: -1976125.262
# Run nr.: 48
#
#  |OOOOOOOOOO| 100.0%   realization nr. 48. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.568 minutes
# Total elapsed time: 9.641 hours
# Variance: 286304269861.178
# Mean: -7770.717
# Max: 1753594.686
# Min: -1722058.909
# Run nr.: 49
#
#  |OOOOOOOOOO| 100.0%   realization nr. 49. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.360 minutes
# Total elapsed time: 9.830 hours
# Variance: 283924659285.662
# Mean: -11644.381
# Max: 1832621.580
# Min: -1457495.569
# Run nr.: 50
#
#  |OOOOOOOOOO| 100.0%   realization nr. 50. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.758 minutes
# Total elapsed time: 10.010 hours
# Variance: 286786825894.098
# Mean: -10638.707
# Max: 1787001.891
# Min: -1798922.719
# Run nr.: 51
#
#  |OOOOOOOOOO| 100.0%   realization nr. 51. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.543 minutes
# Total elapsed time: 10.185 hours
# Variance: 294765253364.415
# Mean: -7188.100
# Max: 1867350.640
# Min: -2215414.426
# Run nr.: 52
#
#  |OOOOOOOOOO| 100.0%   realization nr. 52. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.552 minutes
# Total elapsed time: 10.361 hours
# Variance: 290488333352.393
# Mean: -10738.232
# Max: 1703607.729
# Min: -2238110.518
# Run nr.: 53
#
#  |OOOOOOOOOO| 100.0%   realization nr. 53. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.591 minutes
# Total elapsed time: 10.538 hours
# Variance: 280544978507.754
# Mean: -9653.765
# Max: 1734550.102
# Min: -1466093.051
# Run nr.: 54
#
#  |OOOOOOOOOO| 100.0%   realization nr. 54. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.516 minutes
# Total elapsed time: 10.713 hours
# Variance: 287190839457.115
# Mean: -15122.125
# Max: 1708194.937
# Min: -1516949.752
# Run nr.: 55
#
#  |OOOOOOOOOO| 100.0%   realization nr. 55. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.594 minutes
# Total elapsed time: 10.889 hours
# Variance: 288725125874.933
# Mean: -10190.034
# Max: 1798433.011
# Min: -1457310.717
# Run nr.: 56
#
#  |OOOOOOOOOO| 100.0%   realization nr. 56. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.582 minutes
# Total elapsed time: 11.066 hours
# Variance: 289304800674.048
# Mean: -3258.606
# Max: 1715477.597
# Min: -1609557.196
# Run nr.: 57
#
#  |OOOOOOOOOO| 100.0%   realization nr. 57. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.579 minutes
# Total elapsed time: 11.242 hours
# Variance: 285178831936.960
# Mean: -11350.654
# Max: 1777969.685
# Min: -1576489.171
# Run nr.: 58
#
#  |OOOOOOOOOO| 100.0%   realization nr. 58. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 12.647 minutes
# Total elapsed time: 11.453 hours
# Variance: 283875909068.898
# Mean: -9861.332
# Max: 1926749.492
# Min: -1724962.361
# Run nr.: 59
#
#  |OOOOOOOOOO| 100.0%   realization nr. 59. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 12.062 minutes
# Total elapsed time: 11.654 hours
# Variance: 287530830587.013
# Mean: -11977.597
# Max: 1826342.404
# Min: -1461605.191
# Run nr.: 60
#
#  |OOOOOOOOOO| 100.0%   realization nr. 60. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.800 minutes
# Total elapsed time: 11.851 hours
# Variance: 276832051580.978
# Mean: -11518.377
# Max: 1645758.140
# Min: -1356641.013
# Run nr.: 61
#
#  |OOOOOOOOOO| 100.0%   realization nr. 61. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.353 minutes
# Total elapsed time: 12.023 hours
# Variance: 279491450084.303
# Mean: -13408.570
# Max: 1851433.440
# Min: -2279981.409
# Run nr.: 62
#
#  |OOOOOOOOOO| 100.0%   realization nr. 62. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.335 minutes
# Total elapsed time: 12.195 hours
# Variance: 285413225962.862
# Mean: -7219.193
# Max: 1781533.297
# Min: -1521226.894
# Run nr.: 63
#
#  |OOOOOOOOOO| 100.0%   realization nr. 63. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.415 minutes
# Total elapsed time: 12.369 hours
# Variance: 284781626420.766
# Mean: -8432.059
# Max: 1938767.965
# Min: -1802889.723
# Run nr.: 64
#
#  |OOOOOOOOOO| 100.0%   realization nr. 64. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.382 minutes
# Total elapsed time: 12.542 hours
# Variance: 284783576741.519
# Mean: -12942.230
# Max: 1740498.333
# Min: -1494753.120
# Run nr.: 65
#
#  |OOOOOOOOOO| 100.0%   realization nr. 65. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.378 minutes
# Total elapsed time: 12.715 hours
# Variance: 295320872533.306
# Mean: -4945.150
# Max: 1769189.729
# Min: -1401402.199
# Run nr.: 66
#
#  |OOOOOOOOOO| 100.0%   realization nr. 66. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.455 minutes
# Total elapsed time: 12.889 hours
# Variance: 293748152749.722
# Mean: -3727.389
# Max: 1847978.282
# Min: -2201221.347
# Run nr.: 67
#
#  |OOOOOOOOOO| 100.0%   realization nr. 67. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.489 minutes
# Total elapsed time: 13.064 hours
# Variance: 289661026463.794
# Mean: -10195.097
# Max: 1755503.754
# Min: -1492551.712
# Run nr.: 68
#  |OOOOOOOOOO| 100.0%   realization nr. 68. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.373 minutes
# Total elapsed time: 13.237 hours
# Variance: 289020184250.898
# Mean: -11635.540
# Max: 1803367.326
# Min: -1426313.164
# Run nr.: 69
#
#  |OOOOOOOOOO| 100.0%   realization nr. 69. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.343 minutes
# Total elapsed time: 13.409 hours
# Variance: 285085329035.734
# Mean: -10149.430
# Max: 1805124.546
# Min: -1784966.771
# Run nr.: 70
#
#  |OOOOOOOOOO| 100.0%   realization nr. 70. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.896 minutes
# Total elapsed time: 13.591 hours
# Variance: 283343449000.164
# Mean: -16452.982
# Max: 1902352.997
# Min: -1556437.808
# Run nr.: 71
#
#  |OOOOOOOOOO| 100.0%   realization nr. 71. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.635 minutes
# Total elapsed time: 13.768 hours
# Variance: 292755435873.717
# Mean: -12861.321
# Max: 1883023.746
# Min: -2245407.827
# Run nr.: 72
#
#  |OOOOOOOOOO| 100.0%   realization nr. 72. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.620 minutes
# Total elapsed time: 13.945 hours
# Variance: 285329166408.132
# Mean: -9416.199
# Max: 1697023.660
# Min: -1770308.099
# Run nr.: 73
#
#  |OOOOOOOOOO| 100.0%   realization nr. 73. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.780 minutes
# Total elapsed time: 14.125 hours
# Variance: 279576967930.950
# Mean: -8989.075
# Max: 1687587.436
# Min: -1412234.171
# Run nr.: 74
#
#  |OOOOOOOOOO| 100.0%   realization nr. 74. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.423 minutes
# Total elapsed time: 14.299 hours
# Variance: 281588725296.795
# Mean: -6220.616
# Max: 1743553.930
# Min: -1496134.419
# Run nr.: 75
#
#  |OOOOOOOOOO| 100.0%   realization nr. 75. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.480 minutes
# Total elapsed time: 14.473 hours
# Variance: 281952962463.508
# Mean: -6916.262
# Max: 1722130.957
# Min: -1415667.063
# Run nr.: 76
#
#  |OOOOOOOOOO| 100.0%   realization nr. 76. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.415 minutes
# Total elapsed time: 14.647 hours
# Variance: 282527498222.825
# Mean: -12602.645
# Max: 1762783.964
# Min: -1397410.574
# Run nr.: 77
#
#  |OOOOOOOOOO| 100.0%   realization nr. 77. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.450 minutes
# Total elapsed time: 14.821 hours
# Variance: 285303812629.231
# Mean: -7662.570
# Max: 1664918.792
# Min: -1661551.794
# Run nr.: 78
#
#  |OOOOOOOOOO| 100.0%   realization nr. 78. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.498 minutes
# Total elapsed time: 14.996 hours
# Variance: 286132924814.258
# Mean: -13759.834
# Max: 1807722.251
# Min: -1465010.851
# Run nr.: 79
#
#  |OOOOOOOOOO| 100.0%   realization nr. 79. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.519 minutes
# Total elapsed time: 15.171 hours
# Variance: 284395610734.461
# Mean: -9980.294
# Max: 1940067.852
# Min: -1415235.536
# Run nr.: 80
#
#  |OOOOOOOOOO| 100.0%   realization nr. 80. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.396 minutes
# Total elapsed time: 15.345 hours
# Variance: 289677090732.862
# Mean: -8489.717
# Max: 1786009.000
# Min: -2107535.743
# Run nr.: 81
#
#  |OOOOOOOOOO| 100.0%   realization nr. 81. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.428 minutes
# Total elapsed time: 15.518 hours
# Variance: 283549875387.611
# Mean: -5638.908
# Max: 1711473.241
# Min: -1438832.502
# Run nr.: 82
#
#  |OOOOOOOOOO| 100.0%   realization nr. 82. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.393 minutes
# Total elapsed time: 15.692 hours
# Variance: 282812365741.069
# Mean: -14923.827
# Max: 1784355.824
# Min: -1472550.622
# Run nr.: 83
#
#  |OOOOOOOOOO| 100.0%   realization nr. 83. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.358 minutes
# Total elapsed time: 15.864 hours
# Variance: 285226804587.523
# Mean: -10746.686
# Max: 1857568.587
# Min: -1401978.587
# Run nr.: 84
#
#  |OOOOOOOOOO| 100.0%   realization nr. 84. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.730 minutes
# Total elapsed time: 16.060 hours
# Variance: 275704852252.942
# Mean: -9635.127
# Max: 1823040.102
# Min: -1419481.564
# Run nr.: 85
#
#  |OOOOOOOOOO| 100.0%   realization nr. 85. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.972 minutes
# Total elapsed time: 16.243 hours
# Variance: 279849914419.288
# Mean: -9938.417
# Max: 1815917.022
# Min: -1738179.278
# Run nr.: 86
#
#  |OOOOOOOOOO| 100.0%   realization nr. 86. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.511 minutes
# Total elapsed time: 16.418 hours
# Variance: 289687978310.701
# Mean: -13008.675
# Max: 1733445.247
# Min: -1806670.014
# Run nr.: 87
#
#  |OOOOOOOOOO| 100.0%   realization nr. 87. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 12.354 minutes
# Total elapsed time: 16.624 hours
# Variance: 300723199015.716
# Mean: -370.607
# Max: 1765422.332
# Min: -1524799.360
# Run nr.: 88
#
#  |OOOOOOOOOO| 100.0%   realization nr. 88. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.382 minutes
# Total elapsed time: 16.797 hours
# Variance: 282921131896.831
# Mean: -12466.419
# Max: 1789901.099
# Min: -2055804.841
# Run nr.: 89
#
#  |OOOOOOOOOO| 100.0%   realization nr. 89. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.386 minutes
# Total elapsed time: 16.970 hours
# Variance: 289845432707.422
# Mean: -8961.473
# Max: 1734276.941
# Min: -2175821.904
# Run nr.: 90
#
#  |OOOOOOOOOO| 100.0%   realization nr. 90. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.297 minutes
# Total elapsed time: 17.141 hours
# Variance: 284492659797.476
# Mean: -12313.732
# Max: 1850965.181
# Min: -1547548.798
# Run nr.: 91
#
#  |OOOOOOOOOO| 100.0%   realization nr. 91. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.491 minutes
# Total elapsed time: 17.316 hours
# Variance: 284882868352.078
# Mean: -11928.961
# Max: 1873005.226
# Min: -1404457.809
# Run nr.: 92
#
#  |OOOOOOOOOO| 100.0%   realization nr. 92. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.984 minutes
# Total elapsed time: 17.516 hours
# Variance: 291829145586.713
# Mean: -6029.875
# Max: 2027291.829
# Min: -1531445.028
# Run nr.: 93
#
#  |OOOOOOOOOO| 100.0%   realization nr. 93. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 11.269 minutes
# Total elapsed time: 17.704 hours
# Variance: 283964533402.360
# Mean: -12459.078
# Max: 1822309.465
# Min: -1700891.462
# Run nr.: 94
#
#  |OOOOOOOOOO| 100.0%   realization nr. 94. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.380 minutes
# Total elapsed time: 17.877 hours
# Variance: 291118899488.240
# Mean: -4840.988
# Max: 1822673.707
# Min: -1606397.760
# Run nr.: 95
#
#  |OOOOOOOOOO| 100.0%   realization nr. 95. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.409 minutes
# Total elapsed time: 18.050 hours
# Variance: 277836527462.744
# Mean: -8716.831
# Max: 1812210.036
# Min: -1622242.181
# Run nr.: 96
#
#  |OOOOOOOOOO| 100.0%   realization nr. 96. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.369 minutes
# Total elapsed time: 18.223 hours
# Variance: 289240570495.276
# Mean: -8272.790
# Max: 1849523.182
# Min: -1501958.416
# Run nr.: 97
#
#  |OOOOOOOOOO| 100.0%   realization nr. 97. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.415 minutes
# Total elapsed time: 18.397 hours
# Variance: 290429633749.509
# Mean: -11014.449
# Max: 1753897.080
# Min: -1463612.321
# Run nr.: 98
#
#  |OOOOOOOOOO| 100.0%   realization nr. 98. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.416 minutes
# Total elapsed time: 18.570 hours
# Variance: 285398669474.636
# Mean: -5623.890
# Max: 1690913.182
# Min: -1398503.713
# Run nr.: 99
#
#  |OOOOOOOOOO| 100.0%   realization nr. 99. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.394 minutes
# Total elapsed time: 18.743 hours
# Variance: 286829934301.000
# Mean: -9981.567
# Max: 1801260.472
# Min: -1542693.099
# Run nr.: 100
#
#
# Seqsim RMSE:	 [[1.97711183 1.97336537 1.97848723 1.9823964  1.98886871 1.97784224
#   1.99543934 1.98463073 1.98042733 1.98680752 1.97919999 2.00376658
#   1.98883145 1.97878962 1.97707929 1.97267224 1.98061379 1.98762744
#   1.98367738 2.00528398 1.98026309 1.97664521 1.9824294  1.99135726
#   1.98825254 1.97687115 1.96972248 1.97409168 1.98496371 1.97723047
#   2.00502595 1.96378452 1.98464032 1.97819517 1.98623852 1.99279071
#   1.98331654 1.99570336 1.97974283 1.98305156 1.98502027 1.97568201
#   1.97607652 1.98181281 1.97036907 1.98430306 1.98097328 1.9961652
#   1.98647632 1.98192156 1.96868414 1.9772001  1.98418633 2.00125943
#   1.97603235 1.97091171 1.98434023 1.98210334 1.99559539 1.97024155
#   1.98148515 1.98431212 2.00568798 1.97949041 1.9980685  1.98548225
#   1.98590656 2.00527149 1.99969941 1.97287669 1.9733584  1.981523
#   1.977346   2.01080851 1.98004242 1.97363394 1.9865917  1.9811247
#   1.98803339 1.97594474 1.96783632 1.99257768 1.97707523 1.98702148
#   1.99034482 1.99513966 1.98719843 1.98768703 1.98183774 1.98306623
#   1.99939207 1.9877258  1.98302291 1.98723472 2.00067072 1.98002888
#   1.99274803 1.99174421 2.00076144 1.96922389]]
# <img src="data:image/png;base64,..." width="640">

# %%
core.realization_to_sh_coeff(core.r_cmb, set_nmax = shc_grid)

# %%
core.covmod_lsq_equiv(s_sat.data, Cm, core.G, core.r_cmb)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)
mt_util.plot_sdssim_reproduce(core, core.m_DSS_res, m_equiv_lsq = core.m_equiv_lsq, truth_obj = s_source,
                              lags_use = 1000, spec_r_at = core.r_cmb, spec_show_differences = False,
                              model_dict = {}, figsize=(9,16),
                              hist_bins = 25, res_bins = 25,
                              savefig = False, save_string = "core_sh30_newTI", save_dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
core.grid_glq(nmax = 400, r_at = core.r_cmb)
#core.grid_glq(nmax = 120, r_at = core.r_cmb)

set_nmax = shc_grid

core.ensemble_B(core.g_spec, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_eqa = core.B_ensemble[:,0,:].copy()

#core.g_spec_mean = np.mean(core.g_spec,axis=1)
core.ensemble_B(core.g_spec_mean, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_mean_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
core.ensemble_B(s_sat.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
prior_eqa = core.B_ensemble[:,0].copy()

core.ensemble_B(core.g_lsq_equiv, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
lsq_eqa = core.B_ensemble[:,0].copy()

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)
# ccrs.PlateCarree()
# ccrs.Mollweide()
# ccrs.Orthographic(central_longitude=0.0, central_latitude=0.0)

mt_util.plot_ensemble_map_tiles(core.grid_phi, 90-core.grid_theta, zs_eqa, 
                        field_compare = prior_eqa, field_lsq = lsq_eqa, field_mean = zs_mean_eqa,
                        tile_size_row = 3, tile_size_column = 2, 
                        figsize=(9,12), limit_for_SF = 10**6, point_size = 0.1, cbar_mm_factor = 2/3,
                        coast_width = 0.4, coast_color = "grey", unit_transform_n_to_m = True,
                        cbar_h = 0.1, cbar_text = "mT", cbar_text_color = "black",
                        left=0.03, bottom=0.12, right=0.97, top=0.95, wspace = 0.05, hspace=0.25, 
                        savefig = False, save_string = "core_sh30_newTI", 
                        projection = ccrs.Mollweide(), use_gridlines = True, 
                        gridlines_width = 0.4, gridlines_alpha = 0.4, save_dpi = 100)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
training_image = core.B_ensemble[:,0].copy()

mt_util.plot_global(lat = 90-core.grid_theta, lon = core.grid_phi, data=training_image, 
                cbar_h = 0.075, cbar_mm_factor = 2/3, unit_transform_n_to_m = True,
                cbar_text = "mT", figsize=(6,6), coast_width = 0.4,
                bottom=0.35, top=0.95, hspace=0.01,
                title='Training image', point_size=1,
                savefig = False, save_dpi = 100, save_string ="core_sh30_synth_TI",
                use_gridlines = True, gridlines_width = 0.4, gridlines_alpha = 0.4)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
np.min(core.sph_d[core.sph_d>0.0])
# Out:
# 27.325697459670902
