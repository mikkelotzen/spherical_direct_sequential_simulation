# %%
# %matplotlib notebook

from sdss import SDSS
import mikkel_tools.utility as mt_util
import plot as sds_plt

import numpy as np
#import cupy as cp
import scipy as sp
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

import pyshtools
import pickle

comment = "Finding sparsity by digging into histogram reproduction"
nb_name = "nb_seqsim_find_sparsity_condtab_digging"

# %% [markdown]
# # Core

# %%
core = SDSS(comment, N_SH = 30, sim_type = "core", sat_height = 350)

core.grid_glq(nmax = 30, r_at = core.r_cmb)

grid_in = np.array([core.grid_glq_phi, 90-core.grid_glq_theta]).T
core.make_grid(core.r_cmb, grid_in, calc_sph_d = True)

# %%
core.generate_map()

# %%
mt_util.plot_cartopy_global(lat = core.lat, lon = core.lon, plot_quality = "high", 
                            data=core.data, point_size=10, shift_grid = True, 
                            transpose_grid = True, shape = (121,61), cmap = 'PuOr_r', 
                            title="Prior radial lithosphere information")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
core.condtab(normsize=10*len(core.data), quantiles = len(core.data))

# %%
core.semivar(model_lags = "all", model = "exponential", max_dist = 20000, lag_length = 200,
             zero_nugget = True, hit_target_var = True)
# Out:
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 200.0 km
# Number of lags: 54
# Number of modelling lags: all
#
# Semi-variogram model determined, starting LUT computation

# %%
core.semivar(model_lags = "all", model = "exponential", max_dist = 20000, lag_length = 200,
             zero_nugget = True, hit_target_var = True)

keep_sv_curve = core.sv_curve.copy()
keep_lags_sv_curve = core.lags_sv_curve.copy()

set_model = {"a": 1000, "C0": 0, "C1": core.target_var, "C2": None, "C3": None}

core.semivar(model_lags = 20, model = "exponential", max_dist = 20000, lag_length = 200,
             zero_nugget = True, hit_target_var = True, set_model = set_model)



#%% PLOT SEMI-VARIOGRAM
plt.figure(figsize=(10,8)) 
plt.plot(core.lags,core.pics,'o', markersize=10,color = '0.85',label='data semi-variogram')
plt.plot(core.lags_model,core.pics_model,'.',markersize=10,label='modelling data')
plt.plot(core.lags_sv_curve,core.sv_curve,color='C3', linewidth = 3,label='model')
plt.plot(keep_lags_sv_curve,keep_sv_curve,"--",color='C1',linewidth = 3,label='model large lag')

plt.plot(core.lags_sv_curve,np.ones(core.lags_sv_curve.shape)*core.target_var,linewidth = 3, color="C2", label="target histogram variance")
plt.ylabel('Semi-variance $[%s^2]$' % "nT",fontsize=18,labelpad=18)
plt.xlabel('Lag [km]',fontsize=18,labelpad=18)
plt.title("Semi-variogram model of type: %s " % core.model_names[core.model],fontsize=18,y=1.02)
plt.legend(loc='best',fontsize=18)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
plt.show()
# Out:
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 200.0 km
# Number of lags: 54
# Number of modelling lags: all
#
# Semi-variogram model determined, starting LUT computation
#
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 200.0 km
# Number of lags: 54
# Number of modelling lags: 20
#
# Semi-variogram model determined, starting LUT computation
# <img src="data:image/png;base64,..." width="1000">

# %%
print(core)
# Out:
# ______current attributes______
#
# a:                     6371.2
# r_sat:                 6721.2
# r_cmb:                 3480.0
# rad:                   0.017453292519943295
# mu0:                   1.2566370614359173e-06
# comment:               Finding sparsity by digging into histogram reproduction
# class_abs_path:        /home/mikotz/spherical_direct_sequential_simulation
# N_SH:                  30
# N_SH_secondary:        None
# sim_type:              core
# grid_glq_zero:         (31,), Max/Min: 1.00 / -1.00
# grid_glq_w_shtools:    (31,), Max/Min: 0.10 / 0.01
# grid_glq_shape:        (2,), Max/Min: 61.00 / 31.00
# grid_glq_w:            (1891,), Max/Min: 0.10 / 0.01
# grid_glq_radial:       (1891,), Max/Min: 3480.00 / 3480.00
# grid_glq_theta:        (1891,), Max/Min: 175.63 / 4.37
# grid_glq_phi:          (1891,), Max/Min: 354.10 / 0.00
# grid_glq_N:            1891
# grid_glq_nmax:         30
# r_grid:                3480.0
# grid:                  (1891, 2)
# sph_d:                 (1891, 1891)
# lon:                   (1891,), Max/Min: 354.10 / 0.00
# lat:                   (1891,), Max/Min: 85.63 / -85.63
# N_grid:                1891
# data:                  (1891,), Max/Min: 2717914.01 / -1655937.04
# r_grid_repeat:         (1891,), Max/Min: 3480.00 / 3480.00
# target_var:            281134270951.117
# target_mean_true:      -10745.550297945754
# target_mean:           0.0
# g_prior:               (960,), Max/Min: 5004.71 / -51832.17
# CQF_dist:              (501, 101, 18910)
# CQF_mean:              (501, 101)
# CQF_var:               (501, 101)
# rangv:                 (101,), Max/Min: 2.00 / 0.00
# rangn:                 (501,), Max/Min: 3.50 / -3.50
# condtab_normsize:      18910
# condtab_model_hist:    False
# condtab_table:         rough
# sv_model_lags:         20
# sv_max_dist:           20000
# sv_lag_length:         20
# sv_zero_nugget:        True
# sort_d:                (3575881,), Max/Min: 3575880.00 / 0.00
# cloud_sorted:          (3575881,), Max/Min: 19130572965571.12 / 0.00
# sph_d_sorted:          (3575881,), Max/Min: 10919.08 / 0.00
# max_cloud:             3575881
# n_lags:                545
# lags:                  (544,), Max/Min: 10614.61 / 0.00
# pics:                  (544,), Max/Min: 593552407658.02 / 0.00
# model_select_simple:   False
# model_select_advanced: False
# lags_model:            (53,), Max/Min: 9969.47 / 0.00
# pics_model:            (53,), Max/Min: 458649364791.58 / 0.00
# lags_sv_curve:         (544,), Max/Min: 10615.00 / 0.00
# sv_curve:              (544,), Max/Min: 281134270951.12 / 0.00
# sv_lut:                (1891, 1891)
# model:                 spherical
# a_sv:                  1000
# C0:                    0
# C1:                    281134270951.117
# C2:                    None
# C3:                    None
# G:                     (2773, 1891)
# C_mm_all:              (1891, 1891)
# C_dd:                  (2773, 2773)
# C_dm_all:              (1891, 2773)
# C_e_const:             2
# N_sim:                 1
# idx_nv_collect:        (1891, 2)
# m_DSS:                 (1891, 1), Max/Min: 1786876.50 / -1522982.89
# m_DSS_pred:            (2773, 1), Max/Min: 85907.04 / -84354.68
# m_DSS_res:             (2773, 1), Max/Min: 7.38 / -6.77
# g_spec:                (960, 1), Max/Min: 5004.51 / -51832.33
# g_spec_mean:           (960,), Max/Min: 5004.51 / -51832.33
# m_equiv_lsq:           (1891, 1), Max/Min: 1676130.83 / -1129417.28
# lsq_equiv_pred:        (2773, 1), Max/Min: 85907.48 / -84355.15
# lsq_equiv_res:         (2773, 1), Max/Min: 6.45 / -6.75
# g_lsq_equiv:           (960,), Max/Min: 5004.61 / -51832.54
# pics_m_DSS:            (53, 1), Max/Min: 458649364791.58 / 0.00

# %% [markdown]
# # Synthetic sat

# %%
s_sat = SDSS(comment, N_SH = 30, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_sat.load_swarm("A")

grid_in = np.array([s_sat.swarm_phi, 90-s_sat.swarm_theta]).T
s_sat.make_grid(s_sat.swarm_radius, grid_in, calc_sph_d = False)

#s_sat.grid_equal_area(N_grid= 500, r_at = s_sat.r_sat, poles_remove = True)
#grid_in = np.array([s_sat.grid_eqa_phi, 90-s_sat.grid_eqa_theta]).T
#s_sat.grid(s_sat.r_sat, grid_in, calc_sph_d = False)

# %%
s_sat.generate_map(grid_type = "swarm")

# %%
C_e_const = 2

s_sat.data += np.random.normal(scale = C_e_const, size = s_sat.data.shape)

# %%
mt_util.plot_cartopy_global(lat = s_sat.lat, lon = s_sat.lon, plot_quality = "high", point_size=5, 
                            data=s_sat.data, cmap = 'PuOr_r', title="Synthetic satellite data")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
print(s_sat)
# Out:
# ______current attributes______
#
# a:                6371.2
# r_sat:            6721.2
# r_cmb:            3480.0
# rad:              0.017453292519943295
# mu0:              1.2566370614359173e-06
# comment:          Finding sparsity by digging into histogram reproduction
# class_abs_path:   /home/mikotz/spherical_direct_sequential_simulation
# N_SH:             30
# N_SH_secondary:   None
# sim_type:         core
# swarm_theta:      (2773,), Max/Min: 177.35 / 22.39
# swarm_phi:        (2773,), Max/Min: 179.68 / -179.59
# swarm_radius:     (2773,), Max/Min: 6825.19 / 6806.85
# swarm_obs:        (2773,), Max/Min: 53117.43 / -48881.72
# swarm_N:          2773
# r_grid:           (2773,), Max/Min: 6825.19 / 6806.85
# grid:             (2773, 2)
# sph_d:            None
# lon:              (2773,), Max/Min: 179.68 / -179.59
# lat:              (2773,), Max/Min: 67.61 / -87.35
# N_grid:           2773
# B_ensemble_swarm: (2773, 3)
# data:             (2773,), Max/Min: 85907.02 / -84353.11
# target_var:       2650032519.9717584
# target_mean_true: 18356.49194207425
# target_mean:      0.0
# g_prior:          (960,), Max/Min: 5004.71 / -51832.17

# %%
core.integrating_kernel(s_sat, C_e_const = C_e_const)
# Out:
# Gauss-Legendre RMSE:	 2.041062509950
# <img src="data:image/png;base64,..." width="640">

# %%
N_sim = 100

core.run_sim(N_sim, core.grid_glq_N, core.C_mm_all, core.C_dd, core.C_dm_all, core.G,
        s_sat.data, core.data, scale_m_i = True, unit_d = True, return_idx = True,
        sense_running_error = True, save_string = nb_name)
# Out:
#  |OOOOOOOOOO| 100.0%   realization nr. 0. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.651 minutes
# Total elapsed time: 8.651 minutes
# Variance: 373666626030.719
# Mean: -14642.891
# Max: 2463706.151
# Min: -1667171.674
# Run nr.: 1
#
#  |OOOOOOOOOO| 100.0%   realization nr. 1. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.499 minutes
# Total elapsed time: 17.150 minutes
# Variance: 368033930256.735
# Mean: -15579.912
# Max: 2651828.273
# Min: -1634651.409
# Run nr.: 2
#
#  |OOOOOOOOOO| 100.0%   realization nr. 2. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.546 minutes
# Total elapsed time: 25.696 minutes
# Variance: 374880175002.587
# Mean: -12403.343
# Max: 2133217.324
# Min: -1668621.353
# Run nr.: 3
#
#  |OOOOOOOOOO| 100.0%   realization nr. 3. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.505 minutes
# Total elapsed time: 34.202 minutes
# Variance: 365514611439.674
# Mean: -7791.371
# Max: 2071886.282
# Min: -1664934.808
# Run nr.: 4
#
#  |OOOOOOOOOO| 100.0%   realization nr. 4. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.586 minutes
# Total elapsed time: 42.787 minutes
# Variance: 388114341906.578
# Mean: -4410.044
# Max: 2628397.099
# Min: -1759092.525
# Run nr.: 5
#
#  |OOOOOOOOOO| 100.0%   realization nr. 5. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.574 minutes
# Total elapsed time: 51.361 minutes
# Variance: 378625656312.474
# Mean: -7833.258
# Max: 2341929.877
# Min: -1651234.747
# Run nr.: 6
#
#  |OOOOOOOOOO| 100.0%   realization nr. 6. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.484 minutes
# Total elapsed time: 59.845 minutes
# Variance: 381658498805.857
# Mean: -11046.544
# Max: 1938304.766
# Min: -1933061.306
# Run nr.: 7
#
#  |OOOOOOOOOO| 100.0%   realization nr. 7. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.370 minutes
# Total elapsed time: 1.137 hours
# Variance: 368907186218.112
# Mean: -9905.440
# Max: 1888199.173
# Min: -1646891.039
# Run nr.: 8
#
#  |OOOOOOOOOO| 100.0%   realization nr. 8. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.489 minutes
# Total elapsed time: 1.278 hours
# Variance: 369740093199.241
# Mean: -10251.816
# Max: 1982738.232
# Min: -1749180.883
# Run nr.: 9
#
#  |OOOOOOOOOO| 100.0%   realization nr. 9. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.389 minutes
# Total elapsed time: 1.418 hours
# Variance: 369624316555.812
# Mean: -14877.861
# Max: 2211057.016
# Min: -1695547.718
# Run nr.: 10
#
#  |OOOOOOOOOO| 100.0%   realization nr. 10. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.501 minutes
# Total elapsed time: 1.560 hours
# Variance: 384344143982.773
# Mean: -9375.390
# Max: 2477184.772
# Min: -1634131.882
# Run nr.: 11
#
#  |OOOOOOOOOO| 100.0%   realization nr. 11. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.521 minutes
# Total elapsed time: 1.702 hours
# Variance: 370375199900.631
# Mean: -9077.660
# Max: 1998386.208
# Min: -1616873.510
# Run nr.: 12
#
#  |OOOOOOOOOO| 100.0%   realization nr. 12. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.385 minutes
# Total elapsed time: 1.842 hours
# Variance: 371054879058.705
# Mean: -11625.760
# Max: 2700552.700
# Min: -1652932.609
# Run nr.: 13
#
#  |OOOOOOOOOO| 100.0%   realization nr. 13. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.361 minutes
# Total elapsed time: 1.981 hours
# Variance: 359144396391.980
# Mean: -9577.822
# Max: 2528701.844
# Min: -1663557.330
# Run nr.: 14
#
#  |OOOOOOOOOO| 100.0%   realization nr. 14. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.418 minutes
# Total elapsed time: 2.121 hours
# Variance: 367219013124.543
# Mean: -15732.218
# Max: 2195020.875
# Min: -1637591.580
# Run nr.: 15
#
#  |OOOOOOOOOO| 100.0%   realization nr. 15. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.455 minutes
# Total elapsed time: 2.262 hours
# Variance: 369888093158.007
# Mean: -10211.526
# Max: 1963767.786
# Min: -1706331.509
# Run nr.: 16
#
#  |OOOOOOOOOO| 100.0%   realization nr. 16. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.343 minutes
# Total elapsed time: 2.401 hours
# Variance: 376474052724.582
# Mean: -9257.699
# Max: 2622805.384
# Min: -1870219.288
# Run nr.: 17
#
#  |OOOOOOOOOO| 100.0%   realization nr. 17. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.407 minutes
# Total elapsed time: 2.541 hours
# Variance: 385111033395.603
# Mean: -14438.549
# Max: 2040553.643
# Min: -1644485.384
# Run nr.: 18
#
#  |OOOOOOOOOO| 100.0%   realization nr. 18. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.324 minutes
# Total elapsed time: 2.680 hours
# Variance: 361047149436.978
# Mean: -8609.664
# Max: 1869919.899
# Min: -1641983.130
# Run nr.: 19
#
#  |OOOOOOOOOO| 100.0%   realization nr. 19. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.402 minutes
# Total elapsed time: 2.820 hours
# Variance: 385078032278.288
# Mean: -17418.937
# Max: 2651424.687
# Min: -1900472.059
# Run nr.: 20
#
#  |OOOOOOOOOO| 100.0%   realization nr. 20. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.372 minutes
# Total elapsed time: 2.960 hours
# Variance: 374241354204.068
# Mean: -11902.434
# Max: 2698665.354
# Min: -1776907.609
# Run nr.: 21
#
#  |OOOOOOOOOO| 100.0%   realization nr. 21. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.392 minutes
# Total elapsed time: 3.100 hours
# Variance: 367181997093.728
# Mean: -12195.727
# Max: 1919879.211
# Min: -1660012.368
# Run nr.: 22
#
#  |OOOOOOOOOO| 100.0%   realization nr. 22. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.302 minutes
# Total elapsed time: 3.238 hours
# Variance: 376345102929.243
# Mean: -9732.319
# Max: 2534400.757
# Min: -2011246.484
# Run nr.: 23
#
#  |OOOOOOOOOO| 100.0%   realization nr. 23. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.356 minutes
# Total elapsed time: 3.377 hours
# Variance: 380255661122.972
# Mean: -9676.065
# Max: 2333927.506
# Min: -1708006.642
# Run nr.: 24
#
#  |OOOOOOOOOO| 100.0%   realization nr. 24. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.629 minutes
# Total elapsed time: 3.521 hours
# Variance: 375978317110.955
# Mean: -9034.091
# Max: 2510561.635
# Min: -1776613.392
# Run nr.: 25
#
#  |OOOOOOOOOO| 100.0%   realization nr. 25. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 9.083 minutes
# Total elapsed time: 3.672 hours
# Variance: 370321980047.905
# Mean: -13670.543
# Max: 2522867.517
# Min: -1666555.016
# Run nr.: 26
#
#  |OOOOOOOOOO| 100.0%   realization nr. 26. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 9.557 minutes
# Total elapsed time: 3.832 hours
# Variance: 374250660687.490
# Mean: -8826.838
# Max: 2393797.168
# Min: -1656479.177
# Run nr.: 27
#
#  |OOOOOOOOOO| 100.0%   realization nr. 27. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.651 minutes
# Total elapsed time: 3.993 hours
# Variance: 393159645075.229
# Mean: -11326.293
# Max: 1866314.079
# Min: -1805202.395
# Run nr.: 28
#
#  |OOOOOOOOOO| 100.0%   realization nr. 28. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.542 minutes
# Total elapsed time: 4.152 hours
# Variance: 389781260408.925
# Mean: -12618.012
# Max: 2199559.945
# Min: -2235034.180
# Run nr.: 29
#
#  |OOOOOOOOOO| 100.0%   realization nr. 29. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.560 minutes
# Total elapsed time: 4.311 hours
# Variance: 379512241102.126
# Mean: -9881.808
# Max: 2582732.671
# Min: -1982784.149
# Run nr.: 30
#
#  |OOOOOOOOOO| 100.0%   realization nr. 30. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.640 minutes
# Total elapsed time: 4.472 hours
# Variance: 380022461086.495
# Mean: -14588.669
# Max: 2309812.589
# Min: -1892797.297
# Run nr.: 31
#
#  |OOOOOOOOOO| 100.0%   realization nr. 31. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 9.536 minutes
# Total elapsed time: 4.630 hours
# Variance: 361018872531.293
# Mean: -7628.518
# Max: 2279725.575
# Min: -1639978.432
# Run nr.: 32
#
#  |OOOOOOOOOO| 100.0%   realization nr. 32. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 9.622 minutes
# Total elapsed time: 4.791 hours
# Variance: 370261970438.406
# Mean: -8295.661
# Max: 1900696.112
# Min: -1632369.313
# Run nr.: 33
#
#  |OOOOOOOOOO| 100.0%   realization nr. 33. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 9.633 minutes
# Total elapsed time: 4.951 hours
# Variance: 363831936935.486
# Mean: -8991.104
# Max: 2164922.131
# Min: -1649649.564
# Run nr.: 34
#  |OOOOOOOOOO| 100.0%   realization nr. 34. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.565 minutes
# Total elapsed time: 5.111 hours
# Variance: 382155731669.877
# Mean: -9816.482
# Max: 1872841.882
# Min: -2126245.396
# Run nr.: 35
#
#  |OOOOOOOOOO| 100.0%   realization nr. 35. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 9.691 minutes
# Total elapsed time: 5.272 hours
# Variance: 367366027934.466
# Mean: -6927.131
# Max: 2498806.185
# Min: -1633191.706
# Run nr.: 36
#
#  |OOOOOOOOOO| 100.0%   realization nr. 36. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.595 minutes
# Total elapsed time: 5.432 hours
# Variance: 381500408773.494
# Mean: -16273.593
# Max: 2537115.424
# Min: -1883015.309
# Run nr.: 37
#
#  |OOOOOOOOOO| 100.0%   realization nr. 37. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 9.676 minutes
# Total elapsed time: 5.594 hours
# Variance: 366332283546.102
# Mean: -13314.407
# Max: 1930467.605
# Min: -1651779.382
# Run nr.: 38
#
#  |OOOOOOOOOO| 100.0%   realization nr. 38. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 9.580 minutes
# Total elapsed time: 5.753 hours
# Variance: 361146708504.900
# Mean: -9443.064
# Max: 2585177.216
# Min: -1623648.482
# Run nr.: 39
#
#  |OOOOOOOOOO| 100.0%   realization nr. 39. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 9.605 minutes
# Total elapsed time: 5.913 hours
# Variance: 376948199708.138
# Mean: -10117.897
# Max: 2650763.329
# Min: -2053627.508
# Run nr.: 40
#
#  |OOOOOOOOOO| 100.0%   realization nr. 40. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 9.546 minutes
# Total elapsed time: 6.072 hours
# Variance: 370301441503.418
# Mean: -11530.972
# Max: 2486139.383
# Min: -1712186.232
# Run nr.: 41
#
#  |OOOOOOOOOO| 100.0%   realization nr. 41. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 9.605 minutes
# Total elapsed time: 6.232 hours
# Variance: 382406175449.149
# Mean: -7406.076
# Max: 1995360.120
# Min: -1907707.065
# Run nr.: 42
#
#  |OOOOOOOOOO| 100.0%   realization nr. 42. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 9.664 minutes
# Total elapsed time: 6.394 hours
# Variance: 370932574922.759
# Mean: -13820.259
# Max: 2354256.554
# Min: -1638330.211
# Run nr.: 43
#
#  |OOOOOOOOOO| 100.0%   realization nr. 43. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 9.572 minutes
# Total elapsed time: 6.553 hours
# Variance: 365842779342.878
# Mean: -14965.351
# Max: 1917427.962
# Min: -1652516.990
# Run nr.: 44
#
#  |OOOOOOOOOO| 100.0%   realization nr. 44. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.732 minutes
# Total elapsed time: 6.715 hours
# Variance: 369200579520.151
# Mean: -14644.123
# Max: 2375762.672
# Min: -1777874.116
# Run nr.: 45
#
#  |OOOOOOOOOO| 100.0%   realization nr. 45. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 8.997 minutes
# Total elapsed time: 6.865 hours
# Variance: 369539838162.279
# Mean: -6607.541
# Max: 1911172.387
# Min: -2002859.657
# Run nr.: 46
#
#  |OOOOOOOOOO| 100.0%   realization nr. 46. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.943 minutes
# Total elapsed time: 6.998 hours
# Variance: 380775575340.185
# Mean: -10810.268
# Max: 2007244.183
# Min: -1650439.513
# Run nr.: 47
#
#  |OOOOOOOOOO| 100.0%   realization nr. 47. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.921 minutes
# Total elapsed time: 7.130 hours
# Variance: 372538802010.217
# Mean: -4732.134
# Max: 2304491.596
# Min: -1666972.130
# Run nr.: 48
#
#  |OOOOOOOOOO| 100.0%   realization nr. 48. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.932 minutes
# Total elapsed time: 7.262 hours
# Variance: 378143294186.786
# Mean: -9282.436
# Max: 2014917.501
# Min: -1658048.573
# Run nr.: 49
#
#  |OOOOOOOOOO| 100.0%   realization nr. 49. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.939 minutes
# Total elapsed time: 7.394 hours
# Variance: 371848487445.006
# Mean: -13409.856
# Max: 2596972.446
# Min: -1666933.047
# Run nr.: 50
#
#  |OOOOOOOOOO| 100.0%   realization nr. 50. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.942 minutes
# Total elapsed time: 7.526 hours
# Variance: 369178744044.827
# Mean: -10517.049
# Max: 2004640.577
# Min: -1644496.408
# Run nr.: 51
#
#  |OOOOOOOOOO| 100.0%   realization nr. 51. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.924 minutes
# Total elapsed time: 7.659 hours
# Variance: 368268693977.890
# Mean: -5262.409
# Max: 2466152.537
# Min: -1644908.328
# Run nr.: 52
#
#  |OOOOOOOOOO| 100.0%   realization nr. 52. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.952 minutes
# Total elapsed time: 7.791 hours
# Variance: 376309175993.405
# Mean: -7282.553
# Max: 2711733.440
# Min: -1944507.949
# Run nr.: 53
#
#  |OOOOOOOOOO| 100.0%   realization nr. 53. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.944 minutes
# Total elapsed time: 7.923 hours
# Variance: 371675230550.994
# Mean: -9803.897
# Max: 2193364.538
# Min: -2043117.908
# Run nr.: 54
#
#  |OOOOOOOOOO| 100.0%   realization nr. 54. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.936 minutes
# Total elapsed time: 8.056 hours
# Variance: 381292369980.618
# Mean: -10541.404
# Max: 2380966.024
# Min: -1777829.351
# Run nr.: 55
#
#  |OOOOOOOOOO| 100.0%   realization nr. 55. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.907 minutes
# Total elapsed time: 8.188 hours
# Variance: 363057340030.976
# Mean: -8531.953
# Max: 1881650.712
# Min: -1815164.054
# Run nr.: 56
#
#  |OOOOOOOOOO| 100.0%   realization nr. 56. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.921 minutes
# Total elapsed time: 8.320 hours
# Variance: 372211625030.188
# Mean: -12196.348
# Max: 1967554.165
# Min: -1657761.012
# Run nr.: 57
#
#  |OOOOOOOOOO| 100.0%   realization nr. 57. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.960 minutes
# Total elapsed time: 8.452 hours
# Variance: 376345202035.765
# Mean: -12139.197
# Max: 2639193.192
# Min: -1935293.256
# Run nr.: 58
#
#  |OOOOOOOOOO| 100.0%   realization nr. 58. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.929 minutes
# Total elapsed time: 8.584 hours
# Variance: 374198175714.923
# Mean: -9979.399
# Max: 1908288.787
# Min: -1873521.416
# Run nr.: 59
#
#  |OOOOOOOOOO| 100.0%   realization nr. 59. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.920 minutes
# Total elapsed time: 8.716 hours
# Variance: 378294287454.347
# Mean: -8916.052
# Max: 1930404.732
# Min: -1899600.779
# Run nr.: 60
#
#  |OOOOOOOOOO| 100.0%   realization nr. 60. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.941 minutes
# Total elapsed time: 8.849 hours
# Variance: 370106349743.106
# Mean: -12500.246
# Max: 1925170.846
# Min: -1672130.509
# Run nr.: 61
#
#  |OOOOOOOOOO| 100.0%   realization nr. 61. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.963 minutes
# Total elapsed time: 8.981 hours
# Variance: 378118499068.908
# Mean: -9231.220
# Max: 2406261.773
# Min: -1758971.539
# Run nr.: 62
#
#  |OOOOOOOOOO| 100.0%   realization nr. 62. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.931 minutes
# Total elapsed time: 9.114 hours
# Variance: 369679899069.765
# Mean: -11408.758
# Max: 2269737.526
# Min: -1723937.235
# Run nr.: 63
#
#  |OOOOOOOOOO| 100.0%   realization nr. 63. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.925 minutes
# Total elapsed time: 9.246 hours
# Variance: 374732825802.530
# Mean: -4839.460
# Max: 2076459.981
# Min: -1690232.056
# Run nr.: 64
#
#  |OOOOOOOOOO| 100.0%   realization nr. 64. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.903 minutes
# Total elapsed time: 9.377 hours
# Variance: 377199356704.033
# Mean: -8590.313
# Max: 2379174.842
# Min: -1739244.709
# Run nr.: 65
#
#  |OOOOOOOOOO| 100.0%   realization nr. 65. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.906 minutes
# Total elapsed time: 9.509 hours
# Variance: 388504803245.792
# Mean: -7490.943
# Max: 2404721.903
# Min: -1693814.815
# Run nr.: 66
#
#  |OOOOOOOOOO| 100.0%   realization nr. 66. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.923 minutes
# Total elapsed time: 9.641 hours
# Variance: 379553915133.890
# Mean: -11128.542
# Max: 2774138.904
# Min: -2042283.467
# Run nr.: 67
#
#  |OOOOOOOOOO| 100.0%   realization nr. 67. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.912 minutes
# Total elapsed time: 9.773 hours
# Variance: 367025999156.589
# Mean: -13848.757
# Max: 2377711.196
# Min: -1863184.889
# Run nr.: 68
#  |OOOOOOOOOO| 100.0%   realization nr. 68. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.937 minutes
# Total elapsed time: 9.905 hours
# Variance: 383427866463.582
# Mean: -8649.174
# Max: 1978734.451
# Min: -1607172.913
# Run nr.: 69
#
#  |OOOOOOOOOO| 100.0%   realization nr. 69. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.963 minutes
# Total elapsed time: 10.038 hours
# Variance: 372111698510.711
# Mean: -11460.056
# Max: 2232558.566
# Min: -1657136.819
# Run nr.: 70
#
#  |OOOOOOOOOO| 100.0%   realization nr. 70. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.926 minutes
# Total elapsed time: 10.170 hours
# Variance: 388157621941.117
# Mean: -7976.316
# Max: 2568285.881
# Min: -1759959.310
# Run nr.: 71
#
#  |OOOOOOOOOO| 100.0%   realization nr. 71. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.922 minutes
# Total elapsed time: 10.302 hours
# Variance: 368931279072.236
# Mean: -7564.340
# Max: 2069894.608
# Min: -1650972.864
# Run nr.: 72
#
#  |OOOOOOOOOO| 100.0%   realization nr. 72. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.958 minutes
# Total elapsed time: 10.435 hours
# Variance: 376972627259.745
# Mean: -5726.739
# Max: 1914825.052
# Min: -1711838.846
# Run nr.: 73
#
#  |OOOOOOOOOO| 100.0%   realization nr. 73. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.941 minutes
# Total elapsed time: 10.567 hours
# Variance: 373507377538.983
# Mean: -14459.425
# Max: 1967944.963
# Min: -1820379.058
# Run nr.: 74
#
#  |OOOOOOOOOO| 100.0%   realization nr. 74. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.944 minutes
# Total elapsed time: 10.700 hours
# Variance: 369108811463.337
# Mean: -13687.926
# Max: 2673020.766
# Min: -1704915.585
# Run nr.: 75
#
#  |OOOOOOOOOO| 100.0%   realization nr. 75. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.946 minutes
# Total elapsed time: 10.832 hours
# Variance: 366181686761.661
# Mean: -10051.235
# Max: 2104186.968
# Min: -1627701.284
# Run nr.: 76
#
#  |OOOOOOOOOO| 100.0%   realization nr. 76. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.943 minutes
# Total elapsed time: 10.964 hours
# Variance: 366426065771.384
# Mean: -9820.402
# Max: 2207215.611
# Min: -1658057.190
# Run nr.: 77
#
#  |OOOOOOOOOO| 100.0%   realization nr. 77. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.929 minutes
# Total elapsed time: 11.097 hours
# Variance: 372214976031.581
# Mean: -7456.394
# Max: 2693848.095
# Min: -1650030.937
# Run nr.: 78
#
#  |OOOOOOOOOO| 100.0%   realization nr. 78. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.906 minutes
# Total elapsed time: 11.228 hours
# Variance: 381620017736.197
# Mean: -19834.555
# Max: 2209888.587
# Min: -1896242.862
# Run nr.: 79
#
#  |OOOOOOOOOO| 100.0%   realization nr. 79. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.920 minutes
# Total elapsed time: 11.360 hours
# Variance: 366616838355.940
# Mean: -9589.650
# Max: 2633217.195
# Min: -1788096.628
# Run nr.: 80
#
#  |OOOOOOOOOO| 100.0%   realization nr. 80. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.926 minutes
# Total elapsed time: 11.492 hours
# Variance: 377785092026.070
# Mean: -6477.014
# Max: 2727127.722
# Min: -1698271.771
# Run nr.: 81
#
#  |OOOOOOOOOO| 100.0%   realization nr. 81. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.922 minutes
# Total elapsed time: 11.625 hours
# Variance: 392998021313.109
# Mean: -9764.349
# Max: 2472050.829
# Min: -2168837.456
# Run nr.: 82
#
#  |OOOOOOOOOO| 100.0%   realization nr. 82. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.917 minutes
# Total elapsed time: 11.756 hours
# Variance: 372198006179.899
# Mean: -13012.579
# Max: 2585038.432
# Min: -1736115.543
# Run nr.: 83
#
#  |OOOOOOOOOO| 100.0%   realization nr. 83. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.924 minutes
# Total elapsed time: 11.889 hours
# Variance: 367621671178.769
# Mean: -10808.485
# Max: 2088479.033
# Min: -1643698.597
# Run nr.: 84
#
#  |OOOOOOOOOO| 100.0%   realization nr. 84. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.895 minutes
# Total elapsed time: 12.020 hours
# Variance: 363199599673.615
# Mean: -5793.292
# Max: 1855308.085
# Min: -1670006.163
# Run nr.: 85
#
#  |OOOOOOOOOO| 100.0%   realization nr. 85. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.927 minutes
# Total elapsed time: 12.152 hours
# Variance: 374304965618.313
# Mean: -6268.512
# Max: 2558731.515
# Min: -1782052.254
# Run nr.: 86
#
#  |OOOOOOOOOO| 100.0%   realization nr. 86. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.899 minutes
# Total elapsed time: 12.284 hours
# Variance: 366585069806.418
# Mean: -9812.501
# Max: 1950048.756
# Min: -1907871.032
# Run nr.: 87
#
#  |OOOOOOOOOO| 100.0%   realization nr. 87. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.944 minutes
# Total elapsed time: 12.416 hours
# Variance: 381651590335.596
# Mean: -6555.958
# Max: 2498211.704
# Min: -1923341.888
# Run nr.: 88
#
#  |OOOOOOOOOO| 100.0%   realization nr. 88. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.935 minutes
# Total elapsed time: 12.549 hours
# Variance: 378177492943.836
# Mean: -6056.041
# Max: 1954832.295
# Min: -1656477.555
# Run nr.: 89
#
#  |OOOOOOOOOO| 100.0%   realization nr. 89. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.916 minutes
# Total elapsed time: 12.680 hours
# Variance: 372621290449.577
# Mean: -13091.495
# Max: 2458498.669
# Min: -1662215.718
# Run nr.: 90
#
#  |OOOOOOOOOO| 100.0%   realization nr. 90. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.898 minutes
# Total elapsed time: 12.812 hours
# Variance: 359149808679.976
# Mean: -7493.404
# Max: 1819432.747
# Min: -1648283.298
# Run nr.: 91
#
#  |OOOOOOOOOO| 100.0%   realization nr. 91. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.916 minutes
# Total elapsed time: 12.944 hours
# Variance: 384014962382.556
# Mean: -8808.204
# Max: 2534360.511
# Min: -1654446.833
# Run nr.: 92
#
#  |OOOOOOOOOO| 100.0%   realization nr. 92. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.914 minutes
# Total elapsed time: 13.076 hours
# Variance: 388836674433.599
# Mean: -14778.496
# Max: 2414515.513
# Min: -1907867.186
# Run nr.: 93
#
#  |OOOOOOOOOO| 100.0%   realization nr. 93. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.924 minutes
# Total elapsed time: 13.208 hours
# Variance: 378181997055.860
# Mean: -11492.015
# Max: 2358911.284
# Min: -2083582.012
# Run nr.: 94
#
#  |OOOOOOOOOO| 100.0%   realization nr. 94. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.923 minutes
# Total elapsed time: 13.340 hours
# Variance: 376555285163.820
# Mean: -14686.352
# Max: 2539250.150
# Min: -1888460.117
# Run nr.: 95
#
#  |OOOOOOOOOO| 100.0%   realization nr. 95. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.903 minutes
# Total elapsed time: 13.472 hours
# Variance: 363398551170.178
# Mean: -14002.797
# Max: 2334202.473
# Min: -1654257.281
# Run nr.: 96
#
#  |OOOOOOOOOO| 100.0%   realization nr. 96. Counter: 1891/1891, Running error magnitude: 5.3
# Run time: 7.901 minutes
# Total elapsed time: 13.603 hours
# Variance: 374630649921.188
# Mean: -13072.159
# Max: 2425902.413
# Min: -1678413.744
# Run nr.: 97
#
#  |OOOOOOOOOO| 100.0%   realization nr. 97. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.888 minutes
# Total elapsed time: 13.735 hours
# Variance: 355557541975.292
# Mean: -8894.171
# Max: 2255173.810
# Min: -1638601.198
# Run nr.: 98
#
#  |OOOOOOOOOO| 100.0%   realization nr. 98. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.920 minutes
# Total elapsed time: 13.867 hours
# Variance: 375275549304.613
# Mean: -8169.853
# Max: 2438739.790
# Min: -1651496.362
# Run nr.: 99
#
#  |OOOOOOOOOO| 100.0%   realization nr. 99. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.905 minutes
# Total elapsed time: 13.999 hours
# Variance: 369874226156.071
# Mean: -13547.932
# Max: 2701893.294
# Min: -1754922.415
# Run nr.: 100
#
#
# Seqsim RMSE:	 [[2.02924562 2.03174672 2.05088263 2.02583302 2.01494534 2.03949678
#   2.029628   2.03119901 2.02921464 2.04110927 2.02680157 2.02461567
#   2.03869178 2.0344678  2.03095292 2.01678513 2.04632857 2.03470158
#   2.02214573 2.02685492 2.0216714  2.01730683 2.03326502 2.02358427
#   2.02133763 2.03030293 2.03720751 2.01456504 2.02405542 2.02945158
#   2.02913763 2.01876332 2.02738809 2.03263591 2.02793268 2.01547535
#   2.03217917 2.02375515 2.02339401 2.04469553 2.03802867 2.02834122
#   2.03723808 2.01680344 2.02225394 2.03209573 2.04064802 2.03489283
#   2.01354575 2.01835593 2.03099312 2.0229034  2.01719565 2.05032894
#   2.03876125 2.03016891 2.06447357 2.03878266 2.03392581 2.04982551
#   2.04202322 2.023033   2.0526525  2.02779577 2.04044168 2.02602988
#   2.05432362 2.04628861 2.02029892 2.03741893 2.04100326 2.04203372
#   2.02249588 2.00963278 2.04554501 2.04230937 2.02822353 2.01943671
#   2.04699444 2.04748934 2.03613984 2.01837928 2.0441622  2.0211725
#   2.0402157  2.03212935 2.04490187 2.05193331 2.02248946 2.01493859
#   2.01451668 2.03317198 2.02142595 2.02882503 2.03213231 2.02974133
#   2.05439744 2.04023651 2.04327935 2.03042294]]
# <img src="data:image/png;base64,..." width="640">

# %%
core.realization_to_sh_coeff(core.r_cmb)

# %%
core.covmod_lsq_equiv(s_sat.data, core.C_mm_all, core.G, core.r_cmb)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.grid_glq(nmax = 30, r_at = core.r_cmb)
mt_util.plot_sdssim_reproduce(core, core.m_DSS_res, m_equiv_lsq = core.m_equiv_lsq,
                              lags_use = 1000, spec_r_at = core.r_cmb,
                              model_dict = {}, figsize=(9,16),
                              hist_bins = 20, res_bins = 20,
                              savefig = False, save_string = "core_A_sh30_fithist", save_dpi = 100)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # Conditional table investigation

# %%
print(core)
# Out:
# ______current attributes______
#
# a:                     6371.2
# r_sat:                 6721.2
# r_cmb:                 3480.0
# rad:                   0.017453292519943295
# mu0:                   1.2566370614359173e-06
# comment:               Finding sparsity by digging into histogram reproduction
# class_abs_path:        /home/mikotz/spherical_direct_sequential_simulation
# N_SH:                  30
# N_SH_secondary:        None
# sim_type:              core
# grid_glq_zero:         (31,), Max/Min: 1.00 / -1.00
# grid_glq_w_shtools:    (31,), Max/Min: 0.10 / 0.01
# grid_glq_shape:        (2,), Max/Min: 61.00 / 31.00
# grid_glq_w:            (1891,), Max/Min: 0.10 / 0.01
# grid_glq_radial:       (1891,), Max/Min: 3480.00 / 3480.00
# grid_glq_theta:        (1891,), Max/Min: 175.63 / 4.37
# grid_glq_phi:          (1891,), Max/Min: 354.10 / 0.00
# grid_glq_N:            1891
# grid_glq_nmax:         30
# r_grid:                3480.0
# grid:                  (1891, 2)
# sph_d:                 (1891, 1891)
# lon:                   (1891,), Max/Min: 354.10 / 0.00
# lat:                   (1891,), Max/Min: 85.63 / -85.63
# N_grid:                1891
# data:                  (1891,), Max/Min: 2717914.01 / -1655937.04
# r_grid_repeat:         (1891,), Max/Min: 3480.00 / 3480.00
# target_var:            281134270951.117
# target_mean_true:      -10745.550297945754
# target_mean:           0.0
# g_prior:               (960,), Max/Min: 5004.71 / -51832.17
# CQF_dist:              (501, 101, 18910)
# CQF_mean:              (501, 101)
# CQF_var:               (501, 101)
# rangv:                 (101,), Max/Min: 2.00 / 0.00
# rangn:                 (501,), Max/Min: 3.50 / -3.50
# condtab_normsize:      18910
# condtab_model_hist:    False
# condtab_table:         rough
# sv_model_lags:         all
# sv_max_dist:           20000
# sv_lag_length:         200
# sv_zero_nugget:        True
# sort_d:                (3575881,), Max/Min: 3575880.00 / 0.00
# cloud_sorted:          (3575881,), Max/Min: 19130572965571.12 / 0.00
# sph_d_sorted:          (3575881,), Max/Min: 10919.08 / 0.00
# max_cloud:             3575881
# n_lags:                54
# lags:                  (53,), Max/Min: 9969.47 / 0.00
# pics:                  (53,), Max/Min: 458649364791.58 / 0.00
# model_select_simple:   False
# model_select_advanced: False
# lags_model:            (53,), Max/Min: 9969.47 / 0.00
# pics_model:            (53,), Max/Min: 458649364791.58 / 0.00
# lags_sv_curve:         (53,), Max/Min: 9969.00 / 0.00
# sv_curve:              (53,), Max/Min: 279387606620.04 / 0.00
# sv_lut:                (1891, 1891)
# model:                 exponential
# a_sv:                  5885.90181367607
# C0:                    0.0
# C1:                    281134270951.117
# C2:                    None
# C3:                    None
# G:                     (2773, 1891)
# C_mm_all:              (1891, 1891)
# C_dd:                  (2773, 2773)
# C_dm_all:              (1891, 2773)
# C_e_const:             2
# N_sim:                 1
# idx_nv_collect:        (1891, 2)
# m_DSS:                 (1891, 1), Max/Min: 1786876.50 / -1522982.89
# m_DSS_pred:            (2773, 1), Max/Min: 85907.04 / -84354.68
# m_DSS_res:             (2773, 1), Max/Min: 7.38 / -6.77
# g_spec:                (960, 1), Max/Min: 5004.51 / -51832.33
# g_spec_mean:           (960,), Max/Min: 5004.51 / -51832.33
# m_equiv_lsq:           (1891, 1), Max/Min: 1676130.83 / -1129417.28
# lsq_equiv_pred:        (2773, 1), Max/Min: 85907.48 / -84355.15
# lsq_equiv_res:         (2773, 1), Max/Min: 6.45 / -6.75
# g_lsq_equiv:           (960,), Max/Min: 5004.61 / -51832.54
# pics_m_DSS:            (53, 1), Max/Min: 458649364791.58 / 0.00

# %% [markdown]
# # Density sampling

# %%
#test_CQF_dist = core.CQF_dist[250,50,:]
#test_CQF_dist = core.CQF_dist[450,50,:]
#test_CQF_dist = core.CQF_dist[50,50,:]
#test_CQF_dist = core.CQF_dist[220,20,:]
test_CQF_dist = core.CQF_dist[220,70,:]

sample_emp_QF = test_CQF_dist[np.random.randint(0,core.condtab_normsize,size=100000)]

hist_bins = 50

plt.figure()

y,binEdges=np.histogram(sample_emp_QF,bins=hist_bins, density = True)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'-',color = "k", label='Sampled QF', linewidth = 3)  

y,binEdges=np.histogram(test_CQF_dist,bins=hist_bins, density = True)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'-',color = "C0", label='QF dist')  

y,binEdges=np.histogram(core.data,bins=hist_bins, density = True)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'--',color = "C1", label='Target histogram')  

plt.title("Histogram reproduction of conditional QFs")
plt.legend()
plt.show()

plt.figure()
plt.plot(test_CQF_dist)
plt.title("Empricial quantile function")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Count sampling

# %%
test_CQF_dist = core.CQF_dist[250,50,:]
#test_CQF_dist = core.CQF_dist[450,50,:]
#test_CQF_dist = core.CQF_dist[50,50,:]

sample_emp_QF = test_CQF_dist[np.random.randint(0,core.condtab_normsize,size=len(core.data))]

hist_bins = 50

plt.figure()

y,binEdges=np.histogram(sample_emp_QF,bins=hist_bins, density = False)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'-',color = "k", label='Sampled QF')  

#y,binEdges=np.histogram(test_CQF_dist,bins=hist_bins, density = True)
#bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
#plt.plot(bincenters,y,'-',color = "C0", label='QF dist')  

y,binEdges=np.histogram(core.data,bins=hist_bins, density = False)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'--',color = "C1", label='Target histogram')  

plt.title("Histogram reproduction of conditional QFs")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# animation
from matplotlib import animation, rc
from IPython.display import HTML, Image, display, Video
import os

# %%
samples_emp_QF = []
for j in np.arange(0,core.m_DSS.shape[0]):
    nv_in = core.idx_nv_collect[j]
    test_CQF_dist = core.CQF_dist[nv_in[0],nv_in[1],:]
    samples_emp_QF.append(test_CQF_dist[np.random.randint(0,core.condtab_normsize,size=len(core.data))])
    
samples_emp_QF = np.array(samples_emp_QF)

# %%
samples_emp_QF.shape
# Out:
# (1891, 1891)

# %%
def animate_CQF_sampling(core):

    test_CQF_dist = core.CQF_dist[250,50,:]
    #test_CQF_dist = core.CQF_dist[450,50,:]
    #test_CQF_dist = core.CQF_dist[50,50,:]

    hist_bins = 50

    rgb = 1-(np.arange(0,len(core.data))+1)/len(core.data)

    fig = plt.figure(figsize=(6,6), constrained_layout=False, dpi = 100)

    gs = fig.add_gridspec(1, 1, height_ratios=[1], width_ratios=[1]) # Add x-by-y grid

    ax = fig.add_subplot(gs[0, 0])

    samples_emp_QF = []
    for j in np.arange(0,core.m_DSS.shape[0]):
        nv_in = core.idx_nv_collect[j]
        test_CQF_dist = core.CQF_dist[nv_in[0],nv_in[1],:]
        #samples_emp_QF.append(test_CQF_dist[np.random.randint(0,core.condtab_normsize,size=len(core.data))])
        samples_emp_QF.append(test_CQF_dist[np.random.randint(0,core.condtab_normsize,size=1)])

    samples_emp_QF = np.array(samples_emp_QF)

    y,binEdges=np.histogram(samples_emp_QF[0,:],bins=hist_bins, density = False)
    bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
    ax.plot(bincenters,y,'-',color = (rgb[0],rgb[0],rgb[0]), label='Sampled QF')  

    def animate(i):
        y,binEdges=np.histogram(samples_emp_QF[:(i+1),:],bins=hist_bins, density = False)
        bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
        cb = ax.plot(bincenters,y,'-',color = (rgb[i+1],rgb[i+1],rgb[i+1]))
        return (cb,)

    y,binEdges=np.histogram(core.data,bins=hist_bins, density = False)
    bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
    ax.plot(bincenters,y,'--',color = "C1", label='Target histogram', zorder = 10)  

    plt.title("Histogram reproduction of conditional QFs")
    plt.legend()

    anim = animation.FuncAnimation(fig, animate, frames=len(core.data)-1, interval=5)
    
    plt.close() # Close the active figure to avoid extra plot
    
    return anim

anim = animate_CQF_sampling(core)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
core.rangn[250]
# Out:
# 0.0

# %%
core.rangv[50]
# Out:
# 1.0

# %%
def conditional_lookup(self, mu_k, sigma_sq_k, dm, dv, scaling = True):
        #conditional_lookup(self, cond_mean, cond_var, cond_dist, cond_dist_size, mu_k, sigma_sq_k, dm, dv):
        #conditional_lookup(core.CQF_mean, core.CQF_var, core.CQF_dist, core.condtab_normsize, mu_k, sigma_sq_k, dm_c, dv_c)

        #distance = np.power((self.CQF_mean-mu_k)/dm,2)+np.power((self.CQF_var-sigma_sq_k)/dv,2)        
        distance = np.power((self.CQF_mean-mu_k)/dm,2)+abs(self.CQF_var-sigma_sq_k)/np.sqrt(dv)
        #distance = abs(self.CQF_mean-mu_k)/dm+abs(self.CQF_var-sigma_sq_k)/np.sqrt(dv)

        nearest = np.unravel_index(np.argmin(distance),self.CQF_mean.shape)
        idx_n = nearest[0]
        idx_v = nearest[-1]
        
        nearest_dist = self.CQF_dist[idx_n,idx_v,:]
        
        m_i = nearest_dist[np.random.randint(0,self.condtab_normsize,size=1)]

        if scaling == True:
            m_i_mean = self.CQF_mean[idx_n,idx_v]        
            m_i_std = np.sqrt(self.CQF_var[idx_n,idx_v],dtype=np.float64)

            m_k = (m_i - m_i_mean)*np.sqrt(sigma_sq_k)/m_i_std+mu_k
        else:
            m_k = m_i

        return idx_n, idx_v, nearest_dist, m_i, distance

# %%
from matplotlib.colorbar import Colorbar

data_min = np.min(core.data)
data_max = np.max(core.data)
dm = data_max - data_min
dv = core.target_var

idx_rand_field_value = np.random.randint(0,len(core.data),size=1)
idx_n, idx_v, nearest_dist, m_i, distance = conditional_lookup(core, core.data[idx_rand_field_value], 
                                                               core.target_var, 1, 1)
                                                               #core.target_var, dm, dv)
print(idx_rand_field_value)
print(idx_n)
print(idx_v)

fig = plt.figure(figsize=(8,4), constrained_layout=False) # Initiate figure with constrained layout
fig.suptitle("Distance measure for QF lookup")

gs = fig.add_gridspec(2, 2, height_ratios=[1,0.05], width_ratios=[1,1]) # Add x-by-y grid
ax_cb = fig.add_subplot(gs[1, 0])

#% RESIDUALS
ax = fig.add_subplot(gs[0, 0])
im = ax.imshow(distance)
#cbax = plt.subplot(gs[0,0]) # Set colorbar position
cb = Colorbar(mappable = im, ax = ax_cb, orientation = "horizontal") # im, ax=ax, 
ax.set_xlabel("Variance range")
ax.set_ylabel("Mean range")
ax = fig.add_subplot(gs[:, 1])
ax.plot(distance)
ax.set_xlabel("Mean range")
ax.set_ylabel("Distance measure")

fig.subplots_adjust(left=0.03, bottom=0.12, right=0.97, top=0.85, wspace = 0.2, hspace=0.5)

plt.show()
# Out:
# [1316]
# 257
# 49
# <img src="data:image/png;base64,..." width="800">

# %%
core.grid_glq(nmax = 256, r_at = core.r_cmb)
#core.grid_glq(nmax = 120, r_at = core.r_cmb)

core.ensemble_B(core.g_spec, nmax = 30, r_at = core.r_cmb, grid_type = "glq")
zs_eqa = core.B_ensemble_glq[:,0,:].copy()

#core.g_spec_mean = np.mean(core.g_spec,axis=1)
core.ensemble_B(core.g_spec_mean, nmax = 30, r_at = core.r_cmb, grid_type = "glq")
zs_mean_eqa = core.B_ensemble_glq[:,0].copy()

core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(30)], nmax = 30, r_at = core.r_cmb, grid_type = "glq")
prior_eqa = core.B_ensemble_glq[:,0].copy()

core.ensemble_B(core.g_lsq_equiv, nmax = 30, r_at = core.r_cmb, grid_type = "glq")
lsq_eqa = core.B_ensemble_glq[:,0].copy()

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)
# ccrs.PlateCarree()
# ccrs.Mollweide()
# ccrs.Orthographic(central_longitude=0.0, central_latitude=0.0)

mt_util.plot_ensemble_map_tiles(core.grid_glq_phi, 90-core.grid_glq_theta, zs_eqa, 
                        field_compare = prior_eqa, field_lsq = lsq_eqa, field_mean = zs_mean_eqa,
                        tile_size_row = 3, tile_size_column = 2, 
                        figsize=(9,12), limit_for_SF = 10**6, point_size = 10, cbar_mm_factor = 2/3,
                        coast_width = 0.4, coast_color = "grey", unit_transform_n_to_m = True,
                        cbar_h = 0.1, cbar_text = "mT", cbar_text_color = "black",
                        left=0.03, bottom=0.12, right=0.97, top=0.95, wspace = 0.05, hspace=0.2, 
                        savefig = False, save_string = "core_A_sh30_fithist", 
                        projection = ccrs.Mollweide(), use_gridlines = True, 
                        gridlines_width = 0.4, gridlines_alpha = 0.4, save_dpi = 100)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
plt.figure()
plt.hist(core.m_DSS[0,:],bins=10)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# SAVE RESULT
#print("\nSaving job")
#file_clip = open("core_{}.obj".format(nb_name), "wb")
#pickle.dump(core, file_clip, protocol=4)
#file_clip.close()

#file_clip = open("sat_{}.obj".format(nb_name), "wb")
#pickle.dump(s_sat, file_clip, protocol=4)
#file_clip.close()
#print("\nJob saved and finished")
