# %%
# %matplotlib notebook

from sdss import SDSS
import mikkel_tools.utility as mt_util
import plot as sds_plt

import numpy as np
#import cupy as cp
import scipy as sp
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

import pyshtools
import pickle

comment = "Sat obs based realizations generated with best case for hist reproduction"
nb_name = "nb_seqsim_core_sh30_obs"

# %% [markdown]
# # Core

# %%
shc_g = 30
shc_grid = 30

core = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([core.grid_phi, 90-core.grid_theta]).T
core.make_grid(core.r_cmb, grid_in, calc_sph_d = True)

# %%
core.generate_map(target_var_factor = 1)

# %%
core.condtab(normsize=100, quantiles = 10, 
             rangn_lim = 3.5, rangn_N = 501, rangv_lim = 2.0, rangv_N = 101)

# %%
core.semivar(model_lags = "all", model = "exponential", max_dist = 20000, lag_length = 200,
             zero_nugget = True, hit_target_var = True)

keep_sv_curve = core.sv_curve.copy()
keep_lags_sv_curve = core.lags_sv_curve.copy()

C_e_const = 2.0

#nugget = C_e_const**2
#nugget_p = 0.01
#var_fac = 0.1

#set_model = {"a": 2000, "C0": var_fac*core.target_var*nugget_p, "C1": var_fac*core.target_var*(1-nugget_p), "C2": None, "C3": None}
#set_model = {"a": 1800, "C0": nugget, "C1": var_fac*core.target_var-nugget, "C2": None, "C3": None}

set_model = {"a": 1700, "C0": 0.0, "C1": core.target_var, "C2": None, "C3": None}


#set_model = {"a": 200, "C0": 0.0, "C1": 0.15*core.target_var,
#             "C2": core.target_var-0.15*core.target_var, "C3": 20000}


#core.semivar(model_lags = "all", model = "dub_spherical", max_dist = 20000, lag_length = 200,
#             zero_nugget = True, hit_target_var = True, set_model = set_model)

core.semivar(model_lags = "all", model = "exponential", max_dist = 20000, lag_length = 200,
             zero_nugget = True, hit_target_var = True, set_model = set_model)
# Out:
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 200.0 km
# Number of lags: 54
# Number of modelling lags: all
#
# Semi-variogram model determined, starting LUT computation
#
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 200.0 km
# Number of lags: 54
# Number of modelling lags: all
#
# Semi-variogram model determined, starting LUT computation

# %%
#%% PLOT SEMI-VARIOGRAM
plt.figure(figsize=(10,8)) 
plt.plot(core.lags,core.pics,'o', markersize=5,color = 'C4',label='Semi-variogram')
plt.plot(core.lags_sv_curve,core.sv_curve,color='C1', linewidth = 3,label='Defined model')
plt.plot(keep_lags_sv_curve,keep_sv_curve,"--",color='C0',linewidth = 3,label='Fitted model')

plt.plot(core.lags_sv_curve,np.ones(core.lags_sv_curve.shape)*core.target_var,linewidth = 3,
         color="C2", linestyle="dashed", label="Training image variance")
plt.ylabel('Semi-variance $[%s^2]$' % "nT",fontsize=18,labelpad=18)
plt.xlabel('Lag [km]',fontsize=18,labelpad=18)
plt.title("Semi-variogram model of type: %s " % core.model_names[core.model],fontsize=18,y=1.02)
plt.legend(loc='best',fontsize=18)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#print(core)

# %% [markdown]
# # Swarm observations

# %%
s_sat = SDSS(comment, N_SH = shc_g, sim_type = "core_ens", sat_height = 350, N_SH_secondary = None)

s_sat.load_swarm("A", use_obs = True)

grid_in = np.array([s_sat.grid_phi, 90-s_sat.grid_theta]).T
s_sat.make_grid(s_sat.grid_radial, grid_in, calc_sph_d = False)

#s_sat.grid_equal_area(N_grid= 500, r_at = s_sat.r_sat, poles_remove = True)
#grid_in = np.array([s_sat.grid_phi, 90-s_sat.grid_theta]).T
#s_sat.grid(s_sat.r_sat, grid_in, calc_sph_d = False)

# %% [markdown]
# # System equations

# %%
core.integrating_kernel(s_sat, C_e_const = C_e_const)
# Out:
# Gauss-Legendre RMSE:	 26531.797228366584
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # SDSSIM

# %%
N_sim = 100

core.run_sim(N_sim, core.grid_N, core.C_mm_all, core.C_dd, core.C_dm_all, core.G,
        s_sat.data, core.data, scale_m_i = True, unit_d = False, collect_all = False,
        sense_running_error = True, save_string = nb_name, sim_stochastic = False, solve_cho = True)
# Out:
#  |OOOOOOOOOO| 100.0%   realization nr. 0. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.072 minutes
# Total elapsed time: 10.072 minutes
# Variance: 286499691390.038
# Mean: 4299.176
# Max: 3158779.958
# Min: -1692010.728
# Run nr.: 1
#
#  |OOOOOOOOOO| 100.0%   realization nr. 1. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.141 minutes
# Total elapsed time: 20.213 minutes
# Variance: 294490564468.695
# Mean: 6401.530
# Max: 2630965.193
# Min: -1678241.147
# Run nr.: 2
#
#  |OOOOOOOOOO| 100.0%   realization nr. 2. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.141 minutes
# Total elapsed time: 30.353 minutes
# Variance: 274165628105.415
# Mean: 4060.634
# Max: 2526104.640
# Min: -1669894.229
# Run nr.: 3
#
#  |OOOOOOOOOO| 100.0%   realization nr. 3. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.890 minutes
# Total elapsed time: 41.243 minutes
# Variance: 269399489009.230
# Mean: 2289.473
# Max: 2605250.158
# Min: -1661774.905
# Run nr.: 4
#
#  |OOOOOOOOOO| 100.0%   realization nr. 4. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.820 minutes
# Total elapsed time: 52.063 minutes
# Variance: 267850507282.566
# Mean: 5397.439
# Max: 2592835.665
# Min: -1772027.836
# Run nr.: 5
#
#  |OOOOOOOOOO| 100.0%   realization nr. 5. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.768 minutes
# Total elapsed time: 1.047 hours
# Variance: 262995328002.734
# Mean: 8088.901
# Max: 2590043.648
# Min: -1665427.670
# Run nr.: 6
#
#  |OOOOOOOOOO| 100.0%   realization nr. 6. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.006 minutes
# Total elapsed time: 1.231 hours
# Variance: 266419070720.167
# Mean: 13028.837
# Max: 2571483.699
# Min: -1771035.796
# Run nr.: 7
#
#  |OOOOOOOOOO| 100.0%   realization nr. 7. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.912 minutes
# Total elapsed time: 1.412 hours
# Variance: 289131833970.480
# Mean: 3944.360
# Max: 2619517.459
# Min: -1661050.652
# Run nr.: 8
#
#  |OOOOOOOOOO| 100.0%   realization nr. 8. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.902 minutes
# Total elapsed time: 1.594 hours
# Variance: 246896673973.199
# Mean: 4021.372
# Max: 2630177.235
# Min: -1677141.573
# Run nr.: 9
#
#  |OOOOOOOOOO| 100.0%   realization nr. 9. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.904 minutes
# Total elapsed time: 1.776 hours
# Variance: 274814227262.902
# Mean: 4907.444
# Max: 2642666.879
# Min: -1716342.658
# Run nr.: 10
#
#  |OOOOOOOOOO| 100.0%   realization nr. 10. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.229 minutes
# Total elapsed time: 1.946 hours
# Variance: 288629420602.004
# Mean: 11396.823
# Max: 2639426.844
# Min: -1731354.213
# Run nr.: 11
#
#  |OOOOOOOOOO| 100.0%   realization nr. 11. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.203 minutes
# Total elapsed time: 2.116 hours
# Variance: 256903585415.410
# Mean: 3990.595
# Max: 2578332.994
# Min: -1644477.156
# Run nr.: 12
#
#  |OOOOOOOOOO| 100.0%   realization nr. 12. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.297 minutes
# Total elapsed time: 2.288 hours
# Variance: 259384936370.794
# Mean: 6064.126
# Max: 2507556.476
# Min: -1679108.016
# Run nr.: 13
#
#  |OOOOOOOOOO| 100.0%   realization nr. 13. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.588 minutes
# Total elapsed time: 2.465 hours
# Variance: 269118493694.892
# Mean: 4213.035
# Max: 2706387.751
# Min: -1666638.990
# Run nr.: 14
#
#  |OOOOOOOOOO| 100.0%   realization nr. 14. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.223 minutes
# Total elapsed time: 2.635 hours
# Variance: 288021112743.349
# Mean: 2240.968
# Max: 2675708.796
# Min: -1650744.574
# Run nr.: 15
#
#  |OOOOOOOOOO| 100.0%   realization nr. 15. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.268 minutes
# Total elapsed time: 2.806 hours
# Variance: 257514826728.675
# Mean: 5354.627
# Max: 2819762.315
# Min: -1702067.827
# Run nr.: 16
#
#  |OOOOOOOOOO| 100.0%   realization nr. 16. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.239 minutes
# Total elapsed time: 2.977 hours
# Variance: 252622673854.356
# Mean: 3279.456
# Max: 2599641.974
# Min: -1638054.158
# Run nr.: 17
#
#  |OOOOOOOOOO| 100.0%   realization nr. 17. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.299 minutes
# Total elapsed time: 3.148 hours
# Variance: 259418361295.252
# Mean: 7310.135
# Max: 3060968.582
# Min: -1707740.887
# Run nr.: 18
#
#  |OOOOOOOOOO| 100.0%   realization nr. 18. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.247 minutes
# Total elapsed time: 3.319 hours
# Variance: 266412980020.896
# Mean: 1535.295
# Max: 2696639.681
# Min: -1762012.141
# Run nr.: 19
#
#  |OOOOOOOOOO| 100.0%   realization nr. 19. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.153 minutes
# Total elapsed time: 3.488 hours
# Variance: 280232964317.757
# Mean: 3252.012
# Max: 2643087.147
# Min: -1731013.448
# Run nr.: 20
#
#  |OOOOOOOOOO| 100.0%   realization nr. 20. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.850 minutes
# Total elapsed time: 3.669 hours
# Variance: 257095748350.638
# Mean: 2874.577
# Max: 2441828.445
# Min: -1662265.954
# Run nr.: 21
#
#  |OOOOOOOOOO| 100.0%   realization nr. 21. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.889 minutes
# Total elapsed time: 3.851 hours
# Variance: 252563670659.741
# Mean: 206.306
# Max: 2591651.597
# Min: -1701577.617
# Run nr.: 22
#
#  |OOOOOOOOOO| 100.0%   realization nr. 22. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.517 minutes
# Total elapsed time: 4.026 hours
# Variance: 254481824143.921
# Mean: 3554.058
# Max: 2669210.617
# Min: -1744947.698
# Run nr.: 23
#
#  |OOOOOOOOOO| 100.0%   realization nr. 23. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.157 minutes
# Total elapsed time: 4.195 hours
# Variance: 255081715033.424
# Mean: 3942.281
# Max: 2754264.564
# Min: -1627689.370
# Run nr.: 24
#
#  |OOOOOOOOOO| 100.0%   realization nr. 24. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.156 minutes
# Total elapsed time: 4.364 hours
# Variance: 232035580575.005
# Mean: 4913.534
# Max: 2579056.714
# Min: -1739928.112
# Run nr.: 25
#
#  |OOOOOOOOOO| 100.0%   realization nr. 25. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.538 minutes
# Total elapsed time: 4.540 hours
# Variance: 262103722955.430
# Mean: 2955.392
# Max: 2714211.013
# Min: -1675050.507
# Run nr.: 26
#
#  |OOOOOOOOOO| 100.0%   realization nr. 26. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.122 minutes
# Total elapsed time: 4.709 hours
# Variance: 259164763576.916
# Mean: 3604.654
# Max: 2638356.745
# Min: -1673875.183
# Run nr.: 27
#
#  |OOOOOOOOOO| 100.0%   realization nr. 27. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.163 minutes
# Total elapsed time: 4.878 hours
# Variance: 256141720111.074
# Mean: 1991.286
# Max: 2964988.263
# Min: -1748719.221
# Run nr.: 28
#
#  |OOOOOOOOOO| 100.0%   realization nr. 28. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.124 minutes
# Total elapsed time: 5.047 hours
# Variance: 272959144567.097
# Mean: 1187.142
# Max: 2686405.049
# Min: -1661069.319
# Run nr.: 29
#
#  |OOOOOOOOOO| 100.0%   realization nr. 29. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.006 minutes
# Total elapsed time: 5.230 hours
# Variance: 255434901698.497
# Mean: 5446.848
# Max: 2609442.925
# Min: -1722298.643
# Run nr.: 30
#
#  |OOOOOOOOOO| 100.0%   realization nr. 30. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.120 minutes
# Total elapsed time: 5.416 hours
# Variance: 280127274591.108
# Mean: 4047.929
# Max: 2627817.605
# Min: -1785866.721
# Run nr.: 31
#
#  |OOOOOOOOOO| 100.0%   realization nr. 31. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.416 minutes
# Total elapsed time: 5.589 hours
# Variance: 257024900344.912
# Mean: 4434.443
# Max: 2717373.456
# Min: -1602166.287
# Run nr.: 32
#
#  |OOOOOOOOOO| 100.0%   realization nr. 32. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.174 minutes
# Total elapsed time: 5.759 hours
# Variance: 272768968279.072
# Mean: 1884.974
# Max: 2654838.093
# Min: -1634184.323
# Run nr.: 33
#
#  |OOOOOOOOOO| 100.0%   realization nr. 33. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.281 minutes
# Total elapsed time: 5.930 hours
# Variance: 262964470292.784
# Mean: 3349.939
# Max: 2883553.821
# Min: -1699583.197
# Run nr.: 34
#  |OOOOOOOOOO| 100.0%   realization nr. 34. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.107 minutes
# Total elapsed time: 6.099 hours
# Variance: 257707670650.218
# Mean: 3269.909
# Max: 2971313.296
# Min: -1655198.784
# Run nr.: 35
#
#  |OOOOOOOOOO| 100.0%   realization nr. 35. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.779 minutes
# Total elapsed time: 6.278 hours
# Variance: 281552954940.124
# Mean: 1121.161
# Max: 2749625.202
# Min: -1853631.125
# Run nr.: 36
#
#  |OOOOOOOOOO| 100.0%   realization nr. 36. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.280 minutes
# Total elapsed time: 6.450 hours
# Variance: 247063740934.627
# Mean: 5257.850
# Max: 2718360.443
# Min: -1644790.427
# Run nr.: 37
#
#  |OOOOOOOOOO| 100.0%   realization nr. 37. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.169 minutes
# Total elapsed time: 6.619 hours
# Variance: 248180320846.853
# Mean: 3152.366
# Max: 2623821.973
# Min: -1732487.841
# Run nr.: 38
#
#  |OOOOOOOOOO| 100.0%   realization nr. 38. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.128 minutes
# Total elapsed time: 6.788 hours
# Variance: 275633422599.543
# Mean: -1098.090
# Max: 2546696.026
# Min: -1744025.691
# Run nr.: 39
#
#  |OOOOOOOOOO| 100.0%   realization nr. 39. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.110 minutes
# Total elapsed time: 6.956 hours
# Variance: 267604816499.166
# Mean: -1665.956
# Max: 2909301.654
# Min: -1801368.037
# Run nr.: 40
#
#  |OOOOOOOOOO| 100.0%   realization nr. 40. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.789 minutes
# Total elapsed time: 7.136 hours
# Variance: 240985097638.951
# Mean: 3564.722
# Max: 2989699.304
# Min: -1631076.066
# Run nr.: 41
#
#  |OOOOOOOOOO| 100.0%   realization nr. 41. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.232 minutes
# Total elapsed time: 7.307 hours
# Variance: 270825141359.564
# Mean: 1559.659
# Max: 3035739.443
# Min: -1605947.406
# Run nr.: 42
#
#  |OOOOOOOOOO| 100.0%   realization nr. 42. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.442 minutes
# Total elapsed time: 7.481 hours
# Variance: 252554415640.584
# Mean: 10709.544
# Max: 3251328.919
# Min: -1715811.637
# Run nr.: 43
#
#  |OOOOOOOOOO| 100.0%   realization nr. 43. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.208 minutes
# Total elapsed time: 7.651 hours
# Variance: 263896411706.043
# Mean: 3876.512
# Max: 2679556.505
# Min: -1749867.064
# Run nr.: 44
#
#  |OOOOOOOOOO| 100.0%   realization nr. 44. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.157 minutes
# Total elapsed time: 7.820 hours
# Variance: 274953144969.694
# Mean: 3187.296
# Max: 2635789.279
# Min: -1696651.248
# Run nr.: 45
#
#  |OOOOOOOOOO| 100.0%   realization nr. 45. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.173 minutes
# Total elapsed time: 7.990 hours
# Variance: 281436413356.313
# Mean: 1777.986
# Max: 2683058.247
# Min: -1719274.754
# Run nr.: 46
#
#  |OOOOOOOOOO| 100.0%   realization nr. 46. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.118 minutes
# Total elapsed time: 8.158 hours
# Variance: 302264710840.224
# Mean: 13801.253
# Max: 2763048.168
# Min: -1652249.959
# Run nr.: 47
#
#  |OOOOOOOOOO| 100.0%   realization nr. 47. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.212 minutes
# Total elapsed time: 8.329 hours
# Variance: 280707723584.180
# Mean: 3956.560
# Max: 2976497.163
# Min: -1719325.744
# Run nr.: 48
#
#  |OOOOOOOOOO| 100.0%   realization nr. 48. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.605 minutes
# Total elapsed time: 8.505 hours
# Variance: 280936366961.878
# Mean: 4494.416
# Max: 2824066.368
# Min: -1695631.833
# Run nr.: 49
#
#  |OOOOOOOOOO| 100.0%   realization nr. 49. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.239 minutes
# Total elapsed time: 8.676 hours
# Variance: 269541415359.207
# Mean: 11752.192
# Max: 2735157.829
# Min: -1650978.587
# Run nr.: 50
#
#  |OOOOOOOOOO| 100.0%   realization nr. 50. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.121 minutes
# Total elapsed time: 8.845 hours
# Variance: 256813231252.740
# Mean: 5285.689
# Max: 2698488.700
# Min: -1675887.056
# Run nr.: 51
#
#  |OOOOOOOOOO| 100.0%   realization nr. 51. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.141 minutes
# Total elapsed time: 9.014 hours
# Variance: 254469768274.723
# Mean: 5112.595
# Max: 3089934.264
# Min: -1893519.053
# Run nr.: 52
#
#  |OOOOOOOOOO| 100.0%   realization nr. 52. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.142 minutes
# Total elapsed time: 9.183 hours
# Variance: 254834475922.311
# Mean: 3972.296
# Max: 2722571.647
# Min: -1793330.900
# Run nr.: 53
#
#  |OOOOOOOOOO| 100.0%   realization nr. 53. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.184 minutes
# Total elapsed time: 9.353 hours
# Variance: 267162445899.109
# Mean: 3608.263
# Max: 2651387.379
# Min: -1758617.109
# Run nr.: 54
#
#  |OOOOOOOOOO| 100.0%   realization nr. 54. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.182 minutes
# Total elapsed time: 9.522 hours
# Variance: 297617856311.229
# Mean: 7298.068
# Max: 2801350.120
# Min: -1805586.446
# Run nr.: 55
#
#  |OOOOOOOOOO| 100.0%   realization nr. 55. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.201 minutes
# Total elapsed time: 9.692 hours
# Variance: 300171629486.914
# Mean: 4969.405
# Max: 2685403.926
# Min: -1696947.181
# Run nr.: 56
#
#  |OOOOOOOOOO| 100.0%   realization nr. 56. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.180 minutes
# Total elapsed time: 9.862 hours
# Variance: 256075571242.516
# Mean: 4163.108
# Max: 2553676.144
# Min: -1669695.252
# Run nr.: 57
#
#  |OOOOOOOOOO| 100.0%   realization nr. 57. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.169 minutes
# Total elapsed time: 10.031 hours
# Variance: 259157854650.120
# Mean: 3664.704
# Max: 2578490.878
# Min: -1734986.768
# Run nr.: 58
#
#  |OOOOOOOOOO| 100.0%   realization nr. 58. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.190 minutes
# Total elapsed time: 10.201 hours
# Variance: 279083656781.871
# Mean: 2339.370
# Max: 2659102.713
# Min: -1747873.962
# Run nr.: 59
#
#  |OOOOOOOOOO| 100.0%   realization nr. 59. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.253 minutes
# Total elapsed time: 10.372 hours
# Variance: 248218075027.612
# Mean: 6579.337
# Max: 2722535.802
# Min: -1625270.361
# Run nr.: 60
#
#  |OOOOOOOOOO| 100.0%   realization nr. 60. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.169 minutes
# Total elapsed time: 10.542 hours
# Variance: 267583600853.117
# Mean: -160.627
# Max: 3166326.847
# Min: -1762176.262
# Run nr.: 61
#
#  |OOOOOOOOOO| 100.0%   realization nr. 61. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.237 minutes
# Total elapsed time: 10.712 hours
# Variance: 250937359995.503
# Mean: 3021.608
# Max: 2998130.618
# Min: -1739715.924
# Run nr.: 62
#
#  |OOOOOOOOOO| 100.0%   realization nr. 62. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.227 minutes
# Total elapsed time: 10.883 hours
# Variance: 260768475578.505
# Mean: 4951.383
# Max: 2789616.212
# Min: -1762417.452
# Run nr.: 63
#
#  |OOOOOOOOOO| 100.0%   realization nr. 63. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.244 minutes
# Total elapsed time: 11.053 hours
# Variance: 286127759741.039
# Mean: 970.754
# Max: 2652925.007
# Min: -1993829.765
# Run nr.: 64
#
#  |OOOOOOOOOO| 100.0%   realization nr. 64. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.204 minutes
# Total elapsed time: 11.223 hours
# Variance: 271671639212.622
# Mean: 3557.134
# Max: 2544653.886
# Min: -1758239.483
# Run nr.: 65
#
#  |OOOOOOOOOO| 100.0%   realization nr. 65. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.153 minutes
# Total elapsed time: 11.393 hours
# Variance: 253338941771.059
# Mean: 1976.334
# Max: 2391935.354
# Min: -1655560.206
# Run nr.: 66
#
#  |OOOOOOOOOO| 100.0%   realization nr. 66. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.230 minutes
# Total elapsed time: 11.563 hours
# Variance: 246823160171.214
# Mean: 5115.849
# Max: 2359277.681
# Min: -1652881.115
# Run nr.: 67
#
#  |OOOOOOOOOO| 100.0%   realization nr. 67. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.380 minutes
# Total elapsed time: 11.736 hours
# Variance: 251012428488.765
# Mean: 424.169
# Max: 2569026.421
# Min: -1578776.864
# Run nr.: 68
#  |OOOOOOOOOO| 100.0%   realization nr. 68. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.279 minutes
# Total elapsed time: 11.907 hours
# Variance: 226337790208.587
# Mean: 5207.741
# Max: 2638015.251
# Min: -1681377.437
# Run nr.: 69
#
#  |OOOOOOOOOO| 100.0%   realization nr. 69. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.181 minutes
# Total elapsed time: 12.077 hours
# Variance: 258682115525.863
# Mean: 4349.694
# Max: 2695841.416
# Min: -1718734.961
# Run nr.: 70
#
#  |OOOOOOOOOO| 100.0%   realization nr. 70. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.114 minutes
# Total elapsed time: 12.246 hours
# Variance: 281378231949.030
# Mean: 12207.871
# Max: 2579820.533
# Min: -1675410.671
# Run nr.: 71
#
#  |OOOOOOOOOO| 100.0%   realization nr. 71. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.226 minutes
# Total elapsed time: 12.416 hours
# Variance: 266472100813.605
# Mean: 3477.730
# Max: 2638128.148
# Min: -1617686.367
# Run nr.: 72
#
#  |OOOOOOOOOO| 100.0%   realization nr. 72. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.495 minutes
# Total elapsed time: 12.591 hours
# Variance: 267360296081.074
# Mean: 4122.197
# Max: 2645603.031
# Min: -1711262.921
# Run nr.: 73
#
#  |OOOOOOOOOO| 100.0%   realization nr. 73. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.142 minutes
# Total elapsed time: 12.760 hours
# Variance: 278315641754.295
# Mean: 4119.583
# Max: 2750802.845
# Min: -1772595.826
# Run nr.: 74
#
#  |OOOOOOOOOO| 100.0%   realization nr. 74. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.142 minutes
# Total elapsed time: 12.929 hours
# Variance: 253875436293.175
# Mean: 799.283
# Max: 2619481.707
# Min: -1680760.100
# Run nr.: 75
#
#  |OOOOOOOOOO| 100.0%   realization nr. 75. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.097 minutes
# Total elapsed time: 13.097 hours
# Variance: 265325807872.524
# Mean: 1964.681
# Max: 2951944.828
# Min: -1720777.586
# Run nr.: 76
#
#  |OOOOOOOOOO| 100.0%   realization nr. 76. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.177 minutes
# Total elapsed time: 13.267 hours
# Variance: 257600682458.137
# Mean: 2217.100
# Max: 2629351.592
# Min: -1981403.902
# Run nr.: 77
#
#  |OOOOOOOOOO| 100.0%   realization nr. 77. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.181 minutes
# Total elapsed time: 13.437 hours
# Variance: 258294882810.987
# Mean: 3946.577
# Max: 2755063.426
# Min: -1674339.779
# Run nr.: 78
#
#  |OOOOOOOOOO| 100.0%   realization nr. 78. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.211 minutes
# Total elapsed time: 13.607 hours
# Variance: 251977811139.804
# Mean: 6638.896
# Max: 3228214.504
# Min: -1631588.424
# Run nr.: 79
#
#  |OOOOOOOOOO| 100.0%   realization nr. 79. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.140 minutes
# Total elapsed time: 13.776 hours
# Variance: 287981038562.289
# Mean: 12673.142
# Max: 2658268.101
# Min: -1620184.587
# Run nr.: 80
#
#  |OOOOOOOOOO| 100.0%   realization nr. 80. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.166 minutes
# Total elapsed time: 13.945 hours
# Variance: 251297046573.895
# Mean: 1106.039
# Max: 2568277.461
# Min: -1664883.366
# Run nr.: 81
#
#  |OOOOOOOOOO| 100.0%   realization nr. 81. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.167 minutes
# Total elapsed time: 14.115 hours
# Variance: 261722031012.671
# Mean: 2368.921
# Max: 2720292.402
# Min: -1724370.082
# Run nr.: 82
#
#  |OOOOOOOOOO| 100.0%   realization nr. 82. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.184 minutes
# Total elapsed time: 14.285 hours
# Variance: 271358574599.662
# Mean: 4349.956
# Max: 2721544.125
# Min: -1721914.016
# Run nr.: 83
#
#  |OOOOOOOOOO| 100.0%   realization nr. 83. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.167 minutes
# Total elapsed time: 14.454 hours
# Variance: 267638886011.314
# Mean: 3796.300
# Max: 2614804.356
# Min: -1900904.965
# Run nr.: 84
#
#  |OOOOOOOOOO| 100.0%   realization nr. 84. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.127 minutes
# Total elapsed time: 14.623 hours
# Variance: 259468093484.163
# Mean: 2335.820
# Max: 2855109.718
# Min: -1690141.077
# Run nr.: 85
#
#  |OOOOOOOOOO| 100.0%   realization nr. 85. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.173 minutes
# Total elapsed time: 14.792 hours
# Variance: 247582653847.505
# Mean: 1994.921
# Max: 2345193.732
# Min: -1703424.527
# Run nr.: 86
#
#  |OOOOOOOOOO| 100.0%   realization nr. 86. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.445 minutes
# Total elapsed time: 14.966 hours
# Variance: 276895580373.639
# Mean: 2858.823
# Max: 2608450.298
# Min: -1717389.842
# Run nr.: 87
#
#  |OOOOOOOOOO| 100.0%   realization nr. 87. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.164 minutes
# Total elapsed time: 15.136 hours
# Variance: 262315156722.014
# Mean: 3534.781
# Max: 2590238.072
# Min: -1685962.687
# Run nr.: 88
#
#  |OOOOOOOOOO| 100.0%   realization nr. 88. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.149 minutes
# Total elapsed time: 15.305 hours
# Variance: 234046204886.423
# Mean: 558.558
# Max: 2568589.773
# Min: -1705146.395
# Run nr.: 89
#
#  |OOOOOOOOOO| 100.0%   realization nr. 89. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.199 minutes
# Total elapsed time: 15.475 hours
# Variance: 254613624010.723
# Mean: 4326.981
# Max: 2658670.702
# Min: -1737689.232
# Run nr.: 90
#
#  |OOOOOOOOOO| 100.0%   realization nr. 90. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.146 minutes
# Total elapsed time: 15.644 hours
# Variance: 229148733465.825
# Mean: 1954.840
# Max: 2531215.511
# Min: -1675081.618
# Run nr.: 91
#
#  |OOOOOOOOOO| 100.0%   realization nr. 91. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.117 minutes
# Total elapsed time: 15.813 hours
# Variance: 238185215283.622
# Mean: 3488.739
# Max: 2659449.060
# Min: -1731009.619
# Run nr.: 92
#
#  |OOOOOOOOOO| 100.0%   realization nr. 92. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.121 minutes
# Total elapsed time: 15.981 hours
# Variance: 247983272045.536
# Mean: 4560.563
# Max: 2575538.985
# Min: -1993950.465
# Run nr.: 93
#
#  |OOOOOOOOOO| 100.0%   realization nr. 93. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.223 minutes
# Total elapsed time: 16.152 hours
# Variance: 270668736612.825
# Mean: 4017.231
# Max: 2973994.386
# Min: -1703023.531
# Run nr.: 94
#
#  |OOOOOOOOOO| 100.0%   realization nr. 94. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.229 minutes
# Total elapsed time: 16.322 hours
# Variance: 254625843201.009
# Mean: 6946.342
# Max: 2568418.061
# Min: -1924634.866
# Run nr.: 95
#
#  |OOOOOOOOOO| 100.0%   realization nr. 95. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.272 minutes
# Total elapsed time: 16.493 hours
# Variance: 253948525586.692
# Mean: 5642.595
# Max: 3073649.974
# Min: -1751163.060
# Run nr.: 96
#
#  |OOOOOOOOOO| 100.0%   realization nr. 96. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.525 minutes
# Total elapsed time: 16.669 hours
# Variance: 230530547990.876
# Mean: 4875.772
# Max: 2685244.492
# Min: -1736236.164
# Run nr.: 97
#
#  |OOOOOOOOOO| 100.0%   realization nr. 97. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.305 minutes
# Total elapsed time: 16.841 hours
# Variance: 282229092864.852
# Mean: 4317.836
# Max: 3127967.745
# Min: -1767483.823
# Run nr.: 98
#
#  |OOOOOOOOOO| 100.0%   realization nr. 98. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.178 minutes
# Total elapsed time: 17.010 hours
# Variance: 248102383035.444
# Mean: 5169.779
# Max: 2990503.366
# Min: -1744451.192
# Run nr.: 99
#
#  |OOOOOOOOOO| 100.0%   realization nr. 99. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.183 minutes
# Total elapsed time: 17.180 hours
# Variance: 266093046530.576
# Mean: 3865.555
# Max: 2378260.792
# Min: -1713819.624
# Run nr.: 100
#
#
# Seqsim RMSE:	 [[4.77937456 4.78683791 4.77580915 4.76061385 4.77356606 4.77176493
#   4.76519887 4.77153836 4.76565259 4.77229018 4.77107164 4.78074447
#   4.75442946 4.76033356 4.77040498 4.74667323 4.76899547 4.75485288
#   4.78197536 4.76440435 4.76838696 4.75284801 4.7428373  4.76213765
#   4.75928202 4.76166365 4.75008288 4.79011623 4.76814558 4.78178825
#   4.76642944 4.77534595 4.76659169 4.75444332 4.77426151 4.759485
#   4.76076766 4.76437105 4.76136329 4.76967377 4.77228472 4.77248552
#   4.75416257 4.769307   4.75487569 4.78170988 4.77075947 4.76401901
#   4.77002174 4.78905771 4.77038774 4.77371604 4.76160655 4.76690793
#   4.75159012 4.75824515 4.76062189 4.75294187 4.76160947 4.77381343
#   4.75670931 4.78333971 4.77331089 4.74964942 4.76332423 4.76264118
#   4.76916747 4.76485583 4.76324362 4.76812565 4.77128561 4.76662739
#   4.76124459 4.75961084 4.77983831 4.77471598 4.75829228 4.74932932
#   4.76417395 4.75346437 4.76493217 4.76210382 4.76388024 4.76745472
#   4.75123709 4.76591027 4.78737681 4.76809671 4.75954206 4.77884667
#   4.75175181 4.77354578 4.76382186 4.75679686 4.76657765 4.77510159
#   4.75532195 4.76175338 4.76749255 4.7785286 ]]
# <img src="data:image/png;base64,..." width="640">

# %%
core.realization_to_sh_coeff(core.r_cmb, set_nmax = shc_g)

# %%
core.covmod_lsq_equiv(s_sat.data, core.C_mm_all, core.G, core.r_cmb)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)
mt_util.plot_sdssim_reproduce(core, core.m_DSS_res, m_equiv_lsq = core.m_equiv_lsq, truth_obj = None,
                              lags_use = 1000, spec_r_at = core.r_cmb, spec_show_differences = False,
                              model_dict = {"CHAOS-7"}, figsize=(9,16),
                              hist_bins = 25, res_bins = 25,
                              savefig = False, save_string = "core_sh30_obs", save_dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
core.grid_glq(nmax = 256, r_at = core.r_cmb)
#core.grid_glq(nmax = 120, r_at = core.r_cmb)

set_nmax = shc_g

core.ensemble_B(core.g_spec, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_eqa = core.B_ensemble[:,0,:].copy()

#core.g_spec_mean = np.mean(core.g_spec,axis=1)
core.ensemble_B(core.g_spec_mean, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_mean_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
#core.ensemble_B(s_sat.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
#prior_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_lsq_equiv, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
#lsq_eqa = core.B_ensemble[:,0].copy()

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)
# ccrs.PlateCarree()
# ccrs.Mollweide()
# ccrs.Orthographic(central_longitude=0.0, central_latitude=0.0)

mt_util.plot_ensemble_map_tiles(core.grid_phi, 90-core.grid_theta, zs_eqa, 
                        field_mean = zs_mean_eqa,
                        tile_size_row = 4, tile_size_column = 2, 
                        figsize=(9,12), limit_for_SF = 10**6, point_size = 10, cbar_mm_factor = 2/3,
                        coast_width = 0.4, coast_color = "grey", unit_transform_n_to_m = True,
                        cbar_h = 0.1, cbar_text = "mT", cbar_text_color = "black",
                        left=0.03, bottom=0.12, right=0.97, top=0.95, wspace = 0.05, hspace=0.15, 
                        savefig = False, save_string = "core_sh30_obs", 
                        projection = ccrs.Mollweide(), use_gridlines = True, 
                        gridlines_width = 0.4, gridlines_alpha = 0.4, save_dpi = 100)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# SAVE RESULT
#print("\nSaving job")
#file_clip = open("core_{}.obj".format(nb_name), "wb")
#pickle.dump(core, file_clip, protocol=4)
#file_clip.close()

#file_clip = open("sat_{}.obj".format(nb_name), "wb")
#pickle.dump(s_sat, file_clip, protocol=4)
#file_clip.close()
#print("\nJob saved and finished")
