# %%
# %matplotlib notebook

from sdss import SDSS
import mikkel_tools.utility as mt_util
import plot as sds_plt

import numpy as np
#import cupy as cp
import scipy as sp
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

import pyshtools
import pickle

comment = "Sat obs based realizations generated with best case for hist reproduction. Large conditional distributions."
nb_name = "nb_seqsim_core_sh30_obs_Qlarge"

# %% [markdown]
# # Core

# %%
shc_g = 30
shc_grid = 30

core = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([core.grid_phi, 90-core.grid_theta]).T
core.make_grid(core.r_cmb, grid_in, calc_sph_d = True)

# %%
core.generate_map(target_var_factor = 1)

# %%
core.condtab(normsize=1000, quantiles = 100, 
             rangn_lim = 3.5, rangn_N = 501, rangv_lim = 2.0, rangv_N = 101)

# %%
core.semivar(model_lags = "all", model = "exponential", max_dist = 20000, lag_length = 200,
             zero_nugget = True, hit_target_var = True)

keep_sv_curve = core.sv_curve.copy()
keep_lags_sv_curve = core.lags_sv_curve.copy()

C_e_const = 2.0

#nugget = C_e_const**2
#nugget_p = 0.01
#var_fac = 0.1

#set_model = {"a": 2000, "C0": var_fac*core.target_var*nugget_p, "C1": var_fac*core.target_var*(1-nugget_p), "C2": None, "C3": None}
#set_model = {"a": 1800, "C0": nugget, "C1": var_fac*core.target_var-nugget, "C2": None, "C3": None}

set_model = {"a": 1700, "C0": 0.0, "C1": core.target_var, "C2": None, "C3": None}


#set_model = {"a": 200, "C0": 0.0, "C1": 0.15*core.target_var,
#             "C2": core.target_var-0.15*core.target_var, "C3": 20000}


#core.semivar(model_lags = "all", model = "dub_spherical", max_dist = 20000, lag_length = 200,
#             zero_nugget = True, hit_target_var = True, set_model = set_model)

core.semivar(model_lags = "all", model = "exponential", max_dist = 20000, lag_length = 200,
             zero_nugget = True, hit_target_var = True, set_model = set_model)
# Out:
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 200.0 km
# Number of lags: 54
# Number of modelling lags: all
#
# Semi-variogram model determined, starting LUT computation
#
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 200.0 km
# Number of lags: 54
# Number of modelling lags: all
#
# Semi-variogram model determined, starting LUT computation

# %%
#%% PLOT SEMI-VARIOGRAM
plt.figure(figsize=(10,8)) 
plt.plot(core.lags,core.pics,'o', markersize=5,color = 'C4',label='Semi-variogram')
plt.plot(core.lags_sv_curve,core.sv_curve,color='C1', linewidth = 3,label='Defined model')
plt.plot(keep_lags_sv_curve,keep_sv_curve,"--",color='C0',linewidth = 3,label='Fitted model')

plt.plot(core.lags_sv_curve,np.ones(core.lags_sv_curve.shape)*core.target_var,linewidth = 3,
         color="C2", linestyle="dashed", label="Training image variance")
plt.ylabel('Semi-variance $[%s^2]$' % "nT",fontsize=18,labelpad=18)
plt.xlabel('Lag [km]',fontsize=18,labelpad=18)
plt.title("Semi-variogram model of type: %s " % core.model_names[core.model],fontsize=18,y=1.02)
plt.legend(loc='best',fontsize=18)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
#plt.savefig('SV_models.pdf', bbox_inches='tight', dpi = 300) 

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#print(core)

# %% [markdown]
# # Swarm observations

# %%
s_sat = SDSS(comment, N_SH = shc_g, sim_type = "core_ens", sat_height = 350, N_SH_secondary = None)

s_sat.load_swarm("A", use_obs = True)

grid_in = np.array([s_sat.grid_phi, 90-s_sat.grid_theta]).T
s_sat.make_grid(s_sat.grid_radial, grid_in, calc_sph_d = False)

#s_sat.grid_equal_area(N_grid= 500, r_at = s_sat.r_sat, poles_remove = True)
#grid_in = np.array([s_sat.grid_phi, 90-s_sat.grid_theta]).T
#s_sat.grid(s_sat.r_sat, grid_in, calc_sph_d = False)

# %%
mt_util.plot_global(lat = s_sat.lat, lon = s_sat.lon, data=s_sat.data, 
                cbar_h = 0.075, cbar_mm_factor = 2/3, unit_transform_n_to_m = False,
                cbar_text = "nT", figsize=(6,6), coast_width = 0.4,
                bottom=0.35, top=0.95, hspace=0.01,
                title='Swarm observations', point_size=1,
                savefig = False, save_dpi = 100, save_string ="obs",
                use_gridlines = True, gridlines_width = 0.4, gridlines_alpha = 0.4)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# # System equations

# %%
core.integrating_kernel(s_sat, C_e_const = C_e_const)
# Out:
# Gauss-Legendre RMSE:	 26531.797228366584
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # SDSSIM

# %%
N_sim = 100

core.run_sim(N_sim, core.grid_N, core.C_mm_all, core.C_dd, core.C_dm_all, core.G,
        s_sat.data, core.data, scale_m_i = True, unit_d = False, collect_all = False,
        sense_running_error = True, save_string = nb_name, sim_stochastic = False, solve_cho = True)
# Out:
#  |OOOOOOOOOO| 100.0%   realization nr. 0. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.158 minutes
# Total elapsed time: 11.158 minutes
# Variance: 258874411481.390
# Mean: 864.915
# Max: 2732209.142
# Min: -1647240.232
# Run nr.: 1
#
#  |OOOOOOOOOO| 100.0%   realization nr. 1. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.061 minutes
# Total elapsed time: 22.219 minutes
# Variance: 269946161990.646
# Mean: 10544.836
# Max: 2731502.678
# Min: -1662778.917
# Run nr.: 2
#
#  |OOOOOOOOOO| 100.0%   realization nr. 2. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.076 minutes
# Total elapsed time: 33.295 minutes
# Variance: 284486750658.531
# Mean: 4046.697
# Max: 2745324.869
# Min: -1603387.413
# Run nr.: 3
#
#  |OOOOOOOOOO| 100.0%   realization nr. 3. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.010 minutes
# Total elapsed time: 44.305 minutes
# Variance: 259607065020.755
# Mean: 8108.086
# Max: 2527615.680
# Min: -1672924.810
# Run nr.: 4
#
#  |OOOOOOOOOO| 100.0%   realization nr. 4. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.019 minutes
# Total elapsed time: 55.323 minutes
# Variance: 264794650588.647
# Mean: 1570.565
# Max: 2717559.260
# Min: -1648724.643
# Run nr.: 5
#
#  |OOOOOOOOOO| 100.0%   realization nr. 5. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.177 minutes
# Total elapsed time: 1.108 hours
# Variance: 256399334408.369
# Mean: 7639.915
# Max: 2717502.885
# Min: -1639932.530
# Run nr.: 6
#
#  |OOOOOOOOOO| 100.0%   realization nr. 6. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.953 minutes
# Total elapsed time: 1.291 hours
# Variance: 252968057776.207
# Mean: 8614.497
# Max: 2696483.736
# Min: -1692484.996
# Run nr.: 7
#
#  |OOOOOOOOOO| 100.0%   realization nr. 7. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.344 minutes
# Total elapsed time: 1.480 hours
# Variance: 262344817528.959
# Mean: 6676.269
# Max: 2150794.224
# Min: -1653793.921
# Run nr.: 8
#
#  |OOOOOOOOOO| 100.0%   realization nr. 8. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.946 minutes
# Total elapsed time: 1.662 hours
# Variance: 269901128196.696
# Mean: 1159.068
# Max: 2709347.094
# Min: -2025585.161
# Run nr.: 9
#
#  |OOOOOOOOOO| 100.0%   realization nr. 9. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.042 minutes
# Total elapsed time: 1.846 hours
# Variance: 248949096943.045
# Mean: 9156.774
# Max: 2746221.986
# Min: -1581649.690
# Run nr.: 10
#
#  |OOOOOOOOOO| 100.0%   realization nr. 10. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.030 minutes
# Total elapsed time: 2.030 hours
# Variance: 271884085324.977
# Mean: 9392.209
# Max: 2737487.175
# Min: -1647388.960
# Run nr.: 11
#
#  |OOOOOOOOOO| 100.0%   realization nr. 11. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.038 minutes
# Total elapsed time: 2.214 hours
# Variance: 263850306775.672
# Mean: 9022.805
# Max: 2651890.272
# Min: -1662084.993
# Run nr.: 12
#
#  |OOOOOOOOOO| 100.0%   realization nr. 12. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.079 minutes
# Total elapsed time: 2.399 hours
# Variance: 263503504538.274
# Mean: 8066.390
# Max: 2718771.415
# Min: -1716242.277
# Run nr.: 13
#
#  |OOOOOOOOOO| 100.0%   realization nr. 13. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.120 minutes
# Total elapsed time: 2.584 hours
# Variance: 279983632180.372
# Mean: -1933.227
# Max: 2702035.184
# Min: -2798076.775
# Run nr.: 14
#
#  |OOOOOOOOOO| 100.0%   realization nr. 14. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.166 minutes
# Total elapsed time: 2.770 hours
# Variance: 260751025088.949
# Mean: 2949.546
# Max: 2750365.474
# Min: -1691059.647
# Run nr.: 15
#
#  |OOOOOOOOOO| 100.0%   realization nr. 15. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.089 minutes
# Total elapsed time: 2.955 hours
# Variance: 271880870926.885
# Mean: 6991.079
# Max: 2321959.951
# Min: -2547664.277
# Run nr.: 16
#
#  |OOOOOOOOOO| 100.0%   realization nr. 16. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.139 minutes
# Total elapsed time: 3.141 hours
# Variance: 277559292722.698
# Mean: 2827.086
# Max: 2061294.683
# Min: -1663233.889
# Run nr.: 17
#
#  |OOOOOOOOOO| 100.0%   realization nr. 17. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.019 minutes
# Total elapsed time: 3.324 hours
# Variance: 261629060544.818
# Mean: 2329.053
# Max: 2743859.966
# Min: -1640412.071
# Run nr.: 18
#
#  |OOOOOOOOOO| 100.0%   realization nr. 18. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.140 minutes
# Total elapsed time: 3.510 hours
# Variance: 255001364421.955
# Mean: 3582.880
# Max: 2691525.622
# Min: -1680449.782
# Run nr.: 19
#
#  |OOOOOOOOOO| 100.0%   realization nr. 19. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.128 minutes
# Total elapsed time: 3.696 hours
# Variance: 267922967832.104
# Mean: 1324.276
# Max: 2538537.359
# Min: -1650775.248
# Run nr.: 20
#
#  |OOOOOOOOOO| 100.0%   realization nr. 20. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.258 minutes
# Total elapsed time: 3.883 hours
# Variance: 273197812199.911
# Mean: 9342.831
# Max: 2705694.881
# Min: -1752519.687
# Run nr.: 21
#
#  |OOOOOOOOOO| 100.0%   realization nr. 21. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.045 minutes
# Total elapsed time: 4.067 hours
# Variance: 278779688830.960
# Mean: 4384.659
# Max: 2686982.081
# Min: -1748911.289
# Run nr.: 22
#
#  |OOOOOOOOOO| 100.0%   realization nr. 22. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.245 minutes
# Total elapsed time: 4.255 hours
# Variance: 250058901855.613
# Mean: 6284.448
# Max: 2693133.653
# Min: -1653807.696
# Run nr.: 23
#
#  |OOOOOOOOOO| 100.0%   realization nr. 23. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.209 minutes
# Total elapsed time: 4.441 hours
# Variance: 248254881604.640
# Mean: 3719.010
# Max: 2702122.562
# Min: -1569999.139
# Run nr.: 24
#
#  |OOOOOOOOOO| 100.0%   realization nr. 24. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.126 minutes
# Total elapsed time: 4.627 hours
# Variance: 274292316651.726
# Mean: 1292.870
# Max: 2723506.390
# Min: -2198309.617
# Run nr.: 25
#
#  |OOOOOOOOOO| 100.0%   realization nr. 25. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.004 minutes
# Total elapsed time: 4.810 hours
# Variance: 259005896097.538
# Mean: 5477.538
# Max: 2412175.597
# Min: -1660799.478
# Run nr.: 26
#
#  |OOOOOOOOOO| 100.0%   realization nr. 26. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.146 minutes
# Total elapsed time: 4.996 hours
# Variance: 262224675420.409
# Mean: -1022.928
# Max: 2708121.488
# Min: -1598579.781
# Run nr.: 27
#
#  |OOOOOOOOOO| 100.0%   realization nr. 27. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.175 minutes
# Total elapsed time: 5.182 hours
# Variance: 264054621067.251
# Mean: 1658.604
# Max: 2319944.534
# Min: -1649635.224
# Run nr.: 28
#
#  |OOOOOOOOOO| 100.0%   realization nr. 28. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.070 minutes
# Total elapsed time: 5.367 hours
# Variance: 259659874814.150
# Mean: 313.207
# Max: 2758268.763
# Min: -1765171.091
# Run nr.: 29
#
#  |OOOOOOOOOO| 100.0%   realization nr. 29. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.116 minutes
# Total elapsed time: 5.552 hours
# Variance: 262925300431.432
# Mean: 3401.889
# Max: 2713767.620
# Min: -1774285.920
# Run nr.: 30
#
#  |OOOOOOOOOO| 100.0%   realization nr. 30. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.190 minutes
# Total elapsed time: 5.739 hours
# Variance: 278458496345.719
# Mean: 3701.481
# Max: 2716197.338
# Min: -1882973.353
# Run nr.: 31
#
#  |OOOOOOOOOO| 100.0%   realization nr. 31. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.192 minutes
# Total elapsed time: 5.925 hours
# Variance: 259641946041.381
# Mean: 3989.225
# Max: 2293533.762
# Min: -1678724.302
# Run nr.: 32
#
#  |OOOOOOOOOO| 100.0%   realization nr. 32. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.187 minutes
# Total elapsed time: 6.112 hours
# Variance: 267136854166.623
# Mean: 3987.141
# Max: 2597335.617
# Min: -2139719.031
# Run nr.: 33
#
#  |OOOOOOOOOO| 100.0%   realization nr. 33. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.197 minutes
# Total elapsed time: 6.298 hours
# Variance: 250084759342.804
# Mean: 4362.020
# Max: 2028892.481
# Min: -1646040.218
# Run nr.: 34
#  |OOOOOOOOOO| 100.0%   realization nr. 34. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.074 minutes
# Total elapsed time: 6.483 hours
# Variance: 272298636350.408
# Mean: 3512.278
# Max: 2732011.873
# Min: -1911303.193
# Run nr.: 35
#
#  |OOOOOOOOOO| 100.0%   realization nr. 35. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.332 minutes
# Total elapsed time: 6.672 hours
# Variance: 263822853774.035
# Mean: 4028.704
# Max: 2682757.099
# Min: -1688919.145
# Run nr.: 36
#
#  |OOOOOOOOOO| 100.0%   realization nr. 36. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.871 minutes
# Total elapsed time: 6.853 hours
# Variance: 263051878399.764
# Mean: 4452.249
# Max: 2663221.457
# Min: -1657225.994
# Run nr.: 37
#
#  |OOOOOOOOOO| 100.0%   realization nr. 37. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.892 minutes
# Total elapsed time: 7.034 hours
# Variance: 283671148941.783
# Mean: 506.204
# Max: 2740658.736
# Min: -1785381.462
# Run nr.: 38
#
#  |OOOOOOOOOO| 100.0%   realization nr. 38. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.030 minutes
# Total elapsed time: 7.218 hours
# Variance: 239142661736.231
# Mean: 3300.763
# Max: 2219903.656
# Min: -1934186.173
# Run nr.: 39
#
#  |OOOOOOOOOO| 100.0%   realization nr. 39. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.865 minutes
# Total elapsed time: 7.399 hours
# Variance: 261997808853.248
# Mean: 8652.511
# Max: 2795211.081
# Min: -1658032.782
# Run nr.: 40
#
#  |OOOOOOOOOO| 100.0%   realization nr. 40. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.868 minutes
# Total elapsed time: 7.580 hours
# Variance: 268800457283.051
# Mean: 10182.748
# Max: 2714167.600
# Min: -1665002.619
# Run nr.: 41
#
#  |OOOOOOOOOO| 100.0%   realization nr. 41. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.972 minutes
# Total elapsed time: 7.763 hours
# Variance: 256025568814.796
# Mean: 1520.811
# Max: 1978352.798
# Min: -1661879.217
# Run nr.: 42
#
#  |OOOOOOOOOO| 100.0%   realization nr. 42. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.952 minutes
# Total elapsed time: 7.946 hours
# Variance: 275532105333.194
# Mean: -175.594
# Max: 2404638.241
# Min: -1685583.290
# Run nr.: 43
#
#  |OOOOOOOOOO| 100.0%   realization nr. 43. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.933 minutes
# Total elapsed time: 8.128 hours
# Variance: 266400813013.620
# Mean: 6094.784
# Max: 2743628.659
# Min: -1626211.915
# Run nr.: 44
#
#  |OOOOOOOOOO| 100.0%   realization nr. 44. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.889 minutes
# Total elapsed time: 8.310 hours
# Variance: 256570370957.897
# Mean: 4691.367
# Max: 2704501.735
# Min: -1654032.328
# Run nr.: 45
#
#  |OOOOOOOOOO| 100.0%   realization nr. 45. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.976 minutes
# Total elapsed time: 8.492 hours
# Variance: 258377194027.709
# Mean: 3687.103
# Max: 2078546.047
# Min: -1613736.981
# Run nr.: 46
#
#  |OOOOOOOOOO| 100.0%   realization nr. 46. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.029 minutes
# Total elapsed time: 8.676 hours
# Variance: 305634508318.758
# Mean: 4057.505
# Max: 2818093.459
# Min: -1675295.995
# Run nr.: 47
#
#  |OOOOOOOOOO| 100.0%   realization nr. 47. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.886 minutes
# Total elapsed time: 8.858 hours
# Variance: 263722694057.590
# Mean: -1927.336
# Max: 2724086.246
# Min: -1586688.076
# Run nr.: 48
#
#  |OOOOOOOOOO| 100.0%   realization nr. 48. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.065 minutes
# Total elapsed time: 9.042 hours
# Variance: 246745551307.924
# Mean: 3041.081
# Max: 2767787.933
# Min: -2022134.221
# Run nr.: 49
#
#  |OOOOOOOOOO| 100.0%   realization nr. 49. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.104 minutes
# Total elapsed time: 9.227 hours
# Variance: 276591411626.399
# Mean: 2400.728
# Max: 2720044.141
# Min: -1669336.324
# Run nr.: 50
#
#  |OOOOOOOOOO| 100.0%   realization nr. 50. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.012 minutes
# Total elapsed time: 9.411 hours
# Variance: 251024218650.943
# Mean: 4888.240
# Max: 2347757.684
# Min: -1651712.574
# Run nr.: 51
#
#  |OOOOOOOOOO| 100.0%   realization nr. 51. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.961 minutes
# Total elapsed time: 9.593 hours
# Variance: 273474519976.665
# Mean: 4240.309
# Max: 2428524.993
# Min: -1795419.683
# Run nr.: 52
#
#  |OOOOOOOOOO| 100.0%   realization nr. 52. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.006 minutes
# Total elapsed time: 9.777 hours
# Variance: 261762250934.214
# Mean: -1053.999
# Max: 2744230.762
# Min: -1632954.594
# Run nr.: 53
#
#  |OOOOOOOOOO| 100.0%   realization nr. 53. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.004 minutes
# Total elapsed time: 9.960 hours
# Variance: 282360361848.042
# Mean: 2755.885
# Max: 2711962.375
# Min: -1644879.385
# Run nr.: 54
#
#  |OOOOOOOOOO| 100.0%   realization nr. 54. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.082 minutes
# Total elapsed time: 10.145 hours
# Variance: 269887491142.077
# Mean: 6464.149
# Max: 2230825.566
# Min: -2460024.323
# Run nr.: 55
#
#  |OOOOOOOOOO| 100.0%   realization nr. 55. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.100 minutes
# Total elapsed time: 10.330 hours
# Variance: 282347813319.653
# Mean: -975.082
# Max: 2703468.856
# Min: -1651682.055
# Run nr.: 56
#
#  |OOOOOOOOOO| 100.0%   realization nr. 56. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.006 minutes
# Total elapsed time: 10.513 hours
# Variance: 269532772839.173
# Mean: 3135.631
# Max: 2724716.269
# Min: -1595490.131
# Run nr.: 57
#
#  |OOOOOOOOOO| 100.0%   realization nr. 57. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.995 minutes
# Total elapsed time: 10.697 hours
# Variance: 272257605920.000
# Mean: 6735.011
# Max: 2773576.275
# Min: -1673541.811
# Run nr.: 58
#
#  |OOOOOOOOOO| 100.0%   realization nr. 58. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.005 minutes
# Total elapsed time: 10.880 hours
# Variance: 249104977588.035
# Mean: 2442.269
# Max: 1993012.075
# Min: -1648906.365
# Run nr.: 59
#
#  |OOOOOOOOOO| 100.0%   realization nr. 59. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.974 minutes
# Total elapsed time: 11.063 hours
# Variance: 268660591907.888
# Mean: 5506.608
# Max: 2690635.050
# Min: -1650239.262
# Run nr.: 60
#
#  |OOOOOOOOOO| 100.0%   realization nr. 60. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.942 minutes
# Total elapsed time: 11.245 hours
# Variance: 252447351335.367
# Mean: 5847.159
# Max: 2675056.490
# Min: -1677629.429
# Run nr.: 61
#
#  |OOOOOOOOOO| 100.0%   realization nr. 61. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.095 minutes
# Total elapsed time: 11.430 hours
# Variance: 252195526964.278
# Mean: 2634.205
# Max: 2688173.516
# Min: -1653159.524
# Run nr.: 62
#
#  |OOOOOOOOOO| 100.0%   realization nr. 62. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.179 minutes
# Total elapsed time: 11.617 hours
# Variance: 269624493420.388
# Mean: 1223.202
# Max: 2737294.842
# Min: -1669062.243
# Run nr.: 63
#
#  |OOOOOOOOOO| 100.0%   realization nr. 63. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.927 minutes
# Total elapsed time: 11.799 hours
# Variance: 257742298070.655
# Mean: 4662.052
# Max: 2719820.795
# Min: -1587671.551
# Run nr.: 64
#
#  |OOOOOOOOOO| 100.0%   realization nr. 64. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.081 minutes
# Total elapsed time: 11.983 hours
# Variance: 265560509796.181
# Mean: 8187.558
# Max: 2005071.796
# Min: -1665963.776
# Run nr.: 65
#
#  |OOOOOOOOOO| 100.0%   realization nr. 65. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.216 minutes
# Total elapsed time: 12.170 hours
# Variance: 262344940438.058
# Mean: 4344.255
# Max: 2719144.405
# Min: -1624062.501
# Run nr.: 66
#
#  |OOOOOOOOOO| 100.0%   realization nr. 66. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.024 minutes
# Total elapsed time: 12.354 hours
# Variance: 241954701387.774
# Mean: 7260.628
# Max: 2067296.819
# Min: -1681050.603
# Run nr.: 67
#
#  |OOOOOOOOOO| 100.0%   realization nr. 67. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.021 minutes
# Total elapsed time: 12.538 hours
# Variance: 264683698748.970
# Mean: -455.416
# Max: 2692899.778
# Min: -1723050.606
# Run nr.: 68
#  |OOOOOOOOOO| 100.0%   realization nr. 68. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.005 minutes
# Total elapsed time: 12.721 hours
# Variance: 260742157046.408
# Mean: 6763.138
# Max: 2693288.069
# Min: -1586254.993
# Run nr.: 69
#
#  |OOOOOOOOOO| 100.0%   realization nr. 69. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.024 minutes
# Total elapsed time: 12.905 hours
# Variance: 264881197999.740
# Mean: 5017.731
# Max: 2714737.151
# Min: -1646639.105
# Run nr.: 70
#
#  |OOOOOOOOOO| 100.0%   realization nr. 70. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.912 minutes
# Total elapsed time: 13.087 hours
# Variance: 264781210729.663
# Mean: 16153.249
# Max: 1872633.357
# Min: -1660829.633
# Run nr.: 71
#
#  |OOOOOOOOOO| 100.0%   realization nr. 71. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.911 minutes
# Total elapsed time: 13.269 hours
# Variance: 281538282963.855
# Mean: 8311.940
# Max: 2678999.861
# Min: -1640291.717
# Run nr.: 72
#
#  |OOOOOOOOOO| 100.0%   realization nr. 72. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.875 minutes
# Total elapsed time: 13.450 hours
# Variance: 243151866222.329
# Mean: 1093.861
# Max: 1863134.239
# Min: -1628905.097
# Run nr.: 73
#
#  |OOOOOOOOOO| 100.0%   realization nr. 73. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.991 minutes
# Total elapsed time: 13.633 hours
# Variance: 256043444084.997
# Mean: 1602.543
# Max: 2678588.433
# Min: -1644851.010
# Run nr.: 74
#
#  |OOOOOOOOOO| 100.0%   realization nr. 74. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.002 minutes
# Total elapsed time: 13.816 hours
# Variance: 260120323602.488
# Mean: 2970.632
# Max: 1779936.507
# Min: -1502951.625
# Run nr.: 75
#
#  |OOOOOOOOOO| 100.0%   realization nr. 75. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.991 minutes
# Total elapsed time: 14.000 hours
# Variance: 253013862399.230
# Mean: 5169.340
# Max: 2734962.269
# Min: -1650810.109
# Run nr.: 76
#
#  |OOOOOOOOOO| 100.0%   realization nr. 76. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.060 minutes
# Total elapsed time: 14.184 hours
# Variance: 273704057262.411
# Mean: 4792.302
# Max: 2716488.986
# Min: -1666587.392
# Run nr.: 77
#
#  |OOOOOOOOOO| 100.0%   realization nr. 77. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.904 minutes
# Total elapsed time: 14.366 hours
# Variance: 263241905982.143
# Mean: 4908.820
# Max: 2736117.602
# Min: -1675644.620
# Run nr.: 78
#
#  |OOOOOOOOOO| 100.0%   realization nr. 78. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.920 minutes
# Total elapsed time: 14.548 hours
# Variance: 282482768477.975
# Mean: 6066.717
# Max: 2738454.098
# Min: -1674610.755
# Run nr.: 79
#
#  |OOOOOOOOOO| 100.0%   realization nr. 79. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.855 minutes
# Total elapsed time: 14.729 hours
# Variance: 273838762593.666
# Mean: 4791.757
# Max: 2685518.180
# Min: -1691584.515
# Run nr.: 80
#
#  |OOOOOOOOOO| 100.0%   realization nr. 80. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.036 minutes
# Total elapsed time: 14.912 hours
# Variance: 267766794175.356
# Mean: 1945.955
# Max: 2698835.383
# Min: -1651393.369
# Run nr.: 81
#
#  |OOOOOOOOOO| 100.0%   realization nr. 81. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.987 minutes
# Total elapsed time: 15.096 hours
# Variance: 252559915727.731
# Mean: 3470.371
# Max: 1947656.655
# Min: -1569580.740
# Run nr.: 82
#
#  |OOOOOOOOOO| 100.0%   realization nr. 82. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.812 minutes
# Total elapsed time: 15.276 hours
# Variance: 280598331908.799
# Mean: 3953.214
# Max: 2731179.908
# Min: -1669431.296
# Run nr.: 83
#
#  |OOOOOOOOOO| 100.0%   realization nr. 83. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.969 minutes
# Total elapsed time: 15.459 hours
# Variance: 276431089744.443
# Mean: 6116.668
# Max: 2779497.999
# Min: -1654858.109
# Run nr.: 84
#
#  |OOOOOOOOOO| 100.0%   realization nr. 84. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.118 minutes
# Total elapsed time: 15.644 hours
# Variance: 263872358102.906
# Mean: 755.624
# Max: 2726543.750
# Min: -1644396.037
# Run nr.: 85
#
#  |OOOOOOOOOO| 100.0%   realization nr. 85. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.885 minutes
# Total elapsed time: 15.825 hours
# Variance: 249220930309.480
# Mean: 7006.434
# Max: 1963466.775
# Min: -1656510.744
# Run nr.: 86
#
#  |OOOOOOOOOO| 100.0%   realization nr. 86. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.042 minutes
# Total elapsed time: 16.009 hours
# Variance: 280743907991.084
# Mean: -334.584
# Max: 2727235.886
# Min: -1784851.676
# Run nr.: 87
#
#  |OOOOOOOOOO| 100.0%   realization nr. 87. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.088 minutes
# Total elapsed time: 16.194 hours
# Variance: 268132013688.350
# Mean: 5168.715
# Max: 2753761.074
# Min: -2411521.399
# Run nr.: 88
#
#  |OOOOOOOOOO| 100.0%   realization nr. 88. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.926 minutes
# Total elapsed time: 16.376 hours
# Variance: 260131039189.516
# Mean: 4087.711
# Max: 2080150.784
# Min: -1680589.216
# Run nr.: 89
#
#  |OOOOOOOOOO| 100.0%   realization nr. 89. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.884 minutes
# Total elapsed time: 16.558 hours
# Variance: 278967304068.935
# Mean: 9874.784
# Max: 2696723.025
# Min: -1651856.306
# Run nr.: 90
#
#  |OOOOOOOOOO| 100.0%   realization nr. 90. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.921 minutes
# Total elapsed time: 16.740 hours
# Variance: 274038494449.308
# Mean: 4521.424
# Max: 2766240.335
# Min: -1642504.114
# Run nr.: 91
#
#  |OOOOOOOOOO| 100.0%   realization nr. 91. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.030 minutes
# Total elapsed time: 16.923 hours
# Variance: 286074800409.427
# Mean: 6531.915
# Max: 2742237.260
# Min: -1853926.285
# Run nr.: 92
#
#  |OOOOOOOOOO| 100.0%   realization nr. 92. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.948 minutes
# Total elapsed time: 17.106 hours
# Variance: 264213445237.456
# Mean: 4442.335
# Max: 2673502.030
# Min: -1744649.730
# Run nr.: 93
#
#  |OOOOOOOOOO| 100.0%   realization nr. 93. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.885 minutes
# Total elapsed time: 17.287 hours
# Variance: 268279719254.926
# Mean: 3999.965
# Max: 2308260.893
# Min: -1677961.375
# Run nr.: 94
#
#  |OOOOOOOOOO| 100.0%   realization nr. 94. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.854 minutes
# Total elapsed time: 17.468 hours
# Variance: 256646709401.823
# Mean: 3791.360
# Max: 2726296.388
# Min: -1647027.756
# Run nr.: 95
#
#  |OOOOOOOOOO| 100.0%   realization nr. 95. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.966 minutes
# Total elapsed time: 17.651 hours
# Variance: 254873661770.512
# Mean: 10320.013
# Max: 2697259.276
# Min: -1645238.711
# Run nr.: 96
#
#  |OOOOOOOOOO| 100.0%   realization nr. 96. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.040 minutes
# Total elapsed time: 17.835 hours
# Variance: 263961142266.831
# Mean: 2160.891
# Max: 2724325.312
# Min: -1664500.450
# Run nr.: 97
#
#  |OOOOOOOOOO| 100.0%   realization nr. 97. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.878 minutes
# Total elapsed time: 18.016 hours
# Variance: 254603961292.107
# Mean: 1774.951
# Max: 2717790.713
# Min: -1562788.351
# Run nr.: 98
#
#  |OOOOOOOOOO| 100.0%   realization nr. 98. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.862 minutes
# Total elapsed time: 18.197 hours
# Variance: 269795430312.465
# Mean: 1715.229
# Max: 2726713.974
# Min: -1588461.260
# Run nr.: 99
#
#  |OOOOOOOOOO| 100.0%   realization nr. 99. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.498 minutes
# Total elapsed time: 18.372 hours
# Variance: 243577206240.606
# Mean: 5213.792
# Max: 1953909.408
# Min: -1670485.234
# Run nr.: 100
#
#
# Seqsim RMSE:	 [[4.76232398 4.75397214 4.75679627 4.76836768 4.7719674  4.75877864
#   4.76975098 4.75853921 4.77181946 4.7701972  4.77682638 4.76574781
#   4.76283733 4.75943828 4.76561922 4.76793652 4.7768256  4.76040025
#   4.76296437 4.76251484 4.75827421 4.76137666 4.76227485 4.77337893
#   4.77168346 4.77274246 4.75876525 4.7519619  4.77118357 4.76332457
#   4.76851801 4.76145574 4.76684498 4.77060136 4.75628408 4.76147265
#   4.76566686 4.76120331 4.76919766 4.77847919 4.76209699 4.76713163
#   4.76442586 4.76204263 4.75793511 4.75947447 4.75687254 4.75896604
#   4.76701256 4.76725312 4.75689494 4.75706912 4.76985843 4.76405941
#   4.7632571  4.75833918 4.7628495  4.75833771 4.7595895  4.76518942
#   4.77126994 4.76107373 4.76620662 4.77089847 4.7714652  4.75706929
#   4.75998182 4.75693043 4.76107166 4.7749039  4.7775487  4.7546954
#   4.76847687 4.77291214 4.75673262 4.76213676 4.78008221 4.7614647
#   4.75891715 4.75361885 4.76038343 4.76277234 4.7793464  4.77510982
#   4.75667766 4.76335779 4.7677598  4.76176491 4.76136662 4.78320861
#   4.75699988 4.77065363 4.75399503 4.75540772 4.77966025 4.77296157
#   4.76057712 4.76491335 4.77994578 4.76205221]]
# <img src="data:image/png;base64,..." width="640">

# %%
core.realization_to_sh_coeff(core.r_cmb, set_nmax = shc_g)

# %%
core.covmod_lsq_equiv(s_sat.data, core.C_mm_all, core.G, core.r_cmb)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)
mt_util.plot_sdssim_reproduce(core, core.m_DSS_res, m_equiv_lsq = core.m_equiv_lsq, truth_obj = None,
                              lags_use = 1000, spec_r_at = core.r_cmb, spec_show_differences = False,
                              model_dict = {"CHAOS-7"}, figsize=(9,16),
                              hist_bins = 25, res_bins = 25,
                              savefig = False, save_string = "core_sh30_obs_Qlarge", save_dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
skip = 1

m_skip = core.m_DSS[:,:][0::skip]

lat_skip = core.lat[0::skip]

lon_skip = core.lon[0::skip]

# %%
N_bins = 100
m_centers = []
m_y = []

for i in np.arange(0,m_skip.shape[0]):
    y,binEdges=np.histogram(m_skip[i,:],bins=N_bins)
    bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
    
    m_centers.append(bincenters)
    m_y.append(y)
    
m_centers = np.array(m_centers)
m_y = np.array(m_y)

# %%
deg_range = 1

lat_skip_lin = np.linspace(lat_skip-deg_range,lat_skip+deg_range,N_bins)
lon_skip_lin = np.linspace(lon_skip-2*deg_range,lon_skip+2*deg_range,N_bins)

# %%
m_y_scaled = []

for i in np.arange(0,m_skip.shape[0]):
    scale = np.min(lat_skip_lin[:,i]) + (m_y[i,:]-np.min(m_y[i,:]))*(np.max(lat_skip_lin[:,i])-np.min(lat_skip_lin[:,i]))/(np.max(m_y[i,:])-np.min(m_y[i,:]))

    m_y_scaled.append(scale)
    
m_y_scaled = np.array(m_y_scaled)

# %%
local_lat = m_y_scaled.reshape(-1,)

local_lon = lon_skip_lin.T.reshape(-1,)

local_data = m_centers.reshape(-1,)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)



mt_util.plot_global(lat = local_lat, lon = local_lon, data = local_data, 
                cbar_h = 0.03, cbar_mm_factor = 2/3, unit_transform_n_to_m = True,
                cbar_text = "mT", figsize=(9,10), coast_width = 0.4,
                bottom=0.5, top=0.95, hspace=0.01, left = 0.05,
                title='Local model parameter distributions', point_size=0.05, projection_transformation = "PlateCarree",
                savefig = False, save_dpi = 100, save_string ="core_sh30_obs_Qlarge_loc_mod_dist",
                use_gridlines = True, gridlines_width = 0.4, gridlines_alpha = 0.4)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
core.grid_glq(nmax = 256, r_at = core.r_cmb)
#core.grid_glq(nmax = 120, r_at = core.r_cmb)

set_nmax = shc_g

core.ensemble_B(core.g_spec, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_eqa = core.B_ensemble[:,0,:].copy()

#core.g_spec_mean = np.mean(core.g_spec,axis=1)
core.ensemble_B(core.g_spec_mean, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_mean_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
#core.ensemble_B(s_sat.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
#prior_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_lsq_equiv, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
#lsq_eqa = core.B_ensemble[:,0].copy()

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)
# ccrs.PlateCarree()
# ccrs.Mollweide()
# ccrs.Orthographic(central_longitude=0.0, central_latitude=0.0)

mt_util.plot_ensemble_map_tiles(core.grid_phi, 90-core.grid_theta, zs_eqa, 
                        field_mean = zs_mean_eqa,
                        tile_size_row = 4, tile_size_column = 2, 
                        figsize=(9,12), limit_for_SF = 10**6, point_size = 10, cbar_mm_factor = 2/3,
                        coast_width = 0.4, coast_color = "grey", unit_transform_n_to_m = True,
                        cbar_h = 0.1, cbar_text = "mT", cbar_text_color = "black",
                        left=0.03, bottom=0.12, right=0.97, top=0.95, wspace = 0.05, hspace=0.15, 
                        savefig = False, save_string = "core_sh30_obs_Qlarge", 
                        projection = ccrs.Mollweide(), use_gridlines = True, 
                        gridlines_width = 0.4, gridlines_alpha = 0.4, save_dpi = 100)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# SAVE RESULT
#print("\nSaving job")
#file_clip = open("core_{}.obj".format(nb_name), "wb")
#pickle.dump(core, file_clip, protocol=4)
#file_clip.close()

#file_clip = open("sat_{}.obj".format(nb_name), "wb")
#pickle.dump(s_sat, file_clip, protocol=4)
#file_clip.close()
#print("\nJob saved and finished")
