# %%
# %matplotlib notebook

from sdss import SDSS
import mikkel_tools.utility as mt_util
import plot as sds_plt

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Core

# %%
comment = "first try with new setup"

core = SDSS(comment, N_SH = 30, sim_type = "core", sat_height = 350)

#core.grid_glq(nmax = 38, r_at = core.r_cmb)
core.grid_glq_np(nmax = 30, r_at = core.r_cmb)

grid_in = np.array([core.grid_glq_phi, 90-core.grid_glq_theta]).T
core.grid(core.r_cmb, grid_in, calc_sph_d = True)

#core.grid(core.r_cmb, "gauss_leg", calc_sph_d = True, N_grid = 3000)

# %%
plt.figure()
plt.imshow(core.sph_d)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
core.generate_map()
#core.data()

# %%
mt_util.plot_cartopy_global(lat = core.lat, lon = core.lon, plot_quality = "high", 
                            data=core.data, point_size=10, shift_grid = True, 
                            transpose_grid = True, shape = (121,61), cmap = 'PuOr_r', 
                            title="Prior radial core information")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
core.condtab()
core.semivar(model_lags = 'all', model = "exponential", max_dist = 5000, lag_length = 50, zero_nugget = True)
# Out:
# ____semi-variogram setup___
#
# Number of data used: 1419240
# Max data distance: 4998.608 km
# Lag length chosen: 50.0 km
# Number of lags: 99
# Number of modelling lags: all
#
# Semi-variogram model determined, starting LUT computation

# %%
plt.figure()
plt.imshow(core.sv_lut)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#%% PLOT SEMI-VARIOGRAM
plt.figure(figsize=(10,8)) 
plt.plot(core.lags,core.pics,'o', markersize=10,color = '0.85',label='data semi-variogram')
plt.plot(core.lags_model,core.pics_model,'.',markersize=10,label='modelling data')
plt.plot(core.lags_sv_curve,core.sv_curve,color='C1',linewidth = 3,label='model')
plt.ylabel('Semi-variance $[%s^2]$' % "nT",fontsize=18,labelpad=18)
plt.xlabel('Lag [km]',fontsize=18,labelpad=18)
plt.title("Semi-variogram model of type: %s " % core.model_names[core.model],fontsize=18,y=1.02)
plt.legend(loc='best',fontsize=18)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
print(core)
# Out:
# ______current attributes______
#
# a:                     6371.2
# r_sat:                 6721.2
# r_cmb:                 3480.0
# rad:                   0.017453292519943295
# mu0:                   1.2566370614359173e-06
# comment:               first try with new setup
# class_abs_path:        /home/mikotz/spherical_direct_sequential_simulation
# N_SH:                  30
# sim_type:              core
# weights:               (1800,), Max/Min: 0.10 / 0.01
# grid_glq_radial:       (30,), Max/Min: 3480.00 / 3480.00
# grid_glq_theta:        (1800,), Max/Min: 175.48 / 4.52
# grid_glq_phi:          (1800,), Max/Min: 354.00 / 0.00
# grid_glq_N:            1800
# grid_glq_nmax:         30
# r_grid:                3480.0
# grid:                  (1800, 2)
# sph_d:                 (1800, 1800)
# lon:                   (1800,), Max/Min: 354.00 / 0.00
# lat:                   (1800,), Max/Min: 85.48 / -85.48
# N_grid:                1800
# data:                  (1800,), Max/Min: 2605459.15 / -1617357.24
# r_grid_repeat:         (1800,), Max/Min: 3480.00 / 3480.00
# target_var:            281032362075.1064
# target_mean_true:      -10682.451525756915
# target_mean:           0.0
# CQF_dist:              (501, 101, 100)
# CQF_mean:              (501, 101)
# CQF_var:               (501, 101)
# rangv:                 (101,), Max/Min: 2.00 / 0.00
# rangn:                 (501,), Max/Min: 3.50 / -3.50
# sort_d:                (1419240,), Max/Min: 3239999.00 / 0.00
# cloud_sorted:          (1419240,), Max/Min: 16432963409727.90 / 0.00
# sph_d_sorted:          (1419240,), Max/Min: 4998.61 / 0.00
# max_cloud:             1419240
# n_lags:                99
# lags:                  (98,), Max/Min: 4934.22 / 0.00
# pics:                  (98,), Max/Min: 271503500088.20 / 0.00
# model_select_simple:   False
# model_select_advanced: False
# lags_model:            (98,), Max/Min: 4934.22 / 0.00
# pics_model:            (98,), Max/Min: 271503500088.20 / 0.00
# lags_sv_curve:         (98,), Max/Min: 4934.00 / 0.00
# sv_curve:              (98,), Max/Min: 205104240477.94 / 0.00
# sv_lut:                (1800, 1800)
# model:                 exponential
# a_sv:                  3658.1436731741796
# C0:                    0.0
# C1:                    208754671258.75824
# C2:                    None
# C3:                    None

# %% [markdown]
# # Synthetic sat

# %%
comment = "first try with new setup"

s_sat = SDSS(comment, N_SH = 60, sim_type = "sat", sat_height = 350)

#s_sat.grid_even_spaced(grid_size=3.0, r_at = 1)
s_sat.grid_equal_area(N_grid= 3010, r_at = s_sat.r_sat, poles_remove = True)

grid_in = np.array([s_sat.grid_eqa_phi, 90-s_sat.grid_eqa_theta]).T
s_sat.grid(s_sat.r_sat, grid_in, calc_sph_d = False)

#s_sat.grid(s_sat.r_sat, "equal_area", N_grid = 3010)

# %%
s_sat.generate_map(grid_type = "eqa")

# %%
print(s_sat)
# Out:
# ______current attributes______
#
# a:                6371.2
# r_sat:            6721.2
# r_cmb:            3480.0
# rad:              0.017453292519943295
# mu0:              1.2566370614359173e-06
# comment:          first try with new setup
# class_abs_path:   /home/mikotz/spherical_direct_sequential_simulation
# N_SH:             60
# sim_type:         sat
# n_regions:        (1, 47)
# s_cap:            (1, 47)
# grid_eqa_radial:  (3008,), Max/Min: 6721.20 / 6721.20
# grid_eqa_theta:   (3008,), Max/Min: 176.00 / 4.00
# grid_eqa_phi:     (3008,), Max/Min: 359.85 / 0.27
# grid_eqa_N:       3008
# r_grid:           6721.2
# grid:             (3008, 2)
# sph_d:            None
# lon:              (3008,), Max/Min: 359.85 / 0.27
# lat:              (3008,), Max/Min: 86.00 / -86.00
# N_grid:           3008
# data:             (3008,), Max/Min: 90095.01 / -88243.84
# r_grid_repeat:    (3008,), Max/Min: 6721.20 / 6721.20
# target_var:       2660351491.7487364
# target_mean_true: 0.9331243404514216
# target_mean:      0.0

# %%
# Reload plot module when making small changes
#import importlib
#importlib.reload(mt_util)

# %%
mt_util.plot_cartopy_global(lat = s_sat.lat, lon = s_sat.lon, plot_quality = "high", point_size=5, 
                            data=s_sat.data, cmap = 'PuOr_r', title="Synthetic satellite data")
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
print(s_sat)
# Out:
# ______current attributes______
#
# a:                6371.2
# r_sat:            6721.2
# r_cmb:            3480.0
# rad:              0.017453292519943295
# mu0:              1.2566370614359173e-06
# comment:          first try with new setup
# class_abs_path:   /home/mikotz/spherical_direct_sequential_simulation
# N_SH:             60
# sim_type:         sat
# n_regions:        (1, 47)
# s_cap:            (1, 47)
# grid_eqa_radial:  (3008,), Max/Min: 6721.20 / 6721.20
# grid_eqa_theta:   (3008,), Max/Min: 176.00 / 4.00
# grid_eqa_phi:     (3008,), Max/Min: 359.85 / 0.27
# grid_eqa_N:       3008
# r_grid:           6721.2
# grid:             (3008, 2)
# sph_d:            None
# lon:              (3008,), Max/Min: 359.85 / 0.27
# lat:              (3008,), Max/Min: 86.00 / -86.00
# N_grid:           3008
# data:             (3008,), Max/Min: 90095.01 / -88243.84
# r_grid_repeat:    (3008,), Max/Min: 6721.20 / 6721.20
# target_var:       2660351491.7487364
# target_mean_true: 0.9331243404514216
# target_mean:      0.0

# %%
G_r = mt_util.Gr_vec(core.r_grid, s_sat.r_grid, core.lat, s_sat.lat, core.lon, s_sat.lon)
G_d = np.pi/core.grid_glq_nmax*np.multiply(core.weights.T,G_r)

# %%
plt.figure()
plt.imshow(G_d)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Compute forward and get residuals to synthetic observations
fwd_leg = G_d*core.data.reshape(-1,1)
fwd_leg_res = s_sat.data - fwd_leg.reshape(-1,)

# RMSE
rmse_leg = np.sqrt(np.mean(np.power(fwd_leg_res,2)))

print("")
print("Gauss-Legendre RMSE:\t %0.11f" %rmse_leg)
plt.figure()
y,binEdges=np.histogram(fwd_leg_res,bins=200)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'C0',label="Gauss-Legendre")
plt.xlabel("Radiel field residuals [nT]")
plt.ylabel("Count")
plt.legend()
plt.show()
# Out:
# Gauss-Legendre RMSE:	 0.00003580538
# <img src="data:image/png;base64,..." width="640">

# %%
errorstd = 3
errorvar = errorstd**2

def covmod_lsq_equiv(obs,semivar,target_var,G_d,title="",errorvar = 10e2):
    a_0 = np.empty([0,])
    b_0 = obs
    d_0 = b_0

    G = G_d.copy()
    C_M = target_var - semivar
    C_D = np.zeros((len(a_0)+len(b_0),len(a_0)+len(b_0)))
    C_D[np.arange(len(a_0)+1,len(a_0)+len(b_0)),np.arange(len(a_0)+1,len(a_0)+len(b_0))] = errorvar
    S = C_D + G*C_M*G.T
    T = np.linalg.inv(S)
    m_equiv_lsq = C_M*G.T*T*d_0
    lsq_equiv_pred = G_d*m_equiv_lsq
    lsq_equiv_res = obs - lsq_equiv_pred
    return m_equiv_lsq, lsq_equiv_pred, lsq_equiv_res

m_equiv_lsq, lsq_equiv_pred, lsq_equiv_res = covmod_lsq_equiv(s_sat.data.reshape(-1,1),core.sv_lut,core.target_var,G_d,title="Gauss-Legendre equivalent LSQ solution",errorvar = errorvar)

# RMSE
rmse_leg = np.sqrt(np.mean(np.power(lsq_equiv_res,2)))
print("")
print("Gauss-Legendre RMSE:\t %0.3f" %rmse_leg)
plt.figure()
y,binEdges=np.histogram(lsq_equiv_res,bins=200)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'C0',label="Gauss-Legendre")
plt.xlabel("Radial field residuals [nT]")
plt.ylabel("Count")
plt.legend()
plt.show()

#sds_util.plot_cartopy_global_new(core.lat, core.lon, data=np.ravel(m_equiv_lsq), plot_quality = "high", cmap = 'PuOr_r', title="Gauss-Legendre equivalent LSQ solution", scale_uneven = False)
# Out:
# Gauss-Legendre RMSE:	 0.431
# <img src="data:image/png;base64,..." width="640">

# %%
mt_util.plot_cartopy_global(lat = core.lat, lon = core.lon, plot_quality = "high", 
                            data=np.ravel(m_equiv_lsq), point_size=10,
                            shape = (121,61), cmap = 'PuOr_r', 
                            title="Prior radial core information", limits_data = core.data)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
lsq_test = np.linalg.lstsq(G_d,s_sat.data, rcond=None)
data_lstsq = {"data":lsq_test[0]}

lstsq_pred = G_d*data_lstsq["data"].reshape(-1,1)
lstsq_res = s_sat.data - np.ravel(lstsq_pred)

rmse_leg = np.sqrt(np.mean(np.power(lstsq_res,2)))
print("")
print("LSQ RMSE:\t %0.10f" %rmse_leg)

plt.figure()
y,binEdges=np.histogram(lstsq_res,bins=200)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'C1')
plt.xlabel("Radiel field residuals [nT]")
plt.ylabel("Count")
plt.show()

#sds_util.cartopy_global_plot(data_core["lat"], data_core["lon"], data=data_lstsq["data"],vmin=np.min(data_core["data"]), vmax=np.max(data_core["data"]), cmap = 'PuOr_r', title="LSQ solution", scale_uneven = False)
# Out:
# LSQ RMSE:	 0.0000249391
# <img src="data:image/png;base64,..." width="640">

# %%
mt_util.plot_cartopy_global(lat = core.lat, lon = core.lon, plot_quality = "high", 
                            data=data_lstsq["data"], point_size=10,
                            shape = (121,61), cmap = 'PuOr_r', 
                            title="Prior radial core information", limits_data = core.data)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#% SEMI-VARIOGRAM
plt.figure(figsize=(10,6))

#plt.plot(core.lags_model,core.pics_model,'.',markersize=10,label='modelling data')

plt.plot(core.lags_sv_curve,core.sv_curve,color='C1',label='SV model')

core.sv_zs(core.grid_glq_N,1,core.data.reshape(-1,1),core.sort_d,core.n_lags,core.max_cloud)
plt.plot(core.lags,core.pics_zs[:,0],'k--',label='Core prior')  

core.sv_zs(core.grid_glq_N,1,np.array(m_equiv_lsq),core.sort_d,core.n_lags,core.max_cloud)
plt.plot(core.lags,core.pics_zs[:,0],color = 'C3',label='Seqsim equiv. LSQ')    

core.sv_zs(core.grid_glq_N,1,data_lstsq["data"].reshape(-1,1),core.sort_d,core.n_lags,core.max_cloud)
plt.plot(core.lags,core.pics_zs[:,0],color = 'C4',label='LSQ')  

#plt.plot(core.lags,core.pics,'o', markersize=10,color = '0.85',label='Core field estimate')


plt.ylabel('Semi-variance $[%s^2]$' % "nT",fontsize=18,labelpad=18)
plt.xlabel('Lag [km]',fontsize=18,labelpad=18)
plt.legend(loc='best',fontsize=18)
plt.show()

#% HISTOGRAM
plt.figure(figsize=(10,6))    

y,binEdges=np.histogram(core.data,bins=50,density=False)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'k--',label='Core prior')

y,binEdges=np.histogram(np.array(m_equiv_lsq),bins=50,density=False)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'-',color = 'C3',label='Seqsim equiv. LSQ')  

y,binEdges=np.histogram(data_lstsq["data"].reshape(-1,1),bins=50,density=False)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'-',color = 'C4',label='LSQ')    

plt.legend(loc='best',fontsize=18)
plt.xlabel('Field value %s' % "[nT]",fontsize=18,labelpad=18)
plt.ylabel('Count',fontsize=18,labelpad=18)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
#%% GREENS CORE
print(G_d.shape)
G_k = G_d*(core.target_var-core.sv_lut)
print(G_k.shape)
GG_K = G_k*G_d.T  + np.diag(errorvar*np.ones(s_sat.grid_eqa_N,))
print(GG_K.shape)
sort_support = np.flipud(np.argsort(G_k,axis=0))
idx_data_support = sort_support
# Out:
# (3008, 1800)
# (3008, 1800)
# (3008, 3008)

# %%
import time
import random

N_sim = 100
kriging_method = "simple"
eval_neg_weights = False
fixed_path = False
global_support = False
step_sup_array = np.geomspace(1,2,core.grid_glq_N)
"""
Possible kriging_method(s):
    - simple
    - ordinary
"""

"""efficiency ravels"""
shape = core.CQF_mean.shape

"""Number of simulations"""
zs = np.zeros((core.grid_glq_N,N_sim))
time_average = np.zeros((N_sim))

"""save variables"""
idx_nv = list()
lagrange = list()
kriging_mv = list()
rand_paths = list()
invshapes = list()
kriging_weights = list()
kriging_weights_rel_dat = list()
Zis = list()
lstsq_param = list()


""" Run sequential simulations"""    
for run in range(0,N_sim):
    
    M = np.empty([core.grid_glq_N,],dtype=float)
    # Start timing
    t0 = time.time()
    random.seed(a=None)
    np.random.seed()
    
    # Initialize sequential simulation with random start
    idx_rnd = np.arange( core.grid_glq_N )
    
    # Randomize index array to create random path
    random.shuffle(idx_rnd)
    
    """Run spherical direct sequential simulation"""
    
    #from sds_util import printProgressBar
    # create array for the output and initializations
    #M = np.zeros((setup_core["N"]))
    walked_in_reach = 0
    var_lz = 0
    idx_v = np.empty([0,],dtype=int)
    idx_n = np.empty([0,],dtype=int)
    data_min = np.min(core.data)
    data_max = np.max(core.data)

    dm = data_max - data_min
    dv = core.target_var

    locations_walked = np.empty([0,],dtype=int)
    CQF_dist_len = len(core.CQF_dist[0,0,:])
    
    len_walked = 0
    N_no_sim = 0
    save_weights = list()
    save_weights_rel_dat = list()
    save_lagrange = list()
    save_kriging_mv = list()
    save_idx_nv = list()
    save_invshape = list()
    save_lstsq = list()
    save_Zi = list()
    save_kesterr = list()
    save_mindist = list()
    save_kwksys = list()
    save_Ksyscond = list()
    save_err_mag = list()
    
    err_mag_sum = 0.0
    
    # Start random walk
    for step in idx_rnd:
    
        idx = step
        step_sup = int(step_sup_array[len_walked])
        
        K_ss = np.empty([0,],dtype=np.longdouble)
        K_dd = np.empty([0,],dtype=np.longdouble)
        K_ds = np.empty([0,],dtype=np.longdouble)
        K_sys = np.empty([0,],dtype=np.longdouble)
        
        k_ss = np.empty([0,1],dtype=np.longdouble)
        k_dd = np.empty([0,1],dtype=np.longdouble)
        k_sys = np.empty([0,],dtype=np.longdouble)
        
        Zk = np.empty([0,],dtype=np.longdouble)
        kriging_var = np.empty([0,],dtype=np.longdouble)
        idx_n = np.empty([0,],dtype=int)
        idx_v = np.empty([0,],dtype=int)
        Zf = np.empty([0,],dtype=np.longdouble)
        Zm = np.empty([0,],dtype=np.longdouble)
        Zm_true = np.empty([0,],dtype=np.longdouble)
        Zm_lstsq = np.empty([0,],dtype=np.longdouble)
        
        err_mag_avg = np.empty([0,],dtype=np.longdouble)
        
        idx_data_support_SN = np.empty([0,],dtype=int)
        
        vario_near = np.empty([0,],dtype=np.longdouble)
        idx_vario_sort = np.empty([0,],dtype=int)
        idx_SN = np.empty([0,],dtype=int)
        vario_SN = np.empty([0,],dtype=np.longdouble)
        kriging_weights = np.empty([0,],dtype=np.longdouble)
        Zi = np.empty([0,],dtype=np.longdouble)
        kwksys = np.empty([0,],dtype=np.longdouble)
        
        lagrange = 0.0
        lagrange_vert_sim = np.empty([0,],dtype=np.longdouble)
        lagrange_horz_sim = np.empty([0,],dtype=np.longdouble)
        
        lstsq_sol = np.empty([0,],dtype=np.longdouble)
        
        walked_in_reach += 1
        
        """ SORT METHOD """
        vario_near = core.sv_lut[idx,locations_walked]     
        sort_support = np.argsort(vario_near,axis=0)
        idx_loc_walk_use = locations_walked[sort_support]

        if len(vario_near) >= 1:
            len_sup = len(sort_support)
            idx_SN = np.ravel(np.matrix(idx_loc_walk_use).T)
            vario_SN = core.sv_lut[idx,idx_SN]
        else:             
            idx_SN = idx_loc_walk_use[:0]
            vario_SN = vario_near[sort_support][:0]
        
        """LIMITED DATA USE"""
        
        # Find nearest data
        idx_data_support_SN = idx_data_support[:,idx].T
        
        # G_d lookup for k_dd and K_ds
        look_G_d = G_d[np.ravel(idx_data_support_SN),:]
        #print(np.shape(look_G_d))
        
        # Set up k
        k_ss = core.target_var - np.matrix(vario_SN).T
        k_dd = np.matmul(look_G_d,(core.target_var-(core.sv_lut[idx,:]).T)).reshape(-1,1)
        
        # Lookup all closest location semi-variances to each other (efficiently)
        K_ss = core.target_var - (np.ravel(core.sv_lut)[(idx_SN + (idx_SN * core.sv_lut.shape[1]).reshape((-1,1))).ravel()]).reshape(idx_SN.size, idx_SN.size)
        
        # Efficient lookup of Greens
        K_dd = (np.ravel(GG_K)[(idx_data_support_SN + (idx_data_support_SN * GG_K.shape[1]).reshape((-1,1))).ravel()]).reshape(idx_data_support_SN.size, idx_data_support_SN.size)

        if len(idx_SN) >= 1:
            K_ds = np.matmul(look_G_d,core.target_var-core.sv_lut[idx_SN,:].T).T

        k_sys = np.vstack((k_ss,k_dd))
        
        K_sys = np.zeros((len(K_dd)+len(K_ss),len(K_dd)+len(K_ss)))
        K_sys[-len(K_dd):,-len(K_dd):] = K_dd
        
        if len(idx_SN) >= 1:
            K_sys[:len(K_ss),:len(K_ss)] = K_ss
            K_sys[:len(K_ss),-len(K_dd):] = K_ds
            K_sys[-len(K_dd):,:len(K_ss)] = K_ds.T

        Zi = np.matrix(np.matrix(M[idx_SN]).T)
        
        if len_walked > 0:
            #print(np.shape(np.ravel(B_s_r).reshape(-1,1)))
            #print(np.shape(Zi))
            Zi = np.vstack((Zi,s_sat.data[idx_data_support_SN].reshape(-1,1))).T
        else:
            Zi = s_sat.data[idx_data_support_SN].reshape(-1,1).T
            
        if np.size(Zk) == 0:                
            if kriging_method == "simple":
                """SIMPLE KRIGING (SK)"""
                if np.size(kriging_weights) == 0:
                    kriging_weights = np.linalg.solve(K_sys,k_sys)
                    
                    kesterr = np.linalg.norm(K_sys.dot(kriging_weights)-k_sys)
                    save_kesterr.append([kesterr])                          
                
                kwksys = np.float(kriging_weights.T*k_sys)

                kriging_var = core.target_var - kwksys
                Zk = np.float(np.array(kriging_weights.T*(Zi.T - core.target_mean) + core.target_mean))
                
            elif kriging_method == "ordinary":
                """ORDINARY KRIGING (OK)"""
                # ORDINARY KRIGING CONDITIONS FOR K MATRIX
                if np.size(kriging_weights) == 0:
                    lagrange_vert_sim = np.ones((len(K_sys),1))
                    lagrange_horz_sim = np.vstack((lagrange_vert_sim,0.0)).T
                    K_sys = np.append(K_sys, lagrange_vert_sim, axis=1)
                    K_sys = np.append(K_sys, lagrange_horz_sim, axis=0)
                    k_sys = np.vstack((k_sys,1.0))
                    
                    kriging_weights = np.linalg.solve(K_sys, k_sys)                   

                    kesterr = np.linalg.norm(K_sys.dot(kriging_weights)-k_sys)
                    save_kesterr.append([kesterr])
                        
                    lagrange = kriging_weights[-1]
                    kriging_weights = kriging_weights[:-1]
                    k_sys = k_sys[:-1] 
                    
                    # Possible re-evaluation of kriging weights such that negative kriging weights are set to zero
                    if eval_neg_weights == True:
                        kw_b_idx = kriging_weights<0.0
                        kw_b_sat = kw_b_idx[:len(k_dd)]
                        kw_b_cor = kw_b_idx[len(k_dd):]
                        kw_b = kriging_weights[kw_b_idx].T
                        kw_b_mag = 1/len(kw_b)*np.sum(np.abs(kw_b))
                        kw_C_mag = 1/len(kw_b)*(np.sum(k_dd[kw_b_sat])+np.sum(k_ss[kw_b_cor]))
                        kriging_weights_new = kriging_weights.copy()
                        kriging_weights_new[kw_b_idx] = 0.0
                        kw_b_idx_cond = np.logical_and.reduce((kriging_weights>0.0,k_sys<kw_C_mag,kriging_weights<kw_b_mag))                    
                        kriging_weights_new[kw_b_idx_cond] = 0.0
                        kriging_weights_final = kriging_weights_new/np.sum(kriging_weights_new)
                        kriging_weights = kriging_weights_final 
                    
                kwksys = np.float(kriging_weights.T*k_sys)
                kriging_var = core.target_var - kwksys - lagrange
                kriging_var = np.float(kriging_var)      
                Zk = np.float(np.array(kriging_weights.T*Zi))
                
        if kriging_var < 0.0:
            print("")
            print("Negative kriging variance: %s" %kriging_var)
            print("")
            if kriging_var > -0.001*core.target_var:
                kriging_var = 0.0
            else:
                break
        
        #dist = np.power((condtab["CQF mean"]-Zk)/dm,2)+np.power((condtab["CQF var"]-kriging_var)/dv,2)        
        dist = np.power((core.CQF_mean-Zk)/dm,2)+abs(core.CQF_var-kriging_var)/np.sqrt(dv)
        
        
        inv = np.unravel_index(np.argmin(dist),shape)
        idx_n = inv[0]
        idx_v = inv[-1]
        save_mindist.append(dist[inv[0],inv[-1]])
        
        Zf = core.CQF_dist[idx_n,idx_v,np.random.randint(0,CQF_dist_len,size=1)]
        
        Zf_mean = core.CQF_mean[idx_n,idx_v]        
        Zf_std = np.sqrt(core.CQF_var[idx_n,idx_v],dtype=np.float64)

        Zm = (Zf - Zf_mean)*np.sqrt(kriging_var)/Zf_std+Zk
        
        M[idx] = Zm
        
        # Count locations walked for search neighborhood
        locations_walked = np.append(locations_walked, idx)
        len_walked += 1
        
        # Save running variables
        save_invshape.append([np.shape(K_sys)])
        #save_lagrange.append(float(np.array(lagrange).ravel()))
        #save_kriging_mv.append([Zk, kriging_var])
        save_idx_nv.append([idx_n, idx_v])
        #save_weights.append(kriging_weights)
        #save_kwksys.append(kwksys)
        #save_Ksyscond.append(np.linalg.cond(K_sys))
        err_mag = np.log10(float(np.abs((core.data)[idx]-Zm)))
        err_mag_sum += err_mag
        err_mag_avg = float(err_mag_sum/len_walked)
        save_err_mag.append(err_mag)
        
        mt_util.printProgressBar (len(locations_walked), core.grid_glq_N, err_mag_avg, subject = ' realization nr. %d' % run)
        
    # End timing
    t1 = time.time()
    
    # Keep all realizations
    zs[:,run] = M
    
    # Plot statistics of run
    time_average[run] = (t1-t0)
    if time_average[run] < 60:
        print('Run time: %.3f' %(time_average[run]), 'seconds', '')
    elif time_average[run] < 3600:
        print('Run time: %.3f' %(time_average[run]*60**(-1)), 'minutes', '')
    else:
        print('Run time: %.3f' %(time_average[run]*60**(-2)), 'hours', '')
    if np.sum(time_average[:(run+1)])*60**(-1) > 60:
        print('Total elapsed time: %.3f' %(np.sum(time_average[:(run+1)])*60**(-2)), 'hours', '')
    else:
        print('Total elapsed time: %.3f' %(np.sum(time_average[:(run+1)])*60**(-1)), 'minutes', '')
        
    print('Variance: %.3f' %np.var(M))
    print('Mean: %.3f' %np.mean(M))
    print('Max: %.3f' %np.max(M))
    print('Min: %.3f' %np.min(M))
    print('Run nr.:', run+1)
    print('')
# Out:
#  |OOOOOOOOOO| 100.0%   realization nr. 0. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.693 minutes
# Total elapsed time: 14.693 minutes
# Variance: 253686753280.041
# Mean: -10904.653
# Max: 1928042.641
# Min: -2348869.970
# Run nr.: 1
#
#  |OOOOOOOOOO| 100.0%   realization nr. 1. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.705 minutes
# Total elapsed time: 29.398 minutes
# Variance: 254796388218.193
# Mean: -9155.294
# Max: 1626740.209
# Min: -1949375.636
# Run nr.: 2
#
#  |OOOOOOOOOO| 100.0%   realization nr. 2. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.634 minutes
# Total elapsed time: 44.032 minutes
# Variance: 260718430014.816
# Mean: -9704.628
# Max: 1682823.512
# Min: -1364525.590
# Run nr.: 3
#
#  |OOOOOOOOOO| 100.0%   realization nr. 3. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.776 minutes
# Total elapsed time: 58.808 minutes
# Variance: 258253520428.340
# Mean: -9315.782
# Max: 2697020.240
# Min: -1631099.839
# Run nr.: 4
#
#  |OOOOOOOOOO| 100.0%   realization nr. 4. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 21.402 minutes
# Total elapsed time: 1.337 hours
# Variance: 266788340224.957
# Mean: -10300.378
# Max: 1802582.958
# Min: -1430786.816
# Run nr.: 5
#
#  |OOOOOOOOOO| 100.0%   realization nr. 5. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 21.251 minutes
# Total elapsed time: 1.691 hours
# Variance: 259184759701.895
# Mean: -7983.769
# Max: 1788992.768
# Min: -1964269.563
# Run nr.: 6
#
#  |OOOOOOOOOO| 100.0%   realization nr. 6. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 21.133 minutes
# Total elapsed time: 2.043 hours
# Variance: 262958379349.634
# Mean: -11234.824
# Max: 2100414.430
# Min: -1431379.574
# Run nr.: 7
#
#  |OOOOOOOOOO| 100.0%   realization nr. 7. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 21.028 minutes
# Total elapsed time: 2.394 hours
# Variance: 269950481505.356
# Mean: -8618.991
# Max: 1750986.034
# Min: -1778569.530
# Run nr.: 8
#
#  |OOOOOOOOOO| 100.0%   realization nr. 8. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 20.860 minutes
# Total elapsed time: 2.741 hours
# Variance: 258141858538.592
# Mean: -9753.230
# Max: 1832241.670
# Min: -1311232.295
# Run nr.: 9
#
#  |OOOOOOOOOO| 100.0%   realization nr. 9. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 21.005 minutes
# Total elapsed time: 3.091 hours
# Variance: 261850644399.969
# Mean: -7441.650
# Max: 1864240.067
# Min: -1446100.846
# Run nr.: 10
#
#  |OOOOOOOOOO| 100.0%   realization nr. 10. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 21.111 minutes
# Total elapsed time: 3.443 hours
# Variance: 264541533472.504
# Mean: -10563.751
# Max: 2473042.672
# Min: -1614599.296
# Run nr.: 11
#
#  |OOOOOOOOOO| 100.0%   realization nr. 11. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 21.240 minutes
# Total elapsed time: 3.797 hours
# Variance: 256686871738.586
# Mean: -9532.118
# Max: 2334073.721
# Min: -2209962.856
# Run nr.: 12
#
#  |OOOOOOOOOO| 100.0%   realization nr. 12. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 21.186 minutes
# Total elapsed time: 4.150 hours
# Variance: 254379003512.595
# Mean: -9996.114
# Max: 2368947.632
# Min: -1626509.111
# Run nr.: 13
#
#  |OOOOOOOOOO| 100.0%   realization nr. 13. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 19.836 minutes
# Total elapsed time: 4.481 hours
# Variance: 259257325742.882
# Mean: -10092.854
# Max: 2213471.956
# Min: -1877127.273
# Run nr.: 14
#
#  |OOOOOOOOOO| 100.0%   realization nr. 14. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.472 minutes
# Total elapsed time: 4.722 hours
# Variance: 256496991799.653
# Mean: -7799.602
# Max: 2272758.420
# Min: -2197737.795
# Run nr.: 15
#
#  |OOOOOOOOOO| 100.0%   realization nr. 15. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.555 minutes
# Total elapsed time: 4.965 hours
# Variance: 258478637644.687
# Mean: -9855.087
# Max: 2931154.325
# Min: -1816722.991
# Run nr.: 16
#
#  |OOOOOOOOOO| 100.0%   realization nr. 16. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.399 minutes
# Total elapsed time: 5.205 hours
# Variance: 254037450638.450
# Mean: -12049.904
# Max: 2042214.548
# Min: -1456742.257
# Run nr.: 17
#
#  |OOOOOOOOOO| 100.0%   realization nr. 17. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.344 minutes
# Total elapsed time: 5.444 hours
# Variance: 256507050963.329
# Mean: -9620.248
# Max: 1586621.357
# Min: -1719325.711
# Run nr.: 18
#
#  |OOOOOOOOOO| 100.0%   realization nr. 18. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.410 minutes
# Total elapsed time: 5.684 hours
# Variance: 264008377134.036
# Mean: -8728.685
# Max: 1733155.371
# Min: -1562167.379
# Run nr.: 19
#
#  |OOOOOOOOOO| 100.0%   realization nr. 19. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.603 minutes
# Total elapsed time: 5.927 hours
# Variance: 261856891834.036
# Mean: -9426.650
# Max: 1734223.692
# Min: -1633960.699
# Run nr.: 20
#
#  |OOOOOOOOOO| 100.0%   realization nr. 20. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.504 minutes
# Total elapsed time: 6.169 hours
# Variance: 253555163339.238
# Mean: -9803.274
# Max: 1786341.190
# Min: -1881849.950
# Run nr.: 21
#
#  |OOOOOOOOOO| 100.0%   realization nr. 21. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.286 minutes
# Total elapsed time: 6.407 hours
# Variance: 258879324208.187
# Mean: -11093.227
# Max: 1606296.814
# Min: -1810888.641
# Run nr.: 22
#
#  |OOOOOOOOOO| 100.0%   realization nr. 22. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.454 minutes
# Total elapsed time: 6.648 hours
# Variance: 262784771631.132
# Mean: -11683.886
# Max: 1727696.403
# Min: -2222718.402
# Run nr.: 23
#
#  |OOOOOOOOOO| 100.0%   realization nr. 23. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.480 minutes
# Total elapsed time: 6.889 hours
# Variance: 260897655735.154
# Mean: -10346.119
# Max: 2214717.281
# Min: -1722096.179
# Run nr.: 24
#
#  |OOOOOOOOOO| 100.0%   realization nr. 24. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.453 minutes
# Total elapsed time: 7.130 hours
# Variance: 258079844551.854
# Mean: -9824.043
# Max: 1594015.581
# Min: -1413779.026
# Run nr.: 25
#
#  |OOOOOOOOOO| 100.0%   realization nr. 25. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.359 minutes
# Total elapsed time: 7.370 hours
# Variance: 266090936404.609
# Mean: -10536.384
# Max: 1936527.842
# Min: -2322565.920
# Run nr.: 26
#
#  |OOOOOOOOOO| 100.0%   realization nr. 26. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.528 minutes
# Total elapsed time: 7.612 hours
# Variance: 260728434134.942
# Mean: -10458.896
# Max: 1612290.699
# Min: -2227837.782
# Run nr.: 27
#
#  |OOOOOOOOOO| 100.0%   realization nr. 27. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.559 minutes
# Total elapsed time: 7.854 hours
# Variance: 255956512449.224
# Mean: -10903.233
# Max: 2166353.805
# Min: -1696906.841
# Run nr.: 28
#
#  |OOOOOOOOOO| 100.0%   realization nr. 28. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.282 minutes
# Total elapsed time: 8.092 hours
# Variance: 265854789637.329
# Mean: -8864.816
# Max: 2300925.898
# Min: -2292391.697
# Run nr.: 29
#
#  |OOOOOOOOOO| 100.0%   realization nr. 29. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.324 minutes
# Total elapsed time: 8.331 hours
# Variance: 260040634901.909
# Mean: -11295.937
# Max: 1976965.134
# Min: -1532583.259
# Run nr.: 30
#
#  |OOOOOOOOOO| 100.0%   realization nr. 30. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.323 minutes
# Total elapsed time: 8.570 hours
# Variance: 255805748557.947
# Mean: -9518.561
# Max: 1807571.440
# Min: -1455843.913
# Run nr.: 31
#
#  |OOOOOOOOOO| 100.0%   realization nr. 31. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.455 minutes
# Total elapsed time: 8.811 hours
# Variance: 258315195579.634
# Mean: -8936.522
# Max: 1638919.531
# Min: -1996567.554
# Run nr.: 32
#
#  |OOOOOOOOOO| 100.0%   realization nr. 32. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.742 minutes
# Total elapsed time: 9.057 hours
# Variance: 258976028046.096
# Mean: -10059.868
# Max: 1986081.439
# Min: -1513532.609
# Run nr.: 33
#
#  |OOOOOOOOOO| 100.0%   realization nr. 33. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.483 minutes
# Total elapsed time: 9.298 hours
# Variance: 263692831748.267
# Mean: -8648.734
# Max: 1805900.774
# Min: -1486604.639
# Run nr.: 34
#  |OOOOOOOOOO| 100.0%   realization nr. 34. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.691 minutes
# Total elapsed time: 9.543 hours
# Variance: 264089871273.095
# Mean: -9395.018
# Max: 1975190.564
# Min: -2004845.079
# Run nr.: 35
#
#  |OOOOOOOOOO| 100.0%   realization nr. 35. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.800 minutes
# Total elapsed time: 9.789 hours
# Variance: 276922197352.876
# Mean: -9819.377
# Max: 2021895.262
# Min: -1762567.131
# Run nr.: 36
#
#  |OOOOOOOOOO| 100.0%   realization nr. 36. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.577 minutes
# Total elapsed time: 10.032 hours
# Variance: 259067747303.834
# Mean: -11253.997
# Max: 1670047.654
# Min: -1349163.852
# Run nr.: 37
#
#  |OOOOOOOOOO| 100.0%   realization nr. 37. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.832 minutes
# Total elapsed time: 10.280 hours
# Variance: 268292067680.719
# Mean: -14064.007
# Max: 2039524.831
# Min: -1543691.797
# Run nr.: 38
#
#  |OOOOOOOOOO| 100.0%   realization nr. 38. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.596 minutes
# Total elapsed time: 10.523 hours
# Variance: 261154208961.274
# Mean: -9812.369
# Max: 1787149.426
# Min: -1815607.209
# Run nr.: 39
#
#  |OOOOOOOOOO| 100.0%   realization nr. 39. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.650 minutes
# Total elapsed time: 10.767 hours
# Variance: 255274107913.612
# Mean: -10125.957
# Max: 1653285.759
# Min: -1554562.892
# Run nr.: 40
#
#  |OOOOOOOOOO| 100.0%   realization nr. 40. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.617 minutes
# Total elapsed time: 11.011 hours
# Variance: 256284646269.940
# Mean: -10375.199
# Max: 1971636.430
# Min: -1267868.882
# Run nr.: 41
#
#  |OOOOOOOOOO| 100.0%   realization nr. 41. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.518 minutes
# Total elapsed time: 11.253 hours
# Variance: 264967735622.062
# Mean: -9162.752
# Max: 1715630.385
# Min: -2009578.331
# Run nr.: 42
#
#  |OOOOOOOOOO| 100.0%   realization nr. 42. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.434 minutes
# Total elapsed time: 11.493 hours
# Variance: 258517469140.573
# Mean: -8678.523
# Max: 1565670.121
# Min: -1466956.170
# Run nr.: 43
#
#  |OOOOOOOOOO| 100.0%   realization nr. 43. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.586 minutes
# Total elapsed time: 11.736 hours
# Variance: 258695307159.321
# Mean: -10857.910
# Max: 2101719.118
# Min: -1297658.338
# Run nr.: 44
#
#  |OOOOOOOOOO| 100.0%   realization nr. 44. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.595 minutes
# Total elapsed time: 11.979 hours
# Variance: 263360616155.939
# Mean: -11694.749
# Max: 1600098.143
# Min: -1859577.978
# Run nr.: 45
#
#  |OOOOOOOOOO| 100.0%   realization nr. 45. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.649 minutes
# Total elapsed time: 12.224 hours
# Variance: 264171423664.027
# Mean: -7909.938
# Max: 2092446.535
# Min: -2013496.959
# Run nr.: 46
#
#  |OOOOOOOOOO| 100.0%   realization nr. 46. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.486 minutes
# Total elapsed time: 12.465 hours
# Variance: 256132485922.349
# Mean: -9063.812
# Max: 1583516.266
# Min: -1762046.369
# Run nr.: 47
#
#  |OOOOOOOOOO| 100.0%   realization nr. 47. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.616 minutes
# Total elapsed time: 12.709 hours
# Variance: 264753351652.195
# Mean: -9648.232
# Max: 1632146.425
# Min: -1311847.381
# Run nr.: 48
#
#  |OOOOOOOOOO| 100.0%   realization nr. 48. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.545 minutes
# Total elapsed time: 12.951 hours
# Variance: 258342312706.309
# Mean: -9591.920
# Max: 2214398.631
# Min: -1355916.680
# Run nr.: 49
#
#  |OOOOOOOOOO| 100.0%   realization nr. 49. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.588 minutes
# Total elapsed time: 13.194 hours
# Variance: 255286846001.027
# Mean: -9254.563
# Max: 1680117.319
# Min: -1499829.781
# Run nr.: 50
#
#  |OOOOOOOOOO| 100.0%   realization nr. 50. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.403 minutes
# Total elapsed time: 13.434 hours
# Variance: 254787298735.095
# Mean: -9762.972
# Max: 2019573.950
# Min: -1560215.561
# Run nr.: 51
#
#  |OOOOOOOOOO| 100.0%   realization nr. 51. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.323 minutes
# Total elapsed time: 13.673 hours
# Variance: 263606334240.465
# Mean: -9893.080
# Max: 1544764.728
# Min: -1416803.200
# Run nr.: 52
#
#  |OOOOOOOOOO| 100.0%   realization nr. 52. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.196 minutes
# Total elapsed time: 13.910 hours
# Variance: 252056061475.285
# Mean: -9218.972
# Max: 1540391.920
# Min: -1187678.741
# Run nr.: 53
#
#  |OOOOOOOOOO| 100.0%   realization nr. 53. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.199 minutes
# Total elapsed time: 14.146 hours
# Variance: 256586628364.406
# Mean: -10388.973
# Max: 1644913.921
# Min: -1580648.693
# Run nr.: 54
#
#  |OOOOOOOOOO| 100.0%   realization nr. 54. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.253 minutes
# Total elapsed time: 14.384 hours
# Variance: 256680797792.287
# Mean: -10801.608
# Max: 2414031.720
# Min: -1838782.641
# Run nr.: 55
#
#  |OOOOOOOOOO| 100.0%   realization nr. 55. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.505 minutes
# Total elapsed time: 14.626 hours
# Variance: 252146529006.705
# Mean: -8787.251
# Max: 2045274.149
# Min: -1384292.462
# Run nr.: 56
#
#  |OOOOOOOOOO| 100.0%   realization nr. 56. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.210 minutes
# Total elapsed time: 14.862 hours
# Variance: 261210749804.808
# Mean: -9851.815
# Max: 1864175.265
# Min: -1719378.110
# Run nr.: 57
#
#  |OOOOOOOOOO| 100.0%   realization nr. 57. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.395 minutes
# Total elapsed time: 15.102 hours
# Variance: 260534560062.562
# Mean: -10374.772
# Max: 2153503.436
# Min: -1287727.291
# Run nr.: 58
#
#  |OOOOOOOOOO| 100.0%   realization nr. 58. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.623 minutes
# Total elapsed time: 15.346 hours
# Variance: 257097311517.177
# Mean: -11507.908
# Max: 1719936.372
# Min: -1529128.008
# Run nr.: 59
#
#  |OOOOOOOOOO| 100.0%   realization nr. 59. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.323 minutes
# Total elapsed time: 15.585 hours
# Variance: 262120977110.600
# Mean: -8220.543
# Max: 2417718.657
# Min: -2168645.313
# Run nr.: 60
#
#  |OOOOOOOOOO| 100.0%   realization nr. 60. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.709 minutes
# Total elapsed time: 15.830 hours
# Variance: 263398368576.834
# Mean: -10804.465
# Max: 1914542.133
# Min: -1631596.341
# Run nr.: 61
#
#  |OOOOOOOOOO| 100.0%   realization nr. 61. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.476 minutes
# Total elapsed time: 16.071 hours
# Variance: 260184128819.757
# Mean: -11124.533
# Max: 1575506.031
# Min: -1593840.092
# Run nr.: 62
#
#  |OOOOOOOOOO| 100.0%   realization nr. 62. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.411 minutes
# Total elapsed time: 16.311 hours
# Variance: 257221619757.578
# Mean: -9197.748
# Max: 1877348.179
# Min: -1370150.867
# Run nr.: 63
#
#  |OOOOOOOOOO| 100.0%   realization nr. 63. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.559 minutes
# Total elapsed time: 16.554 hours
# Variance: 265762849779.508
# Mean: -8403.622
# Max: 2394837.693
# Min: -1248753.840
# Run nr.: 64
#
#  |OOOOOOOOOO| 100.0%   realization nr. 64. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.484 minutes
# Total elapsed time: 16.795 hours
# Variance: 261324305623.499
# Mean: -9576.156
# Max: 2219993.821
# Min: -1158166.927
# Run nr.: 65
#
#  |OOOOOOOOOO| 100.0%   realization nr. 65. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.422 minutes
# Total elapsed time: 17.036 hours
# Variance: 259321592024.082
# Mean: -9181.580
# Max: 2354755.292
# Min: -1351701.426
# Run nr.: 66
#
#  |OOOOOOOOOO| 100.0%   realization nr. 66. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.693 minutes
# Total elapsed time: 17.281 hours
# Variance: 259954061728.418
# Mean: -8850.051
# Max: 2062368.322
# Min: -1347163.487
# Run nr.: 67
#
#  |OOOOOOOOOO| 100.0%   realization nr. 67. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.386 minutes
# Total elapsed time: 17.520 hours
# Variance: 257343106445.088
# Mean: -11120.653
# Max: 2439840.970
# Min: -1574764.779
# Run nr.: 68
#  |OOOOOOOOOO| 100.0%   realization nr. 68. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.469 minutes
# Total elapsed time: 17.762 hours
# Variance: 262476161383.599
# Mean: -7380.380
# Max: 1623729.578
# Min: -1568239.763
# Run nr.: 69
#
#  |OOOOOOOOOO| 100.0%   realization nr. 69. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.469 minutes
# Total elapsed time: 18.003 hours
# Variance: 254502292822.021
# Mean: -11331.761
# Max: 2396524.507
# Min: -2159527.821
# Run nr.: 70
#
#  |OOOOOOOOOO| 100.0%   realization nr. 70. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.563 minutes
# Total elapsed time: 18.245 hours
# Variance: 259114824024.959
# Mean: -8703.509
# Max: 1530240.821
# Min: -2165623.714
# Run nr.: 71
#
#  |OOOOOOOOOO| 100.0%   realization nr. 71. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.397 minutes
# Total elapsed time: 18.485 hours
# Variance: 267087506078.795
# Mean: -9139.897
# Max: 1848598.661
# Min: -1822399.821
# Run nr.: 72
#
#  |OOOOOOOOOO| 100.0%   realization nr. 72. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.727 minutes
# Total elapsed time: 18.731 hours
# Variance: 255671501854.185
# Mean: -11176.998
# Max: 2105694.357
# Min: -1257141.648
# Run nr.: 73
#
#  |OOOOOOOOOO| 100.0%   realization nr. 73. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.588 minutes
# Total elapsed time: 18.974 hours
# Variance: 257304612540.970
# Mean: -9588.965
# Max: 2384773.385
# Min: -1719717.812
# Run nr.: 74
#
#  |OOOOOOOOOO| 100.0%   realization nr. 74. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.475 minutes
# Total elapsed time: 19.215 hours
# Variance: 266350941949.055
# Mean: -10621.275
# Max: 1740873.323
# Min: -1826852.481
# Run nr.: 75
#
#  |OOOOOOOOOO| 100.0%   realization nr. 75. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.649 minutes
# Total elapsed time: 19.459 hours
# Variance: 263455648031.723
# Mean: -10926.178
# Max: 2246368.545
# Min: -2067140.488
# Run nr.: 76
#
#  |OOOOOOOOOO| 100.0%   realization nr. 76. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.532 minutes
# Total elapsed time: 19.702 hours
# Variance: 261119287381.202
# Mean: -9105.967
# Max: 2629230.219
# Min: -1405463.530
# Run nr.: 77
#
#  |OOOOOOOOOO| 100.0%   realization nr. 77. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.507 minutes
# Total elapsed time: 19.943 hours
# Variance: 260660226947.861
# Mean: -9044.859
# Max: 2453028.027
# Min: -1523044.343
# Run nr.: 78
#
#  |OOOOOOOOOO| 100.0%   realization nr. 78. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.502 minutes
# Total elapsed time: 20.185 hours
# Variance: 260888618611.350
# Mean: -9967.051
# Max: 1826266.554
# Min: -1975184.359
# Run nr.: 79
#
#  |OOOOOOOOOO| 100.0%   realization nr. 79. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.628 minutes
# Total elapsed time: 20.429 hours
# Variance: 263907879956.052
# Mean: -8256.515
# Max: 1867814.311
# Min: -1706270.570
# Run nr.: 80
#
#  |OOOOOOOOOO| 100.0%   realization nr. 80. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.572 minutes
# Total elapsed time: 20.672 hours
# Variance: 258534712784.431
# Mean: -10438.973
# Max: 2066017.457
# Min: -1440960.183
# Run nr.: 81
#
#  |OOOOOOOOOO| 100.0%   realization nr. 81. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.380 minutes
# Total elapsed time: 20.911 hours
# Variance: 257634096631.055
# Mean: -9795.130
# Max: 1622442.913
# Min: -1498826.942
# Run nr.: 82
#
#  |OOOOOOOOOO| 100.0%   realization nr. 82. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.588 minutes
# Total elapsed time: 21.154 hours
# Variance: 262170173769.786
# Mean: -8867.381
# Max: 2129766.239
# Min: -1488009.346
# Run nr.: 83
#
#  |OOOOOOOOOO| 100.0%   realization nr. 83. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.441 minutes
# Total elapsed time: 21.395 hours
# Variance: 260722237876.280
# Mean: -10754.956
# Max: 2088657.320
# Min: -1305035.739
# Run nr.: 84
#
#  |OOOOOOOOOO| 100.0%   realization nr. 84. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.605 minutes
# Total elapsed time: 21.639 hours
# Variance: 263330145285.929
# Mean: -9464.213
# Max: 2422940.621
# Min: -2415925.223
# Run nr.: 85
#
#  |OOOOOOOOOO| 100.0%   realization nr. 85. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.595 minutes
# Total elapsed time: 21.882 hours
# Variance: 259698226981.628
# Mean: -8500.900
# Max: 1744587.899
# Min: -1468604.226
# Run nr.: 86
#
#  |OOOOOOOOOO| 100.0%   realization nr. 86. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.610 minutes
# Total elapsed time: 22.125 hours
# Variance: 254956310207.192
# Mean: -10019.618
# Max: 1963819.453
# Min: -1596805.683
# Run nr.: 87
#
#  |OOOOOOOOOO| 100.0%   realization nr. 87. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.577 minutes
# Total elapsed time: 22.368 hours
# Variance: 260752164761.637
# Mean: -9684.682
# Max: 1975287.374
# Min: -1839021.874
# Run nr.: 88
#
#  |OOOOOOOOOO| 100.0%   realization nr. 88. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.950 minutes
# Total elapsed time: 22.617 hours
# Variance: 268914193852.609
# Mean: -12909.077
# Max: 2081452.435
# Min: -1576037.837
# Run nr.: 89
#
#  |OOOOOOOOOO| 100.0%   realization nr. 89. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.721 minutes
# Total elapsed time: 22.863 hours
# Variance: 254512997652.351
# Mean: -12015.606
# Max: 1819674.539
# Min: -1466821.551
# Run nr.: 90
#
#  |OOOOOOOOOO| 100.0%   realization nr. 90. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.695 minutes
# Total elapsed time: 23.108 hours
# Variance: 260043711654.955
# Mean: -11117.176
# Max: 1769729.781
# Min: -1588479.151
# Run nr.: 91
#
#  |OOOOOOOOOO| 100.0%   realization nr. 91. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.382 minutes
# Total elapsed time: 23.347 hours
# Variance: 261731372647.231
# Mean: -9919.045
# Max: 2075819.796
# Min: -1917541.744
# Run nr.: 92
#
#  |OOOOOOOOOO| 100.0%   realization nr. 92. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.626 minutes
# Total elapsed time: 23.591 hours
# Variance: 252900071153.894
# Mean: -10473.310
# Max: 1822629.092
# Min: -1229732.119
# Run nr.: 93
#
#  |OOOOOOOOOO| 100.0%   realization nr. 93. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.262 minutes
# Total elapsed time: 23.829 hours
# Variance: 261717857514.668
# Mean: -9251.449
# Max: 1635884.622
# Min: -1413872.346
# Run nr.: 94
#
#  |OOOOOOOOOO| 100.0%   realization nr. 94. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.422 minutes
# Total elapsed time: 24.069 hours
# Variance: 270341405754.706
# Mean: -6558.917
# Max: 2528185.543
# Min: -1793312.468
# Run nr.: 95
#
#  |OOOOOOOOOO| 100.0%   realization nr. 95. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.445 minutes
# Total elapsed time: 24.310 hours
# Variance: 263702013297.625
# Mean: -11307.272
# Max: 1658354.144
# Min: -1611507.760
# Run nr.: 96
#
#  |OOOOOOOOOO| 100.0%   realization nr. 96. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.392 minutes
# Total elapsed time: 24.550 hours
# Variance: 273772302922.624
# Mean: -9787.640
# Max: 1683557.833
# Min: -1869433.949
# Run nr.: 97
#
#  |OOOOOOOOOO| 100.0%   realization nr. 97. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.381 minutes
# Total elapsed time: 24.790 hours
# Variance: 261450097800.936
# Mean: -10070.016
# Max: 2058672.937
# Min: -1569299.553
# Run nr.: 98
#
#  |OOOOOOOOOO| 100.0%   realization nr. 98. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.491 minutes
# Total elapsed time: 25.031 hours
# Variance: 257273366052.453
# Mean: -9526.872
# Max: 2054079.645
# Min: -1602800.634
# Run nr.: 99
#
#  |OOOOOOOOOO| 100.0%   realization nr. 99. Counter: 1800/1800, Running error magnitude: 5.1
# Run time: 14.342 minutes
# Total elapsed time: 25.270 hours
# Variance: 262608807850.464
# Mean: -10627.662
# Max: 2303899.545
# Min: -1318416.245
# Run nr.: 100

# %%
zs.shape
# Out:
# (1800, 100)

# %%
#% SEMI-VARIOGRAM
plt.figure(figsize=(10,6))

#plt.plot(core.lags_model,core.pics_model,'.',markersize=10,label='modelling data')

plt.plot(core.lags_sv_curve,core.sv_curve,color='C1',label='SV model')


core.sv_zs(core.grid_glq_N,1,np.array(m_equiv_lsq),core.sort_d,core.n_lags,core.max_cloud)
plt.plot(core.lags,core.pics_zs[:,0],color = 'C3',label='Seqsim equiv. LSQ')    

for i in np.arange(0,N_sim):
    core.sv_zs(core.grid_glq_N,1,zs[:,[i]],core.sort_d,core.n_lags,core.max_cloud)
    if i == 0:
        plt.plot(core.lags,core.pics_zs[:,0],color = 'C5',label='Seqsim')
    else:
        plt.plot(core.lags,core.pics_zs[:,0],color = 'C5') 
#print(zs[:,[0]].shape)
#print(core.pics_zs.shape)

#core.sv_zs(core.grid_glq_N,1,data_lstsq["data"].reshape(-1,1),core.sort_d,core.n_lags,core.max_cloud)
#plt.plot(core.lags,core.pics_zs[:,0],color = 'C4',label='LSQ')  

#plt.plot(core.lags,core.pics,'o', markersize=10,color = '0.85',label='Core field estimate')

core.sv_zs(core.grid_glq_N,1,core.data.reshape(-1,1),core.sort_d,core.n_lags,core.max_cloud)
plt.plot(core.lags,core.pics_zs[:,0],'k--',label='Core prior') 

plt.ylabel('Semi-variance $[%s^2]$' % "nT",fontsize=18,labelpad=18)
plt.xlabel('Lag [km]',fontsize=18,labelpad=18)
plt.legend(loc='best',fontsize=18)
plt.show()

#% HISTOGRAM
plt.figure(figsize=(10,6))    

y,binEdges=np.histogram(np.array(m_equiv_lsq),bins=50,density=False)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'-',color = 'C3',label='Seqsim equiv. LSQ')  

for i in np.arange(0,N_sim):
    y,binEdges=np.histogram(zs[:,[i]],bins=50,density=False)
    bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
    if i == 0:
        plt.plot(bincenters,y,'-',color = 'C5',label='Seqsim')  
    else:
        plt.plot(bincenters,y,'-',color = 'C5')   

#y,binEdges=np.histogram(data_lstsq["data"].reshape(-1,1),bins=50,density=False)
#bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
#plt.plot(bincenters,y,'-',color = 'C4',label='LSQ')    

y,binEdges=np.histogram(core.data,bins=50,density=False)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'k--',label='Core prior')

plt.legend(loc='best',fontsize=18)
plt.xlabel('Field value %s' % "[nT]",fontsize=18,labelpad=18)
plt.ylabel('Count',fontsize=18,labelpad=18)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
