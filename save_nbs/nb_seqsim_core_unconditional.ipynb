# %%
# %matplotlib notebook

from sdss import SDSS
import mikkel_tools.utility as mt_util
import plot as sds_plt

import numpy as np
#import cupy as cp
import scipy as sp
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

import pyshtools
import pickle

comment = "Unconditional realizations"
nb_name = "nb_seqsim_core_unconditional"

# %% [markdown]
# # Core

# %%
core = SDSS(comment, N_SH = 30, sim_type = "core", sat_height = 350)

core.grid_glq(nmax = 30, r_at = core.r_cmb)

grid_in = np.array([core.grid_glq_phi, 90-core.grid_glq_theta]).T
core.make_grid(core.r_cmb, grid_in, calc_sph_d = True)

# %%
core.generate_map(target_var_factor = 1)

# %%
#core.data = core.data - np.mean(core.data)

# %%
#mt_util.plot_cartopy_global(lat = core.lat, lon = core.lon, plot_quality = "high", 
#                            data=core.data, point_size=10, shift_grid = True, 
#                            transpose_grid = True, shape = (121,61), cmap = 'PuOr_r', 
#                            title="Prior radial lithosphere information")

# %%
core.condtab(normsize=10000, quantiles = 1000, 
             rangn_lim = 3.5, rangn_N = 101, rangv_lim = 2.0, rangv_N = 101)

# %%
core.semivar(model_lags = "all", model = "exponential", max_dist = 20000, lag_length = 200,
             zero_nugget = True, hit_target_var = True)

keep_sv_curve = core.sv_curve.copy()
keep_lags_sv_curve = core.lags_sv_curve.copy()

C_e_const = 2.0

nugget = C_e_const**2
nugget_p = 0.01
var_fac = 1.0

#set_model = {"a": 2000, "C0": var_fac*core.target_var*nugget_p, "C1": var_fac*core.target_var*(1-nugget_p), "C2": None, "C3": None}
set_model = {"a": 2000, "C0": nugget, "C1": var_fac*core.target_var-nugget, "C2": None, "C3": None}


core.semivar(model_lags = 20, model = "spherical", max_dist = 20000, lag_length = 200,
             zero_nugget = True, hit_target_var = True, set_model = set_model)

#core.semivar(model_lags = 3, model = "exponential", max_dist = 20000, lag_length = 200,
#             zero_nugget = True, hit_target_var = True)


#%% PLOT SEMI-VARIOGRAM
plt.figure(figsize=(10,8)) 
plt.plot(core.lags,core.pics,'o', markersize=10,color = '0.85',label='data semi-variogram')
plt.plot(core.lags_model,core.pics_model,'--',markersize=10,label='modelling data')
plt.plot(core.lags_sv_curve,core.sv_curve,color='C3', linewidth = 3,label='model')
plt.plot(keep_lags_sv_curve,keep_sv_curve,"--",color='C1',linewidth = 3,label='model large lag')

plt.plot(core.lags_sv_curve,np.ones(core.lags_sv_curve.shape)*core.target_var,linewidth = 3, color="C2", label="target histogram variance")
plt.ylabel('Semi-variance $[%s^2]$' % "nT",fontsize=18,labelpad=18)
plt.xlabel('Lag [km]',fontsize=18,labelpad=18)
plt.title("Semi-variogram model of type: %s " % core.model_names[core.model],fontsize=18,y=1.02)
plt.legend(loc='best',fontsize=18)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
plt.show()
# Out:
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 200.0 km
# Number of lags: 54
# Number of modelling lags: all
#
# Semi-variogram model determined, starting LUT computation
#
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 200.0 km
# Number of lags: 54
# Number of modelling lags: 20
#
# Semi-variogram model determined, starting LUT computation
# <img src="data:image/png;base64,..." width="1000">

# %%
#print(core)

# %% [markdown]
# # Synthetic sat

# %%
s_sat = SDSS(comment, N_SH = 30, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_sat.load_swarm("A")

grid_in = np.array([s_sat.swarm_phi, 90-s_sat.swarm_theta]).T
s_sat.make_grid(s_sat.swarm_radius, grid_in, calc_sph_d = False)

#s_sat.grid_equal_area(N_grid= 500, r_at = s_sat.r_sat, poles_remove = True)
#grid_in = np.array([s_sat.grid_eqa_phi, 90-s_sat.grid_eqa_theta]).T
#s_sat.grid(s_sat.r_sat, grid_in, calc_sph_d = False)

# %%
s_sat.generate_map(grid_type = "swarm")

# %%
s_sat.data += np.random.normal(scale = C_e_const, size = s_sat.data.shape)

# %%
#mt_util.plot_cartopy_global(lat = s_sat.lat, lon = s_sat.lon, plot_quality = "high", point_size=5, 
#                            data=s_sat.data, cmap = 'PuOr_r', title="Synthetic satellite data")

# %%
#print(s_sat)

# %%
core.integrating_kernel(s_sat, C_e_const = C_e_const)
# Out:
# Gauss-Legendre RMSE:	 2.031337789438
# <img src="data:image/png;base64,..." width="640">

# %%
N_sim = 1000

core.run_sim(N_sim, core.grid_glq_N, core.C_mm_all, core.C_dd, core.C_dm_all, core.G,
        s_sat.data, core.data, scale_m_i = True, unit_d = False, collect_all = False,
        sense_running_error = True, save_string = nb_name, sim_stochastic = True)
# Out:
#  |----------| 9.6%   realization nr. 0. Counter: 182/1891, Running error magnitude: 5.6
#  |O---------| 15.7%   realization nr. 0. Counter: 296/1891, Running error magnitude: 5.5
#  |OOOOOOOOOO| 100.0%   realization nr. 0. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 56.924 seconds
# Total elapsed time: 0.949 minutes
# Variance: 252735844464.024
# Mean: 85726.758
# Max: 1931178.975
# Min: -1467309.187
# Run nr.: 1
#
#  |OOOOOOOOOO| 100.0%   realization nr. 1. Counter: 1891/1891, Running error magnitude: 5.7
# Run time: 1.318 minutes
# Total elapsed time: 2.267 minutes
# Variance: 287802018347.116
# Mean: 142665.451
# Max: 1589628.307
# Min: -1239997.930
# Run nr.: 2
#
#  |OOOOOOOOOO| 100.0%   realization nr. 2. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.138 minutes
# Total elapsed time: 3.405 minutes
# Variance: 213789139772.922
# Mean: -68123.466
# Max: 1709398.746
# Min: -1265836.078
# Run nr.: 3
#
#  |OOOOOOOOOO| 100.0%   realization nr. 3. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.083 minutes
# Total elapsed time: 4.489 minutes
# Variance: 283259183070.402
# Mean: -59542.367
# Max: 1788223.031
# Min: -1377946.193
# Run nr.: 4
#
#  |OOOOOOOOOO| 100.0%   realization nr. 4. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.080 minutes
# Total elapsed time: 5.569 minutes
# Variance: 259940033945.318
# Mean: -178040.378
# Max: 1623956.554
# Min: -1711620.356
# Run nr.: 5
#
#  |OOOOOOOOOO| 100.0%   realization nr. 5. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.046 minutes
# Total elapsed time: 6.615 minutes
# Variance: 294861601998.512
# Mean: 15379.616
# Max: 1971788.591
# Min: -1502894.308
# Run nr.: 6
#
#  |OOOOOOOOOO| 100.0%   realization nr. 6. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.029 minutes
# Total elapsed time: 7.644 minutes
# Variance: 286913665134.377
# Mean: -98990.371
# Max: 1593117.379
# Min: -1445675.569
# Run nr.: 7
#
#  |OOOOOOOOOO| 100.0%   realization nr. 7. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.077 minutes
# Total elapsed time: 8.721 minutes
# Variance: 272292981068.429
# Mean: 37974.844
# Max: 1919402.869
# Min: -1363093.689
# Run nr.: 8
#
#  |OOOOOOOOOO| 100.0%   realization nr. 8. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.073 minutes
# Total elapsed time: 9.794 minutes
# Variance: 393877018900.962
# Mean: -11839.602
# Max: 1957158.648
# Min: -1614599.730
# Run nr.: 9
#
#  |OOOOOOOOOO| 100.0%   realization nr. 9. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.076 minutes
# Total elapsed time: 10.871 minutes
# Variance: 295009279300.974
# Mean: 95511.750
# Max: 1854411.815
# Min: -1432233.075
# Run nr.: 10
#
#  |OOOOOOOOOO| 100.0%   realization nr. 10. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.084 minutes
# Total elapsed time: 11.955 minutes
# Variance: 303994191585.235
# Mean: -37984.434
# Max: 1632070.487
# Min: -1613704.572
# Run nr.: 11
#
#  |OOOOOOOOOO| 100.0%   realization nr. 11. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.101 minutes
# Total elapsed time: 13.056 minutes
# Variance: 282658458202.320
# Mean: -21505.961
# Max: 1484877.691
# Min: -1736078.060
# Run nr.: 12
#
#  |OOOOOOOOOO| 100.0%   realization nr. 12. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.012 minutes
# Total elapsed time: 14.068 minutes
# Variance: 246315064502.082
# Mean: -6940.383
# Max: 1826957.040
# Min: -1339973.132
# Run nr.: 13
#
#  |OOOOOOOOOO| 100.0%   realization nr. 13. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 55.605 seconds
# Total elapsed time: 14.995 minutes
# Variance: 212167916920.485
# Mean: -33004.264
# Max: 1735781.953
# Min: -1471761.533
# Run nr.: 14
#
#  |OOOOOOOOOO| 100.0%   realization nr. 14. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 50.883 seconds
# Total elapsed time: 15.843 minutes
# Variance: 224923300434.552
# Mean: 31437.784
# Max: 1442465.458
# Min: -1479250.831
# Run nr.: 15
#
#  |OOOOOOOOOO| 100.0%   realization nr. 15. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 51.769 seconds
# Total elapsed time: 16.706 minutes
# Variance: 247671824345.879
# Mean: 38914.044
# Max: 1835082.697
# Min: -1629178.239
# Run nr.: 16
#
#  |OOOOOOOOOO| 100.0%   realization nr. 16. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 52.039 seconds
# Total elapsed time: 17.573 minutes
# Variance: 275560488112.185
# Mean: 79528.426
# Max: 1644073.420
# Min: -1627101.366
# Run nr.: 17
#
#  |OOOOOOOOOO| 100.0%   realization nr. 17. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.446 seconds
# Total elapsed time: 18.431 minutes
# Variance: 265503165511.374
# Mean: 118195.969
# Max: 1713771.106
# Min: -1309760.869
# Run nr.: 18
#
#  |OOOOOOOOOO| 100.0%   realization nr. 18. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.080 minutes
# Total elapsed time: 19.511 minutes
# Variance: 242785182226.525
# Mean: 47619.353
# Max: 1502648.030
# Min: -1138217.967
# Run nr.: 19
#
#  |OOOOOOOOOO| 100.0%   realization nr. 19. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.186 minutes
# Total elapsed time: 20.697 minutes
# Variance: 216520715226.778
# Mean: -61182.997
# Max: 1336298.656
# Min: -1620634.659
# Run nr.: 20
#
#  |OOOOOOOOOO| 100.0%   realization nr. 20. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.096 minutes
# Total elapsed time: 21.793 minutes
# Variance: 216055185136.485
# Mean: -19961.259
# Max: 1416409.730
# Min: -1741708.886
# Run nr.: 21
#
#  |OOOOOOOOOO| 100.0%   realization nr. 21. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.041 minutes
# Total elapsed time: 22.834 minutes
# Variance: 290102885729.122
# Mean: -14757.830
# Max: 1474161.622
# Min: -1649948.322
# Run nr.: 22
#
#  |OOOOOOOOOO| 100.0%   realization nr. 22. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.010 minutes
# Total elapsed time: 23.844 minutes
# Variance: 214312806070.200
# Mean: -61156.594
# Max: 1949426.929
# Min: -1543869.268
# Run nr.: 23
#
#  |OOOOOOOOOO| 100.0%   realization nr. 23. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.028 minutes
# Total elapsed time: 24.872 minutes
# Variance: 364600280566.254
# Mean: -122753.343
# Max: 1447780.471
# Min: -1989045.737
# Run nr.: 24
#
#  |OOOOOOOOOO| 100.0%   realization nr. 24. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.054 minutes
# Total elapsed time: 25.926 minutes
# Variance: 279748022596.568
# Mean: 79225.746
# Max: 1499278.505
# Min: -1581225.811
# Run nr.: 25
#
#  |OOOOOOOOOO| 100.0%   realization nr. 25. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.014 minutes
# Total elapsed time: 26.940 minutes
# Variance: 238924702359.940
# Mean: 105021.549
# Max: 1706206.278
# Min: -1516898.676
# Run nr.: 26
#
#  |OOOOOOOOOO| 100.0%   realization nr. 26. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.023 minutes
# Total elapsed time: 27.963 minutes
# Variance: 277435025922.037
# Mean: -6955.460
# Max: 1455872.982
# Min: -1775213.796
# Run nr.: 27
#
#  |OOOOOOOOOO| 100.0%   realization nr. 27. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.018 minutes
# Total elapsed time: 28.981 minutes
# Variance: 198985824780.192
# Mean: -62267.289
# Max: 1689516.719
# Min: -1272211.353
# Run nr.: 28
#
#  |OOOOOOOOOO| 100.0%   realization nr. 28. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.025 minutes
# Total elapsed time: 30.006 minutes
# Variance: 250400060953.735
# Mean: -47560.468
# Max: 1461384.813
# Min: -1690190.873
# Run nr.: 29
#
#  |OOOOOOOOOO| 100.0%   realization nr. 29. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.066 minutes
# Total elapsed time: 31.072 minutes
# Variance: 322206596858.999
# Mean: -655.671
# Max: 1841600.524
# Min: -1530070.509
# Run nr.: 30
#
#  |OOOOOOOOOO| 100.0%   realization nr. 30. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 59.731 seconds
# Total elapsed time: 32.067 minutes
# Variance: 233067069924.834
# Mean: -3405.896
# Max: 1438052.918
# Min: -1504767.847
# Run nr.: 31
#
#  |OOOOOOOOOO| 100.0%   realization nr. 31. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 53.787 seconds
# Total elapsed time: 32.964 minutes
# Variance: 289559219988.769
# Mean: 95963.906
# Max: 1684399.716
# Min: -1662071.141
# Run nr.: 32
#
#  |OOOOOOOOOO| 100.0%   realization nr. 32. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.664 seconds
# Total elapsed time: 33.825 minutes
# Variance: 220379551213.595
# Mean: 136868.688
# Max: 1901053.447
# Min: -1545258.960
# Run nr.: 33
#
#  |OOOOOOOOOO| 100.0%   realization nr. 33. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 49.737 seconds
# Total elapsed time: 34.654 minutes
# Variance: 265692650910.174
# Mean: -8400.350
# Max: 1526494.685
# Min: -1779441.891
# Run nr.: 34
#  |O---------| 11.2%   realization nr. 34. Counter: 211/1891, Running error magnitude: 5.5
#  |O---------| 16.7%   realization nr. 34. Counter: 316/1891, Running error magnitude: 5.5
#  |OOOOOOOOOO| 100.0%   realization nr. 34. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 51.481 seconds
# Total elapsed time: 35.512 minutes
# Variance: 228019675763.389
# Mean: -55571.065
# Max: 1465102.250
# Min: -1739038.050
# Run nr.: 35
#
#  |OOOOOOOOOO| 100.0%   realization nr. 35. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.905 seconds
# Total elapsed time: 36.377 minutes
# Variance: 272093861821.499
# Mean: 31653.803
# Max: 1451377.072
# Min: -1504871.620
# Run nr.: 36
#
#  |OOOOOOOOOO| 100.0%   realization nr. 36. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.368 seconds
# Total elapsed time: 37.233 minutes
# Variance: 274077666038.708
# Mean: -31993.138
# Max: 1950783.946
# Min: -1524998.595
# Run nr.: 37
#
#  |OOOOOOOOOO| 100.0%   realization nr. 37. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.856 seconds
# Total elapsed time: 38.080 minutes
# Variance: 279579374246.025
# Mean: 141078.853
# Max: 2336341.386
# Min: -1453238.169
# Run nr.: 38
#
#  |OOOOOOOOOO| 100.0%   realization nr. 38. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 51.696 seconds
# Total elapsed time: 38.942 minutes
# Variance: 265188982996.379
# Mean: -95926.209
# Max: 1497507.557
# Min: -1670557.046
# Run nr.: 39
#
#  |OOOOOOOOOO| 100.0%   realization nr. 39. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 50.931 seconds
# Total elapsed time: 39.791 minutes
# Variance: 263849444958.915
# Mean: 94463.332
# Max: 1568851.036
# Min: -1634760.613
# Run nr.: 40
#
#  |OOOOOOOOOO| 100.0%   realization nr. 40. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 51.317 seconds
# Total elapsed time: 40.646 minutes
# Variance: 231590089370.423
# Mean: 25631.918
# Max: 1682788.453
# Min: -1627282.680
# Run nr.: 41
#
#  |OOOOOOOOOO| 100.0%   realization nr. 41. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.989 seconds
# Total elapsed time: 41.496 minutes
# Variance: 278572402244.296
# Mean: 1983.686
# Max: 2340192.006
# Min: -1548057.755
# Run nr.: 42
#
#  |OOOOOOOOOO| 100.0%   realization nr. 42. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.601 seconds
# Total elapsed time: 42.356 minutes
# Variance: 256143944710.068
# Mean: 10523.558
# Max: 1568098.903
# Min: -1543243.671
# Run nr.: 43
#
#  |OOOOOOOOOO| 100.0%   realization nr. 43. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.378 seconds
# Total elapsed time: 43.196 minutes
# Variance: 268100506353.712
# Mean: -17939.590
# Max: 1837722.475
# Min: -1892209.506
# Run nr.: 44
#
#  |OOOOOOOOOO| 100.0%   realization nr. 44. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.830 seconds
# Total elapsed time: 44.043 minutes
# Variance: 244488799704.119
# Mean: 22963.664
# Max: 1614250.965
# Min: -1658099.829
# Run nr.: 45
#
#  |OOOOOOOOOO| 100.0%   realization nr. 45. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.558 seconds
# Total elapsed time: 44.902 minutes
# Variance: 268263044772.732
# Mean: 85017.474
# Max: 1920010.569
# Min: -1670194.319
# Run nr.: 46
#
#  |OOOOOOOOOO| 100.0%   realization nr. 46. Counter: 1891/1891, Running error magnitude: 5.7
# Run time: 52.253 seconds
# Total elapsed time: 45.773 minutes
# Variance: 362698417517.728
# Mean: 64696.587
# Max: 1805962.989
# Min: -1851266.743
# Run nr.: 47
#
#  |OOOOOOOOOO| 100.0%   realization nr. 47. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.090 seconds
# Total elapsed time: 46.624 minutes
# Variance: 242623236412.089
# Mean: -42129.031
# Max: 1464781.878
# Min: -1486835.663
# Run nr.: 48
#
#  |OOOOOOOOOO| 100.0%   realization nr. 48. Counter: 1891/1891, Running error magnitude: 5.7
# Run time: 51.551 seconds
# Total elapsed time: 47.484 minutes
# Variance: 397734233113.194
# Mean: 58050.589
# Max: 1937118.239
# Min: -1538722.072
# Run nr.: 49
#
#  |OOOOOOOOOO| 100.0%   realization nr. 49. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.679 seconds
# Total elapsed time: 48.328 minutes
# Variance: 271612132720.321
# Mean: -50581.962
# Max: 1980860.363
# Min: -1634769.588
# Run nr.: 50
#
#  |OOOOOOOOOO| 100.0%   realization nr. 50. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 50.310 seconds
# Total elapsed time: 49.167 minutes
# Variance: 177220260596.452
# Mean: -13579.558
# Max: 1604456.112
# Min: -1290543.845
# Run nr.: 51
#
#  |OOOOOOOOOO| 100.0%   realization nr. 51. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.278 seconds
# Total elapsed time: 50.021 minutes
# Variance: 283767735555.080
# Mean: 78846.951
# Max: 1544639.454
# Min: -1655131.649
# Run nr.: 52
#
#  |OOOOOOOOOO| 100.0%   realization nr. 52. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.062 seconds
# Total elapsed time: 50.872 minutes
# Variance: 273345239100.899
# Mean: -121207.230
# Max: 1326501.012
# Min: -1612936.025
# Run nr.: 53
#
#  |OOOOOOOOOO| 100.0%   realization nr. 53. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 50.573 seconds
# Total elapsed time: 51.715 minutes
# Variance: 252096355602.941
# Mean: -40651.770
# Max: 1531362.809
# Min: -1554573.877
# Run nr.: 54
#
#  |OOOOOOOOOO| 100.0%   realization nr. 54. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.996 seconds
# Total elapsed time: 52.565 minutes
# Variance: 248614178330.451
# Mean: 32296.042
# Max: 1639204.159
# Min: -1390280.631
# Run nr.: 55
#
#  |OOOOOOOOOO| 100.0%   realization nr. 55. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.001 minutes
# Total elapsed time: 53.567 minutes
# Variance: 252515726508.046
# Mean: -57031.781
# Max: 1666423.057
# Min: -1616028.720
# Run nr.: 56
#
#  |OOOOOOOOOO| 100.0%   realization nr. 56. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.054 minutes
# Total elapsed time: 54.621 minutes
# Variance: 307542261831.154
# Mean: -54522.090
# Max: 1448314.294
# Min: -1675004.633
# Run nr.: 57
#
#  |OOOOOOOOOO| 100.0%   realization nr. 57. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.031 minutes
# Total elapsed time: 55.652 minutes
# Variance: 272047415833.104
# Mean: 35029.289
# Max: 1877702.651
# Min: -1488923.520
# Run nr.: 58
#
#  |OOOOOOOOOO| 100.0%   realization nr. 58. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.028 minutes
# Total elapsed time: 56.681 minutes
# Variance: 277371421957.466
# Mean: -47678.154
# Max: 1591330.990
# Min: -1800886.172
# Run nr.: 59
#
#  |OOOOOOOOOO| 100.0%   realization nr. 59. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.013 minutes
# Total elapsed time: 57.693 minutes
# Variance: 241159639739.104
# Mean: -61295.296
# Max: 1408870.450
# Min: -1534530.323
# Run nr.: 60
#
#  |OOOOOOOOOO| 100.0%   realization nr. 60. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.004 minutes
# Total elapsed time: 58.697 minutes
# Variance: 248499378425.338
# Mean: -33522.856
# Max: 1930010.733
# Min: -1457072.512
# Run nr.: 61
#
#  |OOOOOOOOOO| 100.0%   realization nr. 61. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 59.175 seconds
# Total elapsed time: 59.684 minutes
# Variance: 265309244358.491
# Mean: 73016.667
# Max: 2126169.374
# Min: -1509386.308
# Run nr.: 62
#
#  |OOOOOOOOOO| 100.0%   realization nr. 62. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.022 minutes
# Total elapsed time: 1.012 hours
# Variance: 321421267232.443
# Mean: -35701.984
# Max: 1775390.255
# Min: -1778221.000
# Run nr.: 63
#
#  |OOOOOOOOOO| 100.0%   realization nr. 63. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.043 minutes
# Total elapsed time: 1.029 hours
# Variance: 295749937245.527
# Mean: 45392.947
# Max: 1833872.878
# Min: -1499290.439
# Run nr.: 64
#
#  |OOOOOOOOOO| 100.0%   realization nr. 64. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.011 minutes
# Total elapsed time: 1.046 hours
# Variance: 241136415384.146
# Mean: -63495.294
# Max: 1420280.985
# Min: -1572263.060
# Run nr.: 65
#
#  |OOOOOOOOOO| 100.0%   realization nr. 65. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.081 minutes
# Total elapsed time: 1.064 hours
# Variance: 233015282257.431
# Mean: -127952.108
# Max: 1326977.199
# Min: -1615370.216
# Run nr.: 66
#
#  |OOOOOOOOOO| 100.0%   realization nr. 66. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.027 minutes
# Total elapsed time: 1.081 hours
# Variance: 245397087024.958
# Mean: -6450.295
# Max: 1434875.171
# Min: -1598979.411
# Run nr.: 67
#
#  |OOOOOOOOOO| 100.0%   realization nr. 67. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.020 minutes
# Total elapsed time: 1.098 hours
# Variance: 256402614931.062
# Mean: 33053.714
# Max: 1878572.076
# Min: -1477822.829
# Run nr.: 68
#  |----------| 9.9%   realization nr. 68. Counter: 188/1891, Running error magnitude: 5.6
#  |OOOOOOOOOO| 100.0%   realization nr. 68. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.035 minutes
# Total elapsed time: 1.115 hours
# Variance: 258438623967.979
# Mean: 46260.929
# Max: 1558202.180
# Min: -1637900.384
# Run nr.: 69
#
#  |OOOOOOOOOO| 100.0%   realization nr. 69. Counter: 1891/1891, Running error magnitude: 5.7
# Run time: 50.320 seconds
# Total elapsed time: 1.129 hours
# Variance: 327580189455.228
# Mean: -30754.101
# Max: 2040509.837
# Min: -1648587.004
# Run nr.: 70
#
#  |OOOOOOOOOO| 100.0%   realization nr. 70. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.570 seconds
# Total elapsed time: 1.143 hours
# Variance: 261024322851.367
# Mean: 106063.101
# Max: 1920998.347
# Min: -1554028.380
# Run nr.: 71
#
#  |OOOOOOOOOO| 100.0%   realization nr. 71. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 49.834 seconds
# Total elapsed time: 1.157 hours
# Variance: 264261004542.438
# Mean: 36757.476
# Max: 1971503.753
# Min: -1515655.529
# Run nr.: 72
#
#  |OOOOOOOOOO| 100.0%   realization nr. 72. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.496 seconds
# Total elapsed time: 1.171 hours
# Variance: 283734122135.909
# Mean: -11056.928
# Max: 1534424.540
# Min: -1551023.184
# Run nr.: 73
#
#  |OOOOOOOOOO| 100.0%   realization nr. 73. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 49.729 seconds
# Total elapsed time: 1.185 hours
# Variance: 305451221149.755
# Mean: 69966.452
# Max: 1466407.829
# Min: -1581040.082
# Run nr.: 74
#
#  |OOOOOOOOOO| 100.0%   realization nr. 74. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 53.567 seconds
# Total elapsed time: 1.200 hours
# Variance: 227999769296.065
# Mean: 25462.913
# Max: 1425286.167
# Min: -1264744.891
# Run nr.: 75
#
#  |OOOOOOOOOO| 100.0%   realization nr. 75. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 54.009 seconds
# Total elapsed time: 1.215 hours
# Variance: 279201291086.541
# Mean: 8410.791
# Max: 1971974.772
# Min: -1244381.340
# Run nr.: 76
#
#  |OOOOOOOOOO| 100.0%   realization nr. 76. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.710 seconds
# Total elapsed time: 1.229 hours
# Variance: 243737608890.775
# Mean: 112210.165
# Max: 1568298.420
# Min: -1118984.910
# Run nr.: 77
#
#  |OOOOOOOOOO| 100.0%   realization nr. 77. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.374 seconds
# Total elapsed time: 1.243 hours
# Variance: 246619292779.214
# Mean: 30499.985
# Max: 1910823.401
# Min: -1593965.096
# Run nr.: 78
#
#  |OOOOOOOOOO| 100.0%   realization nr. 78. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.270 seconds
# Total elapsed time: 1.258 hours
# Variance: 275298011877.492
# Mean: -6349.618
# Max: 1470994.285
# Min: -1642224.800
# Run nr.: 79
#
#  |OOOOOOOOOO| 100.0%   realization nr. 79. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.136 seconds
# Total elapsed time: 1.272 hours
# Variance: 223627019094.460
# Mean: 72909.851
# Max: 1393923.292
# Min: -1582943.980
# Run nr.: 80
#
#  |OOOOOOOOOO| 100.0%   realization nr. 80. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.083 minutes
# Total elapsed time: 1.290 hours
# Variance: 255776745838.863
# Mean: -145647.929
# Max: 1434295.238
# Min: -1644198.259
# Run nr.: 81
#
#  |OOOOOOOOOO| 100.0%   realization nr. 81. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.086 minutes
# Total elapsed time: 1.308 hours
# Variance: 275467929354.017
# Mean: -2749.451
# Max: 1450959.484
# Min: -1614388.633
# Run nr.: 82
#
#  |OOOOOOOOOO| 100.0%   realization nr. 82. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.164 minutes
# Total elapsed time: 1.327 hours
# Variance: 314725713451.975
# Mean: -95865.452
# Max: 1762956.160
# Min: -1650267.030
# Run nr.: 83
#
#  |OOOOOOOOOO| 100.0%   realization nr. 83. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.083 minutes
# Total elapsed time: 1.345 hours
# Variance: 281732127879.464
# Mean: 105847.101
# Max: 1443485.367
# Min: -1646121.671
# Run nr.: 84
#
#  |OOOOOOOOOO| 100.0%   realization nr. 84. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 57.828 seconds
# Total elapsed time: 1.361 hours
# Variance: 244551494139.329
# Mean: -74898.447
# Max: 1702801.547
# Min: -1525188.298
# Run nr.: 85
#
#  |OOOOOOOOOO| 100.0%   realization nr. 85. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.007 minutes
# Total elapsed time: 1.378 hours
# Variance: 300794533818.867
# Mean: -56073.767
# Max: 1470052.763
# Min: -1506108.893
# Run nr.: 86
#
#  |OOOOOOOOOO| 100.0%   realization nr. 86. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.062 minutes
# Total elapsed time: 1.396 hours
# Variance: 297789080292.691
# Mean: 45970.729
# Max: 1812226.926
# Min: -1653981.667
# Run nr.: 87
#
#  |OOOOOOOOOO| 100.0%   realization nr. 87. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.065 minutes
# Total elapsed time: 1.414 hours
# Variance: 251781160971.874
# Mean: 2935.161
# Max: 1448647.792
# Min: -1507017.517
# Run nr.: 88
#
#  |OOOOOOOOOO| 100.0%   realization nr. 88. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.052 minutes
# Total elapsed time: 1.431 hours
# Variance: 277113259656.703
# Mean: 37692.430
# Max: 1814488.689
# Min: -1481466.389
# Run nr.: 89
#
#  |OOOOOOOOOO| 100.0%   realization nr. 89. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.032 minutes
# Total elapsed time: 1.448 hours
# Variance: 274498975938.347
# Mean: -86422.881
# Max: 1439862.922
# Min: -1623096.907
# Run nr.: 90
#
#  |OOOOOOOOOO| 100.0%   realization nr. 90. Counter: 1891/1891, Running error magnitude: 5.7
# Run time: 1.061 minutes
# Total elapsed time: 1.466 hours
# Variance: 282971458865.524
# Mean: -149457.748
# Max: 1849851.346
# Min: -1618250.870
# Run nr.: 91
#
#  |OOOOOOOOOO| 100.0%   realization nr. 91. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.045 minutes
# Total elapsed time: 1.484 hours
# Variance: 242354745063.532
# Mean: 76493.110
# Max: 1460075.932
# Min: -1615278.827
# Run nr.: 92
#
#  |OOOOOOOOOO| 100.0%   realization nr. 92. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.026 minutes
# Total elapsed time: 1.501 hours
# Variance: 263369121463.125
# Mean: -40690.982
# Max: 1322302.564
# Min: -1630702.858
# Run nr.: 93
#
#  |OOOOOOOOOO| 100.0%   realization nr. 93. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 51.900 seconds
# Total elapsed time: 1.515 hours
# Variance: 275482888883.943
# Mean: -1265.122
# Max: 1906737.066
# Min: -1638903.565
# Run nr.: 94
#
#  |OOOOOOOOOO| 100.0%   realization nr. 94. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.635 seconds
# Total elapsed time: 1.529 hours
# Variance: 261633285230.960
# Mean: -125946.588
# Max: 1426703.025
# Min: -1659204.420
# Run nr.: 95
#
#  |OOOOOOOOOO| 100.0%   realization nr. 95. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.538 seconds
# Total elapsed time: 1.543 hours
# Variance: 221161136993.564
# Mean: 39434.539
# Max: 1391052.411
# Min: -1563755.326
# Run nr.: 96
#
#  |OOOOOOOOOO| 100.0%   realization nr. 96. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.113 seconds
# Total elapsed time: 1.558 hours
# Variance: 277377132285.514
# Mean: -56675.186
# Max: 1901966.588
# Min: -1654431.725
# Run nr.: 97
#
#  |OOOOOOOOOO| 100.0%   realization nr. 97. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 51.158 seconds
# Total elapsed time: 1.572 hours
# Variance: 256808093033.741
# Mean: 44357.035
# Max: 1759282.249
# Min: -1615584.754
# Run nr.: 98
#
#  |OOOOOOOOOO| 100.0%   realization nr. 98. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 54.741 seconds
# Total elapsed time: 1.587 hours
# Variance: 283599140784.173
# Mean: -55119.255
# Max: 1584218.335
# Min: -1654680.553
# Run nr.: 99
#
#  |OOOOOOOOOO| 100.0%   realization nr. 99. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 54.107 seconds
# Total elapsed time: 1.602 hours
# Variance: 254310298987.281
# Mean: 96975.968
# Max: 1423058.608
# Min: -1658839.493
# Run nr.: 100
#
#  |OOOOOOOOOO| 100.0%   realization nr. 100. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 52.296 seconds
# Total elapsed time: 1.617 hours
# Variance: 232258273171.372
# Mean: -28170.812
# Max: 1731019.969
# Min: -1509283.946
# Run nr.: 101
#
#  |OOOOOOOOOO| 100.0%   realization nr. 101. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.022 minutes
# Total elapsed time: 1.634 hours
# Variance: 261181038654.478
# Mean: -88099.814
# Max: 1605763.247
# Min: -1650835.386
# Run nr.: 102
#  |----------| 8.2%   realization nr. 102. Counter: 156/1891, Running error magnitude: 5.5
#  |OOOOOOOOOO| 100.0%   realization nr. 102. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.133 minutes
# Total elapsed time: 1.653 hours
# Variance: 270773119582.306
# Mean: 133578.930
# Max: 1535641.190
# Min: -1531489.486
# Run nr.: 103
#
#  |OOOOOOOOOO| 100.0%   realization nr. 103. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.127 minutes
# Total elapsed time: 1.671 hours
# Variance: 281446883776.273
# Mean: 29379.608
# Max: 1558937.084
# Min: -1598888.714
# Run nr.: 104
#
#  |OOOOOOOOOO| 100.0%   realization nr. 104. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.064 minutes
# Total elapsed time: 1.689 hours
# Variance: 306701074356.928
# Mean: 43180.846
# Max: 1846686.943
# Min: -1652444.942
# Run nr.: 105
#
#  |OOOOOOOOOO| 100.0%   realization nr. 105. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.043 minutes
# Total elapsed time: 1.706 hours
# Variance: 268926890981.290
# Mean: 7296.776
# Max: 1454166.989
# Min: -1620281.764
# Run nr.: 106
#
#  |OOOOOOOOOO| 100.0%   realization nr. 106. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 59.655 seconds
# Total elapsed time: 1.723 hours
# Variance: 270341883626.345
# Mean: -47611.225
# Max: 1324293.128
# Min: -1612164.213
# Run nr.: 107
#
#  |OOOOOOOOOO| 100.0%   realization nr. 107. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.061 minutes
# Total elapsed time: 1.741 hours
# Variance: 260731537548.951
# Mean: 51052.336
# Max: 1819153.193
# Min: -1380384.884
# Run nr.: 108
#
#  |OOOOOOOOOO| 100.0%   realization nr. 108. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.018 minutes
# Total elapsed time: 1.758 hours
# Variance: 306318157107.465
# Mean: -73862.612
# Max: 1827027.429
# Min: -1514835.024
# Run nr.: 109
#
#  |OOOOOOOOOO| 100.0%   realization nr. 109. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.022 minutes
# Total elapsed time: 1.775 hours
# Variance: 201328891920.631
# Mean: 32561.156
# Max: 1582736.851
# Min: -1221856.991
# Run nr.: 110
#
#  |OOOOOOOOOO| 100.0%   realization nr. 110. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.042 minutes
# Total elapsed time: 1.792 hours
# Variance: 247367154362.089
# Mean: -61534.353
# Max: 1418746.134
# Min: -1648473.555
# Run nr.: 111
#
#  |OOOOOOOOOO| 100.0%   realization nr. 111. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.088 minutes
# Total elapsed time: 1.810 hours
# Variance: 289700001151.541
# Mean: 11209.561
# Max: 2344695.585
# Min: -1622504.069
# Run nr.: 112
#
#  |OOOOOOOOOO| 100.0%   realization nr. 112. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.092 minutes
# Total elapsed time: 1.828 hours
# Variance: 230006540937.482
# Mean: 15393.728
# Max: 1339983.326
# Min: -1317498.988
# Run nr.: 113
#
#  |OOOOOOOOOO| 100.0%   realization nr. 113. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.057 minutes
# Total elapsed time: 1.846 hours
# Variance: 279545218846.526
# Mean: 9727.237
# Max: 2219857.659
# Min: -1644213.357
# Run nr.: 114
#
#  |OOOOOOOOOO| 100.0%   realization nr. 114. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 57.160 seconds
# Total elapsed time: 1.862 hours
# Variance: 280432428675.986
# Mean: 85785.203
# Max: 1829302.147
# Min: -1553617.567
# Run nr.: 115
#
#  |OOOOOOOOOO| 100.0%   realization nr. 115. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.887 seconds
# Total elapsed time: 1.876 hours
# Variance: 287874570363.230
# Mean: -29822.507
# Max: 1592381.262
# Min: -1594379.788
# Run nr.: 116
#
#  |OOOOOOOOOO| 100.0%   realization nr. 116. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.294 seconds
# Total elapsed time: 1.890 hours
# Variance: 213694668210.084
# Mean: 20057.993
# Max: 1701965.735
# Min: -1657888.323
# Run nr.: 117
#
#  |OOOOOOOOOO| 100.0%   realization nr. 117. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.197 seconds
# Total elapsed time: 1.904 hours
# Variance: 277024450175.593
# Mean: 21571.853
# Max: 1653903.906
# Min: -1638689.411
# Run nr.: 118
#
#  |OOOOOOOOOO| 100.0%   realization nr. 118. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 50.372 seconds
# Total elapsed time: 1.918 hours
# Variance: 297637688204.645
# Mean: 10829.314
# Max: 1641381.058
# Min: -1448438.997
# Run nr.: 119
#
#  |OOOOOOOOOO| 100.0%   realization nr. 119. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 51.087 seconds
# Total elapsed time: 1.932 hours
# Variance: 208267941388.285
# Mean: -122247.714
# Max: 1418725.301
# Min: -1639090.608
# Run nr.: 120
#
#  |OOOOOOOOOO| 100.0%   realization nr. 120. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.095 seconds
# Total elapsed time: 1.946 hours
# Variance: 276034159314.284
# Mean: 12308.431
# Max: 1863361.025
# Min: -1477704.956
# Run nr.: 121
#
#  |OOOOOOOOOO| 100.0%   realization nr. 121. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 50.871 seconds
# Total elapsed time: 1.960 hours
# Variance: 265967017510.529
# Mean: 13590.931
# Max: 1408500.064
# Min: -1600956.647
# Run nr.: 122
#
#  |OOOOOOOOOO| 100.0%   realization nr. 122. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.018 seconds
# Total elapsed time: 1.975 hours
# Variance: 258106784023.413
# Mean: -4918.456
# Max: 1401241.060
# Min: -1529562.070
# Run nr.: 123
#
#  |OOOOOOOOOO| 100.0%   realization nr. 123. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 50.477 seconds
# Total elapsed time: 1.989 hours
# Variance: 248268771032.101
# Mean: 39333.401
# Max: 1437621.118
# Min: -1602957.380
# Run nr.: 124
#
#  |OOOOOOOOOO| 100.0%   realization nr. 124. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 49.938 seconds
# Total elapsed time: 2.002 hours
# Variance: 267048604468.099
# Mean: 82392.806
# Max: 1487634.040
# Min: -1365050.592
# Run nr.: 125
#
#  |OOOOOOOOOO| 100.0%   realization nr. 125. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 50.909 seconds
# Total elapsed time: 2.017 hours
# Variance: 190192289672.522
# Mean: 66785.637
# Max: 1727081.264
# Min: -1598387.897
# Run nr.: 126
#
#  |OOOOOOOOOO| 100.0%   realization nr. 126. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 51.141 seconds
# Total elapsed time: 2.031 hours
# Variance: 272408327884.105
# Mean: -52816.691
# Max: 1920164.326
# Min: -1633261.150
# Run nr.: 127
#
#  |OOOOOOOOOO| 100.0%   realization nr. 127. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.997 seconds
# Total elapsed time: 2.045 hours
# Variance: 297599603148.427
# Mean: -75433.293
# Max: 1800195.083
# Min: -1696157.851
# Run nr.: 128
#
#  |OOOOOOOOOO| 100.0%   realization nr. 128. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 53.521 seconds
# Total elapsed time: 2.060 hours
# Variance: 260553214246.683
# Mean: -46822.803
# Max: 1632218.167
# Min: -1698360.739
# Run nr.: 129
#
#  |OOOOOOOOOO| 100.0%   realization nr. 129. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 50.794 seconds
# Total elapsed time: 2.074 hours
# Variance: 239846961647.566
# Mean: 64600.109
# Max: 1843646.531
# Min: -1304894.006
# Run nr.: 130
#
#  |OOOOOOOOOO| 100.0%   realization nr. 130. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.074 minutes
# Total elapsed time: 2.092 hours
# Variance: 234773197330.178
# Mean: -160962.483
# Max: 1387163.018
# Min: -1645135.080
# Run nr.: 131
#
#  |OOOOOOOOOO| 100.0%   realization nr. 131. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.132 minutes
# Total elapsed time: 2.111 hours
# Variance: 252381940957.828
# Mean: 90993.137
# Max: 1538928.876
# Min: -1162589.225
# Run nr.: 132
#
#  |OOOOOOOOOO| 100.0%   realization nr. 132. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.084 minutes
# Total elapsed time: 2.129 hours
# Variance: 233523020216.300
# Mean: -79052.882
# Max: 1416348.301
# Min: -1265254.977
# Run nr.: 133
#
#  |OOOOOOOOOO| 100.0%   realization nr. 133. Counter: 1891/1891, Running error magnitude: 5.7
# Run time: 1.072 minutes
# Total elapsed time: 2.147 hours
# Variance: 353995289197.691
# Mean: 194386.897
# Max: 1880678.991
# Min: -1567789.510
# Run nr.: 134
#
#  |OOOOOOOOOO| 100.0%   realization nr. 134. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.006 minutes
# Total elapsed time: 2.164 hours
# Variance: 273559231278.945
# Mean: -22140.705
# Max: 1913666.698
# Min: -1606196.137
# Run nr.: 135
#
#  |OOOOOOOOOO| 100.0%   realization nr. 135. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.025 minutes
# Total elapsed time: 2.181 hours
# Variance: 232344377824.766
# Mean: -52363.588
# Max: 1352629.688
# Min: -1642045.937
# Run nr.: 136
#  |----------| 8.6%   realization nr. 136. Counter: 162/1891, Running error magnitude: 5.6
#  |OOOOOOOOOO| 100.0%   realization nr. 136. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.074 minutes
# Total elapsed time: 2.199 hours
# Variance: 243641314975.567
# Mean: -46201.003
# Max: 1512106.167
# Min: -1557813.695
# Run nr.: 137
#
#  |OOOOOOOOOO| 100.0%   realization nr. 137. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.046 minutes
# Total elapsed time: 2.216 hours
# Variance: 249881620800.914
# Mean: -208.721
# Max: 1672534.345
# Min: -1655909.001
# Run nr.: 138
#
#  |OOOOOOOOOO| 100.0%   realization nr. 138. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.007 minutes
# Total elapsed time: 2.233 hours
# Variance: 290873011857.278
# Mean: 106996.850
# Max: 2123851.867
# Min: -1466608.058
# Run nr.: 139
#
#  |OOOOOOOOOO| 100.0%   realization nr. 139. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.080 minutes
# Total elapsed time: 2.251 hours
# Variance: 281072000523.706
# Mean: -113005.131
# Max: 1686481.089
# Min: -1708117.421
# Run nr.: 140
#
#  |OOOOOOOOOO| 100.0%   realization nr. 140. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.072 minutes
# Total elapsed time: 2.269 hours
# Variance: 238360538926.262
# Mean: -122827.278
# Max: 1465771.110
# Min: -1648959.368
# Run nr.: 141
#
#  |OOOOOOOOOO| 100.0%   realization nr. 141. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.010 minutes
# Total elapsed time: 2.286 hours
# Variance: 305140206300.636
# Mean: -18413.557
# Max: 1439471.768
# Min: -1631796.678
# Run nr.: 142
#
#  |OOOOOOOOOO| 100.0%   realization nr. 142. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.007 minutes
# Total elapsed time: 2.302 hours
# Variance: 232602471148.039
# Mean: 57662.993
# Max: 1839629.353
# Min: -1532479.029
# Run nr.: 143
#
#  |OOOOOOOOOO| 100.0%   realization nr. 143. Counter: 1891/1891, Running error magnitude: 5.7
# Run time: 53.350 seconds
# Total elapsed time: 2.317 hours
# Variance: 333714296535.388
# Mean: -118245.075
# Max: 1909291.489
# Min: -1652196.399
# Run nr.: 144
#
#  |OOOOOOOOOO| 100.0%   realization nr. 144. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.269 seconds
# Total elapsed time: 2.331 hours
# Variance: 242924334714.628
# Mean: -40830.975
# Max: 1970655.898
# Min: -1387526.152
# Run nr.: 145
#
#  |OOOOOOOOOO| 100.0%   realization nr. 145. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.353 seconds
# Total elapsed time: 2.346 hours
# Variance: 251212613517.003
# Mean: -109957.888
# Max: 1500392.941
# Min: -1652147.666
# Run nr.: 146
#
#  |OOOOOOOOOO| 100.0%   realization nr. 146. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 52.265 seconds
# Total elapsed time: 2.360 hours
# Variance: 235490012845.652
# Mean: 412.110
# Max: 1376090.853
# Min: -1381661.950
# Run nr.: 147
#
#  |OOOOOOOOOO| 100.0%   realization nr. 147. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.217 seconds
# Total elapsed time: 2.374 hours
# Variance: 227798337316.575
# Mean: 4624.462
# Max: 1866523.799
# Min: -1418668.024
# Run nr.: 148
#
#  |OOOOOOOOOO| 100.0%   realization nr. 148. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.177 seconds
# Total elapsed time: 2.389 hours
# Variance: 292869981317.698
# Mean: -54889.055
# Max: 1635560.212
# Min: -1616067.448
# Run nr.: 149
#
#  |OOOOOOOOOO| 100.0%   realization nr. 149. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 52.112 seconds
# Total elapsed time: 2.403 hours
# Variance: 213709743606.769
# Mean: -6818.415
# Max: 1345408.627
# Min: -1608672.511
# Run nr.: 150
#
#  |OOOOOOOOOO| 100.0%   realization nr. 150. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 52.064 seconds
# Total elapsed time: 2.418 hours
# Variance: 244364281304.587
# Mean: -40684.494
# Max: 1985745.597
# Min: -1250702.360
# Run nr.: 151
#
#  |OOOOOOOOOO| 100.0%   realization nr. 151. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.091 seconds
# Total elapsed time: 2.432 hours
# Variance: 312111728465.223
# Mean: -58171.582
# Max: 1553265.489
# Min: -1658780.379
# Run nr.: 152
#
#  |OOOOOOOOOO| 100.0%   realization nr. 152. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.183 seconds
# Total elapsed time: 2.446 hours
# Variance: 231881573066.466
# Mean: -68623.558
# Max: 2022938.069
# Min: -1594864.416
# Run nr.: 153
#
#  |OOOOOOOOOO| 100.0%   realization nr. 153. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.831 seconds
# Total elapsed time: 2.460 hours
# Variance: 272377734857.724
# Mean: 23388.060
# Max: 1736801.345
# Min: -1331399.225
# Run nr.: 154
#
#  |OOOOOOOOOO| 100.0%   realization nr. 154. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.696 seconds
# Total elapsed time: 2.475 hours
# Variance: 275812818301.249
# Mean: 65785.270
# Max: 1750935.290
# Min: -1688211.152
# Run nr.: 155
#
#  |OOOOOOOOOO| 100.0%   realization nr. 155. Counter: 1891/1891, Running error magnitude: 5.7
# Run time: 52.261 seconds
# Total elapsed time: 2.489 hours
# Variance: 339920202031.593
# Mean: 122030.348
# Max: 1937039.616
# Min: -1641905.032
# Run nr.: 156
#
#  |OOOOOOOOOO| 100.0%   realization nr. 156. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 51.745 seconds
# Total elapsed time: 2.504 hours
# Variance: 320019215268.648
# Mean: 29071.146
# Max: 2020739.378
# Min: -1505011.401
# Run nr.: 157
#
#  |OOOOOOOOOO| 100.0%   realization nr. 157. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 51.714 seconds
# Total elapsed time: 2.518 hours
# Variance: 254381759313.007
# Mean: -118877.093
# Max: 1628789.587
# Min: -1637466.162
# Run nr.: 158
#
#  |OOOOOOOOOO| 100.0%   realization nr. 158. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 52.616 seconds
# Total elapsed time: 2.533 hours
# Variance: 302665239364.113
# Mean: 74385.740
# Max: 1789187.689
# Min: -1472781.986
# Run nr.: 159
#
#  |OOOOOOOOOO| 100.0%   realization nr. 159. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 52.508 seconds
# Total elapsed time: 2.547 hours
# Variance: 314247029352.426
# Mean: 69483.576
# Max: 1970411.629
# Min: -1411139.393
# Run nr.: 160
#
#  |OOOOOOOOOO| 100.0%   realization nr. 160. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 52.255 seconds
# Total elapsed time: 2.562 hours
# Variance: 279315250576.797
# Mean: -36749.340
# Max: 1561205.950
# Min: -1655022.629
# Run nr.: 161
#
#  |OOOOOOOOOO| 100.0%   realization nr. 161. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 53.387 seconds
# Total elapsed time: 2.577 hours
# Variance: 230714474632.721
# Mean: 70870.336
# Max: 1480489.464
# Min: -1450628.912
# Run nr.: 162
#
#  |OOOOOOOOOO| 100.0%   realization nr. 162. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.069 minutes
# Total elapsed time: 2.594 hours
# Variance: 261555623198.100
# Mean: 88157.455
# Max: 2200363.817
# Min: -1613895.029
# Run nr.: 163
#
#  |OOOOOOOOOO| 100.0%   realization nr. 163. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.208 minutes
# Total elapsed time: 2.614 hours
# Variance: 268664924800.341
# Mean: -50447.124
# Max: 1874055.276
# Min: -1643587.964
# Run nr.: 164
#
#  |OOOOOOOOOO| 100.0%   realization nr. 164. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.113 minutes
# Total elapsed time: 2.633 hours
# Variance: 269175200652.198
# Mean: -39401.980
# Max: 1648063.126
# Min: -1487883.164
# Run nr.: 165
#
#  |OOOOOOOOOO| 100.0%   realization nr. 165. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.057 minutes
# Total elapsed time: 2.651 hours
# Variance: 240379464986.880
# Mean: 66032.040
# Max: 1461348.025
# Min: -1302350.845
# Run nr.: 166
#
#  |OOOOOOOOOO| 100.0%   realization nr. 166. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.041 minutes
# Total elapsed time: 2.668 hours
# Variance: 302938307319.719
# Mean: 110736.066
# Max: 2268685.811
# Min: -1500648.764
# Run nr.: 167
#
#  |OOOOOOOOOO| 100.0%   realization nr. 167. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 59.378 seconds
# Total elapsed time: 2.684 hours
# Variance: 250674941718.615
# Mean: 57874.829
# Max: 2038756.773
# Min: -1340772.883
# Run nr.: 168
#
#  |OOOOOOOOOO| 100.0%   realization nr. 168. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 59.255 seconds
# Total elapsed time: 2.701 hours
# Variance: 277945962779.977
# Mean: -59927.560
# Max: 2004412.574
# Min: -1447217.938
# Run nr.: 169
#
#  |OOOOOOOOOO| 100.0%   realization nr. 169. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 59.870 seconds
# Total elapsed time: 2.718 hours
# Variance: 306946901544.313
# Mean: 41726.687
# Max: 2236563.898
# Min: -1611227.837
# Run nr.: 170
#  |----------| 7.3%   realization nr. 170. Counter: 138/1891, Running error magnitude: 5.6
#  |OOOOOOOOOO| 100.0%   realization nr. 170. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.016 minutes
# Total elapsed time: 2.735 hours
# Variance: 260277630476.204
# Mean: 66484.609
# Max: 1678762.238
# Min: -1337124.304
# Run nr.: 171
#
#  |OOOOOOOOOO| 100.0%   realization nr. 171. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.047 minutes
# Total elapsed time: 2.752 hours
# Variance: 221928919034.100
# Mean: -15286.315
# Max: 1468148.352
# Min: -1593874.004
# Run nr.: 172
#
#  |OOOOOOOOOO| 100.0%   realization nr. 172. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.033 minutes
# Total elapsed time: 2.769 hours
# Variance: 238962338998.561
# Mean: -59597.028
# Max: 1448061.572
# Min: -1587408.904
# Run nr.: 173
#
#  |OOOOOOOOOO| 100.0%   realization nr. 173. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.012 minutes
# Total elapsed time: 2.786 hours
# Variance: 214375809816.961
# Mean: 107328.314
# Max: 1639461.462
# Min: -1226405.692
# Run nr.: 174
#
#  |OOOOOOOOOO| 100.0%   realization nr. 174. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.027 minutes
# Total elapsed time: 2.803 hours
# Variance: 271938932694.199
# Mean: -61607.145
# Max: 1428979.124
# Min: -1653270.463
# Run nr.: 175
#
#  |OOOOOOOOOO| 100.0%   realization nr. 175. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.024 minutes
# Total elapsed time: 2.820 hours
# Variance: 198720393497.018
# Mean: 78270.436
# Max: 1797669.984
# Min: -1591117.061
# Run nr.: 176
#
#  |OOOOOOOOOO| 100.0%   realization nr. 176. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.031 minutes
# Total elapsed time: 2.837 hours
# Variance: 190565535305.146
# Mean: 78590.990
# Max: 1456485.112
# Min: -1122069.266
# Run nr.: 177
#
#  |OOOOOOOOOO| 100.0%   realization nr. 177. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 59.217 seconds
# Total elapsed time: 2.854 hours
# Variance: 254831538181.307
# Mean: -144524.769
# Max: 1541079.842
# Min: -1685302.761
# Run nr.: 178
#
#  |OOOOOOOOOO| 100.0%   realization nr. 178. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 57.509 seconds
# Total elapsed time: 2.870 hours
# Variance: 300175352302.353
# Mean: 90228.703
# Max: 1679251.773
# Min: -1659990.479
# Run nr.: 179
#
#  |OOOOOOOOOO| 100.0%   realization nr. 179. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.045 minutes
# Total elapsed time: 2.887 hours
# Variance: 260197248087.935
# Mean: 210939.892
# Max: 1796014.539
# Min: -1623255.002
# Run nr.: 180
#
#  |OOOOOOOOOO| 100.0%   realization nr. 180. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.037 minutes
# Total elapsed time: 2.905 hours
# Variance: 253629467543.975
# Mean: 66930.264
# Max: 1441677.006
# Min: -1555017.326
# Run nr.: 181
#
#  |OOOOOOOOOO| 100.0%   realization nr. 181. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.030 minutes
# Total elapsed time: 2.922 hours
# Variance: 311387899768.589
# Mean: -125338.013
# Max: 1441447.059
# Min: -1738490.460
# Run nr.: 182
#
#  |OOOOOOOOOO| 100.0%   realization nr. 182. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.072 minutes
# Total elapsed time: 2.940 hours
# Variance: 277766468146.061
# Mean: -46468.184
# Max: 1411563.593
# Min: -1635166.341
# Run nr.: 183
#
#  |OOOOOOOOOO| 100.0%   realization nr. 183. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.011 minutes
# Total elapsed time: 2.956 hours
# Variance: 239215161069.569
# Mean: 57731.689
# Max: 1620519.787
# Min: -1140219.905
# Run nr.: 184
#
#  |OOOOOOOOOO| 100.0%   realization nr. 184. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.053 minutes
# Total elapsed time: 2.974 hours
# Variance: 284847429315.788
# Mean: 98283.406
# Max: 1920530.849
# Min: -1501372.733
# Run nr.: 185
#
#  |OOOOOOOOOO| 100.0%   realization nr. 185. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.045 minutes
# Total elapsed time: 2.991 hours
# Variance: 298823863117.859
# Mean: -33381.291
# Max: 1856765.141
# Min: -1604070.948
# Run nr.: 186
#
#  |OOOOOOOOOO| 100.0%   realization nr. 186. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.048 minutes
# Total elapsed time: 3.009 hours
# Variance: 328178550982.485
# Mean: -106728.309
# Max: 2419532.198
# Min: -1654884.505
# Run nr.: 187
#
#  |OOOOOOOOOO| 100.0%   realization nr. 187. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.027 minutes
# Total elapsed time: 3.026 hours
# Variance: 226090013702.401
# Mean: 151748.138
# Max: 1811809.280
# Min: -1155942.985
# Run nr.: 188
#
#  |OOOOOOOOOO| 100.0%   realization nr. 188. Counter: 1891/1891, Running error magnitude: 5.6
# Run time: 1.035 minutes
# Total elapsed time: 3.043 hours
# Variance: 241660267719.890
# Mean: 22360.948
# Max: 1764265.212
# Min: -1591937.544
# Run nr.: 189
#
#  |OOOOOOOOOO| 100.0%   realization nr. 189. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.032 minutes
# Total elapsed time: 3.060 hours
# Variance: 197002452225.686
# Mean: 10566.577
# Max: 1385597.950
# Min: -1637639.313
# Run nr.: 190
#
#  |OOOOOOOOOO| 100.0%   realization nr. 190. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 1.028 minutes
# Total elapsed time: 3.078 hours
# Variance: 199334315854.477
# Mean: -121542.327
# Max: 1397986.872
# Min: -1529295.069
# Run nr.: 191
#
#  |OOOOOOOOOO| 100.0%   realization nr. 191. Counter: 1891/1891, Running error magnitude: 5.5
# Run time:
core.realization_to_sh_coeff(core.r_cmb, set_nmax = 30)

# %%
core.covmod_lsq_equiv(s_sat.data, core.C_mm_all, core.G, core.r_cmb)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.grid_glq(nmax = 30, r_at = core.r_cmb)
mt_util.plot_sdssim_reproduce(core, core.m_DSS_res, m_equiv_lsq = core.m_equiv_lsq,
                              lags_use = 1000, spec_r_at = core.r_cmb,
                              model_dict = {}, figsize=(9,16),
                              hist_bins = 20, res_bins = 20,
                              savefig = True, save_string = "core_sh30_unconditional", save_dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# # Conditional table investigation

# %%
print(core)
# Out:
# ______current attributes______
#
# a:                     6371.2
# r_sat:                 6721.2
# r_cmb:                 3480.0
# rad:                   0.017453292519943295
# mu0:                   1.2566370614359173e-06
# comment:               Finding sparsity by digging into histogram reproduction
# class_abs_path:        /home/mikotz/spherical_direct_sequential_simulation
# N_SH:                  30
# N_SH_secondary:        None
# sim_type:              core
# grid_glq_zero:         (31,), Max/Min: 1.00 / -1.00
# grid_glq_w_shtools:    (31,), Max/Min: 0.10 / 0.01
# grid_glq_shape:        (2,), Max/Min: 61.00 / 31.00
# grid_glq_w:            (1891,), Max/Min: 0.10 / 0.01
# grid_glq_radial:       (1891,), Max/Min: 3480.00 / 3480.00
# grid_glq_theta:        (1891,), Max/Min: 175.63 / 4.37
# grid_glq_phi:          (1891,), Max/Min: 354.10 / 0.00
# grid_glq_N:            1891
# grid_glq_nmax:         30
# r_grid:                3480.0
# grid:                  (1891, 2)
# sph_d:                 (1891, 1891)
# lon:                   (1891,), Max/Min: 354.10 / 0.00
# lat:                   (1891,), Max/Min: 85.63 / -85.63
# N_grid:                1891
# data:                  (1891,), Max/Min: 2717914.01 / -1655937.04
# r_grid_repeat:         (1891,), Max/Min: 3480.00 / 3480.00
# target_var:            281134270951.117
# target_mean_true:      -10745.550297945754
# target_mean:           0.0
# g_prior:               (960,), Max/Min: 5004.71 / -51832.17
# CQF_dist:              (21, 21, 18910)
# CQF_mean:              (21, 21)
# CQF_var:               (21, 21)
# rangv:                 (21,), Max/Min: 0.50 / 0.00
# rangn:                 (21,), Max/Min: 3.50 / -3.50
# condtab_normsize:      18910
# condtab_model_hist:    False
# condtab_table:         rough
# sv_model_lags:         3
# sv_max_dist:           20000
# sv_lag_length:         200
# sv_zero_nugget:        True
# sort_d:                (3575881,), Max/Min: 3575880.00 / 0.00
# cloud_sorted:          (3575881,), Max/Min: 9565286482785.56 / 0.00
# sph_d_sorted:          (3575881,), Max/Min: 10919.08 / 0.00
# max_cloud:             3575881
# n_lags:                54
# lags:                  (53,), Max/Min: 9969.47 / 0.00
# pics:                  (53,), Max/Min: 458649364791.58 / 0.00
# model_select_simple:   False
# model_select_advanced: False
# lags_model:            (3,), Max/Min: 971.60 / 0.00
# pics_model:            (3,), Max/Min: 124183363843.91 / 0.00
# lags_sv_curve:         (53,), Max/Min: 9969.00 / 0.00
# sv_curve:              (53,), Max/Min: 280302044766.47 / 0.00
# sv_lut:                (1891, 1891)
# model:                 exponential
# a_sv:                  5136.468052012959
# C0:                    0.0
# C1:                    281134270951.117
# C2:                    None
# C3:                    None
# G:                     (2773, 1891)
# C_mm_all:              (1891, 1891)
# C_dd:                  (2773, 2773)
# C_dm_all:              (1891, 2773)
# C_e_const:             2

# %%
idx_n_hist =[]
idx_v_hist = []

for idx_n, idx_v in core.idx_nv_collect:
    idx_n_hist.append(idx_n)
    idx_v_hist.append(idx_v)


plt.figure()
plt.hist(idx_n_hist,bins=101)
plt.show()

plt.figure()
plt.hist(idx_v_hist,bins=101)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
k_vs = []

for i in np.arange(0,len(core.kriging_mv_collect)):
    k_vs.append(core.kriging_mv_collect[i][1])

# %%
plt.figure()
plt.hist(k_vs)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Count sampling

# %%
# animation
from matplotlib import animation, rc
from IPython.display import HTML, Image, display, Video
import os

# %%
samples_emp_QF = []
for j in np.arange(0,core.m_DSS.shape[0]):
    nv_in = core.idx_nv_collect[j]
    test_CQF_dist = core.CQF_dist[nv_in[0],nv_in[1],:]
    samples_emp_QF.append(test_CQF_dist[np.random.randint(0,core.condtab_normsize,size=1)])
    
samples_emp_QF = np.array(samples_emp_QF)

# %%
samples_emp_QF.shape
# Out:
# (1891, 1)

# %%
def conditional_lookup(self, mu_k, sigma_sq_k, dm, dv, scaling = True):
        #conditional_lookup(self, cond_mean, cond_var, cond_dist, cond_dist_size, mu_k, sigma_sq_k, dm, dv):
        #conditional_lookup(core.CQF_mean, core.CQF_var, core.CQF_dist, core.condtab_normsize, mu_k, sigma_sq_k, dm_c, dv_c)

        #distance = np.power((self.CQF_mean-mu_k)/dm,2)+np.power((self.CQF_var-sigma_sq_k)/dv,2)   
        #distance = np.power((self.CQF_mean-mu_k),2)+np.power((self.CQF_var-sigma_sq_k),2)        
        
        #distance = np.power((self.CQF_mean-mu_k)/dm,2)+abs(self.CQF_var-sigma_sq_k)/np.sqrt(dv)
        
        distance = abs(self.CQF_mean-mu_k)/dm+abs(self.CQF_var-sigma_sq_k)/dv # THIS ONE
        
        #distance = abs(self.CQF_mean-mu_k)+abs(self.CQF_var-sigma_sq_k)
        
        nearest = np.unravel_index(np.argmin(distance),self.CQF_mean.shape)
        idx_n = nearest[0]
        idx_v = nearest[-1]
        
        nearest_dist = self.CQF_dist[idx_n,idx_v,:]
        
        m_i = nearest_dist[np.random.randint(0,self.condtab_normsize,size=1)]

        if scaling == True:
            m_i_mean = self.CQF_mean[idx_n,idx_v]        
            m_i_std = np.sqrt(self.CQF_var[idx_n,idx_v],dtype=np.float64)
            m_k = (m_i - m_i_mean)*np.sqrt(sigma_sq_k)/m_i_std+mu_k
        else:
            m_k = m_i

        return idx_n, idx_v, nearest_dist, m_i, distance

# %%
from matplotlib.colorbar import Colorbar

data_min = np.min(core.data)
data_max = np.max(core.data)
dm = data_max - data_min
dv = core.target_var

idx_rand_field_value = np.random.randint(0,len(core.data),size=1)
idx_n, idx_v, nearest_dist, m_i, distance = conditional_lookup(core, core.kriging_mv_collect[int(idx_rand_field_value)][0], 
                                                               core.kriging_mv_collect[int(idx_rand_field_value)][1], dm, dv)
print(idx_rand_field_value)
print(idx_n)
print(idx_v)

fig = plt.figure(figsize=(8,4), constrained_layout=False) # Initiate figure with constrained layout
fig.suptitle("Distance measure for QF lookup")

gs = fig.add_gridspec(2, 2, height_ratios=[1,0.05], width_ratios=[1,1]) # Add x-by-y grid
ax_cb = fig.add_subplot(gs[1, 0])

#% RESIDUALS
ax = fig.add_subplot(gs[0, 0])
im = ax.imshow(distance)
#cbax = plt.subplot(gs[0,0]) # Set colorbar position
cb = Colorbar(mappable = im, ax = ax_cb, orientation = "horizontal") # im, ax=ax, 
ax.set_xlabel("Variance range")
ax.set_ylabel("Mean range")
ax = fig.add_subplot(gs[:, 1])
ax.plot(distance.T)
ax.set_xlabel("Variance range")
ax.set_ylabel("Distance measure")

fig.subplots_adjust(left=0.03, bottom=0.12, right=0.97, top=0.85, wspace = 0.2, hspace=0.5)

plt.show()
# Out:
# [365]
# 23
# 18
# <img src="data:image/png;base64,..." width="800">

# %%
core.grid_glq(nmax = 256, r_at = core.r_cmb)
#core.grid_glq(nmax = 120, r_at = core.r_cmb)

set_nmax = 30

core.ensemble_B(core.g_spec, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_eqa = core.B_ensemble_glq[:,0,:].copy()

#core.g_spec_mean = np.mean(core.g_spec,axis=1)
core.ensemble_B(core.g_spec_mean, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_mean_eqa = core.B_ensemble_glq[:,0].copy()

core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
prior_eqa = core.B_ensemble_glq[:,0].copy()

core.ensemble_B(core.g_lsq_equiv, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
lsq_eqa = core.B_ensemble_glq[:,0].copy()

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)
# ccrs.PlateCarree()
# ccrs.Mollweide()
# ccrs.Orthographic(central_longitude=0.0, central_latitude=0.0)

mt_util.plot_ensemble_map_tiles(core.grid_glq_phi, 90-core.grid_glq_theta, zs_eqa, 
                        field_compare = prior_eqa, field_lsq = lsq_eqa, field_mean = zs_mean_eqa,
                        tile_size_row = 3, tile_size_column = 2, 
                        figsize=(9,12), limit_for_SF = 10**6, point_size = 10, cbar_mm_factor = 2/3,
                        coast_width = 0.4, coast_color = "grey", unit_transform_n_to_m = True,
                        cbar_h = 0.1, cbar_text = "mT", cbar_text_color = "black",
                        left=0.03, bottom=0.12, right=0.97, top=0.95, wspace = 0.05, hspace=0.2, 
                        savefig = False, save_string = "core_sh30_unconditional", 
                        projection = ccrs.Mollweide(), use_gridlines = True, 
                        gridlines_width = 0.4, gridlines_alpha = 0.4, save_dpi = 100)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# SAVE RESULT
#print("\nSaving job")
#file_clip = open("core_{}.obj".format(nb_name), "wb")
#pickle.dump(core, file_clip, protocol=4)
#file_clip.close()

#file_clip = open("sat_{}.obj".format(nb_name), "wb")
#pickle.dump(s_sat, file_clip, protocol=4)
#file_clip.close()
#print("\nJob saved and finished")
