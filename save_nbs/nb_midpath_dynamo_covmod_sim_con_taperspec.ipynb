# %%
# %matplotlib notebook

from sdss import SDSS
import mikkel_tools.utility as mt_util
import plot as sds_plt

import numpy as np
from math import inf
from scipy.optimize import curve_fit
import scipy as sp
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import time
import pyshtools
import pickle

import scipy.linalg as spl

# Function for testing positive definiteness
def is_pos_def(A):
    if np.allclose(A, A.conj().T):
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            return False
    else:
        return False

comment = "Fit to covariance in sim"
nb_name = "nb_midpath_dynamo_covmod_sim"

# %%
shc_g = 30
shc_grid = 30

core = SDSS(comment, N_SH = shc_g, sim_type = "core_ens", sat_height = 350)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([core.grid_phi, 90-core.grid_theta]).T
core.make_grid(core.r_cmb, grid_in, calc_sph_d = True)
core.generate_map(target_var_factor = 1)

core.condtab(normsize=10000, quantiles = 100, 
             rangn_lim = 3.5, rangn_N = 501, rangv_lim = 2.0, rangv_N = 101) #model_hist = "ensemble"

# %%
core.semivar(model_lags = 20, model = "exponential", max_dist = 20000, lag_length = 100,
             zero_nugget = True, hit_target_var = False)
# Out:
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 100.0 km
# Number of lags: 109
# Number of modelling lags: 20
#
# Semi-variogram model determined, starting LUT computation

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

# g ensemble and parameters
g_core_ens = np.genfromtxt("lithosphere_prior/grids/shcoeff_Dynamo/gnm_midpath.dat").T*10**9
g_core_ens = g_core_ens[:mt_util.shc_vec_len(shc_g),:]

a = core.a
c = core.r_cmb
n_max = shc_g

g_cut = g_core_ens[:n_max*(2+n_max),200:] # Truncate g
R = mt_util.lowe_shspec(n_max,c,a,g_cut)

# One spectra for comparison to SHTOOLS
g_cut_one = g_core_ens[:,core.ens_idx][:n_max*(2+n_max)]
R_one = mt_util.lowe_shspec(n_max,c,a,g_cut_one.reshape(-1,1))

# SHTOOLS
ens_cilm_compare = np.array(pyshtools.shio.SHVectorToCilm(np.hstack((np.zeros(1,), g_cut_one))))
p_spec_compare = pyshtools.gravmag.mag_spectrum(ens_cilm_compare, a, c, degrees = np.arange(1,np.shape(ens_cilm_compare)[1]))

# Spectra
plt.figure()
for i in np.arange(R.shape[1]):
    if i == 0:
        plt.semilogy(np.arange(1,n_max+1),R[:,i],color=(0.6,0.6,0.6),label="Ensemble")
    else:
        plt.semilogy(np.arange(1,n_max+1),R[:,i],color=(0.6,0.6,0.6))
plt.semilogy(np.arange(1,n_max+1),R_one,label="My Lowes")
plt.semilogy(np.arange(1,n_max+1),p_spec_compare,linestyle="dashed", label="SHTOOLS")
plt.legend()
plt.show()
# Out:
# <div id='7f431920-a07c-4b30-ad07-6f7361166a4e'></div>

# %%
#
model_n_fit = (np.arange(1,n_max+1).reshape(-1,1)*np.ones(R.shape))[:,core.ens_idx]
model_R_fit = R[:,core.ens_idx]

def roberts(l, C2, B):
    return C2*np.exp(-B*l)

p0 = [10**11,0.055]
bounds = ([0,0],np.inf)
popt, _ = curve_fit(roberts, model_n_fit, model_R_fit, bounds=bounds, p0 = p0)
R_roberts = roberts(np.arange(1,n_max+1), popt[0], popt[1])#, popt[2], popt[3]
print("Roberts:", popt)


def voohries(l, cs, K):
    return K*(l+0.5)/(l*(l+1))*(cs/core.r_cmb)**(2*l+4)

p0 = [10**4,core.r_cmb]
bounds = ([0,0],np.inf)
popt, _ = curve_fit(voohries, model_n_fit, model_R_fit, bounds=bounds, p0 = p0)
R_voohries = voohries(np.arange(1,n_max+1), popt[0], popt[1])#, popt[2], popt[3]
print("Voohries:", popt)


# Spectra
plt.figure()
for i in np.arange(R_tap.shape[1]):
    if i == 0:
        plt.semilogy(np.arange(1,n_max+1),R[:,i],color=(0.6,0.6,0.6),label="Ensemble")
    else:
        plt.semilogy(np.arange(1,n_max+1),R[:,i],color=(0.6,0.6,0.6))
plt.semilogy(np.arange(1,n_max+1),R_one,label="My Lowes")
plt.semilogy(np.arange(1,n_max+1),p_spec_compare,linestyle="dashed", label="SHTOOLS")
plt.semilogy(np.arange(1,n_max+1),R_roberts,label="Roberts model")
plt.semilogy(np.arange(1,n_max+1),R_voohries,label="Voohries model")
plt.legend()
plt.show()
# Out:
# Roberts: [8.77760297e+12 3.42122102e+00]
# Voohries: [8.60409562e+02 1.67390193e+15]
# <img src="data:image/png;base64,..." width="640">

# %%
tap_compare = 20
#tap_to = 160 # WORKS
tap_to = 100

tap_lin = np.linspace(1,0,tap_to).reshape(-1,1)
#tap_cos = np.cos(np.linspace(0,np.pi,tap_to))+1
tap_cos = np.cos(np.linspace(0,np.pi,tap_compare))+1
#tap_cos_norm = tap_cos.reshape(-1,1)
tap_cos_norm = ((tap_cos - np.min(tap_cos))/(np.max(tap_cos)-np.min(tap_cos))).reshape(-1,1)
#lin_tanh = np.linspace(1,4,tap_to) # WORKS
lin_tanh = np.linspace(0.5,2,tap_to)
tap_tanh = -(np.exp(lin_tanh)-np.exp(-lin_tanh))/(np.exp(lin_tanh)+np.exp(-lin_tanh))
tap_tanh_norm = ((tap_tanh - np.min(tap_tanh))/(np.max(tap_tanh)-np.min(tap_tanh))).reshape(-1,1)
plt.figure()
plt.plot(tap_cos_norm,label="cos")
plt.plot(tap_lin,label="linear")
plt.plot(tap_tanh_norm,label="-tanh")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
n_tap = n_max + tap_to

R_add = R[-1,:]*tap_cos_norm #+ tap_cos_norm*np.random.normal(loc=0.0, scale = 0.1*np.mean(R[-1,:]), size = (R[-1,:]*tap_cos_norm).shape)
#R_add = np.ones(R[-1,:].shape)*tap_cos_norm #+ tap_cos_norm*np.random.normal(loc=0.0, scale = 0.1*np.mean(R[-1,:]), size = (R[-1,:]*tap_cos_norm).shape)

#R_add = R[-1,:]*tap_lin
R_add = R[-1,:]*tap_tanh_norm
R_tap = np.vstack((R,R_add))

## Test pos def through defined spectra
#R_tap_lin = np.cos(np.linspace(0,np.pi,n_tap))+1
#R_tap = ((R_tap_lin - np.min(R_tap_lin))/(np.max(R_tap_lin)-np.min(R_tap_lin))).reshape(-1,1)*np.ones(R_tap.shape)
#R_tap = np.linspace(10**11,0,n_tap).reshape(-1,1)*np.ones(R_tap.shape)

# One spectra for comparison to SHTOOLS
g_cut_one = g_core_ens[:,core.ens_idx][:n_max*(2+n_max)]
R_one = mt_util.lowe_shspec(n_max,c,a,g_cut_one.reshape(-1,1))

# SHTOOLS
ens_cilm_compare = np.array(pyshtools.shio.SHVectorToCilm(np.hstack((np.zeros(1,), g_cut_one))))
p_spec_compare = pyshtools.gravmag.mag_spectrum(ens_cilm_compare, a, c, degrees = np.arange(1,np.shape(ens_cilm_compare)[1]))

# Spectra
plt.figure()
for i in np.arange(R_tap.shape[1]):
    if i == 0:
        plt.semilogy(np.arange(1,n_tap+1),R_tap[:,i],color=(0.6,0.6,0.6),label="Tapered ensemble")
    else:
        plt.semilogy(np.arange(1,n_tap+1),R_tap[:,i],color=(0.6,0.6,0.6))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # New tapered cov

# %%
theta_s, theta_d, phi_s, phi_d = map(np.radians, 
                                     [core.grid_theta.reshape(1,-1), core.grid_theta.reshape(-1,1), 
                                      core.grid_phi.reshape(1,-1), core.grid_phi.reshape(-1,1)])

c_angdist = np.cos(theta_d)*np.cos(theta_s)+np.multiply(np.sin(theta_d)@np.sin(theta_s),np.cos(phi_d-phi_s))

c_angdist[c_angdist>1] = 1.0

c_angdist.shape
# Out:
# (1891, 1891)

# %%
c_angdist = np.cos(mt_util.haversine(1, core.grid_phi.reshape(1,-1), 90-core.grid_theta.reshape(1,-1), 
                              core.grid_phi.reshape(-1,1), 90-core.grid_theta.reshape(-1,1)))

print(c_angdist[c_angdist>1])

#c_angdist = np.round(c_angdist,decimals=8)

plt.figure()
plt.imshow(c_angdist)
plt.colorbar()
plt.show()
# Out:
# []
# <div id='cdf08123-f1e8-4725-97dd-02bb30c7ed8f'></div>

# %%
# Compute covariances based on eqn. 11
C_const = (np.arange(1,n_tap+1)+1)/(2*np.arange(1,n_tap+1)+1)

Pn = []

for cmu in np.ravel(c_angdist):
    Pn.append(pyshtools.legendre.PlSchmidt(n_tap,cmu)[1:].reshape(-1,1))
    
Pn = np.array(Pn).reshape((c_angdist.shape[0],c_angdist.shape[1],-1))

#C_Br = Pn*C_const.reshape(1,1,-1)@R_tap
#C_Br = Pn@R_tap
C_Br = Pn@(C_const.reshape(-1,1)*R_tap)

C_Br_model = C_Br[:,:,core.ens_idx]

# %%
# Compute covariances based on eqn. 11
C_const = (np.arange(1,n_max+1)+1)/(2*np.arange(1,n_max+1)+1)

Pn = []

for cmu in np.ravel(c_angdist):
    Pn.append(pyshtools.legendre.PlSchmidt(n_max,cmu)[1:].reshape(-1,1))
    
Pn = np.array(Pn).reshape((c_angdist.shape[0],c_angdist.shape[1],-1))

C_Br = Pn*C_const.reshape(1,1,-1)@R_roberts

C_Br_model = C_Br#[:,:,core.ens_idx]

# %%
plt.figure()
plt.title("Cm tapered")
plt.imshow(C_Br_model)
plt.colorbar()
plt.show()

# Positive definite covariance?
core_eigval = spl.eigh(C_Br_model, eigvals_only=True)
N_neg_eigval = len(core_eigval[core_eigval<=0])
print("C_Br_model is pos def:", is_pos_def(C_Br_model))
print("All eigenvalues > 0:", np.all(core_eigval>=0))
print("Number of negative eigenvalues:",N_neg_eigval,"/",len(core_eigval))

plt.figure()
plt.semilogy(np.arange(0,len(core_eigval)),core_eigval,'.',label="Eigenvalues")
plt.semilogy(np.ones((100,))*N_neg_eigval,np.linspace(core_eigval[N_neg_eigval],core_eigval[-1],100),label="Transition to negative")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C_Br_model is pos def: False
# All eigenvalues > 0: False
# Number of negative eigenvalues: 20 / 1891
# <img src="data:image/png;base64,..." width="640">

# %%
core_eigval, core_eigvec = spl.eigh(C_Br_model, eigvals_only=False)
#core_eigval[core_eigval<0.0] = 0.0
#core_eigvec[:,core_eigval<0.0] = 0.0
C_Br_zero = core_eigvec@np.diag(core_eigval)@np.linalg.inv(core_eigvec)

# %%
plt.figure()
plt.title("Cm zero")
plt.imshow(C_Br_zero)
plt.colorbar()
plt.show()

# Positive definite covariance?
core_eigval = spl.eigh(C_Br_zero, eigvals_only=True)
N_neg_eigval = len(core_eigval[core_eigval<=0])
print("C_Br_model is pos def:", is_pos_def(C_Br_zero))
print("All eigenvalues > 0:", np.all(core_eigval>=0))
print("Number of negative eigenvalues:",N_neg_eigval,"/",len(core_eigval))

plt.figure()
plt.semilogy(np.arange(0,len(core_eigval)),core_eigval,'.',label="Eigenvalues")
plt.semilogy(np.ones((100,))*N_neg_eigval,np.linspace(core_eigval[N_neg_eigval],core_eigval[-1],100),label="Transition to negative")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C_Br_model is pos def: False
# All eigenvalues > 0: False
# Number of negative eigenvalues: 35 / 1891
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Automate pos def find

# %%
tap_to = 140
n_tap = n_max + tap_to

# Compute covariances based on eqn. 11
C_const = (np.arange(1,n_tap+1)+1)/(2*np.arange(1,n_tap+1)+1)

# Pn
Pn = []
for cmu in np.ravel(c_angdist):
    Pn.append(pyshtools.legendre.PlSchmidt(n_tap,cmu)[1:].reshape(-1,1))

Pn = np.array(Pn).reshape((c_angdist.shape[0],c_angdist.shape[1],-1))

fig = plt.figure(figsize=(8,8), constrained_layout=True)
gs = fig.add_gridspec(1, 1) 
ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(tap_cos_norm,label="cos")
legend_list = ["cos"]
ax1.legend(legend_list)
ax1.set_xlabel('Degree')
ax1.set_ylabel('Tapering factor')
fig.canvas.draw()

try_lin = np.flip(np.linspace(1,20,20))

for i in try_lin:
    lin_tanh = np.linspace(0.5,i,tap_to)
    tap_tanh = -(np.exp(lin_tanh)-np.exp(-lin_tanh))/(np.exp(lin_tanh)+np.exp(-lin_tanh))
    tap_tanh_norm = ((tap_tanh - np.min(tap_tanh))/(np.max(tap_tanh)-np.min(tap_tanh))).reshape(-1,1)

    R_add = R[-1,:]*tap_tanh_norm
    R_tap = np.vstack((R,R_add))

    C_Br = Pn@(C_const.reshape(-1,1)*R_tap)

    C_Br_model = C_Br[:,:,core.ens_idx]
    
    PD = is_pos_def(C_Br_model)
    
    # update plot
    ax1.plot(tap_tanh_norm, color = (i/21,i/21,i/21))
    legend_list.append('i={}, PD = {}'.format(np.round(i,decimals=2),PD))
    ax1.legend(legend_list)
    
    fig.canvas.draw()
    time.sleep(0.01)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
lin_tanh = np.linspace(0.5,4.0,tap_to)
tap_tanh = -(np.exp(lin_tanh)-np.exp(-lin_tanh))/(np.exp(lin_tanh)+np.exp(-lin_tanh))
tap_tanh_norm = ((tap_tanh - np.min(tap_tanh))/(np.max(tap_tanh)-np.min(tap_tanh))).reshape(-1,1)

R_add = R[-1,:]*tap_tanh_norm
R_tap = np.vstack((R,R_add))

C_Br = Pn@(C_const.reshape(-1,1)*R_tap)

C_Br_model = C_Br[:,:,core.ens_idx]

PD = is_pos_def(C_Br_model)
print("PD: ", PD)
# Out:
# PD:  True

# %% [markdown]
# # Synthetic sat

# %%
C_e_const = 2.0

s_sat = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_sat.load_swarm("A")

grid_in = np.array([s_sat.grid_phi, 90-s_sat.grid_theta]).T
s_sat.make_grid(s_sat.grid_radial, grid_in, calc_sph_d = False)

s_sat.generate_map(grid_type = "swarm")

s_sat.data += np.random.normal(scale = C_e_const, size = s_sat.data.shape)

# %% [markdown]
# # Source truth

# %%
s_source = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_source.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([s_source.grid_phi, 90-s_source.grid_theta]).T
s_source.make_grid(s_source.r_cmb, grid_in, calc_sph_d = False)

s_source.generate_map()

# %% [markdown]
# # System equations

# %%
core.integrating_kernel(s_sat, C_e_const = C_e_const, C_mm_supply = C_Br_model)

# %% [markdown]
# # SDSSIM

# %%
N_sim = 48
core.target_var = np.max(C_Br_model)
#core.target_var = np.var(core.data)

core.run_sim(N_sim, core.grid_N, core.C_mm_all, core.C_dd, core.C_dm_all, core.G,
        s_sat.data, core.data, scale_m_i = True, unit_d = False, collect_all = True,
        sense_running_error = True, save_string = nb_name, sim_stochastic = False, solve_cho = True)
# Out:
#  |OOOOOOOOOO| 100.0%   realization nr. 0. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.563 minutes
# Total elapsed time: 15.563 minutes
# Variance: 375392740349.765
# Mean: -16660.781
# Max: 2331512.863
# Min: -2014898.496
# Run nr.: 1
#
#  |OOOOOOOOOO| 100.0%   realization nr. 1. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.569 minutes
# Total elapsed time: 31.133 minutes
# Variance: 375735212577.055
# Mean: -13381.485
# Max: 1939264.294
# Min: -2231102.710
# Run nr.: 2
#
#  |OOOOOOOOOO| 100.0%   realization nr. 2. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.631 minutes
# Total elapsed time: 46.764 minutes
# Variance: 391198429810.346
# Mean: -8267.614
# Max: 1955482.651
# Min: -1784028.090
# Run nr.: 3
#
#  |OOOOOOOOOO| 100.0%   realization nr. 3. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.664 minutes
# Total elapsed time: 1.040 hours
# Variance: 375247382855.547
# Mean: -9973.402
# Max: 2099297.523
# Min: -2085134.567
# Run nr.: 4
#
#  |OOOOOOOOOO| 100.0%   realization nr. 4. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.583 minutes
# Total elapsed time: 1.300 hours
# Variance: 390508738047.972
# Mean: -17988.957
# Max: 2127182.572
# Min: -2025966.739
# Run nr.: 5
#
#  |OOOOOOOOOO| 100.0%   realization nr. 5. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.773 minutes
# Total elapsed time: 1.563 hours
# Variance: 402338615826.077
# Mean: -15771.751
# Max: 1994617.764
# Min: -2073957.443
# Run nr.: 6
#
#  |OOOOOOOOOO| 100.0%   realization nr. 6. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.881 minutes
# Total elapsed time: 1.828 hours
# Variance: 391813101865.539
# Mean: -12788.473
# Max: 1982108.980
# Min: -2187946.560
# Run nr.: 7
#
#  |OOOOOOOOOO| 100.0%   realization nr. 7. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.831 minutes
# Total elapsed time: 2.092 hours
# Variance: 362103900328.300
# Mean: -14438.725
# Max: 1944718.416
# Min: -1920598.589
# Run nr.: 8
#
#  |OOOOOOOOOO| 100.0%   realization nr. 8. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.683 minutes
# Total elapsed time: 2.370 hours
# Variance: 374557253853.059
# Mean: -11546.070
# Max: 2082532.232
# Min: -2198642.918
# Run nr.: 9
#
#  |OOOOOOOOOO| 100.0%   realization nr. 9. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.853 minutes
# Total elapsed time: 2.634 hours
# Variance: 375110634556.260
# Mean: -13731.088
# Max: 2157267.335
# Min: -2076146.171
# Run nr.: 10
#
#  |OOOOOOOOOO| 100.0%   realization nr. 10. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.693 minutes
# Total elapsed time: 2.895 hours
# Variance: 377544543984.662
# Mean: -12376.024
# Max: 1986795.604
# Min: -2045131.206
# Run nr.: 11
#
#  |OOOOOOOOOO| 100.0%   realization nr. 11. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.662 minutes
# Total elapsed time: 3.156 hours
# Variance: 380860085992.150
# Mean: -5661.642
# Max: 2022973.199
# Min: -2136380.959
# Run nr.: 12
#
#  |OOOOOOOOOO| 100.0%   realization nr. 12. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.750 minutes
# Total elapsed time: 3.436 hours
# Variance: 372920508801.205
# Mean: -9950.835
# Max: 1971039.068
# Min: -2200693.275
# Run nr.: 13
#
#  |OOOOOOOOOO| 100.0%   realization nr. 13. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.804 minutes
# Total elapsed time: 3.699 hours
# Variance: 391254844947.413
# Mean: -9843.084
# Max: 2323357.366
# Min: -2219817.734
# Run nr.: 14
#
#  |OOOOOOOOOO| 100.0%   realization nr. 14. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.038 minutes
# Total elapsed time: 3.950 hours
# Variance: 376287453269.895
# Mean: -19819.138
# Max: 1947623.624
# Min: -2193316.224
# Run nr.: 15
#
#  |OOOOOOOOOO| 100.0%   realization nr. 15. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.994 minutes
# Total elapsed time: 4.133 hours
# Variance: 374158650458.709
# Mean: -10779.222
# Max: 2065639.174
# Min: -2007806.229
# Run nr.: 16
#
#  |OOOOOOOOOO| 100.0%   realization nr. 16. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.067 minutes
# Total elapsed time: 4.317 hours
# Variance: 379842504187.789
# Mean: -11711.946
# Max: 2026409.416
# Min: -2142082.276
# Run nr.: 17
#
#  |OOOOOOOOOO| 100.0%   realization nr. 17. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.947 minutes
# Total elapsed time: 4.500 hours
# Variance: 378793044362.530
# Mean: -8845.436
# Max: 1951091.635
# Min: -1927874.425
# Run nr.: 18
#
#  |OOOOOOOOOO| 100.0%   realization nr. 18. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.185 minutes
# Total elapsed time: 4.686 hours
# Variance: 381351159081.927
# Mean: -13033.681
# Max: 1969651.909
# Min: -1871868.414
# Run nr.: 19
#
#  |OOOOOOOOOO| 100.0%   realization nr. 19. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.453 minutes
# Total elapsed time: 4.877 hours
# Variance: 377395861320.698
# Mean: -10953.223
# Max: 1974075.139
# Min: -2103093.040
# Run nr.: 20
#
#  |OOOOOOOOOO| 100.0%   realization nr. 20. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.666 minutes
# Total elapsed time: 5.072 hours
# Variance: 381275595900.774
# Mean: -9376.039
# Max: 1979412.161
# Min: -2083870.563
# Run nr.: 21
#
#  |OOOOOOOOOO| 100.0%   realization nr. 21. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.435 minutes
# Total elapsed time: 5.262 hours
# Variance: 377616941280.522
# Mean: -13404.237
# Max: 2151932.075
# Min: -2012423.591
# Run nr.: 22
#
#  |OOOOOOOOOO| 100.0%   realization nr. 22. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.117 minutes
# Total elapsed time: 5.447 hours
# Variance: 381382691442.114
# Mean: -11595.402
# Max: 1984989.606
# Min: -1855986.207
# Run nr.: 23
#
#  |OOOOOOOOOO| 100.0%   realization nr. 23. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.090 minutes
# Total elapsed time: 5.632 hours
# Variance: 385068942841.431
# Mean: -7674.905
# Max: 1864767.266
# Min: -2088308.090
# Run nr.: 24
#
#  |OOOOOOOOOO| 100.0%   realization nr. 24. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.139 minutes
# Total elapsed time: 5.818 hours
# Variance: 386972949051.612
# Mean: -2453.992
# Max: 2161454.534
# Min: -1778343.669
# Run nr.: 25
#
#  |OOOOOOOOOO| 100.0%   realization nr. 25. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.150 minutes
# Total elapsed time: 6.004 hours
# Variance: 377957647487.722
# Mean: -14516.779
# Max: 2149469.991
# Min: -2034383.607
# Run nr.: 26
#
#  |OOOOOOOOOO| 100.0%   realization nr. 26. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.367 minutes
# Total elapsed time: 6.193 hours
# Variance: 382122986332.992
# Mean: -9832.356
# Max: 1985104.950
# Min: -2250591.136
# Run nr.: 27
#
#  |OOOOOOOOOO| 100.0%   realization nr. 27. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.984 minutes
# Total elapsed time: 6.376 hours
# Variance: 384553228206.239
# Mean: -16650.202
# Max: 1988988.336
# Min: -1956088.297
# Run nr.: 28
#
#  |OOOOOOOOOO| 100.0%   realization nr. 28. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.310 minutes
# Total elapsed time: 6.565 hours
# Variance: 377663878606.317
# Mean: -12013.587
# Max: 2000670.730
# Min: -2072909.567
# Run nr.: 29
#
#  |OOOOOOOOOO| 100.0%   realization nr. 29. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.077 minutes
# Total elapsed time: 6.749 hours
# Variance: 398015271833.571
# Mean: -13562.218
# Max: 2292617.971
# Min: -2246452.744
# Run nr.: 30
#
#  |OOOOOOOOOO| 100.0%   realization nr. 30. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.054 minutes
# Total elapsed time: 6.934 hours
# Variance: 369068079021.057
# Mean: -14096.309
# Max: 2046853.843
# Min: -2168177.272
# Run nr.: 31
#
#  |OOOOOOOOOO| 100.0%   realization nr. 31. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.029 minutes
# Total elapsed time: 7.117 hours
# Variance: 371807166264.404
# Mean: -11275.467
# Max: 1947932.511
# Min: -1903900.716
# Run nr.: 32
#
#  |OOOOOOOOOO| 100.0%   realization nr. 32. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.198 minutes
# Total elapsed time: 7.304 hours
# Variance: 363677865801.571
# Mean: -12447.935
# Max: 2316231.666
# Min: -2138382.285
# Run nr.: 33
#
#  |OOOOOOOOOO| 100.0%   realization nr. 33. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.078 minutes
# Total elapsed time: 7.489 hours
# Variance: 386324310515.902
# Mean: -9932.970
# Max: 2171107.193
# Min: -2153077.395
# Run nr.: 34
#  |OOOOOOOOOO| 100.0%   realization nr. 34. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.977 minutes
# Total elapsed time: 7.672 hours
# Variance: 378033757138.046
# Mean: -11550.126
# Max: 1972113.264
# Min: -2148116.022
# Run nr.: 35
#
#  |OOOOOOOOOO| 100.0%   realization nr. 35. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.599 minutes
# Total elapsed time: 7.865 hours
# Variance: 371642494257.371
# Mean: -14485.993
# Max: 1975162.521
# Min: -2123241.070
# Run nr.: 36
#
#  |OOOOOOOOOO| 100.0%   realization nr. 36. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.837 minutes
# Total elapsed time: 8.046 hours
# Variance: 392235379922.027
# Mean: -10205.105
# Max: 2140476.536
# Min: -2237242.163
# Run nr.: 37
#
#  |OOOOOOOOOO| 100.0%   realization nr. 37. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.903 minutes
# Total elapsed time: 8.227 hours
# Variance: 394744647161.072
# Mean: -17191.880
# Max: 1990613.043
# Min: -1991994.941
# Run nr.: 38
#
#  |OOOOOOOOOO| 100.0%   realization nr. 38. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.885 minutes
# Total elapsed time: 8.409 hours
# Variance: 386928962847.656
# Mean: -12701.217
# Max: 1972588.866
# Min: -2173587.079
# Run nr.: 39
#
#  |OOOOOOOOOO| 100.0%   realization nr. 39. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.920 minutes
# Total elapsed time: 8.591 hours
# Variance: 382039745936.550
# Mean: -11816.741
# Max: 2049361.231
# Min: -2127935.650
# Run nr.: 40
#
#  |OOOOOOOOOO| 100.0%   realization nr. 40. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.851 minutes
# Total elapsed time: 8.771 hours
# Variance: 370219144256.506
# Mean: -13781.149
# Max: 1987712.780
# Min: -1988179.944
# Run nr.: 41
#
#  |OOOOOOOOOO| 100.0%   realization nr. 41. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.999 minutes
# Total elapsed time: 8.955 hours
# Variance: 401376316580.247
# Mean: -16888.046
# Max: 2051505.346
# Min: -2218409.376
# Run nr.: 42
#
#  |OOOOOOOOOO| 100.0%   realization nr. 42. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.925 minutes
# Total elapsed time: 9.137 hours
# Variance: 362677289833.104
# Mean: -11730.134
# Max: 1955582.265
# Min: -2145995.478
# Run nr.: 43
#
#  |OOOOOOOOOO| 100.0%   realization nr. 43. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.987 minutes
# Total elapsed time: 9.320 hours
# Variance: 379641348873.043
# Mean: -12803.448
# Max: 2023617.709
# Min: -1993642.089
# Run nr.: 44
#
#  |OOOOOOOOOO| 100.0%   realization nr. 44. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.968 minutes
# Total elapsed time: 9.503 hours
# Variance: 384537183991.229
# Mean: -16520.659
# Max: 1889817.471
# Min: -2078817.862
# Run nr.: 45
#
#  |OOOOOOOOOO| 100.0%   realization nr. 45. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.359 minutes
# Total elapsed time: 9.692 hours
# Variance: 369270941703.112
# Mean: -11582.217
# Max: 2039094.122
# Min: -1971597.449
# Run nr.: 46
#
#  |OOOOOOOOOO| 100.0%   realization nr. 46. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.580 minutes
# Total elapsed time: 9.885 hours
# Variance: 393073030806.941
# Mean: -9240.386
# Max: 2162757.116
# Min: -2082692.137
# Run nr.: 47
#
#  |OOOOOOOOOO| 100.0%   realization nr. 47. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 11.048 minutes
# Total elapsed time: 10.069 hours
# Variance: 392681186246.494
# Mean: -15810.094
# Max: 2090467.719
# Min: -2170055.899
# Run nr.: 48
#
#
# Seqsim RMSE:	 [[1.94830583 1.97293225 1.95033581 1.94736407 1.95611262 1.93877287
#   1.95700596 1.94687279 1.9373431  1.95701629 1.96067025 1.96594247
#   1.96458109 1.95457311 1.97103683 1.94134171 1.93864448 1.94702795
#   1.94810839 1.96353127 1.94744165 1.9412354  1.96439234 1.95291001
#   1.96408168 1.96111271 1.94705522 1.95524911 1.96915755 1.93750917
#   1.95216309 1.96432669 1.94436586 1.94689735 1.97370214 1.96582163
#   1.97654546 1.973307   1.96681363 1.95496383 1.94714433 1.96835684
#   1.95460128 1.95356797 1.93423906 1.94361738 1.94196629 1.96085938]]
# <img src="data:image/png;base64,..." width="640">

# %%
core.realization_to_sh_coeff(core.r_cmb, set_nmax = shc_grid)

# %%
core.covmod_lsq_equiv(s_sat.data, C_Br_model, core.G, core.r_cmb)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)
mt_util.plot_sdssim_reproduce(core, core.m_DSS_res, m_equiv_lsq = core.m_equiv_lsq, truth_obj = s_source,
                              lags_use = 1000, spec_r_at = core.r_cmb, spec_show_differences = False,
                              model_dict = {}, figsize=(9,16),
                              hist_bins = 25, res_bins = 25,
                              savefig = False, save_string = "core_sh30_newTI", save_dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
core.grid_glq(nmax = 256, r_at = core.r_cmb)
#core.grid_glq(nmax = 120, r_at = core.r_cmb)

set_nmax = shc_grid

core.ensemble_B(core.g_spec, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_eqa = core.B_ensemble[:,0,:].copy()

#core.g_spec_mean = np.mean(core.g_spec,axis=1)
core.ensemble_B(core.g_spec_mean, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_mean_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
core.ensemble_B(s_sat.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
prior_eqa = core.B_ensemble[:,0].copy()

core.ensemble_B(core.g_lsq_equiv, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
lsq_eqa = core.B_ensemble[:,0].copy()

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)
# ccrs.PlateCarree()
# ccrs.Mollweide()
# ccrs.Orthographic(central_longitude=0.0, central_latitude=0.0)

mt_util.plot_ensemble_map_tiles(core.grid_phi, 90-core.grid_theta, zs_eqa, 
                        field_compare = prior_eqa, field_lsq = lsq_eqa, field_mean = zs_mean_eqa,
                        tile_size_row = 3, tile_size_column = 2, 
                        figsize=(9,12), limit_for_SF = 10**6, point_size = 0.1, cbar_mm_factor = 2/3,
                        coast_width = 0.4, coast_color = "grey", unit_transform_n_to_m = True,
                        cbar_h = 0.1, cbar_text = "mT", cbar_text_color = "black",
                        left=0.03, bottom=0.12, right=0.97, top=0.95, wspace = 0.05, hspace=0.25, 
                        savefig = False, save_string = "core_sh30_newTI", 
                        projection = ccrs.Mollweide(), use_gridlines = True, 
                        gridlines_width = 0.4, gridlines_alpha = 0.4, save_dpi = 100)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
training_image = core.B_ensemble[:,0].copy()

mt_util.plot_global(lat = 90-core.grid_theta, lon = core.grid_phi, data=training_image, 
                cbar_h = 0.075, cbar_mm_factor = 2/3, unit_transform_n_to_m = True,
                cbar_text = "mT", figsize=(6,6), coast_width = 0.4,
                bottom=0.35, top=0.95, hspace=0.01,
                title='Training image', point_size=1,
                savefig = False, save_dpi = 100, save_string ="core_sh30_synth_TI",
                use_gridlines = True, gridlines_width = 0.4, gridlines_alpha = 0.4)
# Out:
# <img src="data:image/png;base64,..." width="600">
