# %%
# %matplotlib notebook

from sdss import SDSS
import mikkel_tools.utility as mt_util
import plot as sds_plt

import numpy as np
from math import inf
from scipy.optimize import curve_fit
import scipy as sp
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import time
import pyshtools
import pickle

import scipy.linalg as spl

# Function for testing positive definiteness
def is_pos_def(A):
    if np.allclose(A, A.conj().T):
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            return False
    else:
        return False

comment = "Fit to covariance in sim"
nb_name = "nb_midpath_dynamo_covmod_sim"

# %%
shc_g = 30
shc_grid = 30

core = SDSS(comment, N_SH = shc_g, sim_type = "core_ens", sat_height = 350)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([core.grid_phi, 90-core.grid_theta]).T
core.make_grid(core.r_cmb, grid_in, calc_sph_d = True)
core.generate_map(target_var_factor = 1)

core.condtab(normsize=10000, quantiles = 100, 
             rangn_lim = 3.5, rangn_N = 501, rangv_lim = 2.0, rangv_N = 101, model_hist = "ensemble") #model_hist = "ensemble"

# %%
core.semivar(model_lags = 20, model = "exponential", max_dist = 20000, lag_length = 100,
             zero_nugget = True, hit_target_var = False)
# Out:
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 100.0 km
# Number of lags: 109
# Number of modelling lags: 20
#
# Semi-variogram model determined, starting LUT computation

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

# g ensemble and parameters
g_core_ens = np.genfromtxt("lithosphere_prior/grids/shcoeff_Dynamo/gnm_midpath.dat").T*10**9
g_core_ens = g_core_ens[:mt_util.shc_vec_len(shc_g),:]

a = core.a
c = core.r_cmb
n_max = shc_g

g_cut = g_core_ens[:n_max*(2+n_max),200:] # Truncate g
R = mt_util.lowe_shspec(n_max,c,a,g_cut)

# One spectra for comparison to SHTOOLS
g_cut_one = g_core_ens[:,core.ens_idx][:n_max*(2+n_max)]
R_one = mt_util.lowe_shspec(n_max,c,a,g_cut_one.reshape(-1,1))

# SHTOOLS
ens_cilm_compare = np.array(pyshtools.shio.SHVectorToCilm(np.hstack((np.zeros(1,), g_cut_one))))
p_spec_compare = pyshtools.gravmag.mag_spectrum(ens_cilm_compare, a, c, degrees = np.arange(1,np.shape(ens_cilm_compare)[1]))

# Spectra
plt.figure()
for i in np.arange(R.shape[1]):
    if i == 0:
        plt.semilogy(np.arange(1,n_max+1),R[:,i],color=(0.6,0.6,0.6),label="Ensemble")
    else:
        plt.semilogy(np.arange(1,n_max+1),R[:,i],color=(0.6,0.6,0.6))
plt.semilogy(np.arange(1,n_max+1),R_one,label="My Lowes")
plt.semilogy(np.arange(1,n_max+1),p_spec_compare,linestyle="dashed", label="SHTOOLS")
plt.legend()
plt.show()
# Out:
# <div id='acefbf21-81f7-4b95-94b5-e32173576f73'></div>

# %% [markdown]
# # New tapered cov

# %%
c_angdist = np.cos(mt_util.haversine(1, core.grid_phi.reshape(1,-1), 90-core.grid_theta.reshape(1,-1), 
                              core.grid_phi.reshape(-1,1), 90-core.grid_theta.reshape(-1,1)))

print(c_angdist[c_angdist>1])

plt.figure()
plt.imshow(c_angdist)
plt.colorbar()
plt.show()
# Out:
# []
# <div id='44581869-9ece-48f4-8424-982b19b0f307'></div>

# %%
tap_to = 500
n_tap = n_max + tap_to

tap_cos = np.cos(np.linspace(0,np.pi,20))+1
tap_cos_norm = ((tap_cos - np.min(tap_cos))/(np.max(tap_cos)-np.min(tap_cos))).reshape(-1,1)

# Compute covariances based on eqn. 11
C_const = (np.arange(1,n_tap+1)+1)/(2*np.arange(1,n_tap+1)+1)

# Pn
Pn = []
for cmu in np.ravel(c_angdist):
    Pn.append(pyshtools.legendre.PlSchmidt(n_tap,cmu)[1:].reshape(-1,1))

Pn = np.array(Pn).reshape((c_angdist.shape[0],c_angdist.shape[1],-1))

# %% [markdown]
# # Automate pos def find

# %%
init_lin = 100
N_lin = 10

fig = plt.figure(figsize=(8,8), constrained_layout=True)
gs = fig.add_gridspec(1, 1) 
ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(tap_cos_norm,label="cos",zorder=1)
legend_list = ["cos"]
ax1.legend(legend_list)
ax1.set_xlabel('Degree')
ax1.set_ylabel('Tapering factor')
fig.canvas.draw()

try_lin = np.flip(np.round(np.linspace(3,init_lin,N_lin),decimals=2))

for i in try_lin:
    lin_tanh = np.linspace(0.5,i,tap_to)
    tap_tanh = -(np.exp(lin_tanh)-np.exp(-lin_tanh))/(np.exp(lin_tanh)+np.exp(-lin_tanh))
    tap_tanh_norm = ((tap_tanh - np.min(tap_tanh))/(np.max(tap_tanh)-np.min(tap_tanh))).reshape(-1,1)

    R_add = 0.1*R[-1,:]*tap_tanh_norm
    R_tap = np.vstack((R,R_add))

    C_Br = Pn@(C_const.reshape(-1,1)*R_tap)

    C_Br_model = C_Br[:,:,core.ens_idx]
    
    PD = is_pos_def(C_Br_model)
    
    # update plot
    ax1.plot(tap_tanh_norm, color = (i/(init_lin+1),i/(init_lin+1),i/(init_lin+1)),zorder=0)
    if PD:
        legend_list.append('i={}, PD = {}'.format(np.round(i,decimals=2),PD))
    ax1.legend(legend_list)
    
    fig.canvas.draw()
    time.sleep(0.01)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
lin_tanh = np.linspace(0.5,3,tap_to)
tap_tanh = -(np.exp(lin_tanh)-np.exp(-lin_tanh))/(np.exp(lin_tanh)+np.exp(-lin_tanh))
tap_tanh_norm = ((tap_tanh - np.min(tap_tanh))/(np.max(tap_tanh)-np.min(tap_tanh))).reshape(-1,1)

#R_add = 0.000001*R[-1,:]*tap_tanh_norm
R_add = np.ones((R[-1,:].shape))*tap_tanh_norm
R_tap = np.vstack((R,R_add))

# Spectra
plt.figure()
for i in np.arange(R_tap.shape[1]):
    if i == 0:
        plt.semilogy(np.arange(1,n_tap+1),R_tap[:,i],color=(0.6,0.6,0.6),label="Tapered ensemble")
        #plt.plot(np.arange(1,n_tap+1),R_tap[:,i],color=(0.6,0.6,0.6),label="Tapered ensemble")
    else:
        plt.semilogy(np.arange(1,n_tap+1),R_tap[:,i],color=(0.6,0.6,0.6))
        #plt.plot(np.arange(1,n_tap+1),R_tap[:,i],color=(0.6,0.6,0.6))
plt.legend()
plt.show()

C_Br = Pn@(C_const.reshape(-1,1)*R_tap)

C_Br_model = C_Br[:,:,core.ens_idx]

PD = is_pos_def(C_Br_model)
print("PD: ", PD)
# Out:
# <div id='8471fb8c-6a2e-40d8-a8f2-02386ce5578f'></div>
# PD:  True

# %%
i_C_Br_max = np.argmax(np.abs(C_Br),axis=2)

i_C_Br_max.shape
# Out:
# (1891, 1891)

# %%
C_Br_max = []

j = 0
for i in np.ravel(i_C_Br_max):
    C_Br_max.append(C_Br.reshape(-1,487)[j,i])
    j +=1
    
C_Br_model = np.array(C_Br_max).reshape(1891,1891)

# %%
C_Br_model = np.mean(C_Br,axis=2)

# %%
plt.figure()
plt.title("Cm tapered")
plt.imshow(C_Br_model)
plt.colorbar()
plt.show()

# Positive definite covariance?
core_eigval = spl.eigh(C_Br_model, eigvals_only=True)
N_neg_eigval = len(core_eigval[core_eigval<=0])
print("C_Br_model is pos def:", is_pos_def(C_Br_model))
print("All eigenvalues > 0:", np.all(core_eigval>=0))
print("Number of negative eigenvalues:",N_neg_eigval,"/",len(core_eigval))

plt.figure()
plt.semilogy(np.arange(0,len(core_eigval)),core_eigval,'.',label="Eigenvalues")
plt.semilogy(np.ones((100,))*N_neg_eigval,np.linspace(core_eigval[N_neg_eigval],core_eigval[-1],100),label="Transition to negative")
plt.legend()
plt.show()
# Out:
# <div id='181c5faf-ff5d-4b37-ba1d-244f78ec9c58'></div>
# C_Br_model is pos def: True
# All eigenvalues > 0: True
# Number of negative eigenvalues: 0 / 1891
# <div id='8ef610bf-452a-432e-9638-7c7afd214e9f'></div>

# %% [markdown]
# # Synthetic sat

# %%
C_e_const = 2.0

s_sat = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_sat.load_swarm("A")

grid_in = np.array([s_sat.grid_phi, 90-s_sat.grid_theta]).T
s_sat.make_grid(s_sat.grid_radial, grid_in, calc_sph_d = False)

s_sat.generate_map(grid_type = "swarm")

s_sat.data += np.random.normal(scale = C_e_const, size = s_sat.data.shape)

# %% [markdown]
# # Source truth

# %%
s_source = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_source.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([s_source.grid_phi, 90-s_source.grid_theta]).T
s_source.make_grid(s_source.r_cmb, grid_in, calc_sph_d = False)

s_source.generate_map()

# %% [markdown]
# # System equations

# %%
core.integrating_kernel(s_sat, C_e_const = C_e_const, C_mm_supply = C_Br_model)

# %% [markdown]
# # SDSSIM

# %%
N_sim = 100
core.target_var = np.max(C_Br_model)
#core.target_var = np.var(core.data)

core.run_sim(N_sim, core.grid_N, core.C_mm_all, core.C_dd, core.C_dm_all, core.G,
        s_sat.data, core.data, scale_m_i = True, unit_d = False, collect_all = True,
        sense_running_error = True, save_string = nb_name, sim_stochastic = False, solve_cho = True)
# Out:
#  |OOOOOOOOOO| 100.0%   realization nr. 0. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.139 minutes
# Total elapsed time: 15.139 minutes
# Variance: 294116162506.291
# Mean: -11809.503
# Max: 1854126.729
# Min: -1826376.990
# Run nr.: 1
#
#  |OOOOOOOOOO| 100.0%   realization nr. 1. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 14.985 minutes
# Total elapsed time: 30.124 minutes
# Variance: 304351084967.711
# Mean: -11997.023
# Max: 1702597.315
# Min: -1325548.675
# Run nr.: 2
#
#  |OOOOOOOOOO| 100.0%   realization nr. 2. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 14.946 minutes
# Total elapsed time: 45.070 minutes
# Variance: 295341225912.011
# Mean: -8212.298
# Max: 2272787.975
# Min: -1587107.774
# Run nr.: 3
#
#  |OOOOOOOOOO| 100.0%   realization nr. 3. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.133 minutes
# Total elapsed time: 1.003 hours
# Variance: 299423452268.032
# Mean: -10426.227
# Max: 1733248.954
# Min: -1392542.495
# Run nr.: 4
#
#  |OOOOOOOOOO| 100.0%   realization nr. 4. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.237 minutes
# Total elapsed time: 1.257 hours
# Variance: 293912147465.659
# Mean: -11671.485
# Max: 1656435.637
# Min: -1475872.399
# Run nr.: 5
#
#  |OOOOOOOOOO| 100.0%   realization nr. 5. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.279 minutes
# Total elapsed time: 1.512 hours
# Variance: 293996626635.499
# Mean: -5076.431
# Max: 1913206.567
# Min: -1671234.156
# Run nr.: 6
#
#  |OOOOOOOOOO| 100.0%   realization nr. 6. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 14.991 minutes
# Total elapsed time: 1.762 hours
# Variance: 289337722804.451
# Mean: -12149.587
# Max: 1915501.846
# Min: -1452959.396
# Run nr.: 7
#
#  |OOOOOOOOOO| 100.0%   realization nr. 7. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 14.977 minutes
# Total elapsed time: 2.011 hours
# Variance: 293828083226.965
# Mean: -8612.292
# Max: 2118893.781
# Min: -1652853.081
# Run nr.: 8
#
#  |OOOOOOOOOO| 100.0%   realization nr. 8. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.061 minutes
# Total elapsed time: 2.262 hours
# Variance: 300909828595.629
# Mean: -11714.064
# Max: 1987848.073
# Min: -2702410.604
# Run nr.: 9
#
#  |OOOOOOOOOO| 100.0%   realization nr. 9. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 14.822 minutes
# Total elapsed time: 2.510 hours
# Variance: 304082980871.752
# Mean: -14631.271
# Max: 2830097.096
# Min: -1472883.120
# Run nr.: 10
#
#  |OOOOOOOOOO| 100.0%   realization nr. 10. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.233 minutes
# Total elapsed time: 2.763 hours
# Variance: 292731822877.526
# Mean: -8206.071
# Max: 1589414.982
# Min: -1451922.198
# Run nr.: 11
#
#  |OOOOOOOOOO| 100.0%   realization nr. 11. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.245 minutes
# Total elapsed time: 3.017 hours
# Variance: 287078976933.746
# Mean: -6785.955
# Max: 1646350.451
# Min: -1548160.199
# Run nr.: 12
#
#  |OOOOOOOOOO| 100.0%   realization nr. 12. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 14.853 minutes
# Total elapsed time: 3.265 hours
# Variance: 296282136679.038
# Mean: -8998.255
# Max: 2876354.606
# Min: -1794079.564
# Run nr.: 13
#
#  |OOOOOOOOOO| 100.0%   realization nr. 13. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 14.807 minutes
# Total elapsed time: 3.512 hours
# Variance: 286412093468.020
# Mean: -7697.304
# Max: 1721168.773
# Min: -1442330.023
# Run nr.: 14
#
#  |OOOOOOOOOO| 100.0%   realization nr. 14. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 14.911 minutes
# Total elapsed time: 3.760 hours
# Variance: 288125618797.337
# Mean: -5187.803
# Max: 1657586.659
# Min: -1530434.588
# Run nr.: 15
#
#  |OOOOOOOOOO| 100.0%   realization nr. 15. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.078 minutes
# Total elapsed time: 4.012 hours
# Variance: 293333236271.915
# Mean: -9095.666
# Max: 1810162.091
# Min: -1603510.408
# Run nr.: 16
#
#  |OOOOOOOOOO| 100.0%   realization nr. 16. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.282 minutes
# Total elapsed time: 4.266 hours
# Variance: 296798592184.622
# Mean: -11604.953
# Max: 1716461.939
# Min: -1625048.889
# Run nr.: 17
#
#  |OOOOOOOOOO| 100.0%   realization nr. 17. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.122 minutes
# Total elapsed time: 4.518 hours
# Variance: 293681438155.005
# Mean: -10476.915
# Max: 1713526.926
# Min: -1455793.285
# Run nr.: 18
#
#  |OOOOOOOOOO| 100.0%   realization nr. 18. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.097 minutes
# Total elapsed time: 4.770 hours
# Variance: 292720734875.019
# Mean: -10075.655
# Max: 2101791.456
# Min: -1655428.059
# Run nr.: 19
#
#  |OOOOOOOOOO| 100.0%   realization nr. 19. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 14.832 minutes
# Total elapsed time: 5.017 hours
# Variance: 303013083950.458
# Mean: -10375.973
# Max: 2126768.958
# Min: -2071717.707
# Run nr.: 20
#
#  |OOOOOOOOOO| 100.0%   realization nr. 20. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 14.841 minutes
# Total elapsed time: 5.265 hours
# Variance: 293475061857.112
# Mean: -7168.627
# Max: 1918926.484
# Min: -1447936.250
# Run nr.: 21
#
#  |OOOOOOOOOO| 100.0%   realization nr. 21. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 14.832 minutes
# Total elapsed time: 5.512 hours
# Variance: 301751494600.526
# Mean: -8319.698
# Max: 2268798.551
# Min: -1943929.129
# Run nr.: 22
#
#  |OOOOOOOOOO| 100.0%   realization nr. 22. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 14.880 minutes
# Total elapsed time: 5.760 hours
# Variance: 300697349627.449
# Mean: -6348.686
# Max: 1810857.255
# Min: -1569818.014
# Run nr.: 23
#
#  |OOOOOOOOOO| 100.0%   realization nr. 23. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 14.859 minutes
# Total elapsed time: 6.007 hours
# Variance: 297387771137.231
# Mean: -13355.094
# Max: 1846390.315
# Min: -1764014.592
# Run nr.: 24
#
#  |OOOOOOOOOO| 100.0%   realization nr. 24. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 14.891 minutes
# Total elapsed time: 6.256 hours
# Variance: 303151371738.224
# Mean: -10727.508
# Max: 3167447.532
# Min: -1395837.075
# Run nr.: 25
#
#  |OOOOOOOOOO| 100.0%   realization nr. 25. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 14.808 minutes
# Total elapsed time: 6.502 hours
# Variance: 298925162799.297
# Mean: -7620.877
# Max: 2489203.076
# Min: -1519857.891
# Run nr.: 26
#
#  |OOOOOOOOOO| 100.0%   realization nr. 26. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.469 minutes
# Total elapsed time: 6.760 hours
# Variance: 287143302798.335
# Mean: -11392.805
# Max: 2044177.038
# Min: -1376512.371
# Run nr.: 27
#
#  |OOOOOOOOOO| 100.0%   realization nr. 27. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.301 minutes
# Total elapsed time: 7.015 hours
# Variance: 303390897100.499
# Mean: -14534.091
# Max: 1848700.348
# Min: -2613424.404
# Run nr.: 28
#
#  |OOOOOOOOOO| 100.0%   realization nr. 28. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.047 minutes
# Total elapsed time: 7.266 hours
# Variance: 318589562077.058
# Mean: -7350.512
# Max: 2014620.210
# Min: -3188946.284
# Run nr.: 29
#
#  |OOOOOOOOOO| 100.0%   realization nr. 29. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 14.908 minutes
# Total elapsed time: 7.514 hours
# Variance: 311688488084.402
# Mean: -13991.586
# Max: 2897888.862
# Min: -1849522.024
# Run nr.: 30
#
#  |OOOOOOOOOO| 100.0%   realization nr. 30. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.111 minutes
# Total elapsed time: 7.766 hours
# Variance: 285112198683.079
# Mean: -12314.493
# Max: 1937424.314
# Min: -1373784.762
# Run nr.: 31
#
#  |OOOOOOOOOO| 100.0%   realization nr. 31. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 14.983 minutes
# Total elapsed time: 8.016 hours
# Variance: 295252830356.099
# Mean: -9723.314
# Max: 1935228.769
# Min: -1790306.384
# Run nr.: 32
#
#  |OOOOOOOOOO| 100.0%   realization nr. 32. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 14.861 minutes
# Total elapsed time: 8.264 hours
# Variance: 286435885467.820
# Mean: -9161.312
# Max: 1813133.114
# Min: -1442050.096
# Run nr.: 33
#
#  |OOOOOOOOOO| 100.0%   realization nr. 33. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.117 minutes
# Total elapsed time: 8.516 hours
# Variance: 299899006211.432
# Mean: -6503.993
# Max: 2240333.938
# Min: -1606249.779
# Run nr.: 34
#  |OOOOOOOOOO| 100.0%   realization nr. 34. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 14.839 minutes
# Total elapsed time: 8.763 hours
# Variance: 296900726278.455
# Mean: -8798.813
# Max: 1579109.455
# Min: -1518244.435
# Run nr.: 35
#
#  |OOOOOOOOOO| 100.0%   realization nr. 35. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.061 minutes
# Total elapsed time: 9.014 hours
# Variance: 298105857945.407
# Mean: -4888.703
# Max: 1714824.293
# Min: -1494659.102
# Run nr.: 36
#
#  |OOOOOOOOOO| 100.0%   realization nr. 36. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.232 minutes
# Total elapsed time: 9.268 hours
# Variance: 291340549637.634
# Mean: -6994.852
# Max: 1649129.983
# Min: -1346874.633
# Run nr.: 37
#
#  |OOOOOOOOOO| 100.0%   realization nr. 37. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 14.996 minutes
# Total elapsed time: 9.518 hours
# Variance: 300172019753.839
# Mean: -8373.281
# Max: 1816578.451
# Min: -1339194.120
# Run nr.: 38
#
#  |OOOOOOOOOO| 100.0%   realization nr. 38. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.078 minutes
# Total elapsed time: 9.769 hours
# Variance: 304047508590.822
# Mean: -9838.881
# Max: 2242203.767
# Min: -1708692.731
# Run nr.: 39
#
#  |OOOOOOOOOO| 100.0%   realization nr. 39. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 14.905 minutes
# Total elapsed time: 10.017 hours
# Variance: 290821729319.179
# Mean: -8441.032
# Max: 1621273.496
# Min: -1488052.292
# Run nr.: 40
#
#  |OOOOOOOOOO| 100.0%   realization nr. 40. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 10.833 minutes
# Total elapsed time: 10.198 hours
# Variance: 314409655235.572
# Mean: -9425.934
# Max: 1860505.875
# Min: -3758266.437
# Run nr.: 41
#
#  |OOOOOOOOOO| 100.0%   realization nr. 41. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 10.490 minutes
# Total elapsed time: 10.373 hours
# Variance: 287785589144.423
# Mean: -10361.242
# Max: 1760985.955
# Min: -1467293.845
# Run nr.: 42
#
#  |OOOOOOOOOO| 100.0%   realization nr. 42. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.777 minutes
# Total elapsed time: 10.536 hours
# Variance: 290237938814.749
# Mean: -8070.186
# Max: 2001630.494
# Min: -1652443.486
# Run nr.: 43
#
#  |OOOOOOOOOO| 100.0%   realization nr. 43. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.767 minutes
# Total elapsed time: 10.699 hours
# Variance: 296880864596.587
# Mean: -8734.771
# Max: 1817358.685
# Min: -1594597.159
# Run nr.: 44
#
#  |OOOOOOOOOO| 100.0%   realization nr. 44. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.715 minutes
# Total elapsed time: 10.861 hours
# Variance: 292806808471.248
# Mean: -5855.384
# Max: 1607231.252
# Min: -1527920.002
# Run nr.: 45
#
#  |OOOOOOOOOO| 100.0%   realization nr. 45. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.593 minutes
# Total elapsed time: 11.020 hours
# Variance: 288423853378.139
# Mean: -11295.975
# Max: 2177368.855
# Min: -1504726.271
# Run nr.: 46
#
#  |OOOOOOOOOO| 100.0%   realization nr. 46. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.723 minutes
# Total elapsed time: 11.182 hours
# Variance: 306395411137.112
# Mean: -3402.082
# Max: 2029512.913
# Min: -1691932.335
# Run nr.: 47
#
#  |OOOOOOOOOO| 100.0%   realization nr. 47. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.696 minutes
# Total elapsed time: 11.344 hours
# Variance: 294214490605.824
# Mean: -11932.255
# Max: 1508046.232
# Min: -1457769.691
# Run nr.: 48
#
#  |OOOOOOOOOO| 100.0%   realization nr. 48. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.711 minutes
# Total elapsed time: 11.506 hours
# Variance: 295130556694.854
# Mean: -7961.967
# Max: 1812020.567
# Min: -2190314.554
# Run nr.: 49
#
#  |OOOOOOOOOO| 100.0%   realization nr. 49. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.664 minutes
# Total elapsed time: 11.667 hours
# Variance: 298732383089.511
# Mean: -10819.961
# Max: 1799487.419
# Min: -1375958.494
# Run nr.: 50
#
#  |OOOOOOOOOO| 100.0%   realization nr. 50. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 9.868 minutes
# Total elapsed time: 11.831 hours
# Variance: 303553902061.181
# Mean: -3692.121
# Max: 1987963.887
# Min: -1524147.591
# Run nr.: 51
#
#  |OOOOOOOOOO| 100.0%   realization nr. 51. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.619 minutes
# Total elapsed time: 11.992 hours
# Variance: 292564718005.903
# Mean: -12364.634
# Max: 1670840.330
# Min: -1509990.796
# Run nr.: 52
#
#  |OOOOOOOOOO| 100.0%   realization nr. 52. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 9.673 minutes
# Total elapsed time: 12.153 hours
# Variance: 290349678547.075
# Mean: -7556.697
# Max: 1828615.307
# Min: -1565046.033
# Run nr.: 53
#
#  |OOOOOOOOOO| 100.0%   realization nr. 53. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.471 minutes
# Total elapsed time: 12.277 hours
# Variance: 301868196894.040
# Mean: -9052.263
# Max: 2590683.613
# Min: -1566559.041
# Run nr.: 54
#
#  |OOOOOOOOOO| 100.0%   realization nr. 54. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 7.472 minutes
# Total elapsed time: 12.402 hours
# Variance: 297321152840.916
# Mean: -9516.448
# Max: 2315490.308
# Min: -1585482.811
# Run nr.: 55
#
#  |OOOOOOOOOO| 100.0%   realization nr. 55. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.450 minutes
# Total elapsed time: 12.526 hours
# Variance: 294946197663.799
# Mean: -9782.750
# Max: 1567641.422
# Min: -1571345.160
# Run nr.: 56
#
#  |OOOOOOOOOO| 100.0%   realization nr. 56. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.443 minutes
# Total elapsed time: 12.650 hours
# Variance: 298546217659.793
# Mean: -9719.197
# Max: 1949012.516
# Min: -2111080.559
# Run nr.: 57
#
#  |OOOOOOOOOO| 100.0%   realization nr. 57. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 7.502 minutes
# Total elapsed time: 12.775 hours
# Variance: 291277029995.247
# Mean: -8594.153
# Max: 1875892.823
# Min: -1391956.213
# Run nr.: 58
#
#  |OOOOOOOOOO| 100.0%   realization nr. 58. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 7.458 minutes
# Total elapsed time: 12.900 hours
# Variance: 331390857731.075
# Mean: -5636.829
# Max: 2158411.347
# Min: -4720021.176
# Run nr.: 59
#
#  |OOOOOOOOOO| 100.0%   realization nr. 59. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 7.455 minutes
# Total elapsed time: 13.024 hours
# Variance: 302529163589.994
# Mean: -4585.514
# Max: 2646259.161
# Min: -1557167.484
# Run nr.: 60
#
#  |OOOOOOOOOO| 100.0%   realization nr. 60. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 7.464 minutes
# Total elapsed time: 13.148 hours
# Variance: 301264072440.136
# Mean: -11147.285
# Max: 2117682.034
# Min: -1462563.778
# Run nr.: 61
#
#  |OOOOOOOOOO| 100.0%   realization nr. 61. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 7.792 minutes
# Total elapsed time: 13.278 hours
# Variance: 284841010261.713
# Mean: -11137.908
# Max: 1801787.518
# Min: -1429511.469
# Run nr.: 62
#
#  |OOOOOO----| 60.4%   realization nr. 62. Counter: 1143/1891, Running error magnitude: 5.5

# %%
core.realization_to_sh_coeff(core.r_cmb, set_nmax = shc_grid)

# %%
#core.covmod_lsq_equiv(s_sat.data, C_Br_model, core.G, core.r_cmb)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)
mt_util.plot_sdssim_reproduce(core, core.m_DSS_res, m_equiv_lsq = None, truth_obj = s_source,
                              lags_use = 1000, spec_r_at = core.r_cmb, spec_show_differences = False,
                              model_dict = {}, figsize=(9,16), hist_ti_ens = False, hist_density = False,
                              hist_bins = 25, res_bins = 25, hist_pos_mean = False,
                              savefig = False, save_string = "core_sh30_newTI", save_dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
core.grid_glq(nmax = 256, r_at = core.r_cmb)
#core.grid_glq(nmax = 120, r_at = core.r_cmb)

set_nmax = shc_grid

core.ensemble_B(core.g_spec, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_eqa = core.B_ensemble[:,0,:].copy()

#core.g_spec_mean = np.mean(core.g_spec,axis=1)
core.ensemble_B(core.g_spec_mean, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_mean_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
core.ensemble_B(s_sat.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
prior_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_lsq_equiv, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
#lsq_eqa = core.B_ensemble[:,0].copy()

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)
# ccrs.PlateCarree()
# ccrs.Mollweide()
# ccrs.Orthographic(central_longitude=0.0, central_latitude=0.0)

mt_util.plot_ensemble_map_tiles(core.grid_phi, 90-core.grid_theta, zs_eqa, 
                        field_compare = prior_eqa, field_lsq = None, field_mean = zs_mean_eqa,
                        tile_size_row = 3, tile_size_column = 2, 
                        figsize=(9,12), limit_for_SF = 10**6, point_size = 0.1, cbar_mm_factor = 2/3,
                        coast_width = 0.4, coast_color = "grey", unit_transform_n_to_m = True,
                        cbar_h = 0.1, cbar_text = "mT", cbar_text_color = "black",
                        left=0.03, bottom=0.12, right=0.97, top=0.95, wspace = 0.05, hspace=0.25, 
                        savefig = False, save_string = "core_sh30_newTI", 
                        projection = ccrs.Mollweide(), use_gridlines = True, 
                        gridlines_width = 0.4, gridlines_alpha = 0.4, save_dpi = 100)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
training_image = core.B_ensemble[:,0].copy()

mt_util.plot_global(lat = 90-core.grid_theta, lon = core.grid_phi, data=training_image, 
                cbar_h = 0.075, cbar_mm_factor = 2/3, unit_transform_n_to_m = True,
                cbar_text = "mT", figsize=(6,6), coast_width = 0.4,
                bottom=0.35, top=0.95, hspace=0.01,
                title='Training image', point_size=1,
                savefig = False, save_dpi = 100, save_string ="core_sh30_synth_TI",
                use_gridlines = True, gridlines_width = 0.4, gridlines_alpha = 0.4)
# Out:
# <img src="data:image/png;base64,..." width="600">
