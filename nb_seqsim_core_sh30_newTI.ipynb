# %%
# %matplotlib notebook

from sdss import SDSS
import mikkel_tools.utility as mt_util
import plot as sds_plt

import numpy as np
#import cupy as cp
import scipy as sp
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

import pyshtools
import pickle

comment = "Simulation with dynamo midpath ensemble as training image"
nb_name = "nb_seqsim_core_sh30_newTI"

# %% [markdown]
# # Core

# %%
shc_g = 30
shc_grid = 30

core = SDSS(comment, N_SH = shc_g, sim_type = "core_ens", sat_height = 350)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([core.grid_phi, 90-core.grid_theta]).T
core.make_grid(core.r_cmb, grid_in, calc_sph_d = True)

core.generate_map(target_var_factor = 1)

# %%
g_core_ens = np.genfromtxt("lithosphere_prior/grids/shcoeff_Dynamo/gnm_midpath.dat").T*10**9

core.ensemble_B(g_core_ens, nmax = shc_g, r_at = core.r_cmb, grid_type = "glq")
m_core_ens = core.B_ensemble[:,0,:].copy()

# %%
np.var(m_core_ens,axis=0).shape
# Out:
# (687,)

# %%
var_core_ens = np.var(m_core_ens,axis=0)

plt.figure()
plt.plot(var_core_ens)
plt.plot(np.ones(var_core_ens.shape)*np.mean(var_core_ens))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
idx_close_to_var = np.argwhere(np.logical_and(var_core_ens>0.9970*np.mean(var_core_ens), var_core_ens<1.0030*np.mean(var_core_ens)))

# %%
idx_close_to_var
# Out:
# array([[386],
#        [416]])

# %%
plt.figure()
plt.hist(np.ravel(m_core_ens),bins=1000)
plt.show()

plt.figure()
plt.hist(core.data,bins=100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
core.condtab(normsize=10000, quantiles = 100, 
             rangn_lim = 3.5, rangn_N = 501, rangv_lim = 2.0, rangv_N = 101) #model_hist = "ensemble"

# %%
core.semivar(model_lags = 20, model = "exponential", max_dist = 20000, lag_length = 100,
             zero_nugget = True, hit_target_var = False)

#keep_sv_curve = core.sv_curve.copy()
#keep_lags_sv_curve = core.lags_sv_curve.copy()

C_e_const = 2.0

#nugget = C_e_const**2
#nugget_p = 0.01
#var_fac = 0.1

#set_model = {"a": 2000, "C0": var_fac*core.target_var*nugget_p, "C1": var_fac*core.target_var*(1-nugget_p), "C2": None, "C3": None}
#set_model = {"a": 1800, "C0": nugget, "C1": var_fac*core.target_var-nugget, "C2": None, "C3": None}

#set_model = {"a": 1700, "C0": 0.0, "C1": core.target_var, "C2": None, "C3": None}


#set_model = {"a": 200, "C0": 0.0, "C1": 0.15*core.target_var,
#             "C2": core.target_var-0.15*core.target_var, "C3": 20000}


#core.semivar(model_lags = "all", model = "dub_spherical", max_dist = 20000, lag_length = 200,
#             zero_nugget = True, hit_target_var = True, set_model = set_model)

#core.semivar(model_lags = "all", model = "exponential", max_dist = 20000, lag_length = 200,
#             zero_nugget = True, hit_target_var = True, set_model = set_model)
# Out:
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 100.0 km
# Number of lags: 109
# Number of modelling lags: 20
#
# Semi-variogram model determined, starting LUT computation

# %%
#%% PLOT SEMI-VARIOGRAM
plt.figure(figsize=(10,8)) 
plt.plot(core.lags,core.pics,'o', markersize=5,color = 'C4',label='Semi-variogram')
plt.plot(core.lags_sv_curve,core.sv_curve,color='C1', linewidth = 3,label='Fitted model')
#plt.plot(keep_lags_sv_curve,keep_sv_curve,"--",color='C0',linewidth = 3,label='Fitted model')

plt.plot(core.lags_sv_curve,np.ones(core.lags_sv_curve.shape)*core.target_var,linewidth = 3,
         color="C2", linestyle="dashed", label="Training image variance")
plt.ylabel('Semi-variance $[%s^2]$' % "nT",fontsize=18,labelpad=18)
plt.xlabel('Lag [km]',fontsize=18,labelpad=18)
plt.title("Semi-variogram model of type: %s " % core.model_names[core.model],fontsize=18,y=1.02)
plt.legend(loc='best',fontsize=18)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#print(core)

# %% [markdown]
# # Synthetic sat

# %%
s_sat = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_sat.load_swarm("A")

grid_in = np.array([s_sat.grid_phi, 90-s_sat.grid_theta]).T
s_sat.make_grid(s_sat.grid_radial, grid_in, calc_sph_d = False)

#s_sat.grid_equal_area(N_grid= 500, r_at = s_sat.r_sat, poles_remove = True)
#grid_in = np.array([s_sat.grid_phi, 90-s_sat.grid_theta]).T
#s_sat.grid(s_sat.r_sat, grid_in, calc_sph_d = False)

# %%
s_sat.generate_map(grid_type = "swarm")

# %%
s_sat.data += np.random.normal(scale = C_e_const, size = s_sat.data.shape)

# %%
#mt_util.plot_cartopy_global(lat = s_sat.lat, lon = s_sat.lon, plot_quality = "high", point_size=5, 
#                            data=s_sat.data, cmap = 'PuOr_r', title="Synthetic satellite data")

# %%
#print(s_sat)

# %% [markdown]
# # Source truth

# %%
s_source = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_source.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([s_source.grid_phi, 90-s_source.grid_theta]).T
s_source.make_grid(s_source.r_cmb, grid_in, calc_sph_d = False)

s_source.generate_map()

# %% [markdown]
# # System equations

# %%
core.integrating_kernel(s_sat, C_e_const = C_e_const)

# %% [markdown]
# # SDSSIM

# %%
N_sim = 100

core.run_sim(N_sim, core.grid_N, core.C_mm_all, core.C_dd, core.C_dm_all, core.G,
        s_sat.data, core.data, scale_m_i = True, unit_d = False, collect_all = True,
        sense_running_error = True, save_string = nb_name, sim_stochastic = False, solve_cho = True)
# Out:
#  |OOOOOOOOOO| 100.0%   realization nr. 0. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.441 minutes
# Total elapsed time: 8.441 minutes
# Variance: 284708514738.836
# Mean: -9024.374
# Max: 1774425.651
# Min: -1511548.580
# Run nr.: 1
#
#  |OOOOOOOOOO| 100.0%   realization nr. 1. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.391 minutes
# Total elapsed time: 16.832 minutes
# Variance: 292300365149.563
# Mean: -6567.501
# Max: 2027289.579
# Min: -2650500.205
# Run nr.: 2
#
#  |OOOOOOOOOO| 100.0%   realization nr. 2. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.396 minutes
# Total elapsed time: 25.229 minutes
# Variance: 284223899558.849
# Mean: -13976.394
# Max: 1884635.702
# Min: -1475507.163
# Run nr.: 3
#
#  |OOOOOOOOOO| 100.0%   realization nr. 3. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.440 minutes
# Total elapsed time: 33.668 minutes
# Variance: 285698145274.651
# Mean: -8922.926
# Max: 2094223.562
# Min: -1368691.361
# Run nr.: 4
#
#  |OOOOOOOOOO| 100.0%   realization nr. 4. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.393 minutes
# Total elapsed time: 42.061 minutes
# Variance: 287683030478.564
# Mean: -14605.136
# Max: 1906825.850
# Min: -1566193.309
# Run nr.: 5
#
#  |OOOOOOOOOO| 100.0%   realization nr. 5. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.419 minutes
# Total elapsed time: 50.480 minutes
# Variance: 284366465832.739
# Mean: -9437.988
# Max: 1985819.624
# Min: -1467455.156
# Run nr.: 6
#
#  |OOOOOOOOOO| 100.0%   realization nr. 6. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.441 minutes
# Total elapsed time: 58.921 minutes
# Variance: 286582969273.979
# Mean: -9583.920
# Max: 2032821.118
# Min: -1584905.326
# Run nr.: 7
#
#  |OOOOOOOOOO| 100.0%   realization nr. 7. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.377 minutes
# Total elapsed time: 1.122 hours
# Variance: 288123852918.141
# Mean: -10833.240
# Max: 2362212.706
# Min: -1508523.827
# Run nr.: 8
#
#  |OOOOOOOOOO| 100.0%   realization nr. 8. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.420 minutes
# Total elapsed time: 1.262 hours
# Variance: 282343421412.230
# Mean: -11488.785
# Max: 1761531.287
# Min: -1448593.893
# Run nr.: 9
#
#  |OOOOOOOOOO| 100.0%   realization nr. 9. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.438 minutes
# Total elapsed time: 1.403 hours
# Variance: 288616037781.518
# Mean: -9263.839
# Max: 2015786.219
# Min: -1835903.375
# Run nr.: 10
#
#  |OOOOOOOOOO| 100.0%   realization nr. 10. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.468 minutes
# Total elapsed time: 1.544 hours
# Variance: 289584044610.584
# Mean: -12801.598
# Max: 1834367.235
# Min: -1759308.027
# Run nr.: 11
#
#  |OOOOOOOOOO| 100.0%   realization nr. 11. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.420 minutes
# Total elapsed time: 1.684 hours
# Variance: 283166476539.555
# Mean: -9387.929
# Max: 1777225.063
# Min: -2763314.821
# Run nr.: 12
#
#  |OOOOOOOOOO| 100.0%   realization nr. 12. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.394 minutes
# Total elapsed time: 1.824 hours
# Variance: 291584174305.112
# Mean: -15448.711
# Max: 1933269.306
# Min: -2747963.902
# Run nr.: 13
#
#  |OOOOOOOOOO| 100.0%   realization nr. 13. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.488 minutes
# Total elapsed time: 1.965 hours
# Variance: 289629076255.322
# Mean: -12331.221
# Max: 1809762.690
# Min: -1585043.598
# Run nr.: 14
#
#  |OOOOOOOOOO| 100.0%   realization nr. 14. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.455 minutes
# Total elapsed time: 2.106 hours
# Variance: 286046140609.479
# Mean: -11837.267
# Max: 1847858.709
# Min: -1565243.218
# Run nr.: 15
#
#  |OOOOOOOOOO| 100.0%   realization nr. 15. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.436 minutes
# Total elapsed time: 2.247 hours
# Variance: 284565366460.588
# Mean: -9929.556
# Max: 1914709.076
# Min: -1491273.430
# Run nr.: 16
#
#  |OOOOOOOOOO| 100.0%   realization nr. 16. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.355 minutes
# Total elapsed time: 2.386 hours
# Variance: 287936957184.579
# Mean: -9696.237
# Max: 1967856.689
# Min: -1522592.040
# Run nr.: 17
#
#  |OOOOOOOOOO| 100.0%   realization nr. 17. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.446 minutes
# Total elapsed time: 2.527 hours
# Variance: 285010445758.220
# Mean: -12762.084
# Max: 1947888.811
# Min: -2085017.886
# Run nr.: 18
#
#  |OOOOOOOOOO| 100.0%   realization nr. 18. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.382 minutes
# Total elapsed time: 2.667 hours
# Variance: 282723078933.299
# Mean: -14445.186
# Max: 1933010.826
# Min: -1478153.899
# Run nr.: 19
#
#  |OOOOOOOOOO| 100.0%   realization nr. 19. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.377 minutes
# Total elapsed time: 2.806 hours
# Variance: 288700889304.148
# Mean: -9537.494
# Max: 2330528.040
# Min: -1419028.095
# Run nr.: 20
#
#  |OOOOOOOOOO| 100.0%   realization nr. 20. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.404 minutes
# Total elapsed time: 2.946 hours
# Variance: 283438121928.562
# Mean: -6378.629
# Max: 1738362.379
# Min: -1673549.305
# Run nr.: 21
#
#  |OOOOOOOOOO| 100.0%   realization nr. 21. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.360 minutes
# Total elapsed time: 3.086 hours
# Variance: 287996296293.582
# Mean: -11321.333
# Max: 2037672.540
# Min: -1349062.310
# Run nr.: 22
#
#  |OOOOOOOOOO| 100.0%   realization nr. 22. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.397 minutes
# Total elapsed time: 3.226 hours
# Variance: 291917469326.495
# Mean: -5667.920
# Max: 1840175.068
# Min: -1570031.993
# Run nr.: 23
#
#  |OOOOOOOOOO| 100.0%   realization nr. 23. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.433 minutes
# Total elapsed time: 3.366 hours
# Variance: 288519872116.380
# Mean: -15641.548
# Max: 1757208.684
# Min: -1771853.497
# Run nr.: 24
#
#  |OOOOOOOOOO| 100.0%   realization nr. 24. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.408 minutes
# Total elapsed time: 3.506 hours
# Variance: 287543113287.477
# Mean: -11594.820
# Max: 1892120.016
# Min: -1734833.405
# Run nr.: 25
#
#  |OOOOOOOOOO| 100.0%   realization nr. 25. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.378 minutes
# Total elapsed time: 3.646 hours
# Variance: 285464135449.438
# Mean: -16049.323
# Max: 1841630.167
# Min: -1587029.858
# Run nr.: 26
#
#  |OOOOOOOOOO| 100.0%   realization nr. 26. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.427 minutes
# Total elapsed time: 3.786 hours
# Variance: 286753807654.694
# Mean: -7795.715
# Max: 1937527.676
# Min: -1536434.939
# Run nr.: 27
#
#  |OOOOOOOOOO| 100.0%   realization nr. 27. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.401 minutes
# Total elapsed time: 3.926 hours
# Variance: 288669172996.837
# Mean: -5713.529
# Max: 1889252.387
# Min: -1821940.544
# Run nr.: 28
#
#  |OOOOOOOOOO| 100.0%   realization nr. 28. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.408 minutes
# Total elapsed time: 4.067 hours
# Variance: 295508305246.147
# Mean: -5468.221
# Max: 1823511.693
# Min: -2801721.705
# Run nr.: 29
#
#  |OOOOOOOOOO| 100.0%   realization nr. 29. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.427 minutes
# Total elapsed time: 4.207 hours
# Variance: 283804649646.247
# Mean: -11873.921
# Max: 1985749.613
# Min: -1450809.980
# Run nr.: 30
#
#  |OOOOOOOOOO| 100.0%   realization nr. 30. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.437 minutes
# Total elapsed time: 4.348 hours
# Variance: 290252479212.673
# Mean: -4566.911
# Max: 2009412.325
# Min: -1722464.221
# Run nr.: 31
#
#  |OOOOOOOOOO| 100.0%   realization nr. 31. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.494 minutes
# Total elapsed time: 4.489 hours
# Variance: 286601210725.407
# Mean: -10821.680
# Max: 1982155.139
# Min: -1662327.337
# Run nr.: 32
#
#  |OOOOOOOOOO| 100.0%   realization nr. 32. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.419 minutes
# Total elapsed time: 4.629 hours
# Variance: 286926523002.643
# Mean: -12312.724
# Max: 1954960.448
# Min: -1594771.020
# Run nr.: 33
#
#  |OOOOOOOOOO| 100.0%   realization nr. 33. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.369 minutes
# Total elapsed time: 4.769 hours
# Variance: 294067373633.558
# Mean: -6748.787
# Max: 1832472.517
# Min: -1522938.334
# Run nr.: 34
#  |OOOOOOOOOO| 100.0%   realization nr. 34. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.433 minutes
# Total elapsed time: 4.910 hours
# Variance: 285134116933.383
# Mean: -13776.472
# Max: 1795542.163
# Min: -1696271.224
# Run nr.: 35
#
#  |OOOOOOOOOO| 100.0%   realization nr. 35. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.221 minutes
# Total elapsed time: 5.047 hours
# Variance: 279560612705.745
# Mean: -7204.368
# Max: 1815485.343
# Min: -1331295.313
# Run nr.: 36
#
#  |OOOOOOOOOO| 100.0%   realization nr. 36. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.434 minutes
# Total elapsed time: 5.187 hours
# Variance: 290466415274.132
# Mean: -10618.168
# Max: 2054129.297
# Min: -1795492.793
# Run nr.: 37
#
#  |OOOOOOOOOO| 100.0%   realization nr. 37. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.408 minutes
# Total elapsed time: 5.327 hours
# Variance: 284484767722.015
# Mean: -7862.979
# Max: 1964887.005
# Min: -1436668.936
# Run nr.: 38
#
#  |OOOOOOOOOO| 100.0%   realization nr. 38. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.368 minutes
# Total elapsed time: 5.467 hours
# Variance: 286550153463.668
# Mean: -8835.930
# Max: 1824014.853
# Min: -1488209.030
# Run nr.: 39
#
#  |OOOOOOOOOO| 100.0%   realization nr. 39. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.480 minutes
# Total elapsed time: 5.608 hours
# Variance: 291492040834.355
# Mean: -9305.011
# Max: 2338108.699
# Min: -1663419.852
# Run nr.: 40
#
#  |OOOOOOOOOO| 100.0%   realization nr. 40. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.299 minutes
# Total elapsed time: 5.746 hours
# Variance: 288371520682.574
# Mean: -11333.064
# Max: 2012474.858
# Min: -1437418.549
# Run nr.: 41
#
#  |OOOOOOOOOO| 100.0%   realization nr. 41. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.258 minutes
# Total elapsed time: 5.884 hours
# Variance: 286023812129.266
# Mean: -12186.288
# Max: 1736639.399
# Min: -1566178.220
# Run nr.: 42
#
#  |OOOOOOOOOO| 100.0%   realization nr. 42. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.369 minutes
# Total elapsed time: 6.023 hours
# Variance: 292444080341.873
# Mean: -7254.836
# Max: 2035141.115
# Min: -1551261.226
# Run nr.: 43
#
#  |OOOOOOOOOO| 100.0%   realization nr. 43. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.373 minutes
# Total elapsed time: 6.163 hours
# Variance: 290881225791.176
# Mean: -11068.978
# Max: 2106150.188
# Min: -1639753.958
# Run nr.: 44
#
#  |OOOOOOOOOO| 100.0%   realization nr. 44. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 8.376 minutes
# Total elapsed time: 6.303 hours
# Variance: 289349375060.466
# Mean: -12987.336
# Max: 1905536.554
# Min: -1495052.803
# Run nr.: 45
#
#  |OOOOOOOOOO| 100.0%   realization nr. 45. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.350 minutes
# Total elapsed time: 6.442 hours
# Variance: 288277797043.871
# Mean: -9043.480
# Max: 1781059.334
# Min: -1414053.954
# Run nr.: 46
#
#  |OOOOOOOOOO| 100.0%   realization nr. 46. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.363 minutes
# Total elapsed time: 6.581 hours
# Variance: 288108759426.038
# Mean: -10073.610
# Max: 2012889.139
# Min: -1631473.514
# Run nr.: 47
#
#  |OOOOOOOOOO| 100.0%   realization nr. 47. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.528 minutes
# Total elapsed time: 6.723 hours
# Variance: 293219558365.896
# Mean: -14006.881
# Max: 1961242.271
# Min: -1617512.987
# Run nr.: 48
#
#  |OOOOOOOOOO| 100.0%   realization nr. 48. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.487 minutes
# Total elapsed time: 6.865 hours
# Variance: 283922350702.640
# Mean: -10296.594
# Max: 1747665.148
# Min: -1712177.899
# Run nr.: 49
#
#  |OOOOOOOOOO| 100.0%   realization nr. 49. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.420 minutes
# Total elapsed time: 7.005 hours
# Variance: 285171232368.409
# Mean: -8744.349
# Max: 1979158.883
# Min: -1631156.725
# Run nr.: 50
#
#  |OOOOOOOOOO| 100.0%   realization nr. 50. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.371 minutes
# Total elapsed time: 7.145 hours
# Variance: 292448415373.977
# Mean: -11869.236
# Max: 1896242.753
# Min: -2816188.643
# Run nr.: 51
#
#  |OOOOOOOOOO| 100.0%   realization nr. 51. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.479 minutes
# Total elapsed time: 7.286 hours
# Variance: 286311720639.370
# Mean: -7536.925
# Max: 1928914.979
# Min: -1598081.175
# Run nr.: 52
#
#  |OOOOOOOOOO| 100.0%   realization nr. 52. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.443 minutes
# Total elapsed time: 7.427 hours
# Variance: 288992703969.666
# Mean: -8589.121
# Max: 1974630.447
# Min: -1885588.685
# Run nr.: 53
#
#  |OOOOOOOOOO| 100.0%   realization nr. 53. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.384 minutes
# Total elapsed time: 7.566 hours
# Variance: 287703463234.457
# Mean: -10879.972
# Max: 1852508.284
# Min: -1604906.881
# Run nr.: 54
#
#  |OOOOOOOOOO| 100.0%   realization nr. 54. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.417 minutes
# Total elapsed time: 7.707 hours
# Variance: 288127863037.167
# Mean: -8104.051
# Max: 1919502.333
# Min: -1548075.401
# Run nr.: 55
#
#  |OOOOOOOOOO| 100.0%   realization nr. 55. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.409 minutes
# Total elapsed time: 7.847 hours
# Variance: 290057647029.064
# Mean: -12392.741
# Max: 1770827.972
# Min: -1504419.396
# Run nr.: 56
#
#  |OOOOOOOOOO| 100.0%   realization nr. 56. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.369 minutes
# Total elapsed time: 7.986 hours
# Variance: 286638814036.106
# Mean: -8222.821
# Max: 2007888.778
# Min: -1509198.128
# Run nr.: 57
#
#  |OOOOOOOOOO| 100.0%   realization nr. 57. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.421 minutes
# Total elapsed time: 8.127 hours
# Variance: 290744274915.538
# Mean: -11578.579
# Max: 2055812.523
# Min: -1537267.406
# Run nr.: 58
#
#  |OOOOOOOOOO| 100.0%   realization nr. 58. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.352 minutes
# Total elapsed time: 8.266 hours
# Variance: 294886060513.064
# Mean: -5688.812
# Max: 2005026.605
# Min: -2668909.882
# Run nr.: 59
#
#  |OOOOOOOOOO| 100.0%   realization nr. 59. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.374 minutes
# Total elapsed time: 8.405 hours
# Variance: 288014979895.260
# Mean: -7384.589
# Max: 1766348.285
# Min: -1603621.817
# Run nr.: 60
#
#  |OOOOOOOOOO| 100.0%   realization nr. 60. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.461 minutes
# Total elapsed time: 8.546 hours
# Variance: 289410355336.686
# Mean: -9507.324
# Max: 1930416.059
# Min: -1708031.083
# Run nr.: 61
#
#  |OOOOOOOOOO| 100.0%   realization nr. 61. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.380 minutes
# Total elapsed time: 8.686 hours
# Variance: 289864814359.999
# Mean: -8796.118
# Max: 1658325.317
# Min: -1701161.770
# Run nr.: 62
#
#  |OOOOOOOOOO| 100.0%   realization nr. 62. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.402 minutes
# Total elapsed time: 8.826 hours
# Variance: 291268589785.039
# Mean: -11191.768
# Max: 1775147.600
# Min: -1892605.413
# Run nr.: 63
#
#  |OOOOOOOOOO| 100.0%   realization nr. 63. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.336 minutes
# Total elapsed time: 8.965 hours
# Variance: 288103811305.274
# Mean: -6422.125
# Max: 2156080.274
# Min: -1396767.993
# Run nr.: 64
#
#  |OOOOOOOOOO| 100.0%   realization nr. 64. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.355 minutes
# Total elapsed time: 9.104 hours
# Variance: 284803055683.328
# Mean: -5452.315
# Max: 1823818.447
# Min: -1624885.439
# Run nr.: 65
#
#  |OOOOOOOOOO| 100.0%   realization nr. 65. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.436 minutes
# Total elapsed time: 9.245 hours
# Variance: 294945877513.866
# Mean: -10113.737
# Max: 1882383.426
# Min: -2867702.372
# Run nr.: 66
#
#  |OOOOOOOOOO| 100.0%   realization nr. 66. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.390 minutes
# Total elapsed time: 9.385 hours
# Variance: 293116182852.346
# Mean: -16737.201
# Max: 2093199.307
# Min: -1589414.468
# Run nr.: 67
#
#  |OOOOOOOOOO| 100.0%   realization nr. 67. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.354 minutes
# Total elapsed time: 9.524 hours
# Variance: 281759167953.218
# Mean: -10031.902
# Max: 1845375.010
# Min: -1495761.443
# Run nr.: 68
#  |OOOOOOOOOO| 100.0%   realization nr. 68. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.369 minutes
# Total elapsed time: 9.663 hours
# Variance: 288678210218.876
# Mean: -11438.478
# Max: 2122792.445
# Min: -1638135.348
# Run nr.: 69
#
#  |OOOOOOOOOO| 100.0%   realization nr. 69. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.347 minutes
# Total elapsed time: 9.803 hours
# Variance: 291126958622.054
# Mean: -6089.898
# Max: 1921179.420
# Min: -1511365.265
# Run nr.: 70
#
#  |OOOOOOOOOO| 100.0%   realization nr. 70. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.378 minutes
# Total elapsed time: 9.942 hours
# Variance: 282309715321.604
# Mean: -7190.066
# Max: 1936311.214
# Min: -1361075.424
# Run nr.: 71
#
#  |OOOOOOOOOO| 100.0%   realization nr. 71. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.402 minutes
# Total elapsed time: 10.082 hours
# Variance: 284806233309.521
# Mean: -12856.637
# Max: 1732198.810
# Min: -1531507.783
# Run nr.: 72
#
#  |OOOOOOOOOO| 100.0%   realization nr. 72. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.411 minutes
# Total elapsed time: 10.222 hours
# Variance: 292651692624.490
# Mean: -7413.390
# Max: 2000577.335
# Min: -2822879.505
# Run nr.: 73
#
#  |OOOOOOOOOO| 100.0%   realization nr. 73. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.418 minutes
# Total elapsed time: 10.363 hours
# Variance: 287233758979.575
# Mean: -13692.702
# Max: 1877873.449
# Min: -1669925.598
# Run nr.: 74
#
#  |OOOOOOOOOO| 100.0%   realization nr. 74. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.255 minutes
# Total elapsed time: 10.500 hours
# Variance: 288202684016.681
# Mean: -11842.295
# Max: 1850058.416
# Min: -1555563.520
# Run nr.: 75
#
#  |OOOOOOOOOO| 100.0%   realization nr. 75. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.299 minutes
# Total elapsed time: 10.639 hours
# Variance: 291730237965.076
# Mean: -12440.860
# Max: 1924591.629
# Min: -1507842.936
# Run nr.: 76
#
#  |OOOOOOOOOO| 100.0%   realization nr. 76. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.375 minutes
# Total elapsed time: 10.778 hours
# Variance: 286077403493.719
# Mean: -11205.401
# Max: 1948192.761
# Min: -1493115.338
# Run nr.: 77
#
#  |OOOOOOOOOO| 100.0%   realization nr. 77. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.392 minutes
# Total elapsed time: 10.918 hours
# Variance: 284237629491.145
# Mean: -7950.266
# Max: 2035312.701
# Min: -1648945.179
# Run nr.: 78
#
#  |OOOOOOOOOO| 100.0%   realization nr. 78. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.281 minutes
# Total elapsed time: 11.056 hours
# Variance: 287703476854.903
# Mean: -10390.768
# Max: 1868875.449
# Min: -1558946.954
# Run nr.: 79
#
#  |OOOOOOOOOO| 100.0%   realization nr. 79. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.455 minutes
# Total elapsed time: 11.197 hours
# Variance: 289815067132.526
# Mean: -11243.955
# Max: 1905681.382
# Min: -1594157.153
# Run nr.: 80
#
#  |OOOOOOOOOO| 100.0%   realization nr. 80. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.415 minutes
# Total elapsed time: 11.337 hours
# Variance: 291415369923.314
# Mean: -10696.779
# Max: 1836460.277
# Min: -1598536.104
# Run nr.: 81
#
#  |OOOOOOOOOO| 100.0%   realization nr. 81. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.453 minutes
# Total elapsed time: 11.478 hours
# Variance: 286183382759.105
# Mean: -12241.637
# Max: 2034318.967
# Min: -1581279.941
# Run nr.: 82
#
#  |OOOOOOOOOO| 100.0%   realization nr. 82. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.368 minutes
# Total elapsed time: 11.618 hours
# Variance: 289306802657.162
# Mean: -13607.092
# Max: 1851297.072
# Min: -1597777.561
# Run nr.: 83
#
#  |OOOOOOOOOO| 100.0%   realization nr. 83. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.383 minutes
# Total elapsed time: 11.757 hours
# Variance: 285983345779.520
# Mean: -13657.539
# Max: 2002126.577
# Min: -1610120.244
# Run nr.: 84
#
#  |OOOOOOOOOO| 100.0%   realization nr. 84. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.362 minutes
# Total elapsed time: 11.897 hours
# Variance: 291658784197.104
# Mean: -14496.095
# Max: 2094962.444
# Min: -2812154.620
# Run nr.: 85
#
#  |OOOOOOOOOO| 100.0%   realization nr. 85. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.390 minutes
# Total elapsed time: 12.037 hours
# Variance: 290438835605.354
# Mean: -10922.232
# Max: 1760188.571
# Min: -2770999.887
# Run nr.: 86
#
#  |OOOOOOOOOO| 100.0%   realization nr. 86. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.384 minutes
# Total elapsed time: 12.176 hours
# Variance: 284399137440.593
# Mean: -13051.526
# Max: 1795435.311
# Min: -1456005.821
# Run nr.: 87
#
#  |OOOOOOOOOO| 100.0%   realization nr. 87. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.396 minutes
# Total elapsed time: 12.316 hours
# Variance: 296979266865.879
# Mean: -9187.612
# Max: 1963544.259
# Min: -2111919.897
# Run nr.: 88
#
#  |OOOOOOOOOO| 100.0%   realization nr. 88. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.419 minutes
# Total elapsed time: 12.456 hours
# Variance: 286927362112.175
# Mean: -9484.524
# Max: 2065201.920
# Min: -1799050.738
# Run nr.: 89
#
#  |OOOOOOOOOO| 100.0%   realization nr. 89. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.509 minutes
# Total elapsed time: 12.598 hours
# Variance: 288011285788.490
# Mean: -13422.284
# Max: 1956476.846
# Min: -2742943.738
# Run nr.: 90
#
#  |OOOOOOOOOO| 100.0%   realization nr. 90. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.419 minutes
# Total elapsed time: 12.739 hours
# Variance: 290330191084.443
# Mean: -10433.788
# Max: 2115323.041
# Min: -1447907.748
# Run nr.: 91
#
#  |OOOOOOOOOO| 100.0%   realization nr. 91. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.439 minutes
# Total elapsed time: 12.879 hours
# Variance: 286273470505.188
# Mean: -14446.219
# Max: 2069316.159
# Min: -1709080.897
# Run nr.: 92
#
#  |OOOOOOOOOO| 100.0%   realization nr. 92. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.403 minutes
# Total elapsed time: 13.019 hours
# Variance: 289966975073.607
# Mean: -10670.304
# Max: 2016896.410
# Min: -2041049.143
# Run nr.: 93
#
#  |OOOOOOOOOO| 100.0%   realization nr. 93. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.470 minutes
# Total elapsed time: 13.160 hours
# Variance: 288550686603.113
# Mean: -10625.695
# Max: 2017513.422
# Min: -1619605.264
# Run nr.: 94
#
#  |OOOOOOOOOO| 100.0%   realization nr. 94. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.542 minutes
# Total elapsed time: 13.303 hours
# Variance: 288145703512.796
# Mean: -8761.793
# Max: 1804615.078
# Min: -1578058.469
# Run nr.: 95
#
#  |OOOOOOOOOO| 100.0%   realization nr. 95. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.375 minutes
# Total elapsed time: 13.442 hours
# Variance: 286420857244.011
# Mean: -11636.160
# Max: 1966756.575
# Min: -1494012.346
# Run nr.: 96
#
#  |OOOOOOOOOO| 100.0%   realization nr. 96. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.401 minutes
# Total elapsed time: 13.582 hours
# Variance: 287222799893.908
# Mean: -11449.228
# Max: 1917393.898
# Min: -1507776.795
# Run nr.: 97
#
#  |OOOOOOOOOO| 100.0%   realization nr. 97. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.379 minutes
# Total elapsed time: 13.722 hours
# Variance: 287776555969.869
# Mean: -7966.262
# Max: 1850634.369
# Min: -1707900.375
# Run nr.: 98
#
#  |OOOOOOOOOO| 100.0%   realization nr. 98. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.399 minutes
# Total elapsed time: 13.862 hours
# Variance: 288082969706.647
# Mean: -9167.993
# Max: 1825680.017
# Min: -2271845.148
# Run nr.: 99
#
#  |OOOOOOOOOO| 100.0%   realization nr. 99. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 8.410 minutes
# Total elapsed time: 14.002 hours
# Variance: 286209893005.687
# Mean: -9797.272
# Max: 1813367.702
# Min: -1577523.718
# Run nr.: 100
#
#
# Seqsim RMSE:	 [[2.00718435 1.99950887 2.00021094 1.99390656 2.00866008 2.00613331
#   2.00812144 2.0165408  2.00218805 1.99470555 1.99424126 2.01916465
#   1.99786839 1.99151516 1.97867867 1.98272059 1.99328404 1.99514929
#   2.00255196 2.01671341 2.01364612 1.99452257 1.97719486 2.00679187
#   2.00562669 2.00475804 2.00119055 2.00785362 2.00308876 2.00280273
#   1.9849733  1.99789589 1.982935   2.00568789 1.98275514 2.00976158
#   2.01503325 1.99995939 2.00786281 1.99475726 2.0016569  1.99394985
#   1.99232444 1.9885648  2.01482846 1.99606612 2.00616392 1.97742374
#   2.00511603 1.99774264 2.01142289 1.98713707 2.00189452 1.98556994
#   2.00446366 1.99463501 2.00856273 2.00253862 2.00728458 1.99367393
#   2.00112791 1.99552506 2.00405145 2.01317861 1.99831195 1.99180162
#   1.98637914 2.01777829 1.99051356 2.0028868  1.98878931 1.99058047
#   1.98252128 2.00694884 1.98355593 2.00131899 1.99025377 2.0288784
#   1.99214136 1.97962932 2.00572421 2.00001784 1.99276371 2.00229107
#   2.00006186 1.99896461 2.00149194 2.01095423 1.99544215 2.02676022
#   2.00035344 1.98620665 1.98829337 1.99931653 2.00265258 2.00259501
#   1.98901314 1.98264407 2.00602662 2.00224881]]
# <img src="data:image/png;base64,..." width="640">

# %%
core.realization_to_sh_coeff(core.r_cmb, set_nmax = shc_g)

# %%
core.covmod_lsq_equiv(s_sat.data, core.C_mm_all, core.G, core.r_cmb)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)
mt_util.plot_sdssim_reproduce(core, core.m_DSS_res, m_equiv_lsq = core.m_equiv_lsq, truth_obj = s_source,
                              lags_use = 1000, spec_r_at = core.r_cmb, spec_show_differences = False,
                              model_dict = {}, figsize=(9,16),
                              hist_bins = 25, res_bins = 25,
                              savefig = False, save_string = "core_sh30_newTI", save_dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
skip = 1

m_skip = core.m_DSS[:,:][0::skip]

lat_skip = core.lat[0::skip]

lon_skip = core.lon[0::skip]

# %%
N_bins = 20
m_centers = []
m_y = []

for i in np.arange(0,m_skip.shape[0]):
    y,binEdges=np.histogram(m_skip[i,:],bins=N_bins)
    bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
    
    m_centers.append(bincenters)
    m_y.append(y)
    
m_centers = np.array(m_centers)
m_y = np.array(m_y)

# %%
deg_range = 1

lat_skip_lin = np.linspace(lat_skip-deg_range,lat_skip+deg_range,N_bins)
lon_skip_lin = np.linspace(lon_skip-2*deg_range,lon_skip+2*deg_range,N_bins)

# %%
m_y_scaled = []

for i in np.arange(0,m_skip.shape[0]):
    scale = np.min(lat_skip_lin[:,i]) + (m_y[i,:]-np.min(m_y[i,:]))*(np.max(lat_skip_lin[:,i])-np.min(lat_skip_lin[:,i]))/(np.max(m_y[i,:])-np.min(m_y[i,:]))

    m_y_scaled.append(scale)
    
m_y_scaled = np.array(m_y_scaled)

# %%
local_lat = m_y_scaled.reshape(-1,)

local_lon = lon_skip_lin.T.reshape(-1,)

local_data = m_centers.reshape(-1,)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)



mt_util.plot_global(lat = local_lat, lon = local_lon, data = local_data, 
                cbar_h = 0.03, cbar_mm_factor = 2/3, unit_transform_n_to_m = True,
                cbar_text = "mT", figsize=(9,10), coast_width = 0.4,
                bottom=0.5, top=0.95, hspace=0.01, left = 0.05,
                title='Local model parameter distributions', point_size=0.1, projection_transformation = "PlateCarree",
                savefig = False, save_dpi = 100, save_string ="core_sh30_newTI_loc_mod_dist",
                use_gridlines = True, gridlines_width = 0.4, gridlines_alpha = 0.4)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
core.grid_glq(nmax = 256, r_at = core.r_cmb)
#core.grid_glq(nmax = 120, r_at = core.r_cmb)

set_nmax = shc_g

core.ensemble_B(core.g_spec, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_eqa = core.B_ensemble[:,0,:].copy()

#core.g_spec_mean = np.mean(core.g_spec,axis=1)
core.ensemble_B(core.g_spec_mean, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_mean_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
core.ensemble_B(s_sat.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
prior_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_lsq_equiv, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
#lsq_eqa = core.B_ensemble[:,0].copy()

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)
# ccrs.PlateCarree()
# ccrs.Mollweide()
# ccrs.Orthographic(central_longitude=0.0, central_latitude=0.0)

mt_util.plot_ensemble_map_tiles(core.grid_phi, 90-core.grid_theta, zs_eqa, 
                        field_compare = prior_eqa, field_lsq = None, field_mean = zs_mean_eqa,
                        tile_size_row = 3, tile_size_column = 2, 
                        figsize=(9,12), limit_for_SF = 10**6, point_size = 10, cbar_mm_factor = 2/3,
                        coast_width = 0.4, coast_color = "grey", unit_transform_n_to_m = True,
                        cbar_h = 0.1, cbar_text = "mT", cbar_text_color = "black",
                        left=0.03, bottom=0.12, right=0.97, top=0.95, wspace = 0.05, hspace=0.25, 
                        savefig = False, save_string = "core_sh30_newTI", 
                        projection = ccrs.Mollweide(), use_gridlines = True, 
                        gridlines_width = 0.4, gridlines_alpha = 0.4, save_dpi = 100)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
training_image = core.B_ensemble[:,0].copy()

mt_util.plot_global(lat = 90-core.grid_theta, lon = core.grid_phi, data=training_image, 
                cbar_h = 0.075, cbar_mm_factor = 2/3, unit_transform_n_to_m = True,
                cbar_text = "mT", figsize=(6,6), coast_width = 0.4,
                bottom=0.35, top=0.95, hspace=0.01,
                title='Training image', point_size=1,
                savefig = False, save_dpi = 100, save_string ="core_sh30_synth_TI",
                use_gridlines = True, gridlines_width = 0.4, gridlines_alpha = 0.4)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# SAVE RESULT
#print("\nSaving job")
#file_clip = open("core_{}.obj".format(nb_name), "wb")
#pickle.dump(core, file_clip, protocol=4)
#file_clip.close()

#file_clip = open("sat_{}.obj".format(nb_name), "wb")
#pickle.dump(s_sat, file_clip, protocol=4)
#file_clip.close()
#print("\nJob saved and finished")
