# %%
# %matplotlib notebook

from sdss import SDSS
import mikkel_tools.utility as mt_util
import plot as sds_plt

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Core glq

# %%
comment = "comparison of grids"

core = SDSS(comment, N_SH = 60, sim_type = "core", sat_height = 350)

core.grid_glq(nmax = 60, r_at = core.r_cmb)

grid_in = np.array([core.grid_glq_phi, 90-core.grid_glq_theta]).T
core.grid(core.r_cmb, grid_in, calc_sph_d = True)

# %%
print(core)
# Out:
# ______current attributes______
#
# a:                6371.2
# r_sat:            6721.2
# r_cmb:            3480.0
# rad:              0.017453292519943295
# mu0:              1.2566370614359173e-06
# comment:          comparison of grids
# class_abs_path:   C:\Users\Mikkel Otzen\OneDrive - Danmarks Tekniske Universitet\PhD\spherical_direct_sequential_simulation
# N_SH:             60
# sim_type:         core
# grid_glq_zero:    (61,), Max/Min: 1.00 / -1.00
# grid_glq_w:       (61,), Max/Min: 0.05 / 0.00
# grid_glq_shape:   (2,), Max/Min: 121.00 / 61.00
# grid_glq_radial:  (7381,), Max/Min: 3480.00 / 3480.00
# grid_glq_theta:   (7381,), Max/Min: 177.76 / 2.24
# grid_glq_phi:     (7381,), Max/Min: 357.02 / 0.00
# grid_glq_N:       7381
# grid_glq_nmax:    60
# r_grid:           3480.0
# grid:             (7381, 2)
# sph_d:            (7381, 7381)
# lon:              (7381,), Max/Min: 357.02 / 0.00
# lat:              (7381,), Max/Min: 87.76 / -87.76
# N_grid:           7381

# %%
core.grid_glq_zero
# Out:
# array([ 9.99235598e-01,  9.95974600e-01,  9.90116745e-01,  9.81676011e-01,
#         9.70674259e-01,  9.57140152e-01,  9.41108987e-01,  9.22622581e-01,
#         9.01729162e-01,  8.78483237e-01,  8.52945451e-01,  8.25182428e-01,
#         7.95266599e-01,  7.63276011e-01,  7.29294123e-01,  6.93409591e-01,
#         6.55716032e-01,  6.16311785e-01,  5.75299651e-01,  5.32786627e-01,
#         4.88883622e-01,  4.43705177e-01,  3.97369155e-01,  3.49996442e-01,
#         3.01710629e-01,  2.52637687e-01,  2.02905643e-01,  1.52644240e-01,
#         1.01984607e-01,  5.10589067e-02,  1.23259516e-32, -5.10589067e-02,
#        -1.01984607e-01, -1.52644240e-01, -2.02905643e-01, -2.52637687e-01,
#        -3.01710629e-01, -3.49996442e-01, -3.97369155e-01, -4.43705177e-01,
#        -4.88883622e-01, -5.32786627e-01, -5.75299651e-01, -6.16311785e-01,
#        -6.55716032e-01, -6.93409591e-01, -7.29294123e-01, -7.63276011e-01,
# ...

# %% [markdown]
# # Core glq old

# %%
comment = "comparison of grids"

core_old = SDSS(comment, N_SH = 60, sim_type = "core", sat_height = 350)

core_old.grid(core_old.r_cmb, "gauss_leg", calc_sph_d = True, N_grid = 7000)

#grid_in = np.array([core.grid_glq_phi, 90-core.grid_glq_theta]).T
#core.grid(core.r_cmb, grid_in, calc_sph_d = True)

# %%
print(core_old)
# Out:
# ______current attributes______
#
# a:                  6371.2
# r_sat:              6721.2
# r_cmb:              3480.0
# rad:                0.017453292519943295
# mu0:                1.2566370614359173e-06
# comment:            comparison of grids
# class_abs_path:     C:\Users\Mikkel Otzen\OneDrive - Danmarks Tekniske Universitet\PhD\spherical_direct_sequential_simulation
# N_SH:               60
# sim_type:           core
# r_grid:             3480.0
# grid:               gauss_leg
# sph_d:              (7200, 7200)
# N_grid:             7200
# gauss_leg_n_from_N: 60
# weights:            (7200,), Max/Min: 0.05 / 0.00
# lon:                (7200,), Max/Min: 357.00 / 0.00
# lat:                (7200,), Max/Min: 87.72 / -87.72

# %%
plt.figure()
plt.imshow(core.sph_d)
plt.colorbar()

plt.figure()
plt.imshow(core_old.sph_d)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
#  Core is ordered according to increasing longitude (from zero), whereas core_old is ordered according to descending latitude (from near 90).

# %%
core.lat[:100]
# Out:
# array([87.75959615, 87.75959615, 87.75959615, 87.75959615, 87.75959615,
#        87.75959615, 87.75959615, 87.75959615, 87.75959615, 87.75959615,
#        87.75959615, 87.75959615, 87.75959615, 87.75959615, 87.75959615,
#        87.75959615, 87.75959615, 87.75959615, 87.75959615, 87.75959615,
#        87.75959615, 87.75959615, 87.75959615, 87.75959615, 87.75959615,
#        87.75959615, 87.75959615, 87.75959615, 87.75959615, 87.75959615,
#        87.75959615, 87.75959615, 87.75959615, 87.75959615, 87.75959615,
#        87.75959615, 87.75959615, 87.75959615, 87.75959615, 87.75959615,
#        87.75959615, 87.75959615, 87.75959615, 87.75959615, 87.75959615,
#        87.75959615, 87.75959615, 87.75959615, 87.75959615, 87.75959615,
#        87.75959615, 87.75959615, 87.75959615, 87.75959615, 87.75959615,
#        87.75959615, 87.75959615, 87.75959615, 87.75959615, 87.75959615,
#        87.75959615, 87.75959615, 87.75959615, 87.75959615, 87.75959615,
# ...

# %%
core_old.lat[:100]
# Out:
# array([87.72256552, 87.72256552, 87.72256552, 87.72256552, 87.72256552,
#        87.72256552, 87.72256552, 87.72256552, 87.72256552, 87.72256552,
#        87.72256552, 87.72256552, 87.72256552, 87.72256552, 87.72256552,
#        87.72256552, 87.72256552, 87.72256552, 87.72256552, 87.72256552,
#        87.72256552, 87.72256552, 87.72256552, 87.72256552, 87.72256552,
#        87.72256552, 87.72256552, 87.72256552, 87.72256552, 87.72256552,
#        87.72256552, 87.72256552, 87.72256552, 87.72256552, 87.72256552,
#        87.72256552, 87.72256552, 87.72256552, 87.72256552, 87.72256552,
#        87.72256552, 87.72256552, 87.72256552, 87.72256552, 87.72256552,
#        87.72256552, 87.72256552, 87.72256552, 87.72256552, 87.72256552,
#        87.72256552, 87.72256552, 87.72256552, 87.72256552, 87.72256552,
#        87.72256552, 87.72256552, 87.72256552, 87.72256552, 87.72256552,
#        87.72256552, 87.72256552, 87.72256552, 87.72256552, 87.72256552,
# ...

# %%
core.lon[:100]
# Out:
# array([  0.        ,   2.97520661,   5.95041322,   8.92561983,
#         11.90082645,  14.87603306,  17.85123967,  20.82644628,
#         23.80165289,  26.7768595 ,  29.75206612,  32.72727273,
#         35.70247934,  38.67768595,  41.65289256,  44.62809917,
#         47.60330579,  50.5785124 ,  53.55371901,  56.52892562,
#         59.50413223,  62.47933884,  65.45454545,  68.42975207,
#         71.40495868,  74.38016529,  77.3553719 ,  80.33057851,
#         83.30578512,  86.28099174,  89.25619835,  92.23140496,
#         95.20661157,  98.18181818, 101.15702479, 104.1322314 ,
#        107.10743802, 110.08264463, 113.05785124, 116.03305785,
#        119.00826446, 121.98347107, 124.95867769, 127.9338843 ,
#        130.90909091, 133.88429752, 136.85950413, 139.83471074,
#        142.80991736, 145.78512397, 148.76033058, 151.73553719,
#        154.7107438 , 157.68595041, 160.66115702, 163.63636364,
#        166.61157025, 169.58677686, 172.56198347, 175.53719008,
# ...

# %%
core_old.lon[:100]
# Out:
# array([  0.,   3.,   6.,   9.,  12.,  15.,  18.,  21.,  24.,  27.,  30.,
#         33.,  36.,  39.,  42.,  45.,  48.,  51.,  54.,  57.,  60.,  63.,
#         66.,  69.,  72.,  75.,  78.,  81.,  84.,  87.,  90.,  93.,  96.,
#         99., 102., 105., 108., 111., 114., 117., 120., 123., 126., 129.,
#        132., 135., 138., 141., 144., 147., 150., 153., 156., 159., 162.,
#        165., 168., 171., 174., 177., 180., 183., 186., 189., 192., 195.,
#        198., 201., 204., 207., 210., 213., 216., 219., 222., 225., 228.,
#        231., 234., 237., 240., 243., 246., 249., 252., 255., 258., 261.,
#        264., 267., 270., 273., 276., 279., 282., 285., 288., 291., 294.,
#        297.])

# %%
core.generate_map()

# %%
mt_util.plot_cartopy_global(lat = core.lat, lon = core.lon, plot_quality = "high", 
                            data=core.data, point_size=10, shift_grid = True, 
                            transpose_grid = True, shape = (121,61), cmap = 'PuOr_r', 
                            title="Prior radial core information")
# Out:
# <img src="data:image/png;base64,..." width="999.1666666666667">

# %%
core.condtab()
core.semivar(model_lags = 'all', model = "exponential", max_dist = 4500, lag_length = 50, zero_nugget = True)
# Out:
# ____semi-variogram setup___
#
# Number of data used: 20560925
# Max data distance: 4499.680 km
# Lag length chosen: 50.0 km
# Number of lags: 89
# Number of modelling lags: all
#
# Semi-variogram model determined, starting LUT computation

# %%
plt.figure()
plt.imshow(core.sv_lut)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
#%% PLOT SEMI-VARIOGRAM
plt.figure(figsize=(10,8)) 
plt.plot(core.lags,core.pics,'o', markersize=10,color = '0.85',label='data semi-variogram')
plt.plot(core.lags_model,core.pics_model,'.',markersize=10,label='modelling data')
plt.plot(core.lags_sv_curve,core.sv_curve,color='C1',linewidth = 3,label='model')
plt.ylabel('Semi-variance $[%s^2]$' % "nT",fontsize=18,labelpad=18)
plt.xlabel('Lag [km]',fontsize=18,labelpad=18)
plt.title("Semi-variogram model of type: %s " % core.model_names[core.model],fontsize=18,y=1.02)
plt.legend(loc='best',fontsize=18)
ax = plt.gca()
ax.tick_params(axis = 'both', which = 'major', labelsize = 18)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.1666666666667">

# %%
print(core)
# Out:
# ______current attributes______
#
# a:                     6371.2
# r_sat:                 6721.2
# r_cmb:                 3480.0
# rad:                   0.017453292519943295
# mu0:                   1.2566370614359173e-06
# comment:               comparison of grids
# class_abs_path:        C:\Users\Mikkel Otzen\OneDrive - Danmarks Tekniske Universitet\PhD\spherical_direct_sequential_simulation
# N_SH:                  60
# sim_type:              core
# grid_glq_zero:         (61,), Max/Min: 1.00 / -1.00
# grid_glq_w:            (61,), Max/Min: 0.05 / 0.00
# grid_glq_shape:        (2,), Max/Min: 121.00 / 61.00
# grid_glq_radial:       (7381,), Max/Min: 3480.00 / 3480.00
# grid_glq_theta:        (7381,), Max/Min: 177.76 / 2.24
# grid_glq_phi:          (7381,), Max/Min: 357.02 / 0.00
# grid_glq_N:            7381
# grid_glq_nmax:         60
# r_grid:                3480.0
# grid:                  (7381, 2)
# sph_d:                 (7381, 7381)
# ...

# %% [markdown]
# # Synthetic sat

# %%
comment = "first try with new setup"

s_sat = SDSS(comment, N_SH = 60, sim_type = "sat", sat_height = 350)

s_sat.grid_even_spaced(grid_size=3.0, r_at = 1)

grid_in = np.array([s_sat.grid_even_phi, 90-s_sat.grid_even_theta]).T
s_sat.grid(s_sat.r_sat, grid_in, calc_sph_d = False)

#s_sat.grid(s_sat.r_sat, "equal_area", N_grid = 3010)

# %%
s_sat.generate_map(grid_type = "even")

# %%
print(s_sat)
# Out:
# ______current attributes______
#
# a:                   6371.2
# r_sat:               6721.2
# r_cmb:               3480.0
# rad:                 0.017453292519943295
# mu0:                 1.2566370614359173e-06
# comment:             first try with new setup
# class_abs_path:      C:\Users\Mikkel Otzen\OneDrive - Danmarks Tekniske Universitet\PhD\spherical_direct_sequential_simulation
# N_SH:                60
# sim_type:            sat
# grid_even_theta_len: 60
# grid_even_phi_len:   120
# grid_even_shape:     (2,), Max/Min: 120.00 / 60.00
# grid_even_theta:     (7200,), Max/Min: 178.50 / 1.50
# grid_even_phi:       (7200,), Max/Min: 358.50 / 1.50
# grid_even_radial:    (7200,), Max/Min: 1.00 / 1.00
# r_grid:              6721.2
# grid:                (7200, 2)
# sph_d:               None
# lon:                 (7200,), Max/Min: 358.50 / 1.50
# lat:                 (7200,), Max/Min: 88.50 / -88.50
# N_grid:              7200
# ...

# %%
# Reload plot module when making small changes
#import importlib
#importlib.reload(mt_util)

# %%
mt_util.plot_cartopy_global(lat = s_sat.lat, lon = s_sat.lon, plot_quality = "high", point_size=5, 
                            data=s_sat.data, shape = (s_sat.grid_even_phi_len,s_sat.grid_even_theta_len), 
                            cmap = 'PuOr_r', title="Synthetic satellite data")
# Out:
# <img src="data:image/png;base64,..." width="999.1666666666667">

# %%
print(s_sat)
# Out:
# ______current attributes______
#
# a:                   6371.2
# r_sat:               6721.2
# r_cmb:               3480.0
# rad:                 0.017453292519943295
# mu0:                 1.2566370614359173e-06
# comment:             first try with new setup
# class_abs_path:      C:\Users\Mikkel Otzen\OneDrive - Danmarks Tekniske Universitet\PhD\spherical_direct_sequential_simulation
# N_SH:                60
# sim_type:            sat
# grid_even_theta_len: 60
# grid_even_phi_len:   120
# grid_even_shape:     (2,), Max/Min: 120.00 / 60.00
# grid_even_theta:     (7200,), Max/Min: 178.50 / 1.50
# grid_even_phi:       (7200,), Max/Min: 358.50 / 1.50
# grid_even_radial:    (7200,), Max/Min: 1.00 / 1.00
# r_grid:              6721.2
# grid:                (7200, 2)
# sph_d:               None
# lon:                 (7200,), Max/Min: 358.50 / 1.50
# lat:                 (7200,), Max/Min: 88.50 / -88.50
# N_grid:              7200
# ...

# %%
#G_d = np.pi/grid["n"]*np.multiply(grid["weights"].reshape(-1,1),sds_util.Gr_vec(ds.Radius[idx_sort]*10**(-3), grid["radius"], ds.Latitude[idx_sort], grid["lat"], ds.Longitude[idx_sort], grid["lon"]))
G_d = np.pi/grid["n"]*np.multiply(grid["weights"].reshape(1,-1),sds_util.Gr_vec(grid["radius"], ds.Radius[idx_sort]*10**(-3), grid["lat"], ds.Latitude[idx_sort], grid["lon"], ds.Longitude[idx_sort]))

print(np.shape(G_d))
print(np.shape(np.ravel(B_s_r).reshape(-1,1)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-fd375dc33825> in <module>
#       1 #G_d = np.pi/grid["n"]*np.multiply(grid["weights"].reshape(-1,1),sds_util.Gr_vec(ds.Radius[idx_sort]*10**(-3), grid["radius"], ds.Latitude[idx_sort], grid["lat"], ds.Longitude[idx_sort], grid["lon"]))
# ----> 2 G_d = np.pi/grid["n"]*np.multiply(grid["weights"].reshape(1,-1),sds_util.Gr_vec(grid["radius"], ds.Radius[idx_sort]*10**(-3), grid["lat"], ds.Latitude[idx_sort], grid["lon"], ds.Longitude[idx_sort]))
#       3
#       4 print(np.shape(G_d))
#       5 print(np.shape(np.ravel(B_s_r).reshape(-1,1)))
#
# NameError: name 'grid' is not defined

# %%
gauss_leg = np.polynomial.legendre.leggauss(core.N_SH)

# %%
gauss_leg[0]
# Out:
# array([-0.99921012, -0.99584053, -0.9897879 , -0.9810672 , -0.96970179,
#        -0.95572226, -0.93916628, -0.92007848, -0.89851031, -0.87451992,
#        -0.84817198, -0.81953753, -0.78869374, -0.75572378, -0.72071651,
#        -0.68376633, -0.64497283, -0.6044406 , -0.5622789 , -0.5186014 ,
#        -0.47352584, -0.42717374, -0.37967006, -0.33114285, -0.28172294,
#        -0.23154355, -0.18073996, -0.12944914, -0.07780933, -0.02595977,
#         0.02595977,  0.07780933,  0.12944914,  0.18073996,  0.23154355,
#         0.28172294,  0.33114285,  0.37967006,  0.42717374,  0.47352584,
#         0.5186014 ,  0.5622789 ,  0.6044406 ,  0.64497283,  0.68376633,
#         0.72071651,  0.75572378,  0.78869374,  0.81953753,  0.84817198,
#         0.87451992,  0.89851031,  0.92007848,  0.93916628,  0.95572226,
#         0.96970179,  0.9810672 ,  0.9897879 ,  0.99584053,  0.99921012])

# %%
gauss_leg[1].shape
# Out:
# (60,)

# %%
weights, none = np.meshgrid(gauss_leg[1],core.lon,indexing='ij')
print(weights.shape)
# Out:
# (60, 7381)

# %%
np.unique(core.lat)
# Out:
# array([-87.75959615, -84.85733834, -81.93794118, -79.0146716 ,
#        -76.0899332 , -73.16448415, -70.23863805, -67.31254787,
#        -64.38629707, -61.45993504, -58.53349287, -55.6069911 ,
#        -52.68044387, -49.75386124, -46.82725053, -43.90061726,
#        -40.97396562, -38.04729889, -35.12061966, -32.19393003,
#        -29.26723169, -26.34052606, -23.41381432, -20.4870975 ,
#        -17.56037647, -14.63365199, -11.70692475,  -8.78019538,
#         -5.85346444,  -2.92673247,   0.        ,   2.92673247,
#          5.85346444,   8.78019538,  11.70692475,  14.63365199,
#         17.56037647,  20.4870975 ,  23.41381432,  26.34052606,
#         29.26723169,  32.19393003,  35.12061966,  38.04729889,
#         40.97396562,  43.90061726,  46.82725053,  49.75386124,
#         52.68044387,  55.6069911 ,  58.53349287,  61.45993504,
#         64.38629707,  67.31254787,  70.23863805,  73.16448415,
#         76.0899332 ,  79.0146716 ,  81.93794118,  84.85733834,
#         87.75959615])

# %%
weights, none = np.meshgrid(core.grid_glq_w,np.unique(core.lon),indexing='ij')
print(weights.shape)
# Out:
# (61, 121)

# %%
G_r = mt_util.Gr_vec(core.r_grid, s_sat.r_grid, core.lat, s_sat.lat, core.lon, s_sat.lon)
G_d = np.pi/core.N_grid * np.multiply(G_r, weights.reshape(-1,))
print(G_d.shape)
# Out:
# (7200, 7381)

# %%
plt.figure()
plt.imshow(G_r)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
plt.figure()
plt.imshow(core.sv_lut)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
errorstd = 3
errorvar = errorstd**2

def covmod_lsq_equiv(prior,obs,step,semivar,target_var,G_d,title="",errorvar = 10e2):
    a_0 = np.empty([0,])
    b_0 = obs
    d_0 = b_0

    G = G_d.copy()
    C_M = target_var - semivar
    C_D = np.zeros((len(a_0)+len(b_0),len(a_0)+len(b_0)))
    C_D[np.arange(len(a_0)+1,len(a_0)+len(b_0)),np.arange(len(a_0)+1,len(a_0)+len(b_0))] = errorvar
    S = C_D + G*C_M*G.T
    T = np.linalg.inv(S)
    m_equiv_lsq = C_M*G.T*T*d_0
    lsq_equiv_pred = G_d*m_equiv_lsq
    lsq_equiv_res = obs - lsq_equiv_pred
    return m_equiv_lsq, lsq_equiv_pred, lsq_equiv_res

m_equiv_lsq, lsq_equiv_pred, lsq_equiv_res = covmod_lsq_equiv(core,s_sat.data.reshape(-1,1),10,core.sv_lut,core.target_var,G_d,title="Gauss-Legendre equivalent LSQ solution",errorvar = errorvar)

# RMSE
rmse_leg = np.sqrt(np.mean(np.power(lsq_equiv_res,2)))
print("")
print("Gauss-Legendre RMSE:\t %0.3f" %rmse_leg)
plt.figure()
y,binEdges=np.histogram(lsq_equiv_res,bins=200)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'C0',label="Gauss-Legendre")
plt.xlabel("Radial field residuals [nT]")
plt.ylabel("Count")
plt.legend()
plt.show()

#sds_util.plot_cartopy_global_new(core.lat, core.lon, data=np.ravel(m_equiv_lsq), plot_quality = "high", cmap = 'PuOr_r', title="Gauss-Legendre equivalent LSQ solution", scale_uneven = False)
# Out:
# Gauss-Legendre RMSE:	 13.716
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
mt_util.plot_cartopy_global(lat = core.lat, lon = core.lon, plot_quality = "high", 
                            data=np.ravel(m_equiv_lsq), point_size=10,
                            shape = (121,61), cmap = 'PuOr_r', 
                            title="Prior radial core information", limits_data = core.data)
# Out:
# <img src="data:image/png;base64,..." width="999.1666666666667">

# %%
lsq_test = np.linalg.lstsq(G_d,s_sat.data, rcond=None)
data_lstsq = {"data":lsq_test[0]}

lstsq_pred = G_d*data_lstsq["data"].reshape(-1,1)
lstsq_res = s_sat.data - np.ravel(lstsq_pred)

plt.figure()
y,binEdges=np.histogram(lstsq_res,bins=200)
bincenters = 0.5*(binEdges[1:]+binEdges[:-1])
plt.plot(bincenters,y,'C1')
plt.xlabel("Radiel field residuals [nT]")
plt.ylabel("Count")
plt.show()

#sds_util.cartopy_global_plot(data_core["lat"], data_core["lon"], data=data_lstsq["data"],vmin=np.min(data_core["data"]), vmax=np.max(data_core["data"]), cmap = 'PuOr_r', title="LSQ solution", scale_uneven = False)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
rmse_leg = np.sqrt(np.mean(np.power(lstsq_res,2)))
print("")
print("Gauss-Legendre RMSE:\t %0.10f" %rmse_leg)
# Out:
# Gauss-Legendre RMSE:	 0.0000000139

# %%
mt_util.plot_cartopy_global(lat = core.lat, lon = core.lon, plot_quality = "high", 
                            data=data_lstsq["data"], point_size=10,
                            shape = (121,61), cmap = 'PuOr_r', 
                            title="Prior radial core information", limits_data = core.data)
# Out:
# <img src="data:image/png;base64,..." width="999.1666666666667">

# %%
#%% GREENS CORE
errorstd = 3
errorvar = errorstd**2
global_support = False
step_sup = 10

if grid_core["grid_type"] == "equal_area":
    dd_theta_phi_core = sds_util.greens_differentials(grid_core)
    #G_d = np.multiply(dd_theta_phi_core.T,sds_util.Gr_vec(data_core["radius"], data_sat["radius"], data_core["lat"], data_sat["lat"], data_core["lon"], data_sat["lon"]))
    G_d = 4*np.pi/(grid_core["N"]+2)*sds_util.Gr_vec(data_core["radius"], data_sat["radius"], data_core["lat"], data_sat["lat"], data_core["lon"], data_sat["lon"])
elif grid_core["grid_type"] == "leggauss":
    dd_theta_phi_core = grid_core["weights"]
    G_d = np.pi/grid_core["n"]*np.multiply(dd_theta_phi_core.T,sds_util.Gr_vec(data_core["radius"], data_sat["radius"], data_core["lat"], data_sat["lat"], data_core["lon"], data_sat["lon"]))
elif grid_core["grid_type"] == "lebedev":
    dd_theta_phi_core = grid_core["weights"]
    G_d = 4*np.pi*np.multiply(dd_theta_phi_core.T,sds_util.Gr_vec(data_core["radius"], data_sat["radius"], data_core["lat"], data_sat["lat"], data_core["lon"], data_sat["lon"]))

G_k = G_d*(condtab["target variance"]-semivar["semi-variogram LUT"])
GG_K = G_k*G_d.T  + np.diag(errorvar*np.ones(setup_sat["N"],))

sort_support = np.flipud(np.argsort(G_k,axis=0))
if global_support == True:
    N_close = np.max((1,int(DN/2)))
    #N_close = 1
    idx_close_support = sort_support[:N_close,:]
    geom_prob = np.geomspace(1,0.99,data_sat["N"]-N_close)
    geom_prob = geom_prob/np.sum(geom_prob)
    idx_far_support = np.matrix([np.random.choice(np.ravel(sort_support[N_close:,x]),size=(DN-N_close,),replace=False,p=geom_prob) for x in range(0,data_core["N"])]).T
    idx_data_support = np.vstack((idx_close_support,idx_far_support))
elif global_support == "even":
    idx_data_support = sort_support[np.arange(0,len(sort_support),step_sup),:]
    #idx_data_support = sort_support[np.random.randint(0,high=len(sort_support),size=DN),:]
    
else:
    idx_data_support = sort_support[:DN,:]
