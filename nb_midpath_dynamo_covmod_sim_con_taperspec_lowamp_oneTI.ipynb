# %%
# %matplotlib notebook

from sdss import SDSS
import mikkel_tools.utility as mt_util
import plot as sds_plt

import numpy as np
from math import inf
from scipy.optimize import curve_fit
import scipy as sp
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import time
import pyshtools
import pickle

import scipy.linalg as spl

# Function for testing positive definiteness
def is_pos_def(A):
    if np.allclose(A, A.conj().T):
        try:
            np.linalg.cholesky(A)
            return True
        except np.linalg.LinAlgError:
            return False
    else:
        return False

comment = "Fit to covariance in sim"
nb_name = "nb_midpath_dynamo_covmod_sim"

# %%
shc_g = 30
shc_grid = 30

core = SDSS(comment, N_SH = shc_g, sim_type = "core_ens", sat_height = 350)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([core.grid_phi, 90-core.grid_theta]).T
core.make_grid(core.r_cmb, grid_in, calc_sph_d = True)
core.generate_map(target_var_factor = 1)

core.condtab(normsize=10000, quantiles = 100, 
             rangn_lim = 3.5, rangn_N = 501, rangv_lim = 2.0, rangv_N = 101) #model_hist = "ensemble"

# %%
core.semivar(model_lags = 20, model = "exponential", max_dist = 20000, lag_length = 100,
             zero_nugget = True, hit_target_var = False)
# Out:
# ____semi-variogram setup___
#
# Number of data used: 3575881
# Max data distance: 10919.075 km
# Lag length chosen: 100.0 km
# Number of lags: 109
# Number of modelling lags: 20
#
# Semi-variogram model determined, starting LUT computation

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

# g ensemble and parameters
g_core_ens = np.genfromtxt("lithosphere_prior/grids/shcoeff_Dynamo/gnm_midpath.dat").T*10**9
g_core_ens = g_core_ens[:mt_util.shc_vec_len(shc_g),:]

a = core.a
c = core.r_cmb
n_max = shc_g

g_cut = g_core_ens[:n_max*(2+n_max),200:] # Truncate g
R = mt_util.lowe_shspec(n_max,c,a,g_cut)

# One spectra for comparison to SHTOOLS
g_cut_one = g_core_ens[:,core.ens_idx][:n_max*(2+n_max)]
R_one = mt_util.lowe_shspec(n_max,c,a,g_cut_one.reshape(-1,1))

# SHTOOLS
ens_cilm_compare = np.array(pyshtools.shio.SHVectorToCilm(np.hstack((np.zeros(1,), g_cut_one))))
p_spec_compare = pyshtools.gravmag.mag_spectrum(ens_cilm_compare, a, c, degrees = np.arange(1,np.shape(ens_cilm_compare)[1]))

# Spectra
plt.figure()
for i in np.arange(R.shape[1]):
    if i == 0:
        plt.semilogy(np.arange(1,n_max+1),R[:,i],color=(0.6,0.6,0.6),label="Ensemble")
    else:
        plt.semilogy(np.arange(1,n_max+1),R[:,i],color=(0.6,0.6,0.6))
plt.semilogy(np.arange(1,n_max+1),R_one,label="My Lowes")
plt.semilogy(np.arange(1,n_max+1),p_spec_compare,linestyle="dashed", label="SHTOOLS")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # New tapered cov

# %%
c_angdist = np.cos(mt_util.haversine(1, core.grid_phi.reshape(1,-1), 90-core.grid_theta.reshape(1,-1), 
                              core.grid_phi.reshape(-1,1), 90-core.grid_theta.reshape(-1,1)))

print(c_angdist[c_angdist>1])

plt.figure()
plt.imshow(c_angdist)
plt.colorbar()
plt.show()
# Out:
# []
# <img src="data:image/png;base64,..." width="640">

# %%
tap_to = 500
n_tap = n_max + tap_to

tap_cos = np.cos(np.linspace(0,np.pi,20))+1
tap_cos_norm = ((tap_cos - np.min(tap_cos))/(np.max(tap_cos)-np.min(tap_cos))).reshape(-1,1)

# Compute covariances based on eqn. 11
C_const = (np.arange(1,n_tap+1)+1)/(2*np.arange(1,n_tap+1)+1)

# Pn
Pn = []
for cmu in np.ravel(c_angdist):
    Pn.append(pyshtools.legendre.PlSchmidt(n_tap,cmu)[1:].reshape(-1,1))

Pn = np.array(Pn).reshape((c_angdist.shape[0],c_angdist.shape[1],-1))

# %% [markdown]
# # Automate pos def find

# %%
init_lin = 30
N_lin = 30

fig = plt.figure(figsize=(8,8), constrained_layout=True)
gs = fig.add_gridspec(1, 1) 
ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(tap_cos_norm,label="cos",zorder=1)
legend_list = ["cos"]
ax1.legend(legend_list)
ax1.set_xlabel('Degree')
ax1.set_ylabel('Tapering factor')
fig.canvas.draw()

try_lin = np.flip(np.round(np.linspace(2,init_lin,N_lin),decimals=2))

for i in try_lin:
    lin_tanh = np.linspace(0.5,i,tap_to)
    tap_tanh = -(np.exp(lin_tanh)-np.exp(-lin_tanh))/(np.exp(lin_tanh)+np.exp(-lin_tanh))
    tap_tanh_norm = ((tap_tanh - np.min(tap_tanh))/(np.max(tap_tanh)-np.min(tap_tanh))).reshape(-1,1)

    #R_add = 0.1*R[-1,:]*tap_tanh_norm
    R_add = np.ones((R[-1,:].shape))*tap_tanh_norm
    R_tap = np.vstack((R,R_add))

    C_Br = Pn@(C_const.reshape(-1,1)*R_tap)

    C_Br_model = C_Br[:,:,core.ens_idx]
    
    PD = is_pos_def(C_Br_model)
    
    # update plot
    ax1.plot(tap_tanh_norm, color = (i/(init_lin+1),i/(init_lin+1),i/(init_lin+1)),zorder=0)
    if PD:
        legend_list.append('i={}, PD = {}'.format(np.round(i,decimals=2),PD))
    ax1.legend(legend_list)
    
    fig.canvas.draw()
    time.sleep(0.01)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
lin_tanh = np.linspace(0.5,6,tap_to)
tap_tanh = -(np.exp(lin_tanh)-np.exp(-lin_tanh))/(np.exp(lin_tanh)+np.exp(-lin_tanh))
tap_tanh_norm = ((tap_tanh - np.min(tap_tanh))/(np.max(tap_tanh)-np.min(tap_tanh))).reshape(-1,1)

#R_add = 0.000001*R[-1,:]*tap_tanh_norm
R_add = np.ones((R[-1,:].shape))*tap_tanh_norm
R_tap = np.vstack((R,R_add))

# Spectra
plt.figure()
for i in np.arange(R_tap.shape[1]):
    if i == 0:
        plt.semilogy(np.arange(1,n_tap+1),R_tap[:,i],color=(0.6,0.6,0.6),label="Tapered ensemble")
        #plt.plot(np.arange(1,n_tap+1),R_tap[:,i],color=(0.6,0.6,0.6),label="Tapered ensemble")
    else:
        plt.semilogy(np.arange(1,n_tap+1),R_tap[:,i],color=(0.6,0.6,0.6))
        #plt.plot(np.arange(1,n_tap+1),R_tap[:,i],color=(0.6,0.6,0.6))
plt.legend()
plt.show()

C_Br = Pn@(C_const.reshape(-1,1)*R_tap)

C_Br_model = C_Br[:,:,core.ens_idx]

PD = is_pos_def(C_Br_model)
print("PD: ", PD)
# Out:
# <img src="data:image/png;base64,..." width="640">
# PD:  True

# %%
plt.figure()
plt.title("Cm tapered")
plt.imshow(C_Br_model)
plt.colorbar()
plt.show()

# Positive definite covariance?
core_eigval = spl.eigh(C_Br_model, eigvals_only=True)
N_neg_eigval = len(core_eigval[core_eigval<=0])
print("C_Br_model is pos def:", is_pos_def(C_Br_model))
print("All eigenvalues > 0:", np.all(core_eigval>=0))
print("Number of negative eigenvalues:",N_neg_eigval,"/",len(core_eigval))

plt.figure()
plt.semilogy(np.arange(0,len(core_eigval)),core_eigval,'.',label="Eigenvalues")
plt.semilogy(np.ones((100,))*N_neg_eigval,np.linspace(core_eigval[N_neg_eigval],core_eigval[-1],100),label="Transition to negative")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C_Br_model is pos def: True
# All eigenvalues > 0: True
# Number of negative eigenvalues: 0 / 1891
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Synthetic sat

# %%
C_e_const = 2.0

s_sat = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_sat.load_swarm("A")

grid_in = np.array([s_sat.grid_phi, 90-s_sat.grid_theta]).T
s_sat.make_grid(s_sat.grid_radial, grid_in, calc_sph_d = False)

s_sat.generate_map(grid_type = "swarm")

s_sat.data += np.random.normal(scale = C_e_const, size = s_sat.data.shape)

# %% [markdown]
# # Source truth

# %%
s_source = SDSS(comment, N_SH = shc_g, sim_type = "core", sat_height = 350, N_SH_secondary = None)

s_source.grid_glq(nmax = shc_grid, r_at = core.r_cmb)

grid_in = np.array([s_source.grid_phi, 90-s_source.grid_theta]).T
s_source.make_grid(s_source.r_cmb, grid_in, calc_sph_d = False)

s_source.generate_map()

# %% [markdown]
# # System equations

# %%
core.integrating_kernel(s_sat, C_e_const = C_e_const, C_mm_supply = C_Br_model)

# %% [markdown]
# # SDSSIM

# %%
N_sim = 100
core.target_var = np.max(C_Br_model)
#core.target_var = np.var(core.data)

core.run_sim(N_sim, core.grid_N, core.C_mm_all, core.C_dd, core.C_dm_all, core.G,
        s_sat.data, core.data, scale_m_i = True, unit_d = False, collect_all = True,
        sense_running_error = True, save_string = nb_name, sim_stochastic = False, solve_cho = True)
# Out:
#  |OOOOOOOOOO| 100.0%   realization nr. 0. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.465 minutes
# Total elapsed time: 16.465 minutes
# Variance: 307005442151.820
# Mean: -8418.089
# Max: 1863611.507
# Min: -1790667.635
# Run nr.: 1
#
#  |OOOOOOOOOO| 100.0%   realization nr. 1. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.659 minutes
# Total elapsed time: 33.124 minutes
# Variance: 305759062539.976
# Mean: -8980.959
# Max: 1683973.674
# Min: -1535141.190
# Run nr.: 2
#
#  |OOOOOOOOOO| 100.0%   realization nr. 2. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.535 minutes
# Total elapsed time: 49.659 minutes
# Variance: 300555196192.297
# Mean: -10529.174
# Max: 1986165.200
# Min: -1718311.427
# Run nr.: 3
#
#  |OOOOOOOOOO| 100.0%   realization nr. 3. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.148 minutes
# Total elapsed time: 1.097 hours
# Variance: 311074076734.953
# Mean: -11010.661
# Max: 1796880.577
# Min: -1680244.203
# Run nr.: 4
#
#  |OOOOOOOOOO| 100.0%   realization nr. 4. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.942 minutes
# Total elapsed time: 1.379 hours
# Variance: 295840558681.436
# Mean: -11466.854
# Max: 1805015.466
# Min: -1479244.553
# Run nr.: 5
#
#  |OOOOOOOOOO| 100.0%   realization nr. 5. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.140 minutes
# Total elapsed time: 1.648 hours
# Variance: 323651925343.681
# Mean: -9963.243
# Max: 2185096.686
# Min: -1841518.709
# Run nr.: 6
#
#  |OOOOOOOOOO| 100.0%   realization nr. 6. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.665 minutes
# Total elapsed time: 1.926 hours
# Variance: 307377288527.656
# Mean: -9414.674
# Max: 1685903.170
# Min: -1494926.368
# Run nr.: 7
#
#  |OOOOOOOOOO| 100.0%   realization nr. 7. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.514 minutes
# Total elapsed time: 2.201 hours
# Variance: 309177300354.124
# Mean: -6466.069
# Max: 1776922.887
# Min: -1855889.099
# Run nr.: 8
#
#  |OOOOOOOOOO| 100.0%   realization nr. 8. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.416 minutes
# Total elapsed time: 2.475 hours
# Variance: 309306268157.535
# Mean: -11738.599
# Max: 1846486.555
# Min: -1479122.447
# Run nr.: 9
#
#  |OOOOOOOOOO| 100.0%   realization nr. 9. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.106 minutes
# Total elapsed time: 2.743 hours
# Variance: 308430208773.772
# Mean: -7252.135
# Max: 1799189.306
# Min: -1825559.553
# Run nr.: 10
#
#  |OOOOOOOOOO| 100.0%   realization nr. 10. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.572 minutes
# Total elapsed time: 3.019 hours
# Variance: 303766292291.398
# Mean: -3388.734
# Max: 1761381.752
# Min: -1594422.870
# Run nr.: 11
#
#  |OOOOOOOOOO| 100.0%   realization nr. 11. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.528 minutes
# Total elapsed time: 3.295 hours
# Variance: 300180218696.422
# Mean: -7344.102
# Max: 1871711.833
# Min: -1612846.542
# Run nr.: 12
#
#  |OOOOOOOOOO| 100.0%   realization nr. 12. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.310 minutes
# Total elapsed time: 3.567 hours
# Variance: 321118909538.217
# Mean: -7331.275
# Max: 2114248.203
# Min: -1511237.334
# Run nr.: 13
#
#  |OOOOOOOOOO| 100.0%   realization nr. 13. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.521 minutes
# Total elapsed time: 3.842 hours
# Variance: 312681428912.547
# Mean: -11302.392
# Max: 1704739.050
# Min: -1611162.301
# Run nr.: 14
#
#  |OOOOOOOOOO| 100.0%   realization nr. 14. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.459 minutes
# Total elapsed time: 4.116 hours
# Variance: 309563127150.321
# Mean: -12370.386
# Max: 2015183.910
# Min: -1404823.011
# Run nr.: 15
#
#  |OOOOOOOOOO| 100.0%   realization nr. 15. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.025 minutes
# Total elapsed time: 4.383 hours
# Variance: 311895462127.841
# Mean: -7299.862
# Max: 1731627.334
# Min: -2239416.957
# Run nr.: 16
#
#  |OOOOOOOOOO| 100.0%   realization nr. 16. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.033 minutes
# Total elapsed time: 4.651 hours
# Variance: 303607066390.149
# Mean: -8898.076
# Max: 1977116.793
# Min: -1441701.333
# Run nr.: 17
#
#  |OOOOOOOOOO| 100.0%   realization nr. 17. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.063 minutes
# Total elapsed time: 4.918 hours
# Variance: 316262717024.645
# Mean: -11063.687
# Max: 1768165.391
# Min: -1621909.633
# Run nr.: 18
#
#  |OOOOOOOOOO| 100.0%   realization nr. 18. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.548 minutes
# Total elapsed time: 5.194 hours
# Variance: 300062553775.700
# Mean: -12697.309
# Max: 1871648.062
# Min: -1428255.166
# Run nr.: 19
#
#  |OOOOOOOOOO| 100.0%   realization nr. 19. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.073 minutes
# Total elapsed time: 5.462 hours
# Variance: 314028560258.839
# Mean: -11229.933
# Max: 1820936.053
# Min: -1593902.181
# Run nr.: 20
#
#  |OOOOOOOOOO| 100.0%   realization nr. 20. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.082 minutes
# Total elapsed time: 5.730 hours
# Variance: 305815596453.417
# Mean: -12340.688
# Max: 2215951.660
# Min: -1430817.522
# Run nr.: 21
#
#  |OOOOOOOOOO| 100.0%   realization nr. 21. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.104 minutes
# Total elapsed time: 5.998 hours
# Variance: 301932636637.353
# Mean: -10418.542
# Max: 1862274.388
# Min: -1550841.775
# Run nr.: 22
#
#  |OOOOOOOOOO| 100.0%   realization nr. 22. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.443 minutes
# Total elapsed time: 6.273 hours
# Variance: 312505596931.994
# Mean: -10338.289
# Max: 1734255.738
# Min: -1440112.502
# Run nr.: 23
#
#  |OOOOOOOOOO| 100.0%   realization nr. 23. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.554 minutes
# Total elapsed time: 6.548 hours
# Variance: 308553304177.829
# Mean: -10711.393
# Max: 1864166.648
# Min: -1535049.561
# Run nr.: 24
#
#  |OOOOOOOOOO| 100.0%   realization nr. 24. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.277 minutes
# Total elapsed time: 6.820 hours
# Variance: 303781852309.428
# Mean: -10659.165
# Max: 1778141.574
# Min: -1700488.589
# Run nr.: 25
#
#  |OOOOOOOOOO| 100.0%   realization nr. 25. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.500 minutes
# Total elapsed time: 7.095 hours
# Variance: 308154197899.817
# Mean: -5414.728
# Max: 2001854.714
# Min: -1533455.691
# Run nr.: 26
#
#  |OOOOOOOOOO| 100.0%   realization nr. 26. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.564 minutes
# Total elapsed time: 7.371 hours
# Variance: 318108015994.262
# Mean: -11437.621
# Max: 1824797.109
# Min: -1628249.317
# Run nr.: 27
#
#  |OOOOOOOOOO| 100.0%   realization nr. 27. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.605 minutes
# Total elapsed time: 7.648 hours
# Variance: 308860501079.340
# Mean: -12864.667
# Max: 1823122.728
# Min: -1849961.860
# Run nr.: 28
#
#  |OOOOOOOOOO| 100.0%   realization nr. 28. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.537 minutes
# Total elapsed time: 7.923 hours
# Variance: 312088098220.922
# Mean: -5652.451
# Max: 1864087.796
# Min: -1929193.079
# Run nr.: 29
#
#  |OOOOOOOOOO| 100.0%   realization nr. 29. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.073 minutes
# Total elapsed time: 8.191 hours
# Variance: 312090051876.563
# Mean: -5659.007
# Max: 1907473.709
# Min: -1827658.368
# Run nr.: 30
#
#  |OOOOOOOOOO| 100.0%   realization nr. 30. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.217 minutes
# Total elapsed time: 8.461 hours
# Variance: 319181768730.527
# Mean: -12876.448
# Max: 1893760.450
# Min: -1561332.058
# Run nr.: 31
#
#  |OOOOOOOOOO| 100.0%   realization nr. 31. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.144 minutes
# Total elapsed time: 8.730 hours
# Variance: 328473936372.664
# Mean: -9218.934
# Max: 2362572.069
# Min: -1751841.052
# Run nr.: 32
#
#  |OOOOOOOOOO| 100.0%   realization nr. 32. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.516 minutes
# Total elapsed time: 9.006 hours
# Variance: 313483083641.630
# Mean: -3675.906
# Max: 1730825.521
# Min: -1644292.490
# Run nr.: 33
#
#  |OOOOOOOOOO| 100.0%   realization nr. 33. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.094 minutes
# Total elapsed time: 9.274 hours
# Variance: 310725391101.894
# Mean: -6924.160
# Max: 1707000.725
# Min: -1619063.494
# Run nr.: 34
#  |OOOOOOOOOO| 100.0%   realization nr. 34. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.134 minutes
# Total elapsed time: 9.543 hours
# Variance: 314864785284.315
# Mean: -9132.452
# Max: 2011469.431
# Min: -1642089.811
# Run nr.: 35
#
#  |OOOOOOOOOO| 100.0%   realization nr. 35. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.032 minutes
# Total elapsed time: 9.810 hours
# Variance: 323924433151.731
# Mean: -13141.913
# Max: 1902376.591
# Min: -1626225.726
# Run nr.: 36
#
#  |OOOOOOOOOO| 100.0%   realization nr. 36. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.143 minutes
# Total elapsed time: 10.079 hours
# Variance: 304968700451.103
# Mean: -7938.372
# Max: 1848081.039
# Min: -1660143.903
# Run nr.: 37
#
#  |OOOOOOOOOO| 100.0%   realization nr. 37. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.600 minutes
# Total elapsed time: 10.356 hours
# Variance: 312636882439.159
# Mean: -8140.139
# Max: 1759421.445
# Min: -1725695.927
# Run nr.: 38
#
#  |OOOOOOOOOO| 100.0%   realization nr. 38. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.036 minutes
# Total elapsed time: 10.623 hours
# Variance: 319658316899.597
# Mean: -9658.807
# Max: 1902930.198
# Min: -2102644.621
# Run nr.: 39
#
#  |OOOOOOOOOO| 100.0%   realization nr. 39. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.052 minutes
# Total elapsed time: 10.890 hours
# Variance: 299626711894.680
# Mean: -11897.828
# Max: 1832226.467
# Min: -1500057.815
# Run nr.: 40
#
#  |OOOOOOOOOO| 100.0%   realization nr. 40. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.033 minutes
# Total elapsed time: 11.158 hours
# Variance: 312053299813.306
# Mean: -7194.674
# Max: 1816804.097
# Min: -1432928.742
# Run nr.: 41
#
#  |OOOOOOOOOO| 100.0%   realization nr. 41. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.023 minutes
# Total elapsed time: 11.425 hours
# Variance: 303510052759.255
# Mean: -7566.685
# Max: 1728125.490
# Min: -1711559.367
# Run nr.: 42
#
#  |OOOOOOOOOO| 100.0%   realization nr. 42. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.028 minutes
# Total elapsed time: 11.692 hours
# Variance: 314377311280.319
# Mean: -6786.553
# Max: 1991697.837
# Min: -1470847.626
# Run nr.: 43
#
#  |OOOOOOOOOO| 100.0%   realization nr. 43. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.048 minutes
# Total elapsed time: 11.959 hours
# Variance: 320454725925.436
# Mean: -13902.794
# Max: 1742304.685
# Min: -1989599.945
# Run nr.: 44
#
#  |OOOOOOOOOO| 100.0%   realization nr. 44. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.022 minutes
# Total elapsed time: 12.226 hours
# Variance: 307261082917.790
# Mean: -4915.778
# Max: 1965060.366
# Min: -1490563.561
# Run nr.: 45
#
#  |OOOOOOOOOO| 100.0%   realization nr. 45. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.028 minutes
# Total elapsed time: 12.494 hours
# Variance: 298316104263.348
# Mean: -10379.288
# Max: 2061081.388
# Min: -1469687.080
# Run nr.: 46
#
#  |OOOOOOOOOO| 100.0%   realization nr. 46. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.003 minutes
# Total elapsed time: 12.760 hours
# Variance: 308126893823.573
# Mean: -10925.369
# Max: 1824308.408
# Min: -1379343.206
# Run nr.: 47
#
#  |OOOOOOOOOO| 100.0%   realization nr. 47. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.052 minutes
# Total elapsed time: 13.028 hours
# Variance: 320518274571.947
# Mean: -14865.628
# Max: 1822860.192
# Min: -1704654.251
# Run nr.: 48
#
#  |OOOOOOOOOO| 100.0%   realization nr. 48. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.010 minutes
# Total elapsed time: 13.295 hours
# Variance: 304632755547.689
# Mean: -7335.277
# Max: 1785713.390
# Min: -1573891.465
# Run nr.: 49
#
#  |OOOOOOOOOO| 100.0%   realization nr. 49. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.059 minutes
# Total elapsed time: 13.562 hours
# Variance: 316458675486.829
# Mean: -10761.020
# Max: 2096440.623
# Min: -1645047.765
# Run nr.: 50
#
#  |OOOOOOOOOO| 100.0%   realization nr. 50. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.074 minutes
# Total elapsed time: 13.830 hours
# Variance: 309644820242.692
# Mean: -8775.692
# Max: 1993545.213
# Min: -1517464.435
# Run nr.: 51
#
#  |OOOOOOOOOO| 100.0%   realization nr. 51. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.017 minutes
# Total elapsed time: 14.097 hours
# Variance: 303460546384.479
# Mean: -7699.315
# Max: 1831106.812
# Min: -1599744.486
# Run nr.: 52
#
#  |OOOOOOOOOO| 100.0%   realization nr. 52. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.997 minutes
# Total elapsed time: 14.364 hours
# Variance: 323669837454.855
# Mean: -10040.311
# Max: 1831840.812
# Min: -2209834.157
# Run nr.: 53
#
#  |OOOOOOOOOO| 100.0%   realization nr. 53. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.070 minutes
# Total elapsed time: 14.632 hours
# Variance: 309736261066.275
# Mean: -7912.980
# Max: 1744835.784
# Min: -1751694.717
# Run nr.: 54
#
#  |OOOOOOOOOO| 100.0%   realization nr. 54. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.050 minutes
# Total elapsed time: 14.899 hours
# Variance: 295410448191.063
# Mean: -11016.870
# Max: 1712442.807
# Min: -1665913.379
# Run nr.: 55
#
#  |OOOOOOOOOO| 100.0%   realization nr. 55. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.999 minutes
# Total elapsed time: 15.166 hours
# Variance: 307849655412.816
# Mean: -8975.730
# Max: 1999604.116
# Min: -1477698.263
# Run nr.: 56
#
#  |OOOOOOOOOO| 100.0%   realization nr. 56. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.982 minutes
# Total elapsed time: 15.432 hours
# Variance: 313061660140.185
# Mean: -12186.313
# Max: 1659589.708
# Min: -1528830.953
# Run nr.: 57
#
#  |OOOOOOOOOO| 100.0%   realization nr. 57. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.047 minutes
# Total elapsed time: 15.699 hours
# Variance: 309467510677.978
# Mean: -5771.435
# Max: 1861365.693
# Min: -1482406.099
# Run nr.: 58
#
#  |OOOOOOOOOO| 100.0%   realization nr. 58. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.000 minutes
# Total elapsed time: 15.966 hours
# Variance: 331903327778.462
# Mean: -6619.325
# Max: 1941130.415
# Min: -1565106.836
# Run nr.: 59
#
#  |OOOOOOOOOO| 100.0%   realization nr. 59. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.025 minutes
# Total elapsed time: 16.233 hours
# Variance: 305884192247.278
# Mean: -12612.117
# Max: 1823498.389
# Min: -1550066.252
# Run nr.: 60
#
#  |OOOOOOOOOO| 100.0%   realization nr. 60. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.053 minutes
# Total elapsed time: 16.501 hours
# Variance: 303717180532.755
# Mean: -9085.695
# Max: 1824720.778
# Min: -1556832.835
# Run nr.: 61
#
#  |OOOOOOOOOO| 100.0%   realization nr. 61. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.070 minutes
# Total elapsed time: 16.769 hours
# Variance: 306630709298.216
# Mean: -11279.103
# Max: 1747471.285
# Min: -1464724.356
# Run nr.: 62
#
#  |OOOOOOOOOO| 100.0%   realization nr. 62. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.021 minutes
# Total elapsed time: 17.036 hours
# Variance: 297105353955.858
# Mean: -11618.951
# Max: 1815203.461
# Min: -1478242.157
# Run nr.: 63
#
#  |OOOOOOOOOO| 100.0%   realization nr. 63. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.031 minutes
# Total elapsed time: 17.303 hours
# Variance: 312882624894.359
# Mean: -6563.330
# Max: 1912154.190
# Min: -1560952.882
# Run nr.: 64
#
#  |OOOOOOOOOO| 100.0%   realization nr. 64. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.030 minutes
# Total elapsed time: 17.570 hours
# Variance: 314238972602.504
# Mean: -8374.372
# Max: 1952120.239
# Min: -1524491.272
# Run nr.: 65
#
#  |OOOOOOOOOO| 100.0%   realization nr. 65. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.045 minutes
# Total elapsed time: 17.837 hours
# Variance: 308071623241.278
# Mean: -11283.529
# Max: 1746013.091
# Min: -1607853.260
# Run nr.: 66
#
#  |OOOOOOOOOO| 100.0%   realization nr. 66. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.031 minutes
# Total elapsed time: 18.105 hours
# Variance: 299760177192.571
# Mean: -9316.857
# Max: 1819956.280
# Min: -1670422.269
# Run nr.: 67
#
#  |OOOOOOOOOO| 100.0%   realization nr. 67. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.052 minutes
# Total elapsed time: 18.372 hours
# Variance: 315162117963.571
# Mean: -11673.781
# Max: 1979236.431
# Min: -1710138.187
# Run nr.: 68
#  |OOOOOOOOOO| 100.0%   realization nr. 68. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.964 minutes
# Total elapsed time: 18.638 hours
# Variance: 310392741226.864
# Mean: -9458.908
# Max: 1980179.899
# Min: -1752827.935
# Run nr.: 69
#
#  |OOOOOOOOOO| 100.0%   realization nr. 69. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.026 minutes
# Total elapsed time: 18.905 hours
# Variance: 306611143894.490
# Mean: -12767.256
# Max: 1954291.984
# Min: -1491774.527
# Run nr.: 70
#
#  |OOOOOOOOOO| 100.0%   realization nr. 70. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.992 minutes
# Total elapsed time: 19.172 hours
# Variance: 330534998130.672
# Mean: -3493.982
# Max: 1769372.434
# Min: -2220597.944
# Run nr.: 71
#
#  |OOOOOOOOOO| 100.0%   realization nr. 71. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.977 minutes
# Total elapsed time: 19.438 hours
# Variance: 306230232666.593
# Mean: -12790.950
# Max: 1837938.998
# Min: -1860587.743
# Run nr.: 72
#
#  |OOOOOOOOOO| 100.0%   realization nr. 72. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.013 minutes
# Total elapsed time: 19.705 hours
# Variance: 312148363186.346
# Mean: -6910.635
# Max: 1818263.711
# Min: -1506201.694
# Run nr.: 73
#
#  |OOOOOOOOOO| 100.0%   realization nr. 73. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.943 minutes
# Total elapsed time: 19.971 hours
# Variance: 315275858608.086
# Mean: -5674.980
# Max: 1902946.557
# Min: -1978487.812
# Run nr.: 74
#
#  |OOOOOOOOOO| 100.0%   realization nr. 74. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.989 minutes
# Total elapsed time: 20.237 hours
# Variance: 312516431543.791
# Mean: -8000.511
# Max: 1845745.928
# Min: -1782538.542
# Run nr.: 75
#
#  |OOOOOOOOOO| 100.0%   realization nr. 75. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.007 minutes
# Total elapsed time: 20.504 hours
# Variance: 311667237523.870
# Mean: -7577.403
# Max: 1982438.345
# Min: -2176060.591
# Run nr.: 76
#
#  |OOOOOOOOOO| 100.0%   realization nr. 76. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.967 minutes
# Total elapsed time: 20.770 hours
# Variance: 316514844815.888
# Mean: -10972.791
# Max: 1682090.340
# Min: -1407348.882
# Run nr.: 77
#
#  |OOOOOOOOOO| 100.0%   realization nr. 77. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.927 minutes
# Total elapsed time: 21.036 hours
# Variance: 306590122315.492
# Mean: -7406.345
# Max: 1896869.665
# Min: -1565731.379
# Run nr.: 78
#
#  |OOOOOOOOOO| 100.0%   realization nr. 78. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.925 minutes
# Total elapsed time: 21.301 hours
# Variance: 307197680548.978
# Mean: -8481.287
# Max: 1949126.205
# Min: -1546790.923
# Run nr.: 79
#
#  |OOOOOOOOOO| 100.0%   realization nr. 79. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.013 minutes
# Total elapsed time: 21.568 hours
# Variance: 318855824266.019
# Mean: -6775.610
# Max: 1812627.870
# Min: -1599542.278
# Run nr.: 80
#
#  |OOOOOOOOOO| 100.0%   realization nr. 80. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.971 minutes
# Total elapsed time: 21.834 hours
# Variance: 315401324068.524
# Mean: -12027.406
# Max: 1953059.431
# Min: -1692678.821
# Run nr.: 81
#
#  |OOOOOOOOOO| 100.0%   realization nr. 81. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.943 minutes
# Total elapsed time: 22.100 hours
# Variance: 302521405030.525
# Mean: -8413.890
# Max: 1918146.531
# Min: -1403541.186
# Run nr.: 82
#
#  |OOOOOOOOOO| 100.0%   realization nr. 82. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.970 minutes
# Total elapsed time: 22.366 hours
# Variance: 314507984137.564
# Mean: -10069.821
# Max: 2050960.831
# Min: -1515070.034
# Run nr.: 83
#
#  |OOOOOOOOOO| 100.0%   realization nr. 83. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.940 minutes
# Total elapsed time: 22.632 hours
# Variance: 313129003895.316
# Mean: -12879.555
# Max: 1772855.776
# Min: -1543121.140
# Run nr.: 84
#
#  |OOOOOOOOOO| 100.0%   realization nr. 84. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.016 minutes
# Total elapsed time: 22.898 hours
# Variance: 314090535438.897
# Mean: -13281.656
# Max: 1778444.614
# Min: -1733159.099
# Run nr.: 85
#
#  |OOOOOOOOOO| 100.0%   realization nr. 85. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.107 minutes
# Total elapsed time: 23.167 hours
# Variance: 304811936313.192
# Mean: -10386.251
# Max: 1814216.655
# Min: -1384149.641
# Run nr.: 86
#
#  |OOOOOOOOOO| 100.0%   realization nr. 86. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.002 minutes
# Total elapsed time: 23.434 hours
# Variance: 296991846035.069
# Mean: -11053.623
# Max: 1644910.690
# Min: -1513871.224
# Run nr.: 87
#
#  |OOOOOOOOOO| 100.0%   realization nr. 87. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 15.987 minutes
# Total elapsed time: 23.700 hours
# Variance: 301214685116.441
# Mean: -10798.639
# Max: 1772408.352
# Min: -1735522.608
# Run nr.: 88
#
#  |OOOOOOOOOO| 100.0%   realization nr. 88. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.996 minutes
# Total elapsed time: 23.967 hours
# Variance: 308781374750.857
# Mean: -8734.749
# Max: 1888984.269
# Min: -1637451.822
# Run nr.: 89
#
#  |OOOOOOOOOO| 100.0%   realization nr. 89. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.994 minutes
# Total elapsed time: 24.233 hours
# Variance: 303542648663.707
# Mean: -5790.057
# Max: 1681127.527
# Min: -1539473.727
# Run nr.: 90
#
#  |OOOOOOOOOO| 100.0%   realization nr. 90. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.030 minutes
# Total elapsed time: 24.500 hours
# Variance: 318146538431.128
# Mean: -8589.348
# Max: 1746202.478
# Min: -2192771.807
# Run nr.: 91
#
#  |OOOOOOOOOO| 100.0%   realization nr. 91. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 15.990 minutes
# Total elapsed time: 24.767 hours
# Variance: 305830197670.490
# Mean: -7650.925
# Max: 1758252.769
# Min: -1851083.507
# Run nr.: 92
#
#  |OOOOOOOOOO| 100.0%   realization nr. 92. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.062 minutes
# Total elapsed time: 25.035 hours
# Variance: 313869520529.150
# Mean: -6590.843
# Max: 2353200.145
# Min: -1784479.479
# Run nr.: 93
#
#  |OOOOOOOOOO| 100.0%   realization nr. 93. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.009 minutes
# Total elapsed time: 25.301 hours
# Variance: 300256957004.225
# Mean: -8517.972
# Max: 1805411.103
# Min: -1412294.260
# Run nr.: 94
#
#  |OOOOOOOOOO| 100.0%   realization nr. 94. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.004 minutes
# Total elapsed time: 25.568 hours
# Variance: 302014715843.932
# Mean: -11495.113
# Max: 1793620.652
# Min: -1920346.091
# Run nr.: 95
#
#  |OOOOOOOOOO| 100.0%   realization nr. 95. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.029 minutes
# Total elapsed time: 25.835 hours
# Variance: 307415225953.370
# Mean: -11180.142
# Max: 1923743.340
# Min: -1364861.076
# Run nr.: 96
#
#  |OOOOOOOOOO| 100.0%   realization nr. 96. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.023 minutes
# Total elapsed time: 26.102 hours
# Variance: 307593841573.889
# Mean: -8007.119
# Max: 1679517.043
# Min: -1484903.771
# Run nr.: 97
#
#  |OOOOOOOOOO| 100.0%   realization nr. 97. Counter: 1891/1891, Running error magnitude: 5.4
# Run time: 16.057 minutes
# Total elapsed time: 26.370 hours
# Variance: 300322151888.608
# Mean: -11019.249
# Max: 1975152.296
# Min: -1813420.832
# Run nr.: 98
#
#  |OOOOOOOOOO| 100.0%   realization nr. 98. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.060 minutes
# Total elapsed time: 26.638 hours
# Variance: 318797263918.240
# Mean: -8449.253
# Max: 1970343.730
# Min: -1578109.639
# Run nr.: 99
#
#  |OOOOOOOOOO| 100.0%   realization nr. 99. Counter: 1891/1891, Running error magnitude: 5.5
# Run time: 16.016 minutes
# Total elapsed time: 26.905 hours
# Variance: 312489507831.187
# Mean: -10690.799
# Max: 1844677.768
# Min: -1708095.790
# Run nr.: 100
#
#
# Seqsim RMSE:	 [[2.00761434 1.98373555 2.00816347 1.98647406 1.99926784 1.9884523
#   1.99981664 1.98275676 1.98641909 2.00864837 1.99423572 1.98805615
#   1.99437648 1.96426819 1.97769903 1.98331788 2.00310284 1.98950922
#   1.98606305 1.99425634 1.9783828  1.98659772 1.98098893 1.98021784
#   1.99929429 1.98991507 1.97754188 1.97853137 2.00113774 1.99391333
#   1.98343234 1.98430838 1.98036976 1.99004249 1.97889333 1.95904496
#   2.00467953 2.00114307 1.99096845 1.98877387 2.01135974 1.9779182
#   1.98585806 1.96463897 1.99658169 1.98309237 2.00905304 1.99154995
#   1.99965601 1.9836126  2.01183587 1.97144787 1.9987342  2.00209312
#   2.01013438 1.98325138 1.98652518 1.98365608 1.99669775 2.00441033
#   1.97950621 1.98600929 1.98704467 1.98469308 1.9896165  1.98206156
#   1.99559733 1.99973592 1.98352257 1.97610885 2.00109767 2.00692769
#   1.97760478 2.00631698 1.9838022  1.98051102 1.98964361 1.9759078
#   2.01058623 1.97923896 1.98420143 1.98076062 1.97408013 2.00630485
#   1.99205774 1.98261633 1.996812   1.97993491 1.98221989 2.01842034
#   1.98223768 1.97975053 1.98203985 1.99100328 1.99671136 1.97841793
#   1.98942683 1.99548488 1.97390296 1.97932464]]
# <img src="data:image/png;base64,..." width="640">

# %%
core.realization_to_sh_coeff(core.r_cmb, set_nmax = shc_grid)

# %%
#core.covmod_lsq_equiv(s_sat.data, C_Br_model, core.G, core.r_cmb)

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.grid_glq(nmax = shc_grid, r_at = core.r_cmb)
mt_util.plot_sdssim_reproduce(core, core.m_DSS_res, m_equiv_lsq = None, truth_obj = s_source,
                              lags_use = 1000, spec_r_at = core.r_cmb, spec_show_differences = False,
                              model_dict = {}, figsize=(9,16), hist_ti_ens = False, hist_density = False,
                              hist_bins = 25, res_bins = 25, hist_pos_mean = False,
                              savefig = False, save_string = "core_sh30_newTI", save_dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
core.grid_glq(nmax = 256, r_at = core.r_cmb)
#core.grid_glq(nmax = 120, r_at = core.r_cmb)

set_nmax = shc_grid

core.ensemble_B(core.g_spec, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_eqa = core.B_ensemble[:,0,:].copy()

#core.g_spec_mean = np.mean(core.g_spec,axis=1)
core.ensemble_B(core.g_spec_mean, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
zs_mean_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
core.ensemble_B(s_sat.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
prior_eqa = core.B_ensemble[:,0].copy()

#core.ensemble_B(core.g_lsq_equiv, nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
#lsq_eqa = core.B_ensemble[:,0].copy()

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)
# ccrs.PlateCarree()
# ccrs.Mollweide()
# ccrs.Orthographic(central_longitude=0.0, central_latitude=0.0)

mt_util.plot_ensemble_map_tiles(core.grid_phi, 90-core.grid_theta, zs_eqa, 
                        field_compare = prior_eqa, field_lsq = None, field_mean = zs_mean_eqa,
                        tile_size_row = 3, tile_size_column = 2, 
                        figsize=(9,12), limit_for_SF = 10**6, point_size = 0.1, cbar_mm_factor = 2/3,
                        coast_width = 0.4, coast_color = "grey", unit_transform_n_to_m = True,
                        cbar_h = 0.1, cbar_text = "mT", cbar_text_color = "black",
                        left=0.03, bottom=0.12, right=0.97, top=0.95, wspace = 0.05, hspace=0.25, 
                        savefig = False, save_string = "core_sh30_newTI", 
                        projection = ccrs.Mollweide(), use_gridlines = True, 
                        gridlines_width = 0.4, gridlines_alpha = 0.4, save_dpi = 100)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
# Reload plot module when making small changes
import importlib
importlib.reload(mt_util)

core.ensemble_B(core.g_prior[:mt_util.shc_vec_len(set_nmax)], nmax = set_nmax, r_at = core.r_cmb, grid_type = "glq")
training_image = core.B_ensemble[:,0].copy()

mt_util.plot_global(lat = 90-core.grid_theta, lon = core.grid_phi, data=training_image, 
                cbar_h = 0.075, cbar_mm_factor = 2/3, unit_transform_n_to_m = True,
                cbar_text = "mT", figsize=(6,6), coast_width = 0.4,
                bottom=0.35, top=0.95, hspace=0.01,
                title='Training image', point_size=1,
                savefig = False, save_dpi = 100, save_string ="core_sh30_synth_TI",
                use_gridlines = True, gridlines_width = 0.4, gridlines_alpha = 0.4)
# Out:
# <img src="data:image/png;base64,..." width="600">
